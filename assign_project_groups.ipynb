# %%
import pandas as pd

def flatten(t):
    return [item for sublist in t for item in sublist]

# %% [markdown]
# ### Load up the students
# Go to Canvas and export the gradesheet. This gives us a list of current students. Place the file in this directory and change the read_csv() below to load up the proper file.

# %%
df = pd.read_csv('2022-04-12T2045_Grades-COGS108_SP22_A00.csv')
df
# Out:
#                      Student        ID SIS User ID  \
# 0                        NaN       NaN         NaN
# 1            Points Possible       NaN         NaN
# 2          Abdilahi, Mohamed   46899.0   A15893393
# 3    Acevedo-Federico, Oscar   24632.0   A16008996
# 4               Acord, Jared   39001.0   A14360597
# ..                       ...       ...         ...
# 433              Zhu, Joshua   40938.0   A15842955
# 434             Zhu, Langrun   49979.0   A15540540
# 435               Zhu, Zhiyi   19027.0   A15495864
# 436      Zuchlewski, Russell   65129.0   A15973752
# 437            Student, Test  156917.0         NaN
#
#                                  SIS Login ID  \
# 0                                         NaN
# 1                                         NaN
# 2                                    mabdilah
# 3                                    oacevedo
# 4                                     jmadams
# ..                                        ...
# 433                                     jqzhu
# 434                                     lazhu
# 435                                     zhzhu
# 436                                  rjzuchle
# 437  a02172d29f0250ec339ad5e9796e2ade00af520e
#
#                                                Section  D1 (477369)  \
# 0                                                  NaN          NaN
# 1                                                  NaN          2.0
# 2                               COGS 108 - A04 [72980]          NaN
# 3                               COGS 108 - A02 [72978]          NaN
# 4                               COGS 108 - A05 [72981]          NaN
# ..                                                 ...          ...
# 433                             COGS 108 - A04 [72980]          NaN
# 434                             COGS 108 - A04 [72980]          NaN
# 435                             COGS 108 - A02 [72978]          NaN
# 436                             COGS 108 - A05 [72981]          NaN
# 437  COGS 108 - A01 [72977], COGS 108 - A02 [72978]...          NaN
#
#      D2 (477370)  D3 (477371)  PracticeAssignment (477393)  A1 (477364)  ...  \
# 0            NaN          NaN                          NaN          NaN  ...
# 1            2.0          2.0                          1.0          8.0  ...
# 2            NaN          NaN                          NaN          NaN  ...
# 3            NaN          NaN                          NaN          NaN  ...
# 4            NaN          NaN                          NaN          NaN  ...
# ..           ...          ...                          ...          ...  ...
# 433          NaN          NaN                          NaN          NaN  ...
# 434          NaN          NaN                          NaN          NaN  ...
# 435          NaN          NaN                          NaN          NaN  ...
# 436          NaN          NaN                          NaN          NaN  ...
# 437          NaN          NaN                          NaN          NaN  ...
#
#      Project Final Score  Project Unposted Final Score  Current Score  \
# 0                    NaN                           NaN            NaN
# 1            (read only)                   (read only)    (read only)
# 2                   0.00                          0.00         100.00
# 3                   0.00                          0.00           0.00
# 4                   0.00                          0.00         100.00
# ..                   ...                           ...            ...
# 433                 0.00                          0.00         100.00
# 434                 0.00                          0.00         100.00
# 435                 0.00                          0.00         100.00
# 436                 0.00                          0.00         100.00
# 437                 0.00                          0.00           0.00
#
#     Unposted Current Score  Final Score  Unposted Final Score  Current Grade  \
# 0                      NaN          NaN                   NaN            NaN
# 1              (read only)  (read only)           (read only)    (read only)
# 2                   100.00         2.50                 10.50             A+
# 3                    76.19         0.00                  8.00              F
# 4                   100.00         2.50                 10.50             A+
# ..                     ...          ...                   ...            ...
# 433                 100.00         2.50                 10.50             A+
# 434                  96.19         2.50                 10.10             A+
# 435                  98.10         2.50                 10.30             A+
# 436                  98.10         2.50                 10.30             A+
# 437                   0.00         0.00                  0.00              F
#
#     Unposted Current Grade  Final Grade Unposted Final Grade
# 0                      NaN          NaN                  NaN
# 1              (read only)  (read only)          (read only)
# 2                       A+            F                    F
# 3                        C            F                    F
# 4                       A+            F                    F
# ..                     ...          ...                  ...
# 433                     A+            F                    F
# 434                      A            F                    F
# 435                     A+            F                    F
# 436                     A+            F                    F
# 437                      F            F                    F
#
# [438 rows x 45 columns]

# %%
# this is what we are going to drop
df[ df[['Student','SIS User ID','SIS Login ID']].isna().any(axis=1) ]
# Out:
#                  Student        ID SIS User ID  \
# 0                    NaN       NaN         NaN
# 1        Points Possible       NaN         NaN
# 437        Student, Test  156917.0         NaN
#
#                                  SIS Login ID  \
# 0                                         NaN
# 1                                         NaN
# 437  a02172d29f0250ec339ad5e9796e2ade00af520e
#
#                                                Section  D1 (477369)  \
# 0                                                  NaN          NaN
# 1                                                  NaN          2.0
# 437  COGS 108 - A01 [72977], COGS 108 - A02 [72978]...          NaN
#
#      D2 (477370)  D3 (477371)  PracticeAssignment (477393)  A1 (477364)  ...  \
# 0            NaN          NaN                          NaN          NaN  ...
# 1            2.0          2.0                          1.0          8.0  ...
# 437          NaN          NaN                          NaN          NaN  ...
#
#      Project Final Score  Project Unposted Final Score  Current Score  \
# 0                    NaN                           NaN            NaN
# 1            (read only)                   (read only)    (read only)
# 437                 0.00                          0.00           0.00
#
#     Unposted Current Score  Final Score  Unposted Final Score  Current Grade  \
# 0                      NaN          NaN                   NaN            NaN
# 1              (read only)  (read only)           (read only)    (read only)
# 437                   0.00         0.00                  0.00              F
#
#     Unposted Current Grade  Final Grade Unposted Final Grade
# 0                      NaN          NaN                  NaN
# 1              (read only)  (read only)          (read only)
# 437                      F            F                    F
#
# [3 rows x 45 columns]

# %%
enrolled_students = df.drop([0,1]).reset_index(drop=True)[['Student','SIS User ID','SIS Login ID']]
enrolled_students = enrolled_students.rename( {'SIS User ID':'SID', 'SIS Login ID':'email'},axis=1)
# turn last, first into first last
enrolled_students['Student'] = ( enrolled_students['Student']
                                .apply( lambda x: x.split(', ')[::-1]) # reverse order around the ,
                                .apply(lambda x: x[0]+' '+x[1]) # join with space between
                               )
enrolled_students = enrolled_students.dropna() # drop the canvas test student with NaN SID
enrolled_students = enrolled_students[ enrolled_students.Student != 'Cogs 108 Grader Account' ] # dont think this is there every quarter, this is legacy from something I did once. but it doesnt hurt to leave in
enrolled_students
# Out:
#                     Student        SID     email
# 0          Mohamed Abdilahi  A15893393  mabdilah
# 1    Oscar Acevedo-Federico  A16008996  oacevedo
# 2               Jared Acord  A14360597   jmadams
# 3           Ricardo Aguilar  A16153718  r3aguila
# 4             Mohanad Ahmed  A15920748   moahmed
# ..                      ...        ...       ...
# 430              Zach Zhong  A16506536   z1zhong
# 431              Joshua Zhu  A15842955     jqzhu
# 432             Langrun Zhu  A15540540     lazhu
# 433               Zhiyi Zhu  A15495864     zhzhu
# 434      Russell Zuchlewski  A15973752  rjzuchle
#
# [434 rows x 3 columns]

# %%
enrolled_students.Student.unique() # take a quick look to make sure nothing got screwed up
# Out:
# array(['Mohamed Abdilahi', 'Oscar Acevedo-Federico', 'Jared Acord',
#        'Ricardo Aguilar', 'Mohanad Ahmed', 'Rohil Ahuja', 'Omar Akbari',
#        'Kinan Alatasi', 'William Alden', 'Sumiah Ali', 'Sajeda Amin',
#        'Kennedy Anderson', 'Scott Andrews', 'Evelyne Avila', 'Ian Aweeka',
#        'Anthony Azucena', 'Aleene Baeza', 'Lucas Bajoua',
#        'Supratik Banerjee', 'Carol Bao', 'Jiayang Bao', 'Sunay Bargotra',
#        'Bateliel Bassa', 'Kyle Batalla', 'Connor Bates', 'Chloe Bayani',
#        'Soham Bhanvadia', 'Rachel Blumin', 'Anya Bodhisartha',
#        'Samuel Brege', 'Jonah Bryan', 'Jay Buensuceso', 'Rosey Bugayong',
#        'Tram Bui', 'Brooke Byron', 'Zhen Cai', 'Yiling Cao',
#        'Lance Casiple', 'Octavio Castro', 'Joon Cha', 'Dhruv Chaddah',
#        'Jerry Chan', 'Kelly Chang', 'Kevin Chang', 'Maxwell Chang',
#        'Yu Han Chang', 'Justin Chanthabandith', 'Andy Chen', 'Brian Chen',
#        'David Chen', 'Eric Chen', 'Guanji Chen', 'Jeremy Chen',
#        'Jianzhang Chen', 'Karina Chen', 'Keri Chen', 'Qiyu Chen',
#        'Wei Chen', 'Yiru Chen', 'Yuxuan Chen', 'Zihan Chen',
#        'Presley Cheng', 'Tiffany Cheng', 'Raghav Cherukuru',
#        'Vivian Cheung', 'Kathryn Chi-Ferson', 'Yunxiang Chi', 'Ian Chin',
#        'Taylor Chin', 'Sung Cho', 'Jaehoon Choi', 'Katherine Chou',
#        'Martha Chow', 'Asif Chowdhury', 'Brian Chu', 'Goldie Chu',
#        'Junhee Chung', 'Erik Cisneros-Arellano', 'Matthew Cohen',
#        'Albert Constantino', 'Nadia Corral', 'Weining Dai',
#        'Shaheen Daneshvar', 'Aditya Datta', 'Jaida Day', 'Jose Deleon',
#        'Christine Deng', 'Steven Deng', 'Maya Desai', 'Vedan Desai',
#        'Edgar Diaz', 'Leif Diaz', 'Tom Dinh', 'Fajar Dirham',
#        'Abigail Dominguez', 'Michael Donaldson', 'Charmie Donasco',
#        'Fangcheng Dou', 'Isaac Douglas', 'Joshua Dreben',
#        'George Dubinin', 'Doan Duong', 'Eric Duong', 'Hailey Duong',
#        'Matthew Engurasoff', 'Berkeley Erwin', 'Hunter Estrada',
#        'Gaomingyu Fan', 'Zhen Fang', 'Zhongkang Fang', 'Tyler Felipe',
#        'Mizuho Fukuda', 'Rohini Gadde', 'Nada Galal', 'Enrique Gan',
#        'Tian Gao', 'Zibin Gao', 'George Gavrilov', 'Daniel Gitelman',
#        'Antonio Gomez', 'Karen Gong', 'Qingqing Gong',
#        'Jacqueline Gonzalez', 'Leonardo Gonzalez', 'Jacob Graven',
#        'Alex Greene', 'Erick Gulyan', 'Yuxin Guo', 'Jessica Guzman',
#        'Jiahui Han', 'Zichun Hao', 'Liu He', 'Xuying He',
#        'Albert Henderson', 'Chaewon Heo', 'Ryan Heo', 'Emilio Hernandez',
#        'Lauren Himpelmann', 'Sarah Horne', 'Jocelyn Horng', 'Alvin Hsu',
#        'Hugo Huang', 'Justin Huang', 'Weijie Huang', 'Yucheng Huang',
#        'Derek Hwang', 'Muhammad Imran', 'Zm Iqbal', 'Akira Isayama',
#        'Iurii Iuzifovich', 'Moosaa Jalaldin', 'Sharoz Javaid', 'Deng Jia',
#        'Cardiff Jiang', 'Haonan Jiang', 'Man Jiang', 'Nan Jiang',
#        'Yixuan Jiao', 'Yunfei Jiao', 'Armaan Johal', 'Makenzie Johnson',
#        'Patrick Jorgensen', 'Ryan Kao', 'Rina Kaura', 'Amelia Kawasaki',
#        'Rylan Keolanui', 'Amol Khanna', 'Gyuwan Kim', 'Jisu Kim',
#        'Tommy Kim', 'Younghoon Kim', 'Brandon Koh', 'Maxim Kondrashuk',
#        'Linghang Kong', 'Christof Kopera', 'Ashley Kou', 'Robert Kovar',
#        'Daniel Kubeck', 'Abigail Kufeldt', 'Nicky La',
#        'Princess Labrador', 'Ya Qing Lai', 'Brian Lam', 'Kenneth Lam',
#        'Kevin Lam', 'Rhiannon Lang', 'Jonathan Langley', 'Edwin Lau-Mack',
#        'Carmen Le', 'Chloe Lee', 'Hyunjo Lee', 'Jason Lee', 'Nathan Lee',
#        'Matthew Leffler', 'Sha Lei', 'Bernardo Lerma', 'Derek Leung',
#        'Mingson Leung', 'Anni Li', 'Audrey Li', 'Freya Li', 'Junshu Li',
#        'Roy Li', 'Ruichen Li', 'Tianyu Li', 'Yepeng Li', 'Yifan Li',
#        'Ziqiu Li', 'Sihan Liang', 'Vicki Liang', 'Zhi Liang',
#        'Daniel Lin', 'Jacky Lin', 'Jinghao Lin', 'Ming Lin', 'Wen Lin',
#        'Jun Linwu', 'Brian Liu', 'George Liu', 'Huaning Liu',
#        'Jeffrey Liu', 'Jocelyn Liu', 'Michelle Liu', 'Samuel Liu',
#        'Silvia Liu', 'Siyuan Liu', 'Tian Liu', 'Yifan Liu', 'Yilian Liu',
#        'Ziyan Liu', 'Miguel Loera Arvizu', 'Ricardo Loeza',
#        'Nayeli Lopez-Rivera', 'Dilan Lopez', 'Ziniu Lu', 'Jonathan Lum',
#        'Kevin Luo', 'Leming Luo', 'Jingtian Ma', 'Kurtis Ma', 'Ning Ma',
#        'Po Ma', 'Sidney Ma', 'Stella Ma', 'Dan Magaril', 'Navina Mahesh',
#        'Neharika Makam', 'Naweed Malal', 'Dilara Marasli',
#        'Andrew Martinez', 'Cecilia Martinez', 'Oscar Martinez',
#        'Jessica Mata', 'Nachelle Matute', 'Samantha Mccuskey',
#        'Connor McManigal', 'Anokhi Mehta', 'Alexandra Mendivil',
#        'Akshat Mittal', 'Aditya Moghe', 'Aishani Mohapatra',
#        'Connor Moore', 'Jordan Mora', 'Pablo Moreno', 'Valli Nachiappan',
#        'Srianusha Nandula', 'Brinda Narayanan', 'Issac Navarro',
#        'Joelle Nelson', 'Samuel Ng', 'Julie Ngan', 'Andrew Ngo',
#        'David Ngo', 'Annie Nguyen', 'Dat Nguyen', 'Jenna Nguyen',
#        'Ken Nguyen', 'Kevin Nguyen', 'Monica Nguyen', 'Stephanie Nguyen',
#        'Tony Nguyen', 'Tracy Nguyen', 'Tu Anh Nguyen', 'Kelly Nham',
#        'Jiajun Ni', 'Karen Nieto', 'James Okamura', 'Angela Oku',
#        'Angel Olivas', 'John Onza', 'Ozzie Orozco', 'Riley Paik',
#        'Weihua Pan', 'Shreekar Pandey', 'Kalam Park', 'Advik Passi',
#        'Parth Patel', 'Eric Peng', 'Samantha Perez-Corona',
#        'Tin-Trung Pham', 'Melissa Phan', 'Rohith Pillai',
#        'Brenton Porter', 'Briyana Preiger', 'Josh Puray',
#        'Egor Pustovalov', 'Jingjing Qiao', 'Yang-Jie Qin', 'Amanda Quach',
#        'Maya Que', 'Emily Ramond', 'Ishika Rathi', 'Rahul Ravi',
#        'Iain Ro', 'Tristan Romanov', 'Devon Romero', 'Yijie Ruan',
#        'Benjamin Sacks', 'Aryan Safari', 'Brandon Salinas Sanchez',
#        'Travis Salud', 'Mohammad Samadi', 'Pratheek Sankeshi',
#        'Rielle Santos', 'Anmol Saxena', 'Tristan Schwichow',
#        'Stella Seki', 'Girish Senthil', 'Jasmine Shafie',
#        'Nilou Shahbandi', 'Jason Shao', 'Ayushi Sharma', 'Salwan Shathar',
#        'Yunyi She', 'Amy Shen', 'Ashley Shen', 'Divya Shetty',
#        'Kenneth Shin', 'Sandesh Shrestha', 'Cairo Simpson',
#        'Sarbjot Singh', 'Jared Singletary',
#        'Abishek Sivayogagnanamoorthy', 'Costin Smilovici', 'Ruoqing Song',
#        'Kevin Stubbings', 'Yeon Suh', 'Noelle Sumner', 'Kunyang Sun',
#        'Yinghui Sun', 'Ryan Swartz', 'Dat Ta', 'Tushita Tandon',
#        'Long Tang', 'Christian Tapia', 'Arnav Tayal', 'Luke Taylor',
#        'Michelle Tenin', 'Roger Thavixay', 'Dashiell Thumm', 'Di Tian',
#        'Runyu Tian', 'Connor Tillman', 'Charles Ting', 'Jiliana Tiu',
#        'Gideon Tong', 'Arturo Torres-Jimenez', 'Devika Torvi',
#        'Giao Tran', 'David Tu', 'Vincent Tu', 'Delvin Tuankun',
#        'Christina Tyagi', 'Jovanni Valdez', 'Borja Vega-Lojo',
#        'Amogh Vig', 'Anthony Villalba', 'Spencer Vossman', 'Brian Vu',
#        'Tina Vu', 'Alex Wang', 'Bozhi Wang', 'Cindy Wang', 'David Wang',
#        'Eric Wang', 'Gaoying Wang', 'Hanyi Wang', 'Jingxian Wang',
#        'Ryan Wang', 'Stephen Wang', 'Taorui Wang', 'Yidan Wang',
#        'Zhendong Wang', 'Ziyu Wang', 'Shihong Weng', 'Donald Wolfson',
#        'Janet Wong', 'Nicole Wong', 'Jimmy Wu', 'Peicong Wu', 'Brian Xie',
#        'Claudia Xie', 'Jingyue Xu', 'Xuwen Yan', 'Francis Yang',
#        'Hanran Yang', 'Sen Yang', 'Xiji Yang', 'Yifei Ye', 'Audrey Yeh',
#        'Hung-Tam Yie', 'Kancheng Yin', 'Jiseung Yoo', 'Steven Youssef',
#        'Jiangjun Yu', 'Kevin Yu', 'Hao Yuan', 'Yiliang Yuan',
#        'Yiwen Yuan', 'Jiaqi Zhang', 'Jiayi Zhang', 'Jun Zhang',
#        'Michael Zhang', 'Robert Zhang', 'Tianze Zhang', 'Xiaoxuan Zhang',
#        'Yujie Zhang', 'Tianlin Zhao', 'Albert Zhong', 'Zach Zhong',
#        'Joshua Zhu', 'Langrun Zhu', 'Zhiyi Zhu', 'Russell Zuchlewski'],
#       dtype=object)

# %%
# after looking through the list of names above, these are who we are going to drop
# typically this is stuff that gets bodged up by having Canvas link with Datahub or gradescope or something
# todrop = ['Jason G Fleischer','Cogs 118A Grader Account']
todrop=[]
print(enrolled_students.shape)
enrolled_students=enrolled_students.drop(
        enrolled_students.index[ enrolled_students.Student.isin(todrop) ]
                                        )
print(enrolled_students.shape)
# Out:
# (434, 3)
# (434, 3)

# %%
enrolled_students.Student.value_counts() # there might be multiple students with the same name
# Out:
# Iain Ro                   1
# Jacky Lin                 1
# Oscar Acevedo-Federico    1
# Omar Akbari               1
# Matthew Engurasoff        1
#                          ..
# Tu Anh Nguyen             1
# Amelia Kawasaki           1
# Andrew Ngo                1
# Benjamin Sacks            1
# Arturo Torres-Jimenez     1
# Name: Student, Length: 434, dtype: int64

# %%
# my total number of students this quarter
434+259
# Out:
# 693

# %% [markdown]
# ### Load up the group signup google form
# The studnets are responsible for signing themselves up for the self-formed groups via a google form currently in shared drive COGS108/Projects. Export the finished form to a Sheet and download the responses in CSV format. Place them in this directory and change the read_csv(filename) below to point at the proper file

# %% [markdown]
# #### Added support for the new dropdown google form format

# %%
import re

def get_PID(row):
    sids = ""
    for col in row[1:6]:
        sid =  re.findall('A[0-9]+', col) # List of SIDs
        if sid:  # Empty / None for groups with less than 5 people
            sids += sid[0]+", "
            
    return sids[:-2]

def get_names(row):
    names = ""
    for col in row[1:6]:
        name =  col[:-10] # non-elegant string parsing
        if name:  # Empty / None for groups with less than 5 people
            for lname, fname in [name.split(",")]:
                name = (fname.strip(' ') + ' ' + lname)
            names += name + ", "
        
        
            
    return names[:-2] # remove the extra common and space: sloppy but works

df = pd.read_csv('COGS108_ group_signup_Sp22.csv')
df['sids'] = df.apply(get_PID, axis=1)
df['names'] = df.apply(get_names, axis=1)
#df.columns.values[6] = 'gitids'

# %% [markdown]
# We get the github usernames from the students A1 assignments. From the grader account, download the file
# `~/a1_auto/a1.csv`

# %%
ghdf = pd.read_csv('a1.csv')
ghdf
# Out:
#      Unnamed: 0 firstname          lastname        pid   gh_username  pr_repo  \
# 0             0   Mohamed          Abdilahi  A15893393   mabdilahCSE     True
# 1             1     Oscar  Acevedo-Federico  A16008996     OrigamiMM     True
# 2             2     Jared             Acord  A14360597    acordjared     True
# 3             3   Ricardo           Aguilar  A16153718       Aricky3     True
# 4             4   Mohanad             Ahmed  A15920748      moahmed5     True
# ..          ...       ...               ...        ...           ...      ...
# 431         431    Joshua               Zhu  A15842955      jqzhuuuu     True
# 432         432   Langrun               Zhu  A15540540    LangrunZhu     True
# 433         433     Zhiyi               Zhu  A15495864  ZhiyiZhu0226     True
# 434         434   Russell        Zuchlewski  A15973752       SushiRZ     True
# 435         435      Test           Student        NaN           NaN    False
#
#      personal_repo
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# ..             ...
# 431           True
# 432           True
# 433           True
# 434           True
# 435          False
#
# [436 rows x 7 columns]

# %%
# kids who didn't complete the assignment properly
todrop = ghdf.isnull().any(axis=1)
ghdf[todrop]
# Out:
#      Unnamed: 0 firstname   lastname             pid gh_username  pr_repo  \
# 6             6      Omar     Akbari       A16586433         NaN    False
# 10           10    Sajeda       Amin       A16097094         NaN    False
# 47           47      Andy       Chen       A17126654         NaN    False
# 76           76    Junhee      Chung       A14503658         NaN    False
# 82           82   Shaheen  Daneshvar       A15551403         NaN    False
# 124         124  Account,      Grade  99CG108G2_SP22         NaN    False
# 162         162   Patrick  Jorgensen       A15661481         NaN    False
# 209         209     Sihan      Liang       A15905633         NaN    False
# 273         273     David        Ngo       A16113085         NaN    False
# 303         303   Brenton     Porter       A15475855         NaN    False
# 324         324    Rielle     Santos       A16079085         NaN    False
# 331         331     Jason       Shao       A16161236         NaN    False
# 348         348    Noelle     Sumner       A15527866         NaN    False
# 360         360  Dashiell      Thumm       A15561576         NaN    False
# 361         361        Di       Tian       A16578148         NaN    False
# 380         380      Tina         Vu       A15613913         NaN    False
# 428         428   Tianlin       Zhao       A16069918         NaN    False
# 435         435      Test    Student             NaN         NaN    False
#
#      personal_repo
# 6            False
# 10           False
# 47           False
# 76           False
# 82           False
# 124          False
# 162          False
# 209          False
# 273          False
# 303          False
# 324          False
# 331          False
# 348          False
# 360          False
# 361          False
# 380          False
# 428          False
# 435          False

# %%
print(ghdf.shape)
ghdf = ghdf.drop(ghdf.index[todrop])
ghdf = ghdf.set_index('pid')['gh_username']
print(ghdf.shape)
# Out:
# (436, 7)
# (418,)

# %%
ghdf
# Out:
# pid
# A15893393      mabdilahCSE
# A16008996        OrigamiMM
# A14360597       acordjared
# A16153718          Aricky3
# A15920748         moahmed5
#                  ...
# A16506536    zzyzsy0516321
# A15842955         jqzhuuuu
# A15540540       LangrunZhu
# A15495864     ZhiyiZhu0226
# A15973752          SushiRZ
# Name: gh_username, Length: 418, dtype: object

# %%
df['gitids'] = df.sids.apply( lambda x: ', '.join(
    [ ghdf[token.strip()] for token in x.split(',') if (token.strip() in ghdf.index) ]
                                                ) 
                            )

# %%
df
# Out:
#             Timestamp                Group Member #1  \
# 0   4/8/2022 22:41:25        Salud, Travis A16415902
# 1   4/6/2022 20:38:03           Hsu, Alvin A16282696
# 2   4/7/2022 15:20:34        Gadde, Rohini A15939481
# 3   4/7/2022 16:18:47     Gavrilov, George A16608338
# 4   4/8/2022 13:43:23  Zuchlewski, Russell A15973752
# ..                ...                            ...
# 84  4/4/2022 23:51:47         Koh, Brandon A15823139
# 85  4/5/2022 22:04:50           Chen, Eric A16568760
# 86  4/4/2022 19:20:09        Chi, Yunxiang A16416709
# 87  4/5/2022 17:23:16       Horng, Jocelyn A16641170
# 88  4/5/2022 17:10:02         Zhu, Langrun A15540540
#
#                 Group Member #2              Group Member #3  \
# 0         Aweeka, Ian A15543021     Nguyen, Tu Anh A15584892
# 1        Liu, Jeffrey A16365373   Gitelman, Daniel A16861627
# 2   Narayanan, Brinda A16670728  Nachiappan, Valli A16310127
# 3   Smilovici, Costin A15859391       Desai, Vedan A16687858
# 4       Nguyen, Kevin A15928638          Suh, Yeon A16684636
# ..                          ...                          ...
# 84        Chan, Jerry A15872251        Ngo, Andrew A16135396
# 85       Chang, Kevin A16645968        Tu, Vincent A15484541
# 86         Ni, Jiajun A16213006         Liu, Ziyan A16144322
# 87       Liang, Vicki A15649315        Kaura, Rina A16206086
# 88         Li, Yepeng A15390429        Cao, Yiling A16458236
#
#                 Group Member #4              Group Member #5  \
# 0   Iuzifovich, Iurii A14124875   Aguilar, Ricardo A16153718
# 1        Chen, Karina A16322803       Amin, Sajeda A16097094
# 2    Preiger, Briyana A16086824  Anderson, Kennedy A15502653
# 3         Gong, Karen A15850009      Baeza, Aleene A16152481
# 4           Kao, Ryan A17162275      Bates, Connor A15770718
# ..                          ...                          ...
# 84       Chang, Kelly A16406092       Wong, Nicole A16641543
# 85        Wong, Janet A15555141          Wu, Jimmy A16402929
# 86    Zhang, Xiaoxuan A16348660        Wu, Peicong A16614602
# 87   Matute, Nachelle A16136705         Xie, Brian A15627542
# 88         Liu, Yifan A16598590       Yang, Hanran A16537838
#
#                                                  sids  \
# 0   A16415902, A15543021, A15584892, A14124875, A1...
# 1   A16282696, A16365373, A16861627, A16322803, A1...
# 2   A15939481, A16670728, A16310127, A16086824, A1...
# 3   A16608338, A15859391, A16687858, A15850009, A1...
# 4   A15973752, A15928638, A16684636, A17162275, A1...
# ..                                                ...
# 84  A15823139, A15872251, A16135396, A16406092, A1...
# 85  A16568760, A16645968, A15484541, A15555141, A1...
# 86  A16416709, A16213006, A16144322, A16348660, A1...
# 87  A16641170, A15649315, A16206086, A16136705, A1...
# 88  A15540540, A15390429, A16458236, A16598590, A1...
#
#                                                 names  \
# 0   Travis Salud, Ian Aweeka, Tu Anh Nguyen, Iurii...
# 1   Alvin Hsu, Jeffrey Liu, Daniel Gitelman, Karin...
# 2   Rohini Gadde, Brinda Narayanan, Valli Nachiapp...
# 3   George Gavrilov, Costin Smilovici, Vedan Desai...
# 4   Russell Zuchlewski, Kevin Nguyen, Yeon Suh, Ry...
# ..                                                ...
# 84  Brandon Koh, Jerry Chan, Andrew Ngo, Kelly Cha...
# 85  Eric Chen, Kevin Chang, Vincent Tu, Janet Wong...
# 86  Yunxiang Chi, Jiajun Ni, Ziyan Liu, Xiaoxuan Z...
# 87  Jocelyn Horng, Vicki Liang, Rina Kaura, Nachel...
# 88  Langrun Zhu, Yepeng Li, Yiling Cao, Yifan Liu,...
#
#                                                gitids
# 0       TSalud15, ianA1234, tuanhn, iiuzifov, Aricky3
# 1        alvinahsu, hicytree, dgitelman1, karinaechen
# 2   rogadde, bvnarayanan, vnucsd, bpreiger, Kenned...
# 3   GeorgeGavrilov, LtAstros, Grizlucks, kwgong, A...
# 4   SushiRZ, kevinngoow1n, Sunfishhh, ryankao0415,...
# ..                                                ...
# 84       B-Koh, JerryYC, ann043, angrybeanz, nwong419
# 85  erc003, kevinchang1125, v2tu, janet-wong, Opti...
# 86  YunxiangChi, Stefan2Ni, ZiyanLouis, Andrina-ir...
# 87      joceh, viliang, rinakaura, nmatute, brian-x86
# 88  LangrunZhu, gelaneier, Cyl200215, YifanLiuDolo...
#
# [89 rows x 9 columns]

# %%
cols = df.columns.to_list()

df.columns = cols
cols[1] = 'names'
cols[2] = 'sids'
cols[3] = 'gitids'
groups = df.loc[:,['names','sids','gitids']]
gnames = []
for group_num in groups.index:
    gnames.append('Group{:03d}'.format(group_num))
groups['group_name']=gnames
groups['n_people'] = groups.names.apply( lambda x: len(x.split(',')) )
groups = groups.set_index('group_name')
groups
# Out:
#                                                         names  \
# group_name
# Group000    Travis Salud, Ian Aweeka, Tu Anh Nguyen, Iurii...
# Group001    Alvin Hsu, Jeffrey Liu, Daniel Gitelman, Karin...
# Group002    Rohini Gadde, Brinda Narayanan, Valli Nachiapp...
# Group003    George Gavrilov, Costin Smilovici, Vedan Desai...
# Group004    Russell Zuchlewski, Kevin Nguyen, Yeon Suh, Ry...
# ...                                                       ...
# Group084    Brandon Koh, Jerry Chan, Andrew Ngo, Kelly Cha...
# Group085    Eric Chen, Kevin Chang, Vincent Tu, Janet Wong...
# Group086    Yunxiang Chi, Jiajun Ni, Ziyan Liu, Xiaoxuan Z...
# Group087    Jocelyn Horng, Vicki Liang, Rina Kaura, Nachel...
# Group088    Langrun Zhu, Yepeng Li, Yiling Cao, Yifan Liu,...
#
#                                                          sids  \
# group_name
# Group000    A16415902, A15543021, A15584892, A14124875, A1...
# Group001    A16282696, A16365373, A16861627, A16322803, A1...
# Group002    A15939481, A16670728, A16310127, A16086824, A1...
# Group003    A16608338, A15859391, A16687858, A15850009, A1...
# Group004    A15973752, A15928638, A16684636, A17162275, A1...
# ...                                                       ...
# Group084    A15823139, A15872251, A16135396, A16406092, A1...
# Group085    A16568760, A16645968, A15484541, A15555141, A1...
# Group086    A16416709, A16213006, A16144322, A16348660, A1...
# Group087    A16641170, A15649315, A16206086, A16136705, A1...
# Group088    A15540540, A15390429, A16458236, A16598590, A1...
#
#                                                        gitids  n_people
# group_name
# Group000        TSalud15, ianA1234, tuanhn, iiuzifov, Aricky3         5
# Group001         alvinahsu, hicytree, dgitelman1, karinaechen         5
# Group002    rogadde, bvnarayanan, vnucsd, bpreiger, Kenned...         5
# Group003    GeorgeGavrilov, LtAstros, Grizlucks, kwgong, A...         5
# Group004    SushiRZ, kevinngoow1n, Sunfishhh, ryankao0415,...         5
# ...                                                       ...       ...
# Group084         B-Koh, JerryYC, ann043, angrybeanz, nwong419         5
# Group085    erc003, kevinchang1125, v2tu, janet-wong, Opti...         5
# Group086    YunxiangChi, Stefan2Ni, ZiyanLouis, Andrina-ir...         5
# Group087        joceh, viliang, rinakaura, nmatute, brian-x86         5
# Group088    LangrunZhu, gelaneier, Cyl200215, YifanLiuDolo...         5
#
# [89 rows x 4 columns]

# %%
groups.drop_duplicates(subset='names').shape 
# hopefully matches the number just above otherwise someone entered the same group more than once
# Out:
# (89, 4)

# %% [markdown]
# ### Figure out who still needs to be assigned to a group
#
# Method 1: do it by name
#
# Method 2: do it by SID
#
# We will figure out which one works best and correct at the end for the people caught better by the other method

# %%
grouped_students = flatten( 
    groups.names
    .apply( lambda y: [x.strip() for x in y.split(',')])
)
grouped_students
# Out:
# ['Travis Salud',
#  'Ian Aweeka',
#  'Tu Anh Nguyen',
#  'Iurii Iuzifovich',
#  'Ricardo Aguilar',
#  'Alvin Hsu',
#  'Jeffrey Liu',
#  'Daniel Gitelman',
#  'Karina Chen',
#  'Sajeda Amin',
#  'Rohini Gadde',
#  'Brinda Narayanan',
#  'Valli Nachiappan',
#  'Briyana Preiger',
#  'Kennedy Anderson',
#  'George Gavrilov',
#  'Costin Smilovici',
#  'Vedan Desai',
#  'Karen Gong',
#  'Aleene Baeza',
#  'Russell Zuchlewski',
#  'Kevin Nguyen',
#  'Yeon Suh',
#  'Ryan Kao',
#  'Connor Bates',
#  'Jaida Day',
#  'Ayushi Sharma',
#  'Ziyu Wang',
#  'Yunyi She',
#  'Joon Cha',
#  'Yiwen Yuan',
#  'Xiji Yang',
#  'Xuying He',
#  'Jiahui Han',
#  'Yu Han Chang',
#  'Nada Galal',
#  'Michelle Tenin',
#  'Junhee Chung',
#  'Dilara Marasli',
#  'Justin Chanthabandith',
#  'Bozhi Wang',
#  'Berkeley Erwin',
#  'Samuel Brege',
#  'Younghoon Kim',
#  'Andy Chen',
#  'Goldie Chu',
#  'Tram Bui',
#  'Justin Huang',
#  'Jason Lee',
#  'Tiffany Cheng',
#  'Karen Nieto',
#  'Jeremy Chen',
#  'Katherine Chou',
#  'Princess Labrador',
#  'Taylor Chin',
#  'Connor Moore',
#  'Steven Youssef',
#  'Edgar Diaz',
#  'Scott Andrews',
#  'Sung Cho',
#  'Robert Kovar',
#  'Julie Ngan',
#  'Mohamed Abdilahi',
#  'Fajar Dirham',
#  'Erik Cisneros-Arellano',
#  'Melissa Phan',
#  'Tracy Nguyen',
#  'Annie Nguyen',
#  'Tina Vu',
#  'Aditya Datta',
#  'Qiyu Chen',
#  'Tianlin Zhao',
#  'Keri Chen',
#  'Michael Zhang',
#  'Christine Deng',
#  'Jared Acord',
#  'Wei Chen',
#  'Mingson Leung',
#  'Mohanad Ahmed',
#  'Hunter Estrada',
#  'Jun Zhang',
#  'Robert Zhang',
#  'Di Tian',
#  'Sihan Liang',
#  'Zhen Fang',
#  'Tin-Trung Pham',
#  'Brian Chen',
#  'Zhongkang Fang',
#  'Nilou Shahbandi',
#  'Leonardo Gonzalez',
#  'Long Tang',
#  'Hugo Huang',
#  'Daniel Kubeck',
#  'Lucas Bajoua',
#  'Alex Greene',
#  'Leif Diaz',
#  'Taorui Wang',
#  'Brandon Salinas Sanchez',
#  'Sandesh Shrestha',
#  'Sarah Horne',
#  'Sen Yang',
#  'Jinghao Lin',
#  'Zibin Gao',
#  'Gaomingyu Fan',
#  'Yucheng Huang',
#  'Rahul Ravi',
#  'Emilio Hernandez',
#  'Jared Singletary',
#  'Cecilia Martinez',
#  'Zm Iqbal',
#  'Anya Bodhisartha',
#  'Jingyue Xu',
#  'Divya Shetty',
#  'Jiliana Tiu',
#  'Man Jiang',
#  'Roger Thavixay',
#  'Sidney Ma',
#  'Akira Isayama',
#  'David Wang',
#  'Yunfei Jiao',
#  'Giao Tran',
#  'Moosaa Jalaldin',
#  'Sharoz Javaid',
#  'Ming Lin',
#  'Tommy Kim',
#  'Ryan Wang',
#  'Eric Wang',
#  'Rosey Bugayong',
#  'Hanyi Wang',
#  'Christof Kopera',
#  'Zichun Hao',
#  'Cardiff Jiang',
#  'Siyuan Liu',
#  'Oscar Martinez',
#  'Ya Qing Lai',
#  'Advik Passi',
#  'Dat Nguyen',
#  'Donald Wolfson',
#  'Lance Casiple',
#  'Kevin Lam',
#  'Mizuho Fukuda',
#  'Roy Li',
#  'Andrew Martinez',
#  'Hung-Tam Yie',
#  'Bernardo Lerma',
#  'Tian Gao',
#  'Yifei Ye',
#  'Freya Li',
#  'Weining Dai',
#  'Anni Li',
#  'Yujie Zhang',
#  'Zhendong Wang',
#  'David Chen',
#  'Jocelyn Liu',
#  'Ziqiu Li',
#  'Stephanie Nguyen',
#  'Tony Nguyen',
#  'Doan Duong',
#  'Francis Yang',
#  'Daniel Lin',
#  'Kathryn Chi-Ferson',
#  'Albert Constantino',
#  'Joshua Dreben',
#  'Enrique Gan',
#  'Jacky Lin',
#  'Zach Zhong',
#  'Gaoying Wang',
#  'Yifan Li',
#  'Yilian Liu',
#  'Jun Linwu',
#  'Matthew Leffler',
#  'Charmie Donasco',
#  'Michael Donaldson',
#  'Cairo Simpson',
#  'Michelle Liu',
#  'Yijie Ruan',
#  'Ruichen Li',
#  'Ashley Kou',
#  'Carol Bao',
#  'Silvia Liu',
#  'Monica Nguyen',
#  'Alex Wang',
#  'Ziniu Lu',
#  'Nicky La',
#  'Miguel Loera Arvizu',
#  'Evelyne Avila',
#  'Shihong Weng',
#  'Samantha Perez-Corona',
#  'Matthew Engurasoff',
#  'Ricardo Loeza',
#  'Stella Seki',
#  'James Okamura',
#  'Derek Leung',
#  'Tristan Schwichow',
#  'Dilan Lopez',
#  'Claudia Xie',
#  'Dashiell Thumm',
#  'Jovanni Valdez',
#  'Abigail Dominguez',
#  'Kevin Luo',
#  'Rohil Ahuja',
#  'Devika Torvi',
#  'Tom Dinh',
#  'Brian Vu',
#  'Po Ma',
#  'Shreekar Pandey',
#  'Rachel Blumin',
#  'Maya Desai',
#  'Parth Patel',
#  'Dan Magaril',
#  'Samuel Ng',
#  'Jessica Guzman',
#  'Edwin Lau-Mack',
#  'Tristan Romanov',
#  'Naweed Malal',
#  'Jessica Mata',
#  'Brian Liu',
#  'Audrey Li',
#  'John Onza',
#  'David Ngo',
#  'Isaac Douglas',
#  'Emily Ramond',
#  'Shaheen Daneshvar',
#  'Jonah Bryan',
#  'Kunyang Sun',
#  'Stella Ma',
#  'Jingjing Qiao',
#  'Yiru Chen',
#  'Nayeli Lopez-Rivera',
#  'Makenzie Johnson',
#  'Nathan Lee',
#  'Steven Deng',
#  'Joshua Zhu',
#  'Soham Bhanvadia',
#  'Amogh Vig',
#  'Eric Duong',
#  'Connor Tillman',
#  'Abigail Kufeldt',
#  'Joelle Nelson',
#  'Jacob Graven',
#  'Kenneth Shin',
#  'Kenneth Lam',
#  'Bateliel Bassa',
#  'Zhi Liang',
#  'Derek Hwang',
#  'Riley Paik',
#  'Amanda Quach',
#  'Samuel Liu',
#  'George Liu',
#  'Yang-Jie Qin',
#  'Maxwell Chang',
#  'Tian Liu',
#  'Navina Mahesh',
#  'Amol Khanna',
#  'Devon Romero',
#  'Anokhi Mehta',
#  'Vivian Cheung',
#  'Jonathan Lum',
#  'Chloe Lee',
#  'Jenna Nguyen',
#  'Yixuan Jiao',
#  'Dat Ta',
#  'Albert Henderson',
#  'Supratik Banerjee',
#  'Kalam Park',
#  'Gyuwan Kim',
#  'David Tu',
#  'Carmen Le',
#  'Anthony Villalba',
#  'Angela Oku',
#  'Brian Chu',
#  'Kyle Batalla',
#  'Ken Nguyen',
#  'Ishika Rathi',
#  'Albert Zhong',
#  'Issac Navarro',
#  'Kelly Nham',
#  'Aryan Safari',
#  'Armaan Johal',
#  'Sarbjot Singh',
#  'Ryan Heo',
#  'Jason Shao',
#  'Haonan Jiang',
#  'Junshu Li',
#  'Leming Luo',
#  'Ruoqing Song',
#  'Martha Chow',
#  'Chaewon Heo',
#  'Zhiyi Zhu',
#  'Arnav Tayal',
#  'Jose Deleon',
#  'Brandon Kao',
#  'Nadia Corral',
#  'Christina Tyagi',
#  'Gideon Tong',
#  'Iain Ro',
#  'Patrick Jorgensen',
#  'Stephen Wang',
#  'Jianzhang Chen',
#  'Weijie Huang',
#  'Liu He',
#  'Audrey Yeh',
#  'Zihan Chen',
#  'Nan Jiang',
#  'Ning Ma',
#  'Kancheng Yin',
#  'Hao Yuan',
#  'Tianyu Li',
#  'Runyu Tian',
#  'Jiaqi Zhang',
#  'Yuxin Guo',
#  'Sha Lei',
#  'Jingxian Wang',
#  'Jiayi Zhang',
#  'Amogh Vig',
#  'Soham Bhanvadia',
#  'Eric Duong',
#  'Joshua Zhu',
#  'Rylan Keolanui',
#  'Lauren Himpelmann',
#  'Maxim Kondrashuk',
#  'Jasmine Shafie',
#  'Ozzie Orozco',
#  'Aditya Moghe',
#  'Salwan Shathar',
#  'Raghav Cherukuru',
#  'Presley Cheng',
#  'Eric Peng',
#  'Rohith Pillai',
#  'Pratheek Sankeshi',
#  'Christian Tapia',
#  'Luke Taylor',
#  'Josh Puray',
#  'Hyunjo Lee',
#  'Jaehoon Choi',
#  'Muhammad Imran',
#  'Yiliang Yuan',
#  'Maya Que',
#  'Akshat Mittal',
#  'Aishani Mohapatra',
#  'Abishek Sivayogagnanamoorthy',
#  'Srianusha Nandula',
#  'Mohammad Samadi',
#  'Jay Buensuceso',
#  'George Dubinin',
#  'William Alden',
#  'Brian Lam',
#  'Kevin Stubbings',
#  'Jonathan Langley',
#  'Dhruv Chaddah',
#  'Kevin An',
#  'Spencer Vossman',
#  'Noelle Sumner',
#  'Fangcheng Dou',
#  'Weihua Pan',
#  'Kevin Yu',
#  'Wen Lin',
#  'Yinghui Sun',
#  'Connor McManigal',
#  'Xuwen Yan',
#  'Matthew Cohen',
#  'Egor Pustovalov',
#  'Ryan Swartz',
#  'Chloe Bayani',
#  'Brenton Porter',
#  'Alexandra Mendivil',
#  'Rhiannon Lang',
#  'Tushita Tandon',
#  'Benjamin Sacks',
#  'Samantha Mccuskey',
#  'Neharika Makam',
#  'Amelia Kawasaki',
#  'Charles Ting',
#  'Asif Chowdhury',
#  'Rielle Santos',
#  'Erick Gulyan',
#  'Kinan Alatasi',
#  'Arturo Torres-Jimenez',
#  'Anmol Saxena',
#  'Pablo Moreno',
#  'Jiseung Yoo',
#  'Hailey Duong',
#  'Borja Vega-Lojo',
#  'Jiayang Bao',
#  'Yuxuan Chen',
#  'Jingtian Ma',
#  'Tianze Zhang',
#  'Cindy Wang',
#  'Huaning Liu',
#  'Linghang Kong',
#  'Qingqing Gong',
#  'Jiangjun Yu',
#  'Yidan Wang',
#  'Brandon Koh',
#  'Jerry Chan',
#  'Andrew Ngo',
#  'Kelly Chang',
#  'Nicole Wong',
#  'Eric Chen',
#  'Kevin Chang',
#  'Vincent Tu',
#  'Janet Wong',
#  'Jimmy Wu',
#  'Yunxiang Chi',
#  'Jiajun Ni',
#  'Ziyan Liu',
#  'Xiaoxuan Zhang',
#  'Peicong Wu',
#  'Jocelyn Horng',
#  'Vicki Liang',
#  'Rina Kaura',
#  'Nachelle Matute',
#  'Brian Xie',
#  'Langrun Zhu',
#  'Yepeng Li',
#  'Yiling Cao',
#  'Yifan Liu',
#  'Hanran Yang']

# %%
unassigned_1 = set(enrolled_students.Student) - set(grouped_students)
unassigned_1
# Out:
# {'Amy Shen',
#  'Angel Olivas',
#  'Anthony Azucena',
#  'Antonio Gomez',
#  'Ashley Shen',
#  'Brooke Byron',
#  'Delvin Tuankun',
#  'Deng Jia',
#  'Girish Senthil',
#  'Guanji Chen',
#  'Ian Chin',
#  'Jacqueline Gonzalez',
#  'Jisu Kim',
#  'Jordan Mora',
#  'Kurtis Ma',
#  'Octavio Castro',
#  'Omar Akbari',
#  'Oscar Acevedo-Federico',
#  'Sumiah Ali',
#  'Sunay Bargotra',
#  'Tyler Felipe',
#  'Zhen Cai'}

# %%
badnames_1 = set(grouped_students) - set(enrolled_students.Student)
badnames_1
# Out:
# {'Brandon Kao', 'Kevin An'}

# %%
grouped_sids = flatten( 
    groups.sids
    .apply( lambda y: [x.strip() for x in 
                         y.replace('.',',') # some idiot used a . instead of a ,
                         .split(',') # split sids grouped by commas
                      ]
          ) 
    

)
grouped_sids
# Out:
# ['A16415902',
#  'A15543021',
#  'A15584892',
#  'A14124875',
#  'A16153718',
#  'A16282696',
#  'A16365373',
#  'A16861627',
#  'A16322803',
#  'A16097094',
#  'A15939481',
#  'A16670728',
#  'A16310127',
#  'A16086824',
#  'A15502653',
#  'A16608338',
#  'A15859391',
#  'A16687858',
#  'A15850009',
#  'A16152481',
#  'A15973752',
#  'A15928638',
#  'A16684636',
#  'A17162275',
#  'A15770718',
#  'A15524376',
#  'A15886693',
#  'A16149329',
#  'A15879585',
#  'A15263726',
#  'A17126403',
#  'A17135107',
#  'A17155164',
#  'A17177880',
#  'A16541831',
#  'A15977557',
#  'A16542029',
#  'A14503658',
#  'A16585513',
#  'A15485774',
#  'A15518723',
#  'A15465016',
#  'A15476506',
#  'A16124465',
#  'A17126654',
#  'A16132934',
#  'A16291277',
#  'A16646416',
#  'A15566219',
#  'A16309841',
#  'A16567256',
#  'A15409900',
#  'A15867304',
#  'A15972715',
#  'A15983987',
#  'A16525015',
#  'A16096124',
#  'A16001309',
#  'A16568535',
#  'A15480541',
#  'A15939051',
#  'A16128886',
#  'A15893393',
#  'A15539350',
#  'A15631724',
#  'A16037028',
#  'A15965067',
#  'A16088408',
#  'A15613913',
#  'A16132943',
#  'A15437855',
#  'A16069918',
#  'A16672128',
#  'A15397529',
#  'A16279452',
#  'A14360597',
#  'A15962768',
#  'A16472199',
#  'A15920748',
#  'A15421394',
#  'A16130013',
#  'A16239963',
#  'A16578148',
#  'A15905633',
#  'A16351234',
#  'A15950817',
#  'A16377892',
#  'A16563489',
#  'A16122200',
#  'A15964201',
#  'A16603601',
#  'A16571330',
#  'A15559644',
#  'A15996992',
#  'A15512768',
#  'A16555028',
#  'A15569788',
#  'A16760692',
#  'A16654824',
#  'A16658917',
#  'A15897868',
#  'A16129186',
#  'A15798487',
#  'A16142103',
#  'A15873317',
#  'A17174059',
#  'A16121869',
#  'A16166835',
#  'A17203678',
#  'A16365169',
#  'A16600127',
#  'A16151279',
#  'A15390408',
#  'A16303025',
#  'A16147449',
#  'A16688512',
#  'A16496979',
#  'A16208763',
#  'A16035204',
#  'A15969704',
#  'A15490453',
#  'A16572776',
#  'A16607600',
#  'A16596186',
#  'A16010471',
#  'A16193845',
#  'A16150918',
#  'A15826935',
#  'A16146214',
#  'A15960682',
#  'A16599899',
#  'A15894479',
#  'A14972016',
#  'A16101958',
#  'A17158214',
#  'A15465955',
#  'A15918538',
#  'A15417806',
#  'A15597975',
#  'A15925037',
#  'A16310384',
#  'A15490356',
#  'A15669097',
#  'A15928931',
#  'A15519865',
#  'A16150018',
#  'A15499666',
#  'A15791012',
#  'A15910570',
#  'A16157145',
#  'A15620406',
#  'A15605373',
#  'A16012764',
#  'A16148978',
#  'A16005783',
#  'A16215540',
#  'A16220090',
#  'A16218608',
#  'A15839617',
#  'A16280173',
#  'A15767956',
#  'A16136074',
#  'A15812639',
#  'A15626025',
#  'A15599011',
#  'A16506536',
#  'A16131629',
#  'A16669790',
#  'A16562180',
#  'A16452821',
#  'A16574307',
#  'A15660577',
#  'A15948925',
#  'A16067697',
#  'A15406537',
#  'A15857392',
#  'A15896234',
#  'A15810146',
#  'A15811377',
#  'A16131100',
#  'A16030134',
#  'A16133968',
#  'A15538735',
#  'A13959010',
#  'A15891985',
#  'A15941283',
#  'A15534271',
#  'A15420796',
#  'A14957383',
#  'A15521243',
#  'A14903434',
#  'A12925987',
#  'A15515257',
#  'A16619040',
#  'A15923132',
#  'A14534620',
#  'A15561576',
#  'A15544144',
#  'A15875181',
#  'A16582622',
#  'A16041299',
#  'A15998050',
#  'A15412889',
#  'A15437144',
#  'A15602114',
#  'A16407413',
#  'A15766744',
#  'A15949529',
#  'A15897215',
#  'A15868185',
#  'A15497863',
#  'A15791056',
#  'A16585577',
#  'A16040362',
#  'A16578565',
#  'A14833734',
#  'A17207918',
#  'A16567599',
#  'A17204830',
#  'A16113085',
#  'A15583075',
#  'A16011432',
#  'A15551403',
#  'A16689578',
#  'A15455423',
#  'A16130282',
#  'A16578715',
#  'A15936976',
#  'A15841043',
#  'A16026494',
#  'A15563443',
#  'A15824040',
#  'A15842955',
#  'A15383745',
#  'A15498548',
#  'A15600334',
#  'A15468335',
#  'A15956949',
#  'A15784951',
#  'A16490008',
#  'A15943578',
#  'A17175163',
#  'A15631022',
#  'A15971720',
#  'A15780039',
#  'A14597802',
#  'A15597301',
#  'A15793529',
#  'A15836054',
#  'A15905200',
#  'A16548564',
#  'A14607141',
#  'A15971051',
#  'A15912694',
#  'A15592852',
#  'A15783471',
#  'A17151741',
#  'A14282518',
#  'A15912728',
#  'A15663586',
#  'A15607657',
#  'A14423221',
#  'A16384282',
#  'A16587055',
#  'A15920895',
#  'A15451559',
#  'A15477215',
#  'A15547577',
#  'A15480821',
#  'A15624633',
#  'A16358262',
#  'A16107530',
#  'A16592920',
#  'A15837934',
#  'A15798408',
#  'A15958535',
#  'A15849558',
#  'A16091880',
#  'A16280305',
#  'A16134815',
#  'A15954210',
#  'A16161236',
#  'A15850705',
#  'A16130748',
#  'A16534416',
#  'A17191150',
#  'A16014993',
#  'A16158974',
#  'A15495864',
#  'A16651096',
#  'A16155080',
#  'A16683446',
#  'A15917800',
#  'A15895399',
#  'A15960885',
#  'A15997720',
#  'A15661481',
#  'A15814854',
#  'A17159055',
#  'A17178601',
#  'A15707134',
#  'A16124690',
#  'A15639627',
#  'A16150282',
#  'A16156010',
#  'A16152974',
#  'A15928345',
#  'A15972503',
#  'A15910502',
#  'A16418300',
#  'A16349130',
#  'A16344449',
#  'A16543553',
#  'A17142185',
#  'A15498548',
#  'A15383745',
#  'A15600334',
#  'A15842955',
#  'A16105494',
#  'A15965704',
#  'A16331594',
#  'A15470874',
#  'A15091923',
#  'A15963476',
#  'A15857496',
#  'A14795528',
#  'A16548144',
#  'A16584700',
#  'A15797861',
#  'A16279195',
#  'A15977986',
#  'A16256667',
#  'A16488499',
#  'A14978108',
#  'A15131932',
#  'A15867501',
#  'A15445006',
#  'A16426598',
#  'A15908924',
#  'A16652568',
#  'A16290933',
#  'A16226087',
#  'A16607443',
#  'A17213233',
#  'A16594413',
#  'A15771250',
#  'A15897974',
#  'A15862188',
#  'A15394250',
#  'A15507221',
#  'A15508565',
#  'A15992178',
#  'A15527866',
#  'A16526404',
#  'A16538436',
#  'A16548882',
#  'A16577951',
#  'A16529962',
#  'A15930916',
#  'A16293991',
#  'A15897043',
#  'A16137902',
#  'A15920585',
#  'A16034292',
#  'A15475855',
#  'A16077279',
#  'A15571728',
#  'A15438326',
#  'A16131709',
#  'A15668280',
#  'A17174531',
#  'A15568422',
#  'A15414213',
#  'A15598463',
#  'A16079085',
#  'A17163250',
#  'A17190721',
#  'A15920128',
#  'A16361808',
#  'A16112358',
#  'A14933251',
#  'A15844265',
#  'A16569859',
#  'A15812627',
#  'A15904170',
#  'A15951446',
#  'A16133129',
#  'A16658332',
#  'A16147523',
#  'A16127732',
#  'A15780107',
#  'A15859816',
#  'A15909131',
#  'A15823139',
#  'A15872251',
#  'A16135396',
#  'A16406092',
#  'A16641543',
#  'A16568760',
#  'A16645968',
#  'A15484541',
#  'A15555141',
#  'A16402929',
#  'A16416709',
#  'A16213006',
#  'A16144322',
#  'A16348660',
#  'A16614602',
#  'A16641170',
#  'A15649315',
#  'A16206086',
#  'A16136705',
#  'A15627542',
#  'A15540540',
#  'A15390429',
#  'A16458236',
#  'A16598590',
#  'A16537838']

# %%
 
def sid2name(sid):
        try:
            ret = enrolled_students.set_index('SID').loc[sid,'Student']
        except KeyError:
            print('Unknown SID: '+sid)
            ret = None
        return ret

list(map(sid2name, grouped_sids))
# Out:
# Unknown SID: A16683446
# Unknown SID: A15508565
# ['Travis Salud',
#  'Ian Aweeka',
#  'Tu Anh Nguyen',
#  'Iurii Iuzifovich',
#  'Ricardo Aguilar',
#  'Alvin Hsu',
#  'Jeffrey Liu',
#  'Daniel Gitelman',
#  'Karina Chen',
#  'Sajeda Amin',
#  'Rohini Gadde',
#  'Brinda Narayanan',
#  'Valli Nachiappan',
#  'Briyana Preiger',
#  'Kennedy Anderson',
#  'George Gavrilov',
#  'Costin Smilovici',
#  'Vedan Desai',
#  'Karen Gong',
#  'Aleene Baeza',
#  'Russell Zuchlewski',
#  'Kevin Nguyen',
#  'Yeon Suh',
#  'Ryan Kao',
#  'Connor Bates',
#  'Jaida Day',
#  'Ayushi Sharma',
#  'Ziyu Wang',
#  'Yunyi She',
#  'Joon Cha',
#  'Yiwen Yuan',
#  'Xiji Yang',
#  'Xuying He',
#  'Jiahui Han',
#  'Yu Han Chang',
#  'Nada Galal',
#  'Michelle Tenin',
#  'Junhee Chung',
#  'Dilara Marasli',
#  'Justin Chanthabandith',
#  'Bozhi Wang',
#  'Berkeley Erwin',
#  'Samuel Brege',
#  'Younghoon Kim',
#  'Andy Chen',
#  'Goldie Chu',
#  'Tram Bui',
#  'Justin Huang',
#  'Jason Lee',
#  'Tiffany Cheng',
#  'Karen Nieto',
#  'Jeremy Chen',
#  'Katherine Chou',
#  'Princess Labrador',
#  'Taylor Chin',
#  'Connor Moore',
#  'Steven Youssef',
#  'Edgar Diaz',
#  'Scott Andrews',
#  'Sung Cho',
#  'Robert Kovar',
#  'Julie Ngan',
#  'Mohamed Abdilahi',
#  'Fajar Dirham',
#  'Erik Cisneros-Arellano',
#  'Melissa Phan',
#  'Tracy Nguyen',
#  'Annie Nguyen',
#  'Tina Vu',
#  'Aditya Datta',
#  'Qiyu Chen',
#  'Tianlin Zhao',
#  'Keri Chen',
#  'Michael Zhang',
#  'Christine Deng',
#  'Jared Acord',
#  'Wei Chen',
#  'Mingson Leung',
#  'Mohanad Ahmed',
#  'Hunter Estrada',
#  'Jun Zhang',
#  'Robert Zhang',
#  'Di Tian',
#  'Sihan Liang',
#  'Zhen Fang',
#  'Tin-Trung Pham',
#  'Brian Chen',
#  'Zhongkang Fang',
#  'Nilou Shahbandi',
#  'Leonardo Gonzalez',
#  'Long Tang',
#  'Hugo Huang',
#  'Daniel Kubeck',
#  'Lucas Bajoua',
#  'Alex Greene',
#  'Leif Diaz',
#  'Taorui Wang',
#  'Brandon Salinas Sanchez',
#  'Sandesh Shrestha',
#  'Sarah Horne',
#  'Sen Yang',
#  'Jinghao Lin',
#  'Zibin Gao',
#  'Gaomingyu Fan',
#  'Yucheng Huang',
#  'Rahul Ravi',
#  'Emilio Hernandez',
#  'Jared Singletary',
#  'Cecilia Martinez',
#  'Zm Iqbal',
#  'Anya Bodhisartha',
#  'Jingyue Xu',
#  'Divya Shetty',
#  'Jiliana Tiu',
#  'Man Jiang',
#  'Roger Thavixay',
#  'Sidney Ma',
#  'Akira Isayama',
#  'David Wang',
#  'Yunfei Jiao',
#  'Giao Tran',
#  'Moosaa Jalaldin',
#  'Sharoz Javaid',
#  'Ming Lin',
#  'Tommy Kim',
#  'Ryan Wang',
#  'Eric Wang',
#  'Rosey Bugayong',
#  'Hanyi Wang',
#  'Christof Kopera',
#  'Zichun Hao',
#  'Cardiff Jiang',
#  'Siyuan Liu',
#  'Oscar Martinez',
#  'Ya Qing Lai',
#  'Advik Passi',
#  'Dat Nguyen',
#  'Donald Wolfson',
#  'Lance Casiple',
#  'Kevin Lam',
#  'Mizuho Fukuda',
#  'Roy Li',
#  'Andrew Martinez',
#  'Hung-Tam Yie',
#  'Bernardo Lerma',
#  'Tian Gao',
#  'Yifei Ye',
#  'Freya Li',
#  'Weining Dai',
#  'Anni Li',
#  'Yujie Zhang',
#  'Zhendong Wang',
#  'David Chen',
#  'Jocelyn Liu',
#  'Ziqiu Li',
#  'Stephanie Nguyen',
#  'Tony Nguyen',
#  'Doan Duong',
#  'Francis Yang',
#  'Daniel Lin',
#  'Kathryn Chi-Ferson',
#  'Albert Constantino',
#  'Joshua Dreben',
#  'Enrique Gan',
#  'Jacky Lin',
#  'Zach Zhong',
#  'Gaoying Wang',
#  'Yifan Li',
#  'Yilian Liu',
#  'Jun Linwu',
#  'Matthew Leffler',
#  'Charmie Donasco',
#  'Michael Donaldson',
#  'Cairo Simpson',
#  'Michelle Liu',
#  'Yijie Ruan',
#  'Ruichen Li',
#  'Ashley Kou',
#  'Carol Bao',
#  'Silvia Liu',
#  'Monica Nguyen',
#  'Alex Wang',
#  'Ziniu Lu',
#  'Nicky La',
#  'Miguel Loera Arvizu',
#  'Evelyne Avila',
#  'Shihong Weng',
#  'Samantha Perez-Corona',
#  'Matthew Engurasoff',
#  'Ricardo Loeza',
#  'Stella Seki',
#  'James Okamura',
#  'Derek Leung',
#  'Tristan Schwichow',
#  'Dilan Lopez',
#  'Claudia Xie',
#  'Dashiell Thumm',
#  'Jovanni Valdez',
#  'Abigail Dominguez',
#  'Kevin Luo',
#  'Rohil Ahuja',
#  'Devika Torvi',
#  'Tom Dinh',
#  'Brian Vu',
#  'Po Ma',
#  'Shreekar Pandey',
#  'Rachel Blumin',
#  'Maya Desai',
#  'Parth Patel',
#  'Dan Magaril',
#  'Samuel Ng',
#  'Jessica Guzman',
#  'Edwin Lau-Mack',
#  'Tristan Romanov',
#  'Naweed Malal',
#  'Jessica Mata',
#  'Brian Liu',
#  'Audrey Li',
#  'John Onza',
#  'David Ngo',
#  'Isaac Douglas',
#  'Emily Ramond',
#  'Shaheen Daneshvar',
#  'Jonah Bryan',
#  'Kunyang Sun',
#  'Stella Ma',
#  'Jingjing Qiao',
#  'Yiru Chen',
#  'Nayeli Lopez-Rivera',
#  'Makenzie Johnson',
#  'Nathan Lee',
#  'Steven Deng',
#  'Joshua Zhu',
#  'Soham Bhanvadia',
#  'Amogh Vig',
#  'Eric Duong',
#  'Connor Tillman',
#  'Abigail Kufeldt',
#  'Joelle Nelson',
#  'Jacob Graven',
#  'Kenneth Shin',
#  'Kenneth Lam',
#  'Bateliel Bassa',
#  'Zhi Liang',
#  'Derek Hwang',
#  'Riley Paik',
#  'Amanda Quach',
#  'Samuel Liu',
#  'George Liu',
#  'Yang-Jie Qin',
#  'Maxwell Chang',
#  'Tian Liu',
#  'Navina Mahesh',
#  'Amol Khanna',
#  'Devon Romero',
#  'Anokhi Mehta',
#  'Vivian Cheung',
#  'Jonathan Lum',
#  'Chloe Lee',
#  'Jenna Nguyen',
#  'Yixuan Jiao',
#  'Dat Ta',
#  'Albert Henderson',
#  'Supratik Banerjee',
#  'Kalam Park',
#  'Gyuwan Kim',
#  'David Tu',
#  'Carmen Le',
#  'Anthony Villalba',
#  'Angela Oku',
#  'Brian Chu',
#  'Kyle Batalla',
#  'Ken Nguyen',
#  'Ishika Rathi',
#  'Albert Zhong',
#  'Issac Navarro',
#  'Kelly Nham',
#  'Aryan Safari',
#  'Armaan Johal',
#  'Sarbjot Singh',
#  'Ryan Heo',
#  'Jason Shao',
#  'Haonan Jiang',
#  'Junshu Li',
#  'Leming Luo',
#  'Ruoqing Song',
#  'Martha Chow',
#  'Chaewon Heo',
#  'Zhiyi Zhu',
#  'Arnav Tayal',
#  'Jose Deleon',
#  None,
#  'Nadia Corral',
#  'Christina Tyagi',
#  'Gideon Tong',
#  'Iain Ro',
#  'Patrick Jorgensen',
#  'Stephen Wang',
#  'Jianzhang Chen',
#  'Weijie Huang',
#  'Liu He',
#  'Audrey Yeh',
#  'Zihan Chen',
#  'Nan Jiang',
#  'Ning Ma',
#  'Kancheng Yin',
#  'Hao Yuan',
#  'Tianyu Li',
#  'Runyu Tian',
#  'Jiaqi Zhang',
#  'Yuxin Guo',
#  'Sha Lei',
#  'Jingxian Wang',
#  'Jiayi Zhang',
#  'Amogh Vig',
#  'Soham Bhanvadia',
#  'Eric Duong',
#  'Joshua Zhu',
#  'Rylan Keolanui',
#  'Lauren Himpelmann',
#  'Maxim Kondrashuk',
#  'Jasmine Shafie',
#  'Ozzie Orozco',
#  'Aditya Moghe',
#  'Salwan Shathar',
#  'Raghav Cherukuru',
#  'Presley Cheng',
#  'Eric Peng',
#  'Rohith Pillai',
#  'Pratheek Sankeshi',
#  'Christian Tapia',
#  'Luke Taylor',
#  'Josh Puray',
#  'Hyunjo Lee',
#  'Jaehoon Choi',
#  'Muhammad Imran',
#  'Yiliang Yuan',
#  'Maya Que',
#  'Akshat Mittal',
#  'Aishani Mohapatra',
#  'Abishek Sivayogagnanamoorthy',
#  'Srianusha Nandula',
#  'Mohammad Samadi',
#  'Jay Buensuceso',
#  'George Dubinin',
#  'William Alden',
#  'Brian Lam',
#  'Kevin Stubbings',
#  'Jonathan Langley',
#  'Dhruv Chaddah',
#  None,
#  'Spencer Vossman',
#  'Noelle Sumner',
#  'Fangcheng Dou',
#  'Weihua Pan',
#  'Kevin Yu',
#  'Wen Lin',
#  'Yinghui Sun',
#  'Connor McManigal',
#  'Xuwen Yan',
#  'Matthew Cohen',
#  'Egor Pustovalov',
#  'Ryan Swartz',
#  'Chloe Bayani',
#  'Brenton Porter',
#  'Alexandra Mendivil',
#  'Rhiannon Lang',
#  'Tushita Tandon',
#  'Benjamin Sacks',
#  'Samantha Mccuskey',
#  'Neharika Makam',
#  'Amelia Kawasaki',
#  'Charles Ting',
#  'Asif Chowdhury',
#  'Rielle Santos',
#  'Erick Gulyan',
#  'Kinan Alatasi',
#  'Arturo Torres-Jimenez',
#  'Anmol Saxena',
#  'Pablo Moreno',
#  'Jiseung Yoo',
#  'Hailey Duong',
#  'Borja Vega-Lojo',
#  'Jiayang Bao',
#  'Yuxuan Chen',
#  'Jingtian Ma',
#  'Tianze Zhang',
#  'Cindy Wang',
#  'Huaning Liu',
#  'Linghang Kong',
#  'Qingqing Gong',
#  'Jiangjun Yu',
#  'Yidan Wang',
#  'Brandon Koh',
#  'Jerry Chan',
#  'Andrew Ngo',
#  'Kelly Chang',
#  'Nicole Wong',
#  'Eric Chen',
#  'Kevin Chang',
#  'Vincent Tu',
#  'Janet Wong',
#  'Jimmy Wu',
#  'Yunxiang Chi',
#  'Jiajun Ni',
#  'Ziyan Liu',
#  'Xiaoxuan Zhang',
#  'Peicong Wu',
#  'Jocelyn Horng',
#  'Vicki Liang',
#  'Rina Kaura',
#  'Nachelle Matute',
#  'Brian Xie',
#  'Langrun Zhu',
#  'Yepeng Li',
#  'Yiling Cao',
#  'Yifan Liu',
#  'Hanran Yang']

# %%
id2nm = enrolled_students.set_index('SID')['Student'].to_dict()

def sid2name(sid):
        try:
            ret = id2nm[sid]
        except KeyError:
            print('Unknown SID: '+sid)
            ret = None
        return ret
    
    
grouped_names_from_sids = list( map( sid2name, grouped_sids) )
grouped_names_from_sids
# Out:
# Unknown SID: A16683446
# Unknown SID: A15508565
# ['Travis Salud',
#  'Ian Aweeka',
#  'Tu Anh Nguyen',
#  'Iurii Iuzifovich',
#  'Ricardo Aguilar',
#  'Alvin Hsu',
#  'Jeffrey Liu',
#  'Daniel Gitelman',
#  'Karina Chen',
#  'Sajeda Amin',
#  'Rohini Gadde',
#  'Brinda Narayanan',
#  'Valli Nachiappan',
#  'Briyana Preiger',
#  'Kennedy Anderson',
#  'George Gavrilov',
#  'Costin Smilovici',
#  'Vedan Desai',
#  'Karen Gong',
#  'Aleene Baeza',
#  'Russell Zuchlewski',
#  'Kevin Nguyen',
#  'Yeon Suh',
#  'Ryan Kao',
#  'Connor Bates',
#  'Jaida Day',
#  'Ayushi Sharma',
#  'Ziyu Wang',
#  'Yunyi She',
#  'Joon Cha',
#  'Yiwen Yuan',
#  'Xiji Yang',
#  'Xuying He',
#  'Jiahui Han',
#  'Yu Han Chang',
#  'Nada Galal',
#  'Michelle Tenin',
#  'Junhee Chung',
#  'Dilara Marasli',
#  'Justin Chanthabandith',
#  'Bozhi Wang',
#  'Berkeley Erwin',
#  'Samuel Brege',
#  'Younghoon Kim',
#  'Andy Chen',
#  'Goldie Chu',
#  'Tram Bui',
#  'Justin Huang',
#  'Jason Lee',
#  'Tiffany Cheng',
#  'Karen Nieto',
#  'Jeremy Chen',
#  'Katherine Chou',
#  'Princess Labrador',
#  'Taylor Chin',
#  'Connor Moore',
#  'Steven Youssef',
#  'Edgar Diaz',
#  'Scott Andrews',
#  'Sung Cho',
#  'Robert Kovar',
#  'Julie Ngan',
#  'Mohamed Abdilahi',
#  'Fajar Dirham',
#  'Erik Cisneros-Arellano',
#  'Melissa Phan',
#  'Tracy Nguyen',
#  'Annie Nguyen',
#  'Tina Vu',
#  'Aditya Datta',
#  'Qiyu Chen',
#  'Tianlin Zhao',
#  'Keri Chen',
#  'Michael Zhang',
#  'Christine Deng',
#  'Jared Acord',
#  'Wei Chen',
#  'Mingson Leung',
#  'Mohanad Ahmed',
#  'Hunter Estrada',
#  'Jun Zhang',
#  'Robert Zhang',
#  'Di Tian',
#  'Sihan Liang',
#  'Zhen Fang',
#  'Tin-Trung Pham',
#  'Brian Chen',
#  'Zhongkang Fang',
#  'Nilou Shahbandi',
#  'Leonardo Gonzalez',
#  'Long Tang',
#  'Hugo Huang',
#  'Daniel Kubeck',
#  'Lucas Bajoua',
#  'Alex Greene',
#  'Leif Diaz',
#  'Taorui Wang',
#  'Brandon Salinas Sanchez',
#  'Sandesh Shrestha',
#  'Sarah Horne',
#  'Sen Yang',
#  'Jinghao Lin',
#  'Zibin Gao',
#  'Gaomingyu Fan',
#  'Yucheng Huang',
#  'Rahul Ravi',
#  'Emilio Hernandez',
#  'Jared Singletary',
#  'Cecilia Martinez',
#  'Zm Iqbal',
#  'Anya Bodhisartha',
#  'Jingyue Xu',
#  'Divya Shetty',
#  'Jiliana Tiu',
#  'Man Jiang',
#  'Roger Thavixay',
#  'Sidney Ma',
#  'Akira Isayama',
#  'David Wang',
#  'Yunfei Jiao',
#  'Giao Tran',
#  'Moosaa Jalaldin',
#  'Sharoz Javaid',
#  'Ming Lin',
#  'Tommy Kim',
#  'Ryan Wang',
#  'Eric Wang',
#  'Rosey Bugayong',
#  'Hanyi Wang',
#  'Christof Kopera',
#  'Zichun Hao',
#  'Cardiff Jiang',
#  'Siyuan Liu',
#  'Oscar Martinez',
#  'Ya Qing Lai',
#  'Advik Passi',
#  'Dat Nguyen',
#  'Donald Wolfson',
#  'Lance Casiple',
#  'Kevin Lam',
#  'Mizuho Fukuda',
#  'Roy Li',
#  'Andrew Martinez',
#  'Hung-Tam Yie',
#  'Bernardo Lerma',
#  'Tian Gao',
#  'Yifei Ye',
#  'Freya Li',
#  'Weining Dai',
#  'Anni Li',
#  'Yujie Zhang',
#  'Zhendong Wang',
#  'David Chen',
#  'Jocelyn Liu',
#  'Ziqiu Li',
#  'Stephanie Nguyen',
#  'Tony Nguyen',
#  'Doan Duong',
#  'Francis Yang',
#  'Daniel Lin',
#  'Kathryn Chi-Ferson',
#  'Albert Constantino',
#  'Joshua Dreben',
#  'Enrique Gan',
#  'Jacky Lin',
#  'Zach Zhong',
#  'Gaoying Wang',
#  'Yifan Li',
#  'Yilian Liu',
#  'Jun Linwu',
#  'Matthew Leffler',
#  'Charmie Donasco',
#  'Michael Donaldson',
#  'Cairo Simpson',
#  'Michelle Liu',
#  'Yijie Ruan',
#  'Ruichen Li',
#  'Ashley Kou',
#  'Carol Bao',
#  'Silvia Liu',
#  'Monica Nguyen',
#  'Alex Wang',
#  'Ziniu Lu',
#  'Nicky La',
#  'Miguel Loera Arvizu',
#  'Evelyne Avila',
#  'Shihong Weng',
#  'Samantha Perez-Corona',
#  'Matthew Engurasoff',
#  'Ricardo Loeza',
#  'Stella Seki',
#  'James Okamura',
#  'Derek Leung',
#  'Tristan Schwichow',
#  'Dilan Lopez',
#  'Claudia Xie',
#  'Dashiell Thumm',
#  'Jovanni Valdez',
#  'Abigail Dominguez',
#  'Kevin Luo',
#  'Rohil Ahuja',
#  'Devika Torvi',
#  'Tom Dinh',
#  'Brian Vu',
#  'Po Ma',
#  'Shreekar Pandey',
#  'Rachel Blumin',
#  'Maya Desai',
#  'Parth Patel',
#  'Dan Magaril',
#  'Samuel Ng',
#  'Jessica Guzman',
#  'Edwin Lau-Mack',
#  'Tristan Romanov',
#  'Naweed Malal',
#  'Jessica Mata',
#  'Brian Liu',
#  'Audrey Li',
#  'John Onza',
#  'David Ngo',
#  'Isaac Douglas',
#  'Emily Ramond',
#  'Shaheen Daneshvar',
#  'Jonah Bryan',
#  'Kunyang Sun',
#  'Stella Ma',
#  'Jingjing Qiao',
#  'Yiru Chen',
#  'Nayeli Lopez-Rivera',
#  'Makenzie Johnson',
#  'Nathan Lee',
#  'Steven Deng',
#  'Joshua Zhu',
#  'Soham Bhanvadia',
#  'Amogh Vig',
#  'Eric Duong',
#  'Connor Tillman',
#  'Abigail Kufeldt',
#  'Joelle Nelson',
#  'Jacob Graven',
#  'Kenneth Shin',
#  'Kenneth Lam',
#  'Bateliel Bassa',
#  'Zhi Liang',
#  'Derek Hwang',
#  'Riley Paik',
#  'Amanda Quach',
#  'Samuel Liu',
#  'George Liu',
#  'Yang-Jie Qin',
#  'Maxwell Chang',
#  'Tian Liu',
#  'Navina Mahesh',
#  'Amol Khanna',
#  'Devon Romero',
#  'Anokhi Mehta',
#  'Vivian Cheung',
#  'Jonathan Lum',
#  'Chloe Lee',
#  'Jenna Nguyen',
#  'Yixuan Jiao',
#  'Dat Ta',
#  'Albert Henderson',
#  'Supratik Banerjee',
#  'Kalam Park',
#  'Gyuwan Kim',
#  'David Tu',
#  'Carmen Le',
#  'Anthony Villalba',
#  'Angela Oku',
#  'Brian Chu',
#  'Kyle Batalla',
#  'Ken Nguyen',
#  'Ishika Rathi',
#  'Albert Zhong',
#  'Issac Navarro',
#  'Kelly Nham',
#  'Aryan Safari',
#  'Armaan Johal',
#  'Sarbjot Singh',
#  'Ryan Heo',
#  'Jason Shao',
#  'Haonan Jiang',
#  'Junshu Li',
#  'Leming Luo',
#  'Ruoqing Song',
#  'Martha Chow',
#  'Chaewon Heo',
#  'Zhiyi Zhu',
#  'Arnav Tayal',
#  'Jose Deleon',
#  None,
#  'Nadia Corral',
#  'Christina Tyagi',
#  'Gideon Tong',
#  'Iain Ro',
#  'Patrick Jorgensen',
#  'Stephen Wang',
#  'Jianzhang Chen',
#  'Weijie Huang',
#  'Liu He',
#  'Audrey Yeh',
#  'Zihan Chen',
#  'Nan Jiang',
#  'Ning Ma',
#  'Kancheng Yin',
#  'Hao Yuan',
#  'Tianyu Li',
#  'Runyu Tian',
#  'Jiaqi Zhang',
#  'Yuxin Guo',
#  'Sha Lei',
#  'Jingxian Wang',
#  'Jiayi Zhang',
#  'Amogh Vig',
#  'Soham Bhanvadia',
#  'Eric Duong',
#  'Joshua Zhu',
#  'Rylan Keolanui',
#  'Lauren Himpelmann',
#  'Maxim Kondrashuk',
#  'Jasmine Shafie',
#  'Ozzie Orozco',
#  'Aditya Moghe',
#  'Salwan Shathar',
#  'Raghav Cherukuru',
#  'Presley Cheng',
#  'Eric Peng',
#  'Rohith Pillai',
#  'Pratheek Sankeshi',
#  'Christian Tapia',
#  'Luke Taylor',
#  'Josh Puray',
#  'Hyunjo Lee',
#  'Jaehoon Choi',
#  'Muhammad Imran',
#  'Yiliang Yuan',
#  'Maya Que',
#  'Akshat Mittal',
#  'Aishani Mohapatra',
#  'Abishek Sivayogagnanamoorthy',
#  'Srianusha Nandula',
#  'Mohammad Samadi',
#  'Jay Buensuceso',
#  'George Dubinin',
#  'William Alden',
#  'Brian Lam',
#  'Kevin Stubbings',
#  'Jonathan Langley',
#  'Dhruv Chaddah',
#  None,
#  'Spencer Vossman',
#  'Noelle Sumner',
#  'Fangcheng Dou',
#  'Weihua Pan',
#  'Kevin Yu',
#  'Wen Lin',
#  'Yinghui Sun',
#  'Connor McManigal',
#  'Xuwen Yan',
#  'Matthew Cohen',
#  'Egor Pustovalov',
#  'Ryan Swartz',
#  'Chloe Bayani',
#  'Brenton Porter',
#  'Alexandra Mendivil',
#  'Rhiannon Lang',
#  'Tushita Tandon',
#  'Benjamin Sacks',
#  'Samantha Mccuskey',
#  'Neharika Makam',
#  'Amelia Kawasaki',
#  'Charles Ting',
#  'Asif Chowdhury',
#  'Rielle Santos',
#  'Erick Gulyan',
#  'Kinan Alatasi',
#  'Arturo Torres-Jimenez',
#  'Anmol Saxena',
#  'Pablo Moreno',
#  'Jiseung Yoo',
#  'Hailey Duong',
#  'Borja Vega-Lojo',
#  'Jiayang Bao',
#  'Yuxuan Chen',
#  'Jingtian Ma',
#  'Tianze Zhang',
#  'Cindy Wang',
#  'Huaning Liu',
#  'Linghang Kong',
#  'Qingqing Gong',
#  'Jiangjun Yu',
#  'Yidan Wang',
#  'Brandon Koh',
#  'Jerry Chan',
#  'Andrew Ngo',
#  'Kelly Chang',
#  'Nicole Wong',
#  'Eric Chen',
#  'Kevin Chang',
#  'Vincent Tu',
#  'Janet Wong',
#  'Jimmy Wu',
#  'Yunxiang Chi',
#  'Jiajun Ni',
#  'Ziyan Liu',
#  'Xiaoxuan Zhang',
#  'Peicong Wu',
#  'Jocelyn Horng',
#  'Vicki Liang',
#  'Rina Kaura',
#  'Nachelle Matute',
#  'Brian Xie',
#  'Langrun Zhu',
#  'Yepeng Li',
#  'Yiling Cao',
#  'Yifan Liu',
#  'Hanran Yang']

# %%
unassigned_2 = set(enrolled_students.Student) - set(grouped_names_from_sids)
unassigned_2
# Out:
# {'Amy Shen',
#  'Angel Olivas',
#  'Anthony Azucena',
#  'Antonio Gomez',
#  'Ashley Shen',
#  'Brooke Byron',
#  'Delvin Tuankun',
#  'Deng Jia',
#  'Girish Senthil',
#  'Guanji Chen',
#  'Ian Chin',
#  'Jacqueline Gonzalez',
#  'Jisu Kim',
#  'Jordan Mora',
#  'Kurtis Ma',
#  'Octavio Castro',
#  'Omar Akbari',
#  'Oscar Acevedo-Federico',
#  'Sumiah Ali',
#  'Sunay Bargotra',
#  'Tyler Felipe',
#  'Zhen Cai'}

# %%
badnames_2 = set(grouped_names_from_sids) - set(enrolled_students.Student)
badnames_2
# Out:
# {None}

# %% [markdown]
# Clearly it looks like the method for unassigned students via SID is the best version for this quarter, let's roll with it.
#
# You might need to make a different call in a different quarter :)
#
# But first let's see if there's any cases where the SID was bad but the student name was recorded properly

# %%
# these are students who were recorded properly by name but not by SID
correction = unassigned_2.intersection( set(grouped_students) )
correction
# Out:
# set()

# %%
unassigned_students = list( unassigned_2 - correction)
print('there are {} unassigned_students:\n{}'.format(len(unassigned_students), unassigned_students))
# Out:
# there are 22 unassigned_students:
# ['Antonio Gomez', 'Tyler Felipe', 'Omar Akbari', 'Girish Senthil', 'Oscar Acevedo-Federico', 'Kurtis Ma', 'Amy Shen', 'Sumiah Ali', 'Brooke Byron', 'Jisu Kim', 'Jacqueline Gonzalez', 'Ian Chin', 'Deng Jia', 'Sunay Bargotra', 'Jordan Mora', 'Delvin Tuankun', 'Anthony Azucena', 'Zhen Cai', 'Angel Olivas', 'Guanji Chen', 'Octavio Castro', 'Ashley Shen']

# %%
# theses are the students to email (copy/paste below into TO: line) 
# ask them if they really didn't sign up for a project group 
# because they are about to be randomly assigned to a group
emails = enrolled_students.set_index('Student').email + '@ucsd.edu'
for x in emails.loc[unassigned_students]:
    print(x)
# Out:
# jagomez@ucsd.edu
# tfelipe@ucsd.edu
# omakbari@ucsd.edu
# gsenthil@ucsd.edu
# oacevedo@ucsd.edu
# kyma@ucsd.edu
# axshen@ucsd.edu
# s3ali@ucsd.edu
# bbyron@ucsd.edu
# jik003@ucsd.edu
# jag129@ucsd.edu
# ichin@ucsd.edu
# dejia@ucsd.edu
# sbargotra@ucsd.edu
# jomora@ucsd.edu
# dtuankun@ucsd.edu
# adazucen@ucsd.edu
# zyc004@ucsd.edu
# aaolivas@ucsd.edu
# g1chen@ucsd.edu
# occastro@ucsd.edu
# a2shen@ucsd.edu

# %% [markdown]
# Hi,
#
# You are one of a few dozen students who didn’t sign up for a project group according to my automatic scripts.
#
# This email is to verify that my scripts didn’t get messed up somehow.
#
# Please reply to this email ONLY if there is some kind of mistake.  Reply ONLY if you did actually signup with a group.  Otherwise you can ignore this email, and you will be assigned randomly to a project group.
#
# Thanks

# %% [markdown]
# ### Create new groups and/or fill up sub-sized groups with the unassigned

# %% [markdown]
# What should you do?  let's do this manually becuase its impossible to do it well automatically

# %%
subsized_groups = groups[ groups.n_people < 4 ]
subsized_groups
# Out:
#                                                 names  \
# group_name
# Group054        Yixuan Jiao, Dat Ta, Albert Henderson
# Group055    Supratik Banerjee, Kalam Park, Gyuwan Kim
#
#                                        sids                            gitids  \
# group_name
# Group054    A15607657, A14423221, A16384282  YixuanJiao, dqta21, AlbertHender
# Group055    A16587055, A15920895, A15451559   awesomesup, kalampark, giwi2123
#
#             n_people
# group_name
# Group054           3
# Group055           3

# %%
len(unassigned_students) - 2
# Out:
# 20

# %% [markdown]
#  In this quarter I will be adding 2 total people to 2 subsized groups, creating groups of 4, which will leave me 20 unassigned to make 4 groups of 5.
#
# As you make the groups below copy/paste the email list into a TO line and send the below email to them.
#
# **NB** If you need to add 2 or more people to a group, just copy/paste the gr = 'GroupXXX' cell that many times

# %% [markdown]
# Hi,
#
# Previously <4 people had been in your group from the signup form.  I'm randomly assigning ___ to make your group >= 4 people. This email is to serve as an introduction for you all and help you get together and organize.
#
# As a reminder, please accept the Github invite ASAP (sent as a seperate email).
#
# Good luck this quarter!

# %%
counter = 0
assignments = {}

# %%
gr = 'Group054'

print(groups.loc[gr,'names'])
groups.loc[gr,'names'] = groups.loc[gr,'names']+', '+unassigned_students[counter]
groups.loc[gr,'names']
assignments[unassigned_students[counter]] = gr
counter = counter + 1
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Yixuan Jiao, Dat Ta, Albert Henderson
# Yixuan Jiao, Dat Ta, Albert Henderson, Antonio Gomez
# y9jiao@ucsd.edu
# dqta@ucsd.edu
# adhender@ucsd.edu
# jagomez@ucsd.edu

# %%
gr = 'Group055'

print(groups.loc[gr,'names'])
groups.loc[gr,'names'] = groups.loc[gr,'names']+', '+unassigned_students[counter]
groups.loc[gr,'names']
assignments[unassigned_students[counter]] = gr
counter = counter + 1
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Supratik Banerjee, Kalam Park, Gyuwan Kim
# Supratik Banerjee, Kalam Park, Gyuwan Kim, Tyler Felipe
# s1banerj@ucsd.edu
# kapark@ucsd.edu
# gykim@ucsd.edu
# tfelipe@ucsd.edu

# %% [markdown]
# OK now do the rest of the unassigned in new groups

# %%
# this tells you the number of the last group formed by signup; 
# start randomly assigned groups 1 up from here
groups.tail(1)
# Out:
#                                                         names  \
# group_name
# Group088    Langrun Zhu, Yepeng Li, Yiling Cao, Yifan Liu,...
#
#                                                          sids  \
# group_name
# Group088    A15540540, A15390429, A16458236, A16598590, A1...
#
#                                                        gitids  n_people
# group_name
# Group088    LangrunZhu, gelaneier, Cyl200215, YifanLiuDolo...         5

# %%
# this should match teh expeted number of groups/students
len(unassigned_students[counter:])
# Out:
# 20

# %% [markdown]
# As you make the randomly groups below, copy/paste the email list into a TO line and send the below email to them.

# %% [markdown]
# Hi,
#
# You did not sign up for a group, so you have been randomly assigned to groupXXX.
#
# Please talk with each other and organize for the group projects.
#
# As a reminder, please accept the Github invite ASAP (sent as a seperate email).
#
# Good luck this quarter!

# %%
gr = 'Group089'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+5
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Omar Akbari, Girish Senthil, Oscar Acevedo-Federico, Kurtis Ma, Amy Shen
# omakbari@ucsd.edu
# gsenthil@ucsd.edu
# oacevedo@ucsd.edu
# kyma@ucsd.edu
# axshen@ucsd.edu

# %%
gr = 'Group090'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+5
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Sumiah Ali, Brooke Byron, Jisu Kim, Jacqueline Gonzalez, Ian Chin
# s3ali@ucsd.edu
# bbyron@ucsd.edu
# jik003@ucsd.edu
# jag129@ucsd.edu
# ichin@ucsd.edu

# %%
gr = 'Group091'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+5
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Deng Jia, Sunay Bargotra, Jordan Mora, Delvin Tuankun, Anthony Azucena
# dejia@ucsd.edu
# sbargotra@ucsd.edu
# jomora@ucsd.edu
# dtuankun@ucsd.edu
# adazucen@ucsd.edu

# %%
gr = 'Group092'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+5
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Zhen Cai, Angel Olivas, Guanji Chen, Octavio Castro, Ashley Shen
# zyc004@ucsd.edu
# aaolivas@ucsd.edu
# g1chen@ucsd.edu
# occastro@ucsd.edu
# a2shen@ucsd.edu

# %%
len(unassigned_students[counter:])
# Out:
# 0

# %%
groups
# Out:
#                                                         names  \
# group_name
# Group000    Travis Salud, Ian Aweeka, Tu Anh Nguyen, Iurii...
# Group001    Alvin Hsu, Jeffrey Liu, Daniel Gitelman, Karin...
# Group002    Rohini Gadde, Brinda Narayanan, Valli Nachiapp...
# Group003    George Gavrilov, Costin Smilovici, Vedan Desai...
# Group004    Russell Zuchlewski, Kevin Nguyen, Yeon Suh, Ry...
# ...                                                       ...
# Group089    Omar Akbari, Girish Senthil, Oscar Acevedo-Fed...
# Group090    Sumiah Ali, Brooke Byron, Jisu Kim, Jacqueline...
# Group091    Deng Jia, Sunay Bargotra, Jordan Mora, Delvin ...
# Group092    Zhen Cai, Angel Olivas, Guanji Chen, Octavio C...
# Group093
#
#                                                          sids  \
# group_name
# Group000    A16415902, A15543021, A15584892, A14124875, A1...
# Group001    A16282696, A16365373, A16861627, A16322803, A1...
# Group002    A15939481, A16670728, A16310127, A16086824, A1...
# Group003    A16608338, A15859391, A16687858, A15850009, A1...
# Group004    A15973752, A15928638, A16684636, A17162275, A1...
# ...                                                       ...
# Group089                                                  NaN
# Group090                                                  NaN
# Group091                                                  NaN
# Group092                                                  NaN
# Group093                                                  NaN
#
#                                                        gitids  n_people
# group_name
# Group000        TSalud15, ianA1234, tuanhn, iiuzifov, Aricky3       5.0
# Group001         alvinahsu, hicytree, dgitelman1, karinaechen       5.0
# Group002    rogadde, bvnarayanan, vnucsd, bpreiger, Kenned...       5.0
# Group003    GeorgeGavrilov, LtAstros, Grizlucks, kwgong, A...       5.0
# Group004    SushiRZ, kevinngoow1n, Sunfishhh, ryankao0415,...       5.0
# ...                                                       ...       ...
# Group089                                                  NaN       NaN
# Group090                                                  NaN       NaN
# Group091                                                  NaN       NaN
# Group092                                                  NaN       NaN
# Group093                                                  NaN       NaN
#
# [94 rows x 4 columns]

# %%
ghdf = pd.read_csv('a1.csv')
ghdf
# Out:
#      Unnamed: 0 firstname          lastname        pid   gh_username  pr_repo  \
# 0             0   Mohamed          Abdilahi  A15893393   mabdilahCSE     True
# 1             1     Oscar  Acevedo-Federico  A16008996     OrigamiMM     True
# 2             2     Jared             Acord  A14360597    acordjared     True
# 3             3   Ricardo           Aguilar  A16153718       Aricky3     True
# 4             4   Mohanad             Ahmed  A15920748      moahmed5     True
# ..          ...       ...               ...        ...           ...      ...
# 431         431    Joshua               Zhu  A15842955      jqzhuuuu     True
# 432         432   Langrun               Zhu  A15540540    LangrunZhu     True
# 433         433     Zhiyi               Zhu  A15495864  ZhiyiZhu0226     True
# 434         434   Russell        Zuchlewski  A15973752       SushiRZ     True
# 435         435      Test           Student        NaN           NaN    False
#
#      personal_repo
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# ..             ...
# 431           True
# 432           True
# 433           True
# 434           True
# 435          False
#
# [436 rows x 7 columns]

# %%
# kids who didn't complete the assignment properly
todrop = ghdf.isnull().any(axis=1)
ghdf[todrop]
# Out:
#      Unnamed: 0 firstname   lastname             pid gh_username  pr_repo  \
# 6             6      Omar     Akbari       A16586433         NaN    False
# 10           10    Sajeda       Amin       A16097094         NaN    False
# 47           47      Andy       Chen       A17126654         NaN    False
# 76           76    Junhee      Chung       A14503658         NaN    False
# 82           82   Shaheen  Daneshvar       A15551403         NaN    False
# 124         124  Account,      Grade  99CG108G2_SP22         NaN    False
# 162         162   Patrick  Jorgensen       A15661481         NaN    False
# 209         209     Sihan      Liang       A15905633         NaN    False
# 273         273     David        Ngo       A16113085         NaN    False
# 303         303   Brenton     Porter       A15475855         NaN    False
# 324         324    Rielle     Santos       A16079085         NaN    False
# 331         331     Jason       Shao       A16161236         NaN    False
# 348         348    Noelle     Sumner       A15527866         NaN    False
# 360         360  Dashiell      Thumm       A15561576         NaN    False
# 361         361        Di       Tian       A16578148         NaN    False
# 380         380      Tina         Vu       A15613913         NaN    False
# 428         428   Tianlin       Zhao       A16069918         NaN    False
# 435         435      Test    Student             NaN         NaN    False
#
#      personal_repo
# 6            False
# 10           False
# 47           False
# 76           False
# 82           False
# 124          False
# 162          False
# 209          False
# 273          False
# 303          False
# 324          False
# 331          False
# 348          False
# 360          False
# 361          False
# 380          False
# 428          False
# 435          False

# %%
ghdf['names'] = ghdf['firstname'] + ' ' + ghdf['lastname']
ghdf
# Out:
#      Unnamed: 0 firstname          lastname        pid   gh_username  pr_repo  \
# 0             0   Mohamed          Abdilahi  A15893393   mabdilahCSE     True
# 1             1     Oscar  Acevedo-Federico  A16008996     OrigamiMM     True
# 2             2     Jared             Acord  A14360597    acordjared     True
# 3             3   Ricardo           Aguilar  A16153718       Aricky3     True
# 4             4   Mohanad             Ahmed  A15920748      moahmed5     True
# ..          ...       ...               ...        ...           ...      ...
# 431         431    Joshua               Zhu  A15842955      jqzhuuuu     True
# 432         432   Langrun               Zhu  A15540540    LangrunZhu     True
# 433         433     Zhiyi               Zhu  A15495864  ZhiyiZhu0226     True
# 434         434   Russell        Zuchlewski  A15973752       SushiRZ     True
# 435         435      Test           Student        NaN           NaN    False
#
#      personal_repo                   names
# 0             True        Mohamed Abdilahi
# 1             True  Oscar Acevedo-Federico
# 2             True             Jared Acord
# 3             True         Ricardo Aguilar
# 4             True           Mohanad Ahmed
# ..             ...                     ...
# 431           True              Joshua Zhu
# 432           True             Langrun Zhu
# 433           True               Zhiyi Zhu
# 434           True      Russell Zuchlewski
# 435          False            Test Student
#
# [436 rows x 8 columns]

# %%
print(ghdf.shape)
ghdf = ghdf.drop(ghdf.index[todrop])
ghdf = ghdf.set_index('names')['gh_username']
print(ghdf.shape)
# Out:
# (436, 8)
# (418,)

# %%
groups['gitids'] = groups.names.apply( lambda x: ', '.join(
    [ ghdf[token.strip()] for token in x.split(',') if (token.strip() in ghdf.index) ]
                                                ) 
                            )

# %%
groups
# Out:
#                                                         names  \
# group_name
# Group000    Travis Salud, Ian Aweeka, Tu Anh Nguyen, Iurii...
# Group001    Alvin Hsu, Jeffrey Liu, Daniel Gitelman, Karin...
# Group002    Rohini Gadde, Brinda Narayanan, Valli Nachiapp...
# Group003    George Gavrilov, Costin Smilovici, Vedan Desai...
# Group004    Russell Zuchlewski, Kevin Nguyen, Yeon Suh, Ry...
# ...                                                       ...
# Group088    Langrun Zhu, Yepeng Li, Yiling Cao, Yifan Liu,...
# Group089    Omar Akbari, Girish Senthil, Oscar Acevedo-Fed...
# Group090    Sumiah Ali, Brooke Byron, Jisu Kim, Jacqueline...
# Group091    Deng Jia, Sunay Bargotra, Jordan Mora, Delvin ...
# Group092    Zhen Cai, Angel Olivas, Guanji Chen, Octavio C...
#
#                                                          sids  \
# group_name
# Group000    A16415902, A15543021, A15584892, A14124875, A1...
# Group001    A16282696, A16365373, A16861627, A16322803, A1...
# Group002    A15939481, A16670728, A16310127, A16086824, A1...
# Group003    A16608338, A15859391, A16687858, A15850009, A1...
# Group004    A15973752, A15928638, A16684636, A17162275, A1...
# ...                                                       ...
# Group088    A15540540, A15390429, A16458236, A16598590, A1...
# Group089                                                  NaN
# Group090                                                  NaN
# Group091                                                  NaN
# Group092                                                  NaN
#
#                                                        gitids  n_people
# group_name
# Group000                TSalud15, ianA1234, iiuzifov, Aricky3       5.0
# Group001         alvinahsu, hicytree, dgitelman1, karinaechen       5.0
# Group002    rogadde, bvnarayanan, vnucsd, bpreiger, Kenned...       5.0
# Group003    GeorgeGavrilov, LtAstros, Grizlucks, kwgong, A...       5.0
# Group004    SushiRZ, kevinngoow1n, Sunfishhh, ryankao0415,...       5.0
# ...                                                       ...       ...
# Group088    LangrunZhu, gelaneier, Cyl200215, YifanLiuDolo...       5.0
# Group089            girishsenthil, OrigamiMM, KurtisMa, amys8       NaN
# Group090     sumiahali, brookebyron, jik003, jciil, ichinucsd       NaN
# Group091    vinhimself, sbargotra, Jordanmora, dtuankun, A...       NaN
# Group092     z3nnnn, aaolivas, CGuanji, occastro, ashleyyshen       NaN
#
# [93 rows x 4 columns]

# %%
groups.to_csv('assigned_groups.csv')

# %% [markdown]
# ### Github
# OK time to create a github repo for each and every group. Note to do this you need to have gh CLI installed and have authenticated it as your user (see `gh auth login` documentation)
#
# The process will create one repo for each group from the group_template.  Next we invite users to their repo. Then we checkout the project locally, rename the files, push, and delete the local copy

# %%
# YOU NEED TO CHANGE THINGS HERE EACH QUARTER!!!
# you'll have to change the name of the quarter in command_add_instructors
# and also in grpsuffix

import os
import glob


command_create = 'gh repo create --private --template COGS108/group_template -y COGS108/' # + groupname
command_invite = 'gh api -X PUT -f permission=push repos/COGS108/' # + groupname/collaborators/username
command_add_instructors = 'gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/' # + groupname

grpsuffix = 'Sp22' #change this name suffix each quarter

# %%
for grp in groups.index:

    gname = grp+grpsuffix 
    
    # create new repo
    cmd = command_create+gname
    ret = os.system(cmd)
    print(cmd,ret)
    
    # add instructors to have admin access to the repo
    cmd=command_add_instructors+gname
    ret = os.system(cmd)
    print(cmd,ret)
    
    # invite everyone in the group to the repo
    for uname in groups.loc[grp,'gitids'].split(','):
        cmd=command_invite+gname+'/collaborators/'+uname.strip()
        ret = os.system(cmd)
        print(cmd,ret)
        
    # get a local copy of the repo
    cmd='gh repo clone COGS108/'+gname
    ret = os.system(cmd)
    print(cmd,ret)

    # rename the files in the repo to the groups name pattern
    for fname in glob.glob(gname+'/*groupXXX.ipynb'):
        source = fname.split('/')[1]
        target = source.split("_")[0]+gname+'.ipynb'
        cmd = ( 'cd '+gname+'; '+
                        ' '.join(['git mv',source,target]))
        ret = os.system(cmd)
        print(cmd,ret)
    
    # commit changes and push
    cmd = 'cd '+gname+'; git add -A; git commit -m "renamed files"; git push'
    ret = os.system(cmd)
    print(cmd,ret)
    
    # remove local copy of repo
    cmd = 'rm -rf '+gname
    ret = os.system(cmd)
    print(cmd,ret)
    
    # add instructors to the repo
    cmd=command_add_instructors+gname
    ret = os.system(cmd)
    print(cmd,ret)
# Out:
# gh repo create --private --template COGS108/group_template -y COGS108/Group000Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group000Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group000Sp22/collaborators/TSalud15 0
# gh api -X PUT -f permission=push repos/COGS108/Group000Sp22/collaborators/ianA1234 0
# gh api -X PUT -f permission=push repos/COGS108/Group000Sp22/collaborators/iiuzifov 0
# gh api -X PUT -f permission=push repos/COGS108/Group000Sp22/collaborators/Aricky3 0
# gh repo clone COGS108/Group000Sp22 0
# cd Group000Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup000Sp22.ipynb 0
# cd Group000Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup000Sp22.ipynb 0
# cd Group000Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup000Sp22.ipynb 0
# cd Group000Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup000Sp22.ipynb 0
# cd Group000Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group000Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group000Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group001Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group001Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group001Sp22/collaborators/alvinahsu 0
# gh api -X PUT -f permission=push repos/COGS108/Group001Sp22/collaborators/hicytree 0
# gh api -X PUT -f permission=push repos/COGS108/Group001Sp22/collaborators/dgitelman1 0
# gh api -X PUT -f permission=push repos/COGS108/Group001Sp22/collaborators/karinaechen 0
# gh repo clone COGS108/Group001Sp22 0
# cd Group001Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup001Sp22.ipynb 0
# cd Group001Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup001Sp22.ipynb 0
# cd Group001Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup001Sp22.ipynb 0
# cd Group001Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup001Sp22.ipynb 0
# cd Group001Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group001Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group001Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group002Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group002Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group002Sp22/collaborators/rogadde 0
# gh api -X PUT -f permission=push repos/COGS108/Group002Sp22/collaborators/bvnarayanan 0
# gh api -X PUT -f permission=push repos/COGS108/Group002Sp22/collaborators/vnucsd 0
# gh api -X PUT -f permission=push repos/COGS108/Group002Sp22/collaborators/bpreiger 0
# gh api -X PUT -f permission=push repos/COGS108/Group002Sp22/collaborators/KennedyrAnderson 0
# gh repo clone COGS108/Group002Sp22 0
# cd Group002Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup002Sp22.ipynb 0
# cd Group002Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup002Sp22.ipynb 0
# cd Group002Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup002Sp22.ipynb 0
# cd Group002Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup002Sp22.ipynb 0
# cd Group002Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group002Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group002Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group003Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group003Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group003Sp22/collaborators/GeorgeGavrilov 0
# gh api -X PUT -f permission=push repos/COGS108/Group003Sp22/collaborators/LtAstros 0
# gh api -X PUT -f permission=push repos/COGS108/Group003Sp22/collaborators/Grizlucks 0
# gh api -X PUT -f permission=push repos/COGS108/Group003Sp22/collaborators/kwgong 0
# gh api -X PUT -f permission=push repos/COGS108/Group003Sp22/collaborators/AleeneB7 0
# gh repo clone COGS108/Group003Sp22 0
# cd Group003Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup003Sp22.ipynb 0
# cd Group003Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup003Sp22.ipynb 0
# cd Group003Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup003Sp22.ipynb 0
# cd Group003Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup003Sp22.ipynb 0
# cd Group003Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group003Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group003Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group004Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group004Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group004Sp22/collaborators/SushiRZ 0
# gh api -X PUT -f permission=push repos/COGS108/Group004Sp22/collaborators/kevinngoow1n 0
# gh api -X PUT -f permission=push repos/COGS108/Group004Sp22/collaborators/Sunfishhh 0
# gh api -X PUT -f permission=push repos/COGS108/Group004Sp22/collaborators/ryankao0415 0
# gh api -X PUT -f permission=push repos/COGS108/Group004Sp22/collaborators/csbates 0
# gh repo clone COGS108/Group004Sp22 0
# cd Group004Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup004Sp22.ipynb 0
# cd Group004Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup004Sp22.ipynb 0
# cd Group004Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup004Sp22.ipynb 0
# cd Group004Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup004Sp22.ipynb 0
# cd Group004Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group004Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group004Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group005Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group005Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group005Sp22/collaborators/aadiaaj 0
# gh api -X PUT -f permission=push repos/COGS108/Group005Sp22/collaborators/ayushiatsharma 0
# gh api -X PUT -f permission=push repos/COGS108/Group005Sp22/collaborators/ZiyuWang0113 0
# gh api -X PUT -f permission=push repos/COGS108/Group005Sp22/collaborators/yunyiwinnieshe 0
# gh api -X PUT -f permission=push repos/COGS108/Group005Sp22/collaborators/kier0813 0
# gh repo clone COGS108/Group005Sp22 0
# cd Group005Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup005Sp22.ipynb 0
# cd Group005Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup005Sp22.ipynb 0
# cd Group005Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup005Sp22.ipynb 0
# cd Group005Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup005Sp22.ipynb 0
# cd Group005Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group005Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group005Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group006Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group006Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group006Sp22/collaborators/yiy051 0
# gh api -X PUT -f permission=push repos/COGS108/Group006Sp22/collaborators/XijijiXi 0
# gh api -X PUT -f permission=push repos/COGS108/Group006Sp22/collaborators/pika-chu11 0
# gh api -X PUT -f permission=push repos/COGS108/Group006Sp22/collaborators/WillHan06 0
# gh repo clone COGS108/Group006Sp22 0
# cd Group006Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup006Sp22.ipynb 0
# cd Group006Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup006Sp22.ipynb 0
# cd Group006Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup006Sp22.ipynb 0
# cd Group006Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup006Sp22.ipynb 0
# cd Group006Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group006Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group006Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group007Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group007Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group007Sp22/collaborators/nadagehad01 0
# gh api -X PUT -f permission=push repos/COGS108/Group007Sp22/collaborators/MichelleTenin 0
# gh api -X PUT -f permission=push repos/COGS108/Group007Sp22/collaborators/dmarasli 0
# gh api -X PUT -f permission=push repos/COGS108/Group007Sp22/collaborators/thejustinrock 0
# gh repo clone COGS108/Group007Sp22 0
# cd Group007Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup007Sp22.ipynb 0
# cd Group007Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup007Sp22.ipynb 0
# cd Group007Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup007Sp22.ipynb 0
# cd Group007Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup007Sp22.ipynb 0
# cd Group007Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group007Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group007Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group008Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group008Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group008Sp22/collaborators/Bowang1337 0
# gh api -X PUT -f permission=push repos/COGS108/Group008Sp22/collaborators/BerkeleyErwin 0
# gh api -X PUT -f permission=push repos/COGS108/Group008Sp22/collaborators/samuelbrege 0
# gh api -X PUT -f permission=push repos/COGS108/Group008Sp22/collaborators/yok029 0
# gh repo clone COGS108/Group008Sp22 0
# cd Group008Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup008Sp22.ipynb 0
# cd Group008Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup008Sp22.ipynb 0
# cd Group008Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup008Sp22.ipynb 0
# cd Group008Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup008Sp22.ipynb 0
# cd Group008Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group008Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group008Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group009Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group009Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group009Sp22/collaborators/zqtelcorte 0
# gh api -X PUT -f permission=push repos/COGS108/Group009Sp22/collaborators/tqbui 0
# gh api -X PUT -f permission=push repos/COGS108/Group009Sp22/collaborators/jnhuang02 0
# gh api -X PUT -f permission=push repos/COGS108/Group009Sp22/collaborators/jal004 0
# gh api -X PUT -f permission=push repos/COGS108/Group009Sp22/collaborators/tiffanycchengg 0
# gh repo clone COGS108/Group009Sp22 0
# cd Group009Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup009Sp22.ipynb 0
# cd Group009Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup009Sp22.ipynb 0
# cd Group009Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup009Sp22.ipynb 0
# cd Group009Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup009Sp22.ipynb 0
# cd Group009Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group009Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group009Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group010Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group010Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group010Sp22/collaborators/karennieto 0
# gh api -X PUT -f permission=push repos/COGS108/Group010Sp22/collaborators/jec004 0
# gh api -X PUT -f permission=push repos/COGS108/Group010Sp22/collaborators/kitkatkatherine 0
# gh api -X PUT -f permission=push repos/COGS108/Group010Sp22/collaborators/princesslabrad 0
# gh api -X PUT -f permission=push repos/COGS108/Group010Sp22/collaborators/taylorchin 0
# gh repo clone COGS108/Group010Sp22 0
# cd Group010Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup010Sp22.ipynb 0
# cd Group010Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup010Sp22.ipynb 0
# cd Group010Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup010Sp22.ipynb 0
# cd Group010Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup010Sp22.ipynb 0
# cd Group010Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group010Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group010Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group011Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group011Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group011Sp22/collaborators/CMoore6258 0
# gh api -X PUT -f permission=push repos/COGS108/Group011Sp22/collaborators/stevenyoussef 0
# gh api -X PUT -f permission=push repos/COGS108/Group011Sp22/collaborators/Edgar-ship-it 0
# gh api -X PUT -f permission=push repos/COGS108/Group011Sp22/collaborators/ScottAndrews40 0
# gh api -X PUT -f permission=push repos/COGS108/Group011Sp22/collaborators/s8cho 0
# gh repo clone COGS108/Group011Sp22 0
# cd Group011Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup011Sp22.ipynb 0
# cd Group011Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup011Sp22.ipynb 0
# cd Group011Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup011Sp22.ipynb 0
# cd Group011Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup011Sp22.ipynb 0
# cd Group011Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group011Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group011Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group012Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group012Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group012Sp22/collaborators/robyounow 0
# gh api -X PUT -f permission=push repos/COGS108/Group012Sp22/collaborators/julie-17 0
# gh api -X PUT -f permission=push repos/COGS108/Group012Sp22/collaborators/mabdilahCSE 0
# gh api -X PUT -f permission=push repos/COGS108/Group012Sp22/collaborators/fDirham 0
# gh api -X PUT -f permission=push repos/COGS108/Group012Sp22/collaborators/ecisnero 0
# gh repo clone COGS108/Group012Sp22 0
# cd Group012Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup012Sp22.ipynb 0
# cd Group012Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup012Sp22.ipynb 0
# cd Group012Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup012Sp22.ipynb 0
# cd Group012Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup012Sp22.ipynb 0
# cd Group012Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group012Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group012Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group013Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group013Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group013Sp22/collaborators/memelissa 0
# gh api -X PUT -f permission=push repos/COGS108/Group013Sp22/collaborators/xtrasee 0
# gh api -X PUT -f permission=push repos/COGS108/Group013Sp22/collaborators/anguyen698 0
# gh api -X PUT -f permission=push repos/COGS108/Group013Sp22/collaborators/addatta10 0
# gh repo clone COGS108/Group013Sp22 0
# cd Group013Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup013Sp22.ipynb 0
# cd Group013Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup013Sp22.ipynb 0
# cd Group013Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup013Sp22.ipynb 0
# cd Group013Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup013Sp22.ipynb 0
# cd Group013Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group013Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group013Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group014Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group014Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group014Sp22/collaborators/Jameschen7 0
# gh api -X PUT -f permission=push repos/COGS108/Group014Sp22/collaborators/kchen283 0
# gh api -X PUT -f permission=push repos/COGS108/Group014Sp22/collaborators/EternalSnowman 0
# gh api -X PUT -f permission=push repos/COGS108/Group014Sp22/collaborators/christine-deng 0
# gh repo clone COGS108/Group014Sp22 0
# cd Group014Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup014Sp22.ipynb 0
# cd Group014Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup014Sp22.ipynb 0
# cd Group014Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup014Sp22.ipynb 0
# cd Group014Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup014Sp22.ipynb 0
# cd Group014Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group014Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group014Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group015Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group015Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group015Sp22/collaborators/acordjared 0
# gh api -X PUT -f permission=push repos/COGS108/Group015Sp22/collaborators/Wei-Ji-Chen 0
# gh api -X PUT -f permission=push repos/COGS108/Group015Sp22/collaborators/dk2684 0
# gh api -X PUT -f permission=push repos/COGS108/Group015Sp22/collaborators/moahmed5 0
# gh api -X PUT -f permission=push repos/COGS108/Group015Sp22/collaborators/Hunter27E 0
# gh repo clone COGS108/Group015Sp22 0
# cd Group015Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup015Sp22.ipynb 0
# cd Group015Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup015Sp22.ipynb 0
# cd Group015Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup015Sp22.ipynb 0
# cd Group015Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup015Sp22.ipynb 0
# cd Group015Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group015Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group015Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group016Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group016Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group016Sp22/collaborators/junzhh 0
# gh api -X PUT -f permission=push repos/COGS108/Group016Sp22/collaborators/robertzhang0531 0
# gh api -X PUT -f permission=push repos/COGS108/Group016Sp22/collaborators/Zhfang01 0
# gh repo clone COGS108/Group016Sp22 0
# cd Group016Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup016Sp22.ipynb 0
# cd Group016Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup016Sp22.ipynb 0
# cd Group016Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup016Sp22.ipynb 0
# cd Group016Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup016Sp22.ipynb 0
# cd Group016Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group016Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group016Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group017Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group017Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group017Sp22/collaborators/tintrungp 0
# gh api -X PUT -f permission=push repos/COGS108/Group017Sp22/collaborators/brianchen3970 0
# gh api -X PUT -f permission=push repos/COGS108/Group017Sp22/collaborators/z4fang 0
# gh api -X PUT -f permission=push repos/COGS108/Group017Sp22/collaborators/nilou-sh 0
# gh api -X PUT -f permission=push repos/COGS108/Group017Sp22/collaborators/lleoys 0
# gh repo clone COGS108/Group017Sp22 0
# cd Group017Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup017Sp22.ipynb 0
# cd Group017Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup017Sp22.ipynb 0
# cd Group017Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup017Sp22.ipynb 0
# cd Group017Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup017Sp22.ipynb 0
# cd Group017Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group017Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group017Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group018Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group018Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group018Sp22/collaborators/brendon3tang 0
# gh api -X PUT -f permission=push repos/COGS108/Group018Sp22/collaborators/Yaofeng-Hugo-Huang 0
# gh api -X PUT -f permission=push repos/COGS108/Group018Sp22/collaborators/DPKubeck 0
# gh api -X PUT -f permission=push repos/COGS108/Group018Sp22/collaborators/lucasbajoua 0
# gh api -X PUT -f permission=push repos/COGS108/Group018Sp22/collaborators/Agreene-08 0
# gh repo clone COGS108/Group018Sp22 0
# cd Group018Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup018Sp22.ipynb 0
# cd Group018Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup018Sp22.ipynb 0
# cd Group018Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup018Sp22.ipynb 0
# cd Group018Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup018Sp22.ipynb 0
# cd Group018Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group018Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group018Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group019Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group019Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group019Sp22/collaborators/gabriel-diaz-ucsd 0
# gh api -X PUT -f permission=push repos/COGS108/Group019Sp22/collaborators/t2wang 0
# gh api -X PUT -f permission=push repos/COGS108/Group019Sp22/collaborators/sbsx 0
# gh api -X PUT -f permission=push repos/COGS108/Group019Sp22/collaborators/SNHorne 0
# gh repo clone COGS108/Group019Sp22 0
# cd Group019Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup019Sp22.ipynb 0
# cd Group019Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup019Sp22.ipynb 0
# cd Group019Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup019Sp22.ipynb 0
# cd Group019Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup019Sp22.ipynb 0
# cd Group019Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group019Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group019Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group020Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group020Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group020Sp22/collaborators/jasonnsen 0
# gh api -X PUT -f permission=push repos/COGS108/Group020Sp22/collaborators/pdvincentlin 0
# gh api -X PUT -f permission=push repos/COGS108/Group020Sp22/collaborators/zibingao 0
# gh api -X PUT -f permission=push repos/COGS108/Group020Sp22/collaborators/fangaomingyu 0
# gh api -X PUT -f permission=push repos/COGS108/Group020Sp22/collaborators/AidenHuang01 0
# gh repo clone COGS108/Group020Sp22 0
# cd Group020Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup020Sp22.ipynb 0
# cd Group020Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup020Sp22.ipynb 0
# cd Group020Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup020Sp22.ipynb 0
# cd Group020Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup020Sp22.ipynb 0
# cd Group020Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group020Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group020Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group021Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group021Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group021Sp22/collaborators/rravi3 0
# gh api -X PUT -f permission=push repos/COGS108/Group021Sp22/collaborators/EHERN920 0
# gh api -X PUT -f permission=push repos/COGS108/Group021Sp22/collaborators/J-Singletary 0
# gh api -X PUT -f permission=push repos/COGS108/Group021Sp22/collaborators/cecilia-martinez 0
# gh api -X PUT -f permission=push repos/COGS108/Group021Sp22/collaborators/Promiit 0
# gh repo clone COGS108/Group021Sp22 0
# cd Group021Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup021Sp22.ipynb 0
# cd Group021Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup021Sp22.ipynb 0
# cd Group021Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup021Sp22.ipynb 0
# cd Group021Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup021Sp22.ipynb 0
# cd Group021Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group021Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group021Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group022Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group022Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group022Sp22/collaborators/AnyaBoo 0
# gh api -X PUT -f permission=push repos/COGS108/Group022Sp22/collaborators/xrsAlveus 0
# gh api -X PUT -f permission=push repos/COGS108/Group022Sp22/collaborators/dxn-sh 0
# gh api -X PUT -f permission=push repos/COGS108/Group022Sp22/collaborators/jiliana 0
# gh api -X PUT -f permission=push repos/COGS108/Group022Sp22/collaborators/YoyoMan0414 0
# gh repo clone COGS108/Group022Sp22 0
# cd Group022Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup022Sp22.ipynb 0
# cd Group022Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup022Sp22.ipynb 0
# cd Group022Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup022Sp22.ipynb 0
# cd Group022Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup022Sp22.ipynb 0
# cd Group022Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group022Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group022Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group023Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group023Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group023Sp22/collaborators/rthavixay23 0
# gh api -X PUT -f permission=push repos/COGS108/Group023Sp22/collaborators/stma733 0
# gh api -X PUT -f permission=push repos/COGS108/Group023Sp22/collaborators/akira731 0
# gh api -X PUT -f permission=push repos/COGS108/Group023Sp22/collaborators/Bootpocalypse 0
# gh api -X PUT -f permission=push repos/COGS108/Group023Sp22/collaborators/CielJiao 0
# gh repo clone COGS108/Group023Sp22 0
# cd Group023Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup023Sp22.ipynb 0
# cd Group023Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup023Sp22.ipynb 0
# cd Group023Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup023Sp22.ipynb 0
# cd Group023Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup023Sp22.ipynb 0
# cd Group023Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group023Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group023Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group024Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group024Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group024Sp22/collaborators/Ghghtr7845 0
# gh api -X PUT -f permission=push repos/COGS108/Group024Sp22/collaborators/- 0
# gh api -X PUT -f permission=push repos/COGS108/Group024Sp22/collaborators/SharozJavaid 0
# gh api -X PUT -f permission=push repos/COGS108/Group024Sp22/collaborators/471289795 0
# gh api -X PUT -f permission=push repos/COGS108/Group024Sp22/collaborators/Toggers 0
# gh repo clone COGS108/Group024Sp22 0
# cd Group024Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup024Sp22.ipynb 0
# cd Group024Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup024Sp22.ipynb 0
# cd Group024Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup024Sp22.ipynb 0
# cd Group024Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup024Sp22.ipynb 0
# cd Group024Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group024Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group024Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group025Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group025Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group025Sp22/collaborators/rwanger 0
# gh api -X PUT -f permission=push repos/COGS108/Group025Sp22/collaborators/ericwang2001-ucsd 0
# gh api -X PUT -f permission=push repos/COGS108/Group025Sp22/collaborators/roseybugayon 0
# gh api -X PUT -f permission=push repos/COGS108/Group025Sp22/collaborators/Hanyi27 0
# gh api -X PUT -f permission=push repos/COGS108/Group025Sp22/collaborators/christofkopera 0
# gh repo clone COGS108/Group025Sp22 0
# cd Group025Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup025Sp22.ipynb 0
# cd Group025Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup025Sp22.ipynb 0
# cd Group025Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup025Sp22.ipynb 0
# cd Group025Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup025Sp22.ipynb 0
# cd Group025Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group025Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group025Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group026Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group026Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group026Sp22/collaborators/zichunhao 0
# gh api -X PUT -f permission=push repos/COGS108/Group026Sp22/collaborators/z8jiang 0
# gh api -X PUT -f permission=push repos/COGS108/Group026Sp22/collaborators/AimerMizuki 0
# gh api -X PUT -f permission=push repos/COGS108/Group026Sp22/collaborators/oscarmtz1 0
# gh repo clone COGS108/Group026Sp22 0
# cd Group026Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup026Sp22.ipynb 0
# cd Group026Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup026Sp22.ipynb 0
# cd Group026Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup026Sp22.ipynb 0
# cd Group026Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup026Sp22.ipynb 0
# cd Group026Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group026Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group026Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group027Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group027Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group027Sp22/collaborators/advikpassi 0
# gh api -X PUT -f permission=push repos/COGS108/Group027Sp22/collaborators/binhut2001 0
# gh api -X PUT -f permission=push repos/COGS108/Group027Sp22/collaborators/DonaldWolfson 0
# gh api -X PUT -f permission=push repos/COGS108/Group027Sp22/collaborators/lancecasiple 0
# gh api -X PUT -f permission=push repos/COGS108/Group027Sp22/collaborators/ckckcake 0
# gh repo clone COGS108/Group027Sp22 0
# cd Group027Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup027Sp22.ipynb 0
# cd Group027Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup027Sp22.ipynb 0
# cd Group027Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup027Sp22.ipynb 0
# cd Group027Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup027Sp22.ipynb 0
# cd Group027Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group027Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group027Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group028Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group028Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group028Sp22/collaborators/mf02511 0
# gh api -X PUT -f permission=push repos/COGS108/Group028Sp22/collaborators/royli8 0
# gh api -X PUT -f permission=push repos/COGS108/Group028Sp22/collaborators/anm004 0
# gh api -X PUT -f permission=push repos/COGS108/Group028Sp22/collaborators/- 0
# gh api -X PUT -f permission=push repos/COGS108/Group028Sp22/collaborators/bl3am 0
# gh repo clone COGS108/Group028Sp22 0
# cd Group028Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup028Sp22.ipynb 0
# cd Group028Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup028Sp22.ipynb 0
# cd Group028Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup028Sp22.ipynb 0
# cd Group028Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup028Sp22.ipynb 0
# cd Group028Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group028Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group028Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group029Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group029Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group029Sp22/collaborators/TianGao0123 0
# gh api -X PUT -f permission=push repos/COGS108/Group029Sp22/collaborators/yifeiye 0
# gh api -X PUT -f permission=push repos/COGS108/Group029Sp22/collaborators/Fruitcoco 0
# gh api -X PUT -f permission=push repos/COGS108/Group029Sp22/collaborators/Winnie1711 0
# gh api -X PUT -f permission=push repos/COGS108/Group029Sp22/collaborators/AnniLi1212 0
# gh repo clone COGS108/Group029Sp22 0
# cd Group029Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup029Sp22.ipynb 0
# cd Group029Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup029Sp22.ipynb 0
# cd Group029Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup029Sp22.ipynb 0
# cd Group029Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup029Sp22.ipynb 0
# cd Group029Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group029Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group029Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group030Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group030Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group030Sp22/collaborators/yujiezhang0914 0
# gh api -X PUT -f permission=push repos/COGS108/Group030Sp22/collaborators/zhw005 0
# gh api -X PUT -f permission=push repos/COGS108/Group030Sp22/collaborators/CDavid99 0
# gh api -X PUT -f permission=push repos/COGS108/Group030Sp22/collaborators/Joejo-e 0
# gh api -X PUT -f permission=push repos/COGS108/Group030Sp22/collaborators/ZiqiuLiCLSL 0
# gh repo clone COGS108/Group030Sp22 0
# cd Group030Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup030Sp22.ipynb 0
# cd Group030Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup030Sp22.ipynb 0
# cd Group030Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup030Sp22.ipynb 0
# cd Group030Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup030Sp22.ipynb 0
# cd Group030Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group030Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group030Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group031Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group031Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group031Sp22/collaborators/stephanienguyen2002 0
# gh api -X PUT -f permission=push repos/COGS108/Group031Sp22/collaborators/tonynguyen2001 0
# gh api -X PUT -f permission=push repos/COGS108/Group031Sp22/collaborators/Dltduong 0
# gh api -X PUT -f permission=push repos/COGS108/Group031Sp22/collaborators/Fy50167 0
# gh api -X PUT -f permission=push repos/COGS108/Group031Sp22/collaborators/daniellin162 0
# gh repo clone COGS108/Group031Sp22 0
# cd Group031Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup031Sp22.ipynb 0
# cd Group031Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup031Sp22.ipynb 0
# cd Group031Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup031Sp22.ipynb 0
# cd Group031Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup031Sp22.ipynb 0
# cd Group031Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group031Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group031Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group032Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group032Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group032Sp22/collaborators/kchiferson 0
# gh api -X PUT -f permission=push repos/COGS108/Group032Sp22/collaborators/SnowySG 0
# gh api -X PUT -f permission=push repos/COGS108/Group032Sp22/collaborators/JoshDreben 0
# gh api -X PUT -f permission=push repos/COGS108/Group032Sp22/collaborators/PitEG 0
# gh api -X PUT -f permission=push repos/COGS108/Group032Sp22/collaborators/jzql 0
# gh repo clone COGS108/Group032Sp22 0
# cd Group032Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup032Sp22.ipynb 0
# cd Group032Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup032Sp22.ipynb 0
# cd Group032Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup032Sp22.ipynb 0
# cd Group032Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup032Sp22.ipynb 0
# cd Group032Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group032Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group032Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group033Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group033Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group033Sp22/collaborators/zzyzsy0516321 0
# gh api -X PUT -f permission=push repos/COGS108/Group033Sp22/collaborators/wgyyy 0
# gh api -X PUT -f permission=push repos/COGS108/Group033Sp22/collaborators/yil011 0
# gh api -X PUT -f permission=push repos/COGS108/Group033Sp22/collaborators/elaine-123 0
# gh api -X PUT -f permission=push repos/COGS108/Group033Sp22/collaborators/juxx8 0
# gh repo clone COGS108/Group033Sp22 0
# cd Group033Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup033Sp22.ipynb 0
# cd Group033Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup033Sp22.ipynb 0
# cd Group033Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup033Sp22.ipynb 0
# cd Group033Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup033Sp22.ipynb 0
# cd Group033Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group033Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group033Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group034Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group034Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group034Sp22/collaborators/matthewleffler1 0
# gh api -X PUT -f permission=push repos/COGS108/Group034Sp22/collaborators/cdonasco 0
# gh api -X PUT -f permission=push repos/COGS108/Group034Sp22/collaborators/donaldsonm 0
# gh api -X PUT -f permission=push repos/COGS108/Group034Sp22/collaborators/cairosimpson 0
# gh api -X PUT -f permission=push repos/COGS108/Group034Sp22/collaborators/m2liu 0
# gh repo clone COGS108/Group034Sp22 0
# cd Group034Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup034Sp22.ipynb 0
# cd Group034Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup034Sp22.ipynb 0
# cd Group034Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup034Sp22.ipynb 0
# cd Group034Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup034Sp22.ipynb 0
# cd Group034Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group034Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group034Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group035Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group035Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group035Sp22/collaborators/YijieRuan 0
# gh api -X PUT -f permission=push repos/COGS108/Group035Sp22/collaborators/RLinter 0
# gh api -X PUT -f permission=push repos/COGS108/Group035Sp22/collaborators/ashk233 0
# gh api -X PUT -f permission=push repos/COGS108/Group035Sp22/collaborators/byh0926 0
# gh api -X PUT -f permission=push repos/COGS108/Group035Sp22/collaborators/syueo 0
# gh repo clone COGS108/Group035Sp22 0
# cd Group035Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup035Sp22.ipynb 0
# cd Group035Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup035Sp22.ipynb 0
# cd Group035Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup035Sp22.ipynb 0
# cd Group035Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup035Sp22.ipynb 0
# cd Group035Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group035Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group035Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group036Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group036Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group036Sp22/collaborators/monavi25 0
# gh api -X PUT -f permission=push repos/COGS108/Group036Sp22/collaborators/alw002 0
# gh api -X PUT -f permission=push repos/COGS108/Group036Sp22/collaborators/z4lu 0
# gh api -X PUT -f permission=push repos/COGS108/Group036Sp22/collaborators/nickyla2 0
# gh repo clone COGS108/Group036Sp22 0
# cd Group036Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup036Sp22.ipynb 0
# cd Group036Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup036Sp22.ipynb 0
# cd Group036Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup036Sp22.ipynb 0
# cd Group036Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup036Sp22.ipynb 0
# cd Group036Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group036Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group036Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group037Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group037Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group037Sp22/collaborators/EvelyneAvila 0
# gh api -X PUT -f permission=push repos/COGS108/Group037Sp22/collaborators/WengShihong 0
# gh api -X PUT -f permission=push repos/COGS108/Group037Sp22/collaborators/SamPerezC 0
# gh api -X PUT -f permission=push repos/COGS108/Group037Sp22/collaborators/menguras 0
# gh api -X PUT -f permission=push repos/COGS108/Group037Sp22/collaborators/rloeza 0
# gh repo clone COGS108/Group037Sp22 0
# cd Group037Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup037Sp22.ipynb 0
# cd Group037Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup037Sp22.ipynb 0
# cd Group037Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup037Sp22.ipynb 0
# cd Group037Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup037Sp22.ipynb 0
# cd Group037Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group037Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group037Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group038Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group038Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group038Sp22/collaborators/starhseki 0
# gh api -X PUT -f permission=push repos/COGS108/Group038Sp22/collaborators/jokamur 0
# gh api -X PUT -f permission=push repos/COGS108/Group038Sp22/collaborators/djleung 0
# gh api -X PUT -f permission=push repos/COGS108/Group038Sp22/collaborators/DivusDev 0
# gh api -X PUT -f permission=push repos/COGS108/Group038Sp22/collaborators/dnlopez1 0
# gh repo clone COGS108/Group038Sp22 0
# cd Group038Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup038Sp22.ipynb 0
# cd Group038Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup038Sp22.ipynb 0
# cd Group038Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup038Sp22.ipynb 0
# cd Group038Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup038Sp22.ipynb 0
# cd Group038Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group038Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group038Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group039Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group039Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group039Sp22/collaborators/claudiaxie 0
# gh api -X PUT -f permission=push repos/COGS108/Group039Sp22/collaborators/Jvaldez023 0
# gh api -X PUT -f permission=push repos/COGS108/Group039Sp22/collaborators/abbydom 0
# gh api -X PUT -f permission=push repos/COGS108/Group039Sp22/collaborators/kevinyluo 0
# gh repo clone COGS108/Group039Sp22 0
# cd Group039Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup039Sp22.ipynb 0
# cd Group039Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup039Sp22.ipynb 0
# cd Group039Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup039Sp22.ipynb 0
# cd Group039Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup039Sp22.ipynb 0
# cd Group039Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group039Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group039Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group040Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group040Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group040Sp22/collaborators/ahujar27 0
# gh api -X PUT -f permission=push repos/COGS108/Group040Sp22/collaborators/dtorvi 0
# gh api -X PUT -f permission=push repos/COGS108/Group040Sp22/collaborators/UCSDTOMPHAMDINH 0
# gh api -X PUT -f permission=push repos/COGS108/Group040Sp22/collaborators/bvvu 0
# gh api -X PUT -f permission=push repos/COGS108/Group040Sp22/collaborators/mapauline 0
# gh repo clone COGS108/Group040Sp22 0
# cd Group040Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup040Sp22.ipynb 0
# cd Group040Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup040Sp22.ipynb 0
# cd Group040Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup040Sp22.ipynb 0
# cd Group040Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup040Sp22.ipynb 0
# cd Group040Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group040Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group040Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group041Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group041Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group041Sp22/collaborators/shreekarp 0
# gh api -X PUT -f permission=push repos/COGS108/Group041Sp22/collaborators/rachelblumin 0
# ...
# gh api -X PUT -f permission=push repos/COGS108/Group079Sp22/collaborators/amelia-kawasaki 0
# gh api -X PUT -f permission=push repos/COGS108/Group079Sp22/collaborators/theting641 0
# gh repo clone COGS108/Group079Sp22 0
# cd Group079Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup079Sp22.ipynb 0
# cd Group079Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup079Sp22.ipynb 0
# cd Group079Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup079Sp22.ipynb 0
# cd Group079Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup079Sp22.ipynb 0
# cd Group079Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group079Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group079Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group080Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group080Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group080Sp22/collaborators/C-Asif 0
# gh api -X PUT -f permission=push repos/COGS108/Group080Sp22/collaborators/erick-gulyan 0
# gh api -X PUT -f permission=push repos/COGS108/Group080Sp22/collaborators/kinana52 0
# gh api -X PUT -f permission=push repos/COGS108/Group080Sp22/collaborators/iKollektor 0
# gh repo clone COGS108/Group080Sp22 0
# cd Group080Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup080Sp22.ipynb 0
# cd Group080Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup080Sp22.ipynb 0
# cd Group080Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup080Sp22.ipynb 0
# cd Group080Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup080Sp22.ipynb 0
# cd Group080Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group080Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group080Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group081Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group081Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group081Sp22/collaborators/AnmolS1 0
# gh api -X PUT -f permission=push repos/COGS108/Group081Sp22/collaborators/pmoreno629 0
# gh api -X PUT -f permission=push repos/COGS108/Group081Sp22/collaborators/wltmd153 0
# gh api -X PUT -f permission=push repos/COGS108/Group081Sp22/collaborators/h2duong 0
# gh api -X PUT -f permission=push repos/COGS108/Group081Sp22/collaborators/bvegaloj 0
# gh repo clone COGS108/Group081Sp22 0
# cd Group081Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup081Sp22.ipynb 0
# cd Group081Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup081Sp22.ipynb 0
# cd Group081Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup081Sp22.ipynb 0
# cd Group081Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup081Sp22.ipynb 0
# cd Group081Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group081Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group081Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group082Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group082Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group082Sp22/collaborators/BellaBao1111 0
# gh api -X PUT -f permission=push repos/COGS108/Group082Sp22/collaborators/YUXUAN0118 0
# gh api -X PUT -f permission=push repos/COGS108/Group082Sp22/collaborators/JingtianMa 0
# gh api -X PUT -f permission=push repos/COGS108/Group082Sp22/collaborators/zterryy 0
# gh api -X PUT -f permission=push repos/COGS108/Group082Sp22/collaborators/xiw013 0
# gh repo clone COGS108/Group082Sp22 0
# cd Group082Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup082Sp22.ipynb 0
# cd Group082Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup082Sp22.ipynb 0
# cd Group082Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup082Sp22.ipynb 0
# cd Group082Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup082Sp22.ipynb 0
# cd Group082Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group082Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group082Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group083Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group083Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group083Sp22/collaborators/Stevela-hn 0
# gh api -X PUT -f permission=push repos/COGS108/Group083Sp22/collaborators/AlbertKong0827 0
# gh api -X PUT -f permission=push repos/COGS108/Group083Sp22/collaborators/qgong13 0
# gh api -X PUT -f permission=push repos/COGS108/Group083Sp22/collaborators/AlexYu-009 0
# gh api -X PUT -f permission=push repos/COGS108/Group083Sp22/collaborators/cathyw36 0
# gh repo clone COGS108/Group083Sp22 0
# cd Group083Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup083Sp22.ipynb 0
# cd Group083Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup083Sp22.ipynb 0
# cd Group083Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup083Sp22.ipynb 0
# cd Group083Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup083Sp22.ipynb 0
# cd Group083Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group083Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group083Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group084Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group084Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group084Sp22/collaborators/B-Koh 0
# gh api -X PUT -f permission=push repos/COGS108/Group084Sp22/collaborators/JerryYC 0
# gh api -X PUT -f permission=push repos/COGS108/Group084Sp22/collaborators/ann043 0
# gh api -X PUT -f permission=push repos/COGS108/Group084Sp22/collaborators/angrybeanz 0
# gh api -X PUT -f permission=push repos/COGS108/Group084Sp22/collaborators/nwong419 0
# gh repo clone COGS108/Group084Sp22 0
# cd Group084Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup084Sp22.ipynb 0
# cd Group084Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup084Sp22.ipynb 0
# cd Group084Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup084Sp22.ipynb 0
# cd Group084Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup084Sp22.ipynb 0
# cd Group084Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group084Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group084Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group085Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group085Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group085Sp22/collaborators/erc003 0
# gh api -X PUT -f permission=push repos/COGS108/Group085Sp22/collaborators/kevinchang1125 0
# gh api -X PUT -f permission=push repos/COGS108/Group085Sp22/collaborators/v2tu 0
# gh api -X PUT -f permission=push repos/COGS108/Group085Sp22/collaborators/janet-wong 0
# gh api -X PUT -f permission=push repos/COGS108/Group085Sp22/collaborators/OptimizeZ 0
# gh repo clone COGS108/Group085Sp22 0
# cd Group085Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup085Sp22.ipynb 0
# cd Group085Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup085Sp22.ipynb 0
# cd Group085Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup085Sp22.ipynb 0
# cd Group085Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup085Sp22.ipynb 0
# cd Group085Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group085Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group085Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group086Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group086Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group086Sp22/collaborators/YunxiangChi 0
# gh api -X PUT -f permission=push repos/COGS108/Group086Sp22/collaborators/Stefan2Ni 0
# gh api -X PUT -f permission=push repos/COGS108/Group086Sp22/collaborators/ZiyanLouis 0
# gh api -X PUT -f permission=push repos/COGS108/Group086Sp22/collaborators/Andrina-iris 0
# gh api -X PUT -f permission=push repos/COGS108/Group086Sp22/collaborators/PatriciaWuu 0
# gh repo clone COGS108/Group086Sp22 0
# cd Group086Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup086Sp22.ipynb 0
# cd Group086Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup086Sp22.ipynb 0
# cd Group086Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup086Sp22.ipynb 0
# cd Group086Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup086Sp22.ipynb 0
# cd Group086Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group086Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group086Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group087Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group087Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group087Sp22/collaborators/joceh 0
# gh api -X PUT -f permission=push repos/COGS108/Group087Sp22/collaborators/viliang 0
# gh api -X PUT -f permission=push repos/COGS108/Group087Sp22/collaborators/rinakaura 0
# gh api -X PUT -f permission=push repos/COGS108/Group087Sp22/collaborators/nmatute 0
# gh api -X PUT -f permission=push repos/COGS108/Group087Sp22/collaborators/brian-x86 0
# gh repo clone COGS108/Group087Sp22 0
# cd Group087Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup087Sp22.ipynb 0
# cd Group087Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup087Sp22.ipynb 0
# cd Group087Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup087Sp22.ipynb 0
# cd Group087Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup087Sp22.ipynb 0
# cd Group087Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group087Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group087Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group088Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group088Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group088Sp22/collaborators/LangrunZhu 0
# gh api -X PUT -f permission=push repos/COGS108/Group088Sp22/collaborators/gelaneier 0
# gh api -X PUT -f permission=push repos/COGS108/Group088Sp22/collaborators/Cyl200215 0
# gh api -X PUT -f permission=push repos/COGS108/Group088Sp22/collaborators/YifanLiuDolores 0
# gh api -X PUT -f permission=push repos/COGS108/Group088Sp22/collaborators/Hay-Harry 0
# gh repo clone COGS108/Group088Sp22 0
# cd Group088Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup088Sp22.ipynb 0
# cd Group088Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup088Sp22.ipynb 0
# cd Group088Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup088Sp22.ipynb 0
# cd Group088Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup088Sp22.ipynb 0
# cd Group088Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group088Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group088Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group089Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group089Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group089Sp22/collaborators/girishsenthil 0
# gh api -X PUT -f permission=push repos/COGS108/Group089Sp22/collaborators/OrigamiMM 0
# gh api -X PUT -f permission=push repos/COGS108/Group089Sp22/collaborators/KurtisMa 0
# gh api -X PUT -f permission=push repos/COGS108/Group089Sp22/collaborators/amys8 0
# gh repo clone COGS108/Group089Sp22 0
# cd Group089Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup089Sp22.ipynb 0
# cd Group089Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup089Sp22.ipynb 0
# cd Group089Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup089Sp22.ipynb 0
# cd Group089Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup089Sp22.ipynb 0
# cd Group089Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group089Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group089Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group090Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group090Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group090Sp22/collaborators/sumiahali 0
# gh api -X PUT -f permission=push repos/COGS108/Group090Sp22/collaborators/brookebyron 0
# gh api -X PUT -f permission=push repos/COGS108/Group090Sp22/collaborators/jik003 0
# gh api -X PUT -f permission=push repos/COGS108/Group090Sp22/collaborators/jciil 0
# gh api -X PUT -f permission=push repos/COGS108/Group090Sp22/collaborators/ichinucsd 0
# gh repo clone COGS108/Group090Sp22 0
# cd Group090Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup090Sp22.ipynb 0
# cd Group090Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup090Sp22.ipynb 0
# cd Group090Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup090Sp22.ipynb 0
# cd Group090Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup090Sp22.ipynb 0
# cd Group090Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group090Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group090Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group091Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group091Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group091Sp22/collaborators/vinhimself 0
# gh api -X PUT -f permission=push repos/COGS108/Group091Sp22/collaborators/sbargotra 0
# gh api -X PUT -f permission=push repos/COGS108/Group091Sp22/collaborators/Jordanmora 0
# gh api -X PUT -f permission=push repos/COGS108/Group091Sp22/collaborators/dtuankun 0
# gh api -X PUT -f permission=push repos/COGS108/Group091Sp22/collaborators/AdazCog 0
# gh repo clone COGS108/Group091Sp22 0
# cd Group091Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup091Sp22.ipynb 0
# cd Group091Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup091Sp22.ipynb 0
# cd Group091Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup091Sp22.ipynb 0
# cd Group091Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup091Sp22.ipynb 0
# cd Group091Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group091Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group091Sp22 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group092Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group092Sp22 0
# gh api -X PUT -f permission=push repos/COGS108/Group092Sp22/collaborators/z3nnnn 0
# gh api -X PUT -f permission=push repos/COGS108/Group092Sp22/collaborators/aaolivas 0
# gh api -X PUT -f permission=push repos/COGS108/Group092Sp22/collaborators/CGuanji 0
# gh api -X PUT -f permission=push repos/COGS108/Group092Sp22/collaborators/occastro 0
# gh api -X PUT -f permission=push repos/COGS108/Group092Sp22/collaborators/ashleyyshen 0
# gh repo clone COGS108/Group092Sp22 0
# cd Group092Sp22; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup092Sp22.ipynb 0
# cd Group092Sp22; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup092Sp22.ipynb 0
# cd Group092Sp22; git mv FinalProject_groupXXX.ipynb FinalProjectGroup092Sp22.ipynb 0
# cd Group092Sp22; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup092Sp22.ipynb 0
# cd Group092Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group092Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS108/teams/Staff_Sp22/repos/COGS108/Group092Sp22 0
