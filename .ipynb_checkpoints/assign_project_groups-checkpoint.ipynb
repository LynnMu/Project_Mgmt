# %%
import pandas as pd

def flatten(t):
    return [item for sublist in t for item in sublist]

# %% [markdown]
# ### Load up the students
# Go to Canvas and export the gradesheet. This gives us a list of current students. Place the file in this directory and change the read_csv() below to load up the proper file.

# %%
df = pd.read_csv('2023-02-14T1449_Grades-COGS118A_WI23_A00.csv')
df
# Out:
#                  Student        ID SIS User ID  \
# 0        Points Possible       NaN         NaN
# 1         Acevedo, Jorge   67792.0   A15834274
# 2            Ahmed, Zaki  107120.0   A16671152
# 3           Ahuja, Rohil   65261.0   A16041299
# 4        Aldama, Antonio   42637.0   A15780834
# ..                   ...       ...         ...
# 183         Zhong, Wenyu  141080.0   A17169057
# 184      Zhou, Zhengyuan   65764.0   A16146369
# 185         Zhou, Zhetai    8482.0   A15428825
# 186           Zou, Ellie  129572.0   A17117056
# 187        Student, Test  182619.0         NaN
#
#                                  SIS Login ID  \
# 0                                         NaN
# 1                                    jacevedo
# 2                                      zahmed
# 3                                     rhahuja
# 4                                    aaaldama
# ..                                        ...
# 183                                   w1zhong
# 184                                     zzhou
# 185                                    z2zhou
# 186                                     w3zou
# 187  5d94964267f45488210448b710ff9b1b3ccae838
#
#                                                Section  D1 (599822)  \
# 0                                                  NaN          2.0
# 1                             COGS 118A - A04 [115290]          2.0
# 2                             COGS 118A - A01 [115287]          2.0
# 3                             COGS 118A - A02 [115288]          1.9
# 4                             COGS 118A - A02 [115288]          2.0
# ..                                                 ...          ...
# 183                           COGS 118A - A03 [115289]          1.8
# 184                           COGS 118A - A02 [115288]          2.0
# 185                           COGS 118A - A03 [115289]          2.0
# 186                           COGS 118A - A03 [115289]          2.0
# 187  COGS 118A - A01 [115287], COGS 118A - A02 [115...          NaN
#
#      A2 (600095)  A3 (602507)  D2 (601956)  D3 (601957)  ...  Current Points  \
# 0            2.0          2.0          2.0          2.0  ...     (read only)
# 1            NaN          NaN          2.0          NaN  ...            5.80
# 2            NaN          NaN          2.0          NaN  ...            6.91
# 3            NaN          NaN          2.0          NaN  ...            7.02
# 4            NaN          NaN          2.0          NaN  ...            5.80
# ..           ...          ...          ...          ...  ...             ...
# 183          NaN          NaN          1.7          NaN  ...            3.05
# 184          NaN          NaN          2.0          NaN  ...            6.95
# 185          NaN          NaN          1.7          NaN  ...            5.15
# 186          NaN          NaN          1.7          NaN  ...            5.50
# 187          NaN          NaN          NaN          NaN  ...            0.00
#
#      Final Points  Current Score  Unposted Current Score  Final Score  \
# 0     (read only)    (read only)             (read only)  (read only)
# 1            7.46         114.85                  114.85        44.54
# 2            7.13         111.45                  111.45        42.57
# 3            7.18         108.84                  108.84        42.87
# 4            7.40         114.85                  114.85        44.18
# ..            ...            ...                     ...          ...
# 183          4.75         122.00                  122.00        28.36
# 184          7.25         112.10                  112.10        43.28
# 185          6.85         108.42                  108.42        40.90
# 186          7.20         115.79                  115.79        42.99
# 187          0.00            NaN                     NaN         0.00
#
#      Unposted Final Score  Current Grade  Unposted Current Grade  Final Grade  \
# 0             (read only)    (read only)             (read only)  (read only)
# 1                   44.54             A+                      A+            F
# 2                   42.57             A+                      A+            F
# 3                   42.87             A+                      A+            F
# 4                   44.18             A+                      A+            F
# ..                    ...            ...                     ...          ...
# 183                 28.36             A+                      A+            F
# 184                 43.28             A+                      A+            F
# 185                 40.90             A+                      A+            F
# 186                 42.99             A+                      A+            F
# 187                  0.00            NaN                     NaN            F
#
#     Unposted Final Grade
# 0            (read only)
# 1                      F
# 2                      F
# 3                      F
# 4                      F
# ..                   ...
# 183                    F
# 184                    F
# 185                    F
# 186                    F
# 187                    F
#
# [188 rows x 52 columns]

# %%
# this is what we are going to drop
df[ df[['Student','SIS User ID','SIS Login ID']].isna().any(axis=1) ]
# Out:
#                  Student        ID SIS User ID  \
# 0        Points Possible       NaN         NaN
# 187        Student, Test  182619.0         NaN
#
#                                  SIS Login ID  \
# 0                                         NaN
# 187  5d94964267f45488210448b710ff9b1b3ccae838
#
#                                                Section  D1 (599822)  \
# 0                                                  NaN          2.0
# 187  COGS 118A - A01 [115287], COGS 118A - A02 [115...          NaN
#
#      A2 (600095)  A3 (602507)  D2 (601956)  D3 (601957)  ...  Current Points  \
# 0            2.0          2.0          2.0          2.0  ...     (read only)
# 187          NaN          NaN          NaN          NaN  ...            0.00
#
#      Final Points  Current Score  Unposted Current Score  Final Score  \
# 0     (read only)    (read only)             (read only)  (read only)
# 187          0.00            NaN                     NaN         0.00
#
#      Unposted Final Score  Current Grade  Unposted Current Grade  Final Grade  \
# 0             (read only)    (read only)             (read only)  (read only)
# 187                  0.00            NaN                     NaN            F
#
#     Unposted Final Grade
# 0            (read only)
# 187                    F
#
# [2 rows x 52 columns]

# %%
enrolled_students = df.drop([0,187]).reset_index(drop=True)[['Student','SIS User ID','SIS Login ID']]
enrolled_students = enrolled_students.rename( {'SIS User ID':'SID', 'SIS Login ID':'email'},axis=1)
# turn last, first into first last
enrolled_students['Student'] = ( enrolled_students['Student']
                                .apply( lambda x: x.split(', ')[::-1]) # reverse order around the ,
                                .apply(lambda x: x[0]+' '+x[1]) # join with space between
                               )
enrolled_students = enrolled_students.dropna() # drop the canvas test student with NaN SID
enrolled_students = enrolled_students[ enrolled_students.Student != 'Cogs 108 Grader Account' ] # dont think this is there every quarter, this is legacy from something I did once. but it doesnt hurt to leave in
enrolled_students
# Out:
#                           Student        SID     email
# 0                   Jorge Acevedo  A15834274  jacevedo
# 1                      Zaki Ahmed  A16671152    zahmed
# 2                     Rohil Ahuja  A16041299   rhahuja
# 3                  Antonio Aldama  A15780834  aaaldama
# 4    Sebastian Algharaballi-Yanow  A16314698  salghara
# ..                            ...        ...       ...
# 181                   Simon Zheng  A16193539   sdzheng
# 182                   Wenyu Zhong  A17169057   w1zhong
# 183                Zhengyuan Zhou  A16146369     zzhou
# 184                   Zhetai Zhou  A15428825    z2zhou
# 185                     Ellie Zou  A17117056     w3zou
#
# [186 rows x 3 columns]

# %%
enrolled_students.Student.unique() # take a quick look to make sure nothing got screwed up
# Out:
# array(['Jorge Acevedo', 'Zaki Ahmed', 'Rohil Ahuja', 'Antonio Aldama',
#        'Sebastian Algharaballi-Yanow', 'Isabella Anderson',
#        'Angkitha Anguraj', 'Muhammad Arsani', 'Jacob Au', 'Darius Azure',
#        'Neil Bajaj', 'Trent Barker', 'Peter Barnett', 'Bobby Baylon',
#        'Maya Beeri-Feldman', 'Gege Bei', 'Nil Beserler', 'Tianyi Bian',
#        'Trevor Bonaiuto', 'Kyra Brandt', 'Miko Brown', 'Jay Buensuceso',
#        'Aleksandar Bumbalov', 'Niko Calsada', 'Abhinav Chandra',
#        'Abby Chang', 'Brian Chen', 'Ethan Chen', 'Haixin Chen',
#        'Jeffrey Chen', 'Joshua Chen', 'Vivian Cheung', 'Yu-Hsuan Chi',
#        'Naomi Chin', 'Sung Cho', 'Andy Chow', 'Shenova Davis',
#        'Neel Dhar', 'Dhathry Doppalapudi', 'Garrett Dungca',
#        'Grant Duntugan', 'Keate Ehrenburg', 'Cameron Faulkner',
#        'Kira Fleischer', 'Carly Freedman', 'Mizuho Fukuda',
#        'Lucas Giumarra', 'Qianxi Gong', 'Cogs 118A Grader Account',
#        'Tekin Gunasar', 'Jialong Guo', 'Himanshi Gupta',
#        'Jayson Gutierrez', 'Omri Habot', 'Nikhil Hegde',
#        'Albert Henderson', 'Tom Hocquet', 'Gyujin Hong', 'Yewon Hong',
#        'Sarah Horne', 'Ruoqian Huang', 'Irisa Jin', 'Armaan Johal',
#        'Laurensius Junaidy', 'Ryan Kabbes', 'Sarah Kagzi', 'Ryan Kan',
#        'Brandon Kao', 'Rina Kaura', 'Serina Khanna', 'Christian Kim',
#        'Joshua Kim', 'Ilya Kogan', 'Zhilin Kong', 'Adi Krishnamoorthy',
#        'Dou Kwark', 'Jacob Lamadrid', 'Chenxi Li', 'Qiqing Li',
#        'Ruoxin Li', 'Tunan Li', 'Xiang Li', 'Zecheng Li', 'Zehong Li',
#        'Sikai Liang', 'Yongxi Liang', 'Eric Lin', 'Hannah Lin',
#        'Zirui Lin', 'Evan Liu', 'George Liu', 'Jiaqi Liu', 'Andrew Lona',
#        'Zhangxiang Lu', 'Lauren Lui', 'William Lutz', 'Sidney Ma',
#        'Nathaniel Mackler', 'Masiah Manzano', 'Haokai Mao',
#        'Cecilia Martinez', 'MJ Mei', 'Jesus Mendez', 'Cray Minor',
#        'Akshat Mittal', 'Christopher Myers', 'Sujal Nahata', 'Atul Nair',
#        'Tej Nair', 'Brinda Narayanan', 'Wesley Nguyen',
#        'Brooks(Ruijia) Niu', 'Seonghun Oh', 'Sebastian Olivas Beltran',
#        'Angel Olivas', 'Kalam Park', 'Ian Pearson', 'Jessica Perez',
#        'Hieu Pham', 'Walter Qiu', 'Maya Que', 'Stephen Rabin',
#        'Sarita Raghunath', 'Nicole Rangan', 'Sean Rote',
#        'Vincent Rothenberg', 'Janet Ruiz', 'Winah Ruiz', 'Aryan Safari',
#        'Shay Samat', 'Varsha Sampath', 'Jesse Sanchez-Villegas',
#        'Pratheek Sankeshi', 'Ricardo Sedano', 'Selim Shaalan',
#        'Deepansha Singh', 'Ria Singh', 'Jared Singletary',
#        'Abdulrahman Sinjab', 'Stanley Sisson', 'Raina Song',
#        'Finn St-John', 'Kevin Su', 'Taolan Taolan', 'Jackson Teel',
#        'Xiaofei Teng', 'Aditya Tomar', 'Abraham Torok', 'Sang Tran',
#        'Anthony Truong', 'Akhil Vasanth', 'Juhita Vijjali',
#        'Andres Villegas', 'Duy Vu', 'Gaoying Wang', 'Jiawen Wang',
#        'Shiyuan Wang', 'Ziyu Wang', 'Wallace Wefel', 'Jamie Wei',
#        'Ye Win', 'Yuntian Wu', 'Yandong Xiang', 'Yunhan Xiao',
#        'Zhuotong Xie', 'Jiaying Yang', 'Yingnan Yang', 'Jiaxin Ye',
#        'Yutao Ye', 'Kai Yeung', 'Xinyao Yi', 'Denny Yoo', 'Sally Yu',
#        'Alden Yue', 'Dominik Zeman', 'Xiaotong Zeng', 'Yaosen Zhang',
#        'Gavin Zhao', 'Jinyi Zhao', 'Weixiang Zhao', 'Xinhao Zhao',
#        'Simon Zheng', 'Wenyu Zhong', 'Zhengyuan Zhou', 'Zhetai Zhou',
#        'Ellie Zou'], dtype=object)

# %%
# after looking through the list of names above, these are who we are going to drop
# typically this is stuff that gets bodged up by having Canvas link with Datahub or gradescope or something 
todrop = ['Jason G Fleischer','Cogs 118A Grader Account', 'Cogs 118A Test Account']
#todrop=[]
print(enrolled_students.shape)
enrolled_students=enrolled_students.drop(
        enrolled_students.index[ enrolled_students.Student.isin(todrop) ]
                                        )
print(enrolled_students.shape)
# Out:
# (186, 3)
# (185, 3)

# %%
enrolled_students.Student.value_counts().sort_values() # there might be multiple students with the same name
# Out:
# Jorge Acevedo          1
# Aleksandar Bumbalov    1
# Jay Buensuceso         1
# Rohil Ahuja            1
# Antonio Aldama         1
#                       ..
# Simon Zheng            1
# Wenyu Zhong            1
# Zhengyuan Zhou         1
# Dominik Zeman          1
# Ellie Zou              1
# Name: Student, Length: 185, dtype: int64

# %% [markdown]
# ### Load up the group signup google form
# The studnets are responsible for signing themselves up for the self-formed groups via a google form currently in shared drive COGS108/Projects. Export the finished form to a Sheet and download the responses in CSV format. Place them in this directory and change the read_csv(filename) below to point at the proper file

# %% [markdown]
# #### Added support for the new dropdown google form format

# %%
import re

def get_PID(row):
    sids = ""
    for col in row[1:6]:
        if not pd.isnull(col):
            sid =  re.findall('A[0-9]+', col) # List of SIDs
            if sid:  # Empty / None for groups with less than 5 people
                sids += sid[0]+", "
            
    return sids[:-2]

def get_names(row):
    names = ""
    for col in row[1:6]:
        if not pd.isnull(col):
            name =  col[:-10] # non-elegant string parsing
            if name:  # Empty / None for groups with less than 5 people
                for lname, fname in [name.split(",")]:
                    name = (fname.strip(' ') + ' ' + lname)
                names += name + ", "
        
        
            
    return names[:-2] # remove the extra common and space: sloppy but works

df = pd.read_csv('Wi23 COGS 118A Group Signup (Responses) - Form Responses 1.csv')
df = df.drop('Email Address',axis='columns')
df['sids'] = df.apply(get_PID, axis=1)
df['names'] = df.apply(get_names, axis=1)
df.columns.values[6] = 'gitids'

# %%
#
#                             Group Member #2  \
# 0                       Liu, Evan A16675674
# 1                     Zhao, Gavin A16200230
# 2                    Kao, Brandon A16683446
# 3                      Pham, Hieu A16347157
# 4                      Lin, Zirui A16352835
# 5                  Zeng, Xiaotong A15960860
# 6                   Wang, Gaoying A16131629
# 7                    Chen, Joshua A16810747
# 8                      Yi, Xinyao A59019592
# 9                       Ye, Yutao A17139018
# 10                   Zhou, Zhetai A15428825
# 11                   Oh, Seonghun A17655174
# 12                Duntugan, Grant A15830666
# 13                    Chang, Abby A15633379
# 14                 Rabin, Stephen A16138290
# 15  Algharaballi-Yanow, Sebastian A16314698
# 16                   Zhong, Wenyu A17169057
# 17               Ehrenburg, Keate A15322099
# 18                   Zheng, Simon A16193539
# 19             Myers, Christopher A17234842
# 20                 Khanna, Serina A15851279
# 21                    Brown, Miko A16237566
# 22                 Davis, Shenova A16314363
# 23                    Chen, Brian A16135072
# 24                   Ahuja, Rohil A16041299
# 25                     Dhar, Neel A15839185
# 26               Singh, Deepansha A16468249
# 27                 Fukuda, Mizuho A16310384
# 28                      Lin, Eric A16266295
# 29                     Yeung, Kai A14260065
# 30                   Lona, Andrew A13164368
# 31                    Samat, Shay A16816403
# 32                     Yue, Alden A15902882
# 33                   Liang, Sikai A16839298
# 34                  Yang, Jiaying A16351140
# 35                     Wei, Jamie A15921963
# 36                Giumarra, Lucas A15907438
# 37                    Park, Kalam A15920895
# 38                      Kan, Ryan A17009505
# 39               Arsani, Muhammad A16468481
# 40                     Nair, Atul A17129206
# 41                 Wefel, Wallace A16381599
#
#                       Group Member #3                 Group Member #4  \
# 0               Lui, Lauren A16657998           Kaura, Rina A16206086
# 1                   Vu, Duy A17190576          Bian, Tianyi A16134259
# 2            Mittal, Akshat A15908924   Krishnamoorthy, Adi A16742939
# 3         Anguraj, Angkitha A16660906            Yoo, Denny A16480259
# 4            Huang, Ruoqian A16489764          Xiao, Yunhan A16166274
# 5                Ye, Jiaxin A16287976        Xiang, Yandong A16629743
# 6                 Yu, Sally A16519059          Wang, Jiawen A16830133
# 7           Aldama, Antonio A15780834           Ruiz, Janet A15050976
# 8             Yang, Yingnan A16018172                             NaN
# 9               Qiu, Walter A17167459            Zou, Ellie A17117056
# 10             Horne, Sarah A16658917            Rote, Sean A17589873
# 11              Hong, Yewon A17192484                             NaN
# 12  Sanchez-Villegas, Jesse A15569627         Barker, Trent A16468643
# 13      Beeri-Feldman, Maya A16650164           Chen, Ethan A16739832
# 14            Baylon, Bobby A17233593    Mackler, Nathaniel A16579484
# 15             Pearson, Ian A16671890   Junaidy, Laurensius A16617195
# 16            Wang, Shiyuan A17166171          Zhao, Xinhao A16355760
# 17                                NaN                             NaN
# 18        Henderson, Albert A16384282       Zhou, Zhengyuan A16146369
# 19           Shaalan, Selim A15929044                             NaN
# 20        Fleschner, Alyssa A16127164  Doppalapudi, Dhathry A16298078
# 21               Wang, Ziyu A16149329                             NaN
# 22       Sankeshi, Pratheek A16279195            Singh, Ria A16195380
# 23            Chen, Jeffrey A16135050        Cheung, Vivian A17151741
# 24           Torok, Abraham A15890615     Narayanan, Brinda A16670728
# 25          Buensuceso, Jay A17213233       Vijjali, Juhita A15669338
# 26              Kogan, Ilya A15424869           Song, Raina A17696287
# 27          Sampath, Varsha A16294875             Que, Maya A16426598
# 28            St-John, Finn A16133473     Martinez, Cecilia A17203678
# 29             Chen, Haixin A16534853           Mao, Haokai A17185018
# 30              Chin, Naomi A15861575            Chow, Andy A16197124
# 31            Tomar, Aditya A17162996        Vasanth, Akhil A16807774
# 32            Beserler, Nil A16312351         Safari, Aryan A16091880
# 33               Li, Chenxi A16341810           Zhao, Jinyi A16315154
# 34                                NaN                             NaN
# 35        Raghunath, Sarita A16425750        Rangan, Nicole A15011222
# 36            Chi, Yu-Hsuan A16314326          Hocquet, Tom A16661125
# 37              Minor, Cray A15863773                             NaN
# 38          Gupta, Himanshi A15804892                             NaN
# 39             Kagzi, Sarah A16155549                             NaN
# 40            Hegde, Nikhil A16261926          Gong, Qianxi A15986849
# 41                                NaN                             NaN
#
#                 Group Member #5  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3    Villegas, Andres A15917448
# 4          Li, Ruoxin A17151340
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9       Zhang, Yaosen A16161252
# 10          Su, Kevin A16632888
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14  Gutierrez, Jayson A16166652
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18   Chandra, Abhinav A16517764
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                         None
# 27                          NaN
# 28                          NaN
# 29                          NaN
# 30                          NaN
# 31                          NaN
# 32                          NaN
# 33       Guo, Jialong A15851883
# 34                          NaN
# 35                          NaN
# 36                          NaN
# 37                          NaN
# 38                          NaN
# 39                          NaN
# 40                          NaN
# 41                          NaN
#
#                                                gitids  \
# 0           jacobayu, EvanLiu0, laurennlui, rinakaura
# 1   LexuZhao, Tianyibian, TianjinTunan, quocduyvu6262
# 2        atruong39, Brandon028, AkshatMittal7, AK4032
# 3      SujalN, hugompham, angkitha, dennyyoo1, av1929
# 4   wincy02, Awu-Lin, RuoqianHuang, yunhan-xiao, C...
# 5      JackLiX0105, jiaxin-yeah, x6zeng, yandongxiang
# 6                  yushi20, Cocodayo, wgyyy, tomxienb
# 7             Zaanis, janetar, MJ-git-maker, aaaldama
# 8                           g9liu, IsLydia, xinyao-yi
# 9   Nikki991018, leo-ye0, uswalter, Neb345, Ellie-Zou
# 10       stma733, Cyuaz, SNHorne, seanrote, Kevinsu12
# 11                 howonjoshua, seonghunnn, yewonh311
# 12     grantDuntugan, JesseSV, trent8800, isabellllaa
# 13  JPerez3001, tochangUCSD, mbeerifeldman, ethanucsd
# 14  KBrandt57, srabin-cmd, Bobbybeatzdev, jay-matz...
# 15  c5k1m, sebastianalgharaballi, iepearson02, Lau...
# 16              kdaeve, Eunggseo, moonwsy, XinhaoZhao
# 17                         j-lamadrid, keateehrenburg
# 18  Simon-Zheng99,AlbertHender,AndrewZ987,Abhinav2...
# 19                  DouHoonKwark,chessmyers,SelimUCSD
# 20         dhathry, helloserina, afleschner, kneeko97
# 21               MajorDarius, mikobrown, ZiyuWang0113
# 22           nb110240, shenovad, Ria-Singh, psankesh9
# 23       brichen,JeffrChen,vivianacheung,luzhangxiang
# 24    jorgeacevedo13, ahujar27, bvnarayanan, abetorok
# 25  wesleyynguyenn, juhitavijjali, flashruler, a3dhar
# 26    Wfelicity, Algorithmist-Girl, koilya, rainasong
# 27            irijin, MF02511, varshasampath20, m-que
# 28  J-Singletary, etlin3, stjohnfinn, cecilia-mart...
# 29               ZhilinK,haixinchen2022,KaiMHK,Kyy006
# 30        fmshobojoe,na0mich1n,AndyLAndrew,AndyCesium
# 31               adi-tomar,ssamat,zaki1503,AVGithub-1
# 32     vrothenbergUCSD,aldenyue,NilBeserler,aryan3844
# 33  Maggiebgg, Skyi1232123, Jinyiz, MinilordKREE, ...
# 34                             jiaying6429; brooksniu
# 35    dominik0420, s1raghun, nicolerangan, JamieWei21
# 36                 Seb0071,lugiumarra,philchi,tomok59
# 37                kirafleischer, crayminor, kalampark
# 38                          DomZeman,kan-ryan,munch-g
# 39                 SinjabPortal, adli0029, SarahKagzi
# 40                 Devouringbowl57, nihegde18, atooln
# 41  tbonaiut, wewefel. Just wanted to add a quick ...
#
#                                                  sids  \
# 0          A16341584, A16675674, A16657998, A16206086
# 1          A16129170, A16200230, A17190576, A16134259
# 2          A17209279, A16683446, A15908924, A16742939
# 3   A16495043, A16347157, A16660906, A16480259, A1...
# 4   A17151355, A16352835, A16489764, A16166274, A1...
# 5          A16335965, A15960860, A16287976, A16629743
# 6          A16153086, A16131629, A16519059, A16830133
# 7          A15825777, A16810747, A15780834, A15050976
# 8                     A15836054, A59019592, A16018172
# 9   A17146964, A17139018, A17167459, A17117056, A1...
# 10  A16496979, A15428825, A16658917, A17589873, A1...
# 11                    A15612157, A17655174, A17192484
# 12         A15930676, A15830666, A15569627, A16468643
# 13         A15775285, A15633379, A16650164, A16739832
# 14  A16195757, A16138290, A17233593, A16579484, A1...
# 15         A16132108, A16314698, A16671890, A16617195
# 16         A17200680, A17169057, A17166171, A16355760
# 17                               A16282531, A15322099
# 18  A15480541, A16193539, A16384282, A16146369, A1...
# 19                    A15741627, A17234842, A15929044
# 20         A15352545, A15851279, A16127164, A16298078
# 21                    A15786330, A16237566, A16149329
# 22         A16218424, A16314363, A16279195, A16195380
# 23         A16029521, A16135072, A16135050, A17151741
# 24         A15834274, A16041299, A15890615, A16670728
# 25         A15947818, A15839185, A17213233, A15669338
# 26         A16677648, A16468249, A15424869, A17696287
# 27         A16386965, A16310384, A16294875, A16426598
# 28         A16166835, A16266295, A16133473, A17203678
# 29         A17173283, A14260065, A16534853, A17185018
# 30         A59019538, A13164368, A15861575, A16197124
# 31         A16671152, A16816403, A17162996, A16807774
# 32         A16534656, A15902882, A16312351, A16091880
# 33  A16356724, A16839298, A16341810, A16315154, A1...
# 34                               A16147262, A16351140
# 35         A15852954, A15921963, A16425750, A15011222
# 36         A16031413, A15907438, A16314326, A16661125
# 37                    A16248495, A15920895, A15863773
# 38                    A16218261, A17009505, A15804892
# 39                    A17216655, A16468481, A16155549
# 40         A15957201, A17129206, A16261926, A15986849
# 41                               A15387764, A16381599
#
#                                                 names
# 0          Jacob Au, Evan Liu, Lauren Lui, Rina Kaura
# 1           Tunan Li, Gavin Zhao, Duy Vu, Tianyi Bian
# 2   Anthony Truong, Brandon Kao, Akshat Mittal, Ad...
# 3   Sujal Nahata, Hieu Pham, Angkitha Anguraj, Den...
# 4   Yongxi Liang, Zirui Lin, Ruoqian Huang, Yunhan...
# 5   Xiang Li, Xiaotong Zeng, Jiaxin Ye, Yandong Xiang
# 6   Zhuotong Xie, Gaoying Wang, Sally Yu, Jiawen Wang
# 7     MJ Mei, Joshua Chen, Antonio Aldama, Janet Ruiz
# 8                 George Liu, Xinyao Yi, Yingnan Yang
# 9   Qiqing Li, Yutao Ye, Walter Qiu, Ellie Zou, Ya...
# 10  Sidney Ma, Zhetai Zhou, Sarah Horne, Sean Rote...
# 11                Joshua Kim, Seonghun Oh, Yewon Hong
# 12  Isabella Anderson, Grant Duntugan, Jesse Sanch...
# 13  Jessica Perez, Abby Chang, Maya Beeri-Feldman,...
# 14  Kyra Brandt, Stephen Rabin, Bobby Baylon, Nath...
# 15  Christian Kim, Sebastian Algharaballi-Yanow, I...
# 16  Yuntian Wu, Wenyu Zhong, Shiyuan Wang, Xinhao ...
# 17                    Jacob Lamadrid, Keate Ehrenburg
# 18  Sung Cho, Simon Zheng, Albert Henderson, Zheng...
# 19        Dou Kwark, Christopher Myers, Selim Shaalan
# 20  Niko Calsada, Serina Khanna, Alyssa Fleschner,...
# 21                Darius Azure, Miko Brown, Ziyu Wang
# 22  Neil Bajaj, Shenova Davis, Pratheek Sankeshi, ...
# 23  Zhangxiang Lu, Brian Chen, Jeffrey Chen, Vivia...
# 24  Jorge Acevedo, Rohil Ahuja, Abraham Torok, Bri...
# 25  Wesley Nguyen, Neel Dhar, Jay Buensuceso, Juhi...
# 26  Winah Ruiz, Deepansha Singh, Ilya Kogan, Raina...
# 27  Irisa Jin, Mizuho Fukuda, Varsha Sampath, Maya...
# 28  Jared Singletary, Eric Lin, Finn St-John, Ceci...
# 29    Zhilin Kong, Kai Yeung, Haixin Chen, Haokai Mao
# 30      Jiaqi Liu, Andrew Lona, Naomi Chin, Andy Chow
# 31  Zaki Ahmed, Shay Samat, Aditya Tomar, Akhil Va...
# 32  Vincent Rothenberg, Alden Yue, Nil Beserler, A...
# 33  Gege Bei, Sikai Liang, Chenxi Li, Jinyi Zhao, ...
# 34                   Brooks(Ruijia) Niu, Jiaying Yang
# 35  Zehong Li, Jamie Wei, Sarita Raghunath, Nicole...
# 36  Sebastian Olivas Beltran, Lucas Giumarra, Yu-H...
# 37             Kira Fleischer, Kalam Park, Cray Minor
# 38            Dominik Zeman, Ryan Kan, Himanshi Gupta
# 39   Abdulrahman Sinjab, Muhammad Arsani, Sarah Kagzi
# 40  Cameron Faulkner, Atul Nair, Nikhil Hegde, Qia...
# 41                     Trevor Bonaiuto, Wallace Wefel

# %%
cols = df.columns.to_list()

df.columns = cols
cols[1] = 'names'
cols[2] = 'sids'
cols[3] = 'gitids'
groups = df.loc[:,['names','sids','gitids']]
# Group011                   howonjoshua, seonghunnn, yewonh311         3
# Group012       grantDuntugan, JesseSV, trent8800, isabellllaa         4
# Group013    JPerez3001, tochangUCSD, mbeerifeldman, ethanucsd         4
# Group014    KBrandt57, srabin-cmd, Bobbybeatzdev, jay-matz...         5
# Group015    c5k1m, sebastianalgharaballi, iepearson02, Lau...         4
# Group016                kdaeve, Eunggseo, moonwsy, XinhaoZhao         4
# Group017                           j-lamadrid, keateehrenburg         2
# Group018    Simon-Zheng99,AlbertHender,AndrewZ987,Abhinav2...         5
# Group019                    DouHoonKwark,chessmyers,SelimUCSD         3
# Group020           dhathry, helloserina, afleschner, kneeko97         4
# Group021                 MajorDarius, mikobrown, ZiyuWang0113         3
# Group022             nb110240, shenovad, Ria-Singh, psankesh9         4
# Group023         brichen,JeffrChen,vivianacheung,luzhangxiang         4
# Group024      jorgeacevedo13, ahujar27, bvnarayanan, abetorok         4
# Group025    wesleyynguyenn, juhitavijjali, flashruler, a3dhar         4
# Group026      Wfelicity, Algorithmist-Girl, koilya, rainasong         4
# Group027              irijin, MF02511, varshasampath20, m-que         4
# Group028    J-Singletary, etlin3, stjohnfinn, cecilia-mart...         4
# Group029                 ZhilinK,haixinchen2022,KaiMHK,Kyy006         4
# Group030          fmshobojoe,na0mich1n,AndyLAndrew,AndyCesium         4
# Group031                 adi-tomar,ssamat,zaki1503,AVGithub-1         4
# Group032       vrothenbergUCSD,aldenyue,NilBeserler,aryan3844         4
# Group033    Maggiebgg, Skyi1232123, Jinyiz, MinilordKREE, ...         5
# Group034                               jiaying6429; brooksniu         2
# Group035      dominik0420, s1raghun, nicolerangan, JamieWei21         4
# Group036                   Seb0071,lugiumarra,philchi,tomok59         4
# Group037                  kirafleischer, crayminor, kalampark         3
# Group038                            DomZeman,kan-ryan,munch-g         3
# Group039                   SinjabPortal, adli0029, SarahKagzi         3
# Group040                   Devouringbowl57, nihegde18, atooln         4
# Group041    tbonaiut, wewefel. Just wanted to add a quick ...         2

# %%
groups.drop_duplicates(subset='names').shape 
# hopefully matches the number just above otherwise someone entered the same group more than once
# Out:
# (42, 4)

# %% [markdown]
# ### Figure out who still needs to be assigned to a group
#
# Method 1: do it by name
#
# Method 2: do it by SID
#
# We will figure out which one works best and correct at the end for the people caught better by the other method

# %%
grouped_students = flatten( 
    groups.names
    .apply( lambda y: [x.strip() for x in y.split(',')])
)
grouped_students
# Out:
# ['Jacob Au',
#  'Evan Liu',
#  'Lauren Lui',
#  'Rina Kaura',
#  'Tunan Li',
#  'Gavin Zhao',
#  'Duy Vu',
#  'Tianyi Bian',
#  'Anthony Truong',
#  'Brandon Kao',
#  'Akshat Mittal',
#  'Adi Krishnamoorthy',
#  'Sujal Nahata',
#  'Hieu Pham',
#  'Angkitha Anguraj',
#  'Denny Yoo',
#  'Andres Villegas',
#  'Yongxi Liang',
#  'Zirui Lin',
#  'Ruoqian Huang',
#  'Yunhan Xiao',
#  'Ruoxin Li',
#  'Xiang Li',
#  'Xiaotong Zeng',
#  'Jiaxin Ye',
#  'Yandong Xiang',
#  'Zhuotong Xie',
#  'Gaoying Wang',
#  'Sally Yu',
#  'Jiawen Wang',
#  'MJ Mei',
#  'Joshua Chen',
#  'Antonio Aldama',
#  'Janet Ruiz',
#  'George Liu',
#  'Xinyao Yi',
#  'Yingnan Yang',
#  'Qiqing Li',
#  'Yutao Ye',
#  'Walter Qiu',
#  'Ellie Zou',
#  'Yaosen Zhang',
#  'Sidney Ma',
#  'Zhetai Zhou',
#  'Sarah Horne',
#  'Sean Rote',
#  'Kevin Su',
#  'Joshua Kim',
#  'Seonghun Oh',
#  'Yewon Hong',
#  'Isabella Anderson',
#  'Grant Duntugan',
#  'Jesse Sanchez-Villegas',
#  'Trent Barker',
#  'Jessica Perez',
#  'Abby Chang',
#  'Maya Beeri-Feldman',
#  'Ethan Chen',
#  'Kyra Brandt',
#  'Stephen Rabin',
#  'Bobby Baylon',
#  'Nathaniel Mackler',
#  'Jayson Gutierrez',
#  'Christian Kim',
#  'Sebastian Algharaballi-Yanow',
#  'Ian Pearson',
#  'Laurensius Junaidy',
#  'Yuntian Wu',
#  'Wenyu Zhong',
#  'Shiyuan Wang',
#  'Xinhao Zhao',
#  'Jacob Lamadrid',
#  'Keate Ehrenburg',
#  'Sung Cho',
#  'Simon Zheng',
#  'Albert Henderson',
#  'Zhengyuan Zhou',
#  'Abhinav Chandra',
#  'Dou Kwark',
#  'Christopher Myers',
#  'Selim Shaalan',
#  'Niko Calsada',
#  'Serina Khanna',
#  'Alyssa Fleschner',
#  'Dhathry Doppalapudi',
#  'Darius Azure',
#  'Miko Brown',
#  'Ziyu Wang',
#  'Neil Bajaj',
#  'Shenova Davis',
#  'Pratheek Sankeshi',
#  'Ria Singh',
#  'Zhangxiang Lu',
#  'Brian Chen',
#  'Jeffrey Chen',
#  'Vivian Cheung',
#  'Jorge Acevedo',
#  'Rohil Ahuja',
#  'Abraham Torok',
#  'Brinda Narayanan',
#  'Wesley Nguyen',
#  'Neel Dhar',
#  'Jay Buensuceso',
#  'Juhita Vijjali',
#  'Winah Ruiz',
#  'Deepansha Singh',
#  'Ilya Kogan',
#  'Raina Song',
#  'Irisa Jin',
#  'Mizuho Fukuda',
#  'Varsha Sampath',
#  'Maya Que',
#  'Jared Singletary',
#  'Eric Lin',
#  'Finn St-John',
#  'Cecilia Martinez',
#  'Zhilin Kong',
#  'Kai Yeung',
#  'Haixin Chen',
#  'Haokai Mao',
#  'Jiaqi Liu',
#  'Andrew Lona',
#  'Naomi Chin',
#  'Andy Chow',
#  'Zaki Ahmed',
#  'Shay Samat',
#  'Aditya Tomar',
#  'Akhil Vasanth',
#  'Vincent Rothenberg',
#  'Alden Yue',
#  'Nil Beserler',
#  'Aryan Safari',
#  'Gege Bei',
#  'Sikai Liang',
#  'Chenxi Li',
#  'Jinyi Zhao',
#  'Jialong Guo',
#  'Brooks(Ruijia) Niu',
#  'Jiaying Yang',
#  'Zehong Li',
#  'Jamie Wei',
#  'Sarita Raghunath',
#  'Nicole Rangan',
#  'Sebastian Olivas Beltran',
#  'Lucas Giumarra',
#  'Yu-Hsuan Chi',
#  'Tom Hocquet',
#  'Kira Fleischer',
#  'Kalam Park',
#  'Cray Minor',
#  'Dominik Zeman',
#  'Ryan Kan',
#  'Himanshi Gupta',
#  'Abdulrahman Sinjab',
#  'Muhammad Arsani',
#  'Sarah Kagzi',
#  'Cameron Faulkner',
#  'Atul Nair',
#  'Nikhil Hegde',
#  'Qianxi Gong',
#  'Trevor Bonaiuto',
#  'Wallace Wefel']

# %%
unassigned_1 = set(enrolled_students.Student) - set(grouped_students)
unassigned_1
# Out:
# {'Aleksandar Bumbalov',
#  'Angel Olivas',
#  'Armaan Johal',
#  'Carly Freedman',
#  'Garrett Dungca',
#  'Gyujin Hong',
#  'Hannah Lin',
#  'Jackson Teel',
#  'Jesus Mendez',
#  'Masiah Manzano',
#  'Omri Habot',
#  'Peter Barnett',
#  'Ricardo Sedano',
#  'Ryan Kabbes',
#  'Sang Tran',
#  'Stanley Sisson',
#  'Taolan Taolan',
#  'Tej Nair',
#  'Tekin Gunasar',
#  'Weixiang Zhao',
#  'William Lutz',
#  'Xiaofei Teng',
#  'Ye Win',
#  'Zecheng Li'}

# %%
badnames_1 = set(grouped_students) - set(enrolled_students.Student)
badnames_1
# Out:
# {'Alyssa Fleschner'}

# %%
grouped_sids = flatten( 
    groups.sids
    .apply( lambda y: [x.strip() for x in 
                         y.replace('.',',') # some idiot used a . instead of a ,
                         .split(',') # split sids grouped by commas
                      ]
          ) 
    

)
grouped_sids
# Out:
# ['A16341584',
#  'A16675674',
#  'A16657998',
#  'A16206086',
#  'A16129170',
#  'A16200230',
#  'A17190576',
#  'A16134259',
#  'A17209279',
#  'A16683446',
#  'A15908924',
#  'A16742939',
#  'A16495043',
#  'A16347157',
#  'A16660906',
#  'A16480259',
#  'A15917448',
#  'A17151355',
#  'A16352835',
#  'A16489764',
#  'A16166274',
#  'A17151340',
#  'A16335965',
#  'A15960860',
#  'A16287976',
#  'A16629743',
#  'A16153086',
#  'A16131629',
#  'A16519059',
#  'A16830133',
#  'A15825777',
#  'A16810747',
#  'A15780834',
#  'A15050976',
#  'A15836054',
#  'A59019592',
#  'A16018172',
#  'A17146964',
#  'A17139018',
#  'A17167459',
#  'A17117056',
#  'A16161252',
#  'A16496979',
#  'A15428825',
#  'A16658917',
#  'A17589873',
#  'A16632888',
#  'A15612157',
#  'A17655174',
#  'A17192484',
#  'A15930676',
#  'A15830666',
#  'A15569627',
#  'A16468643',
#  'A15775285',
#  'A15633379',
#  'A16650164',
#  'A16739832',
#  'A16195757',
#  'A16138290',
#  'A17233593',
#  'A16579484',
#  'A16166652',
#  'A16132108',
#  'A16314698',
#  'A16671890',
#  'A16617195',
#  'A17200680',
#  'A17169057',
#  'A17166171',
#  'A16355760',
#  'A16282531',
#  'A15322099',
#  'A15480541',
#  'A16193539',
#  'A16384282',
#  'A16146369',
#  'A16517764',
#  'A15741627',
#  'A17234842',
#  'A15929044',
#  'A15352545',
#  'A15851279',
#  'A16127164',
#  'A16298078',
#  'A15786330',
#  'A16237566',
#  'A16149329',
#  'A16218424',
#  'A16314363',
#  'A16279195',
#  'A16195380',
#  'A16029521',
#  'A16135072',
#  'A16135050',
#  'A17151741',
#  'A15834274',
#  'A16041299',
#  'A15890615',
#  'A16670728',
#  'A15947818',
#  'A15839185',
#  'A17213233',
#  'A15669338',
#  'A16677648',
#  'A16468249',
#  'A15424869',
#  'A17696287',
#  'A16386965',
#  'A16310384',
#  'A16294875',
#  'A16426598',
#  'A16166835',
#  'A16266295',
#  'A16133473',
#  'A17203678',
#  'A17173283',
#  'A14260065',
#  'A16534853',
#  'A17185018',
#  'A59019538',
#  'A13164368',
#  'A15861575',
#  'A16197124',
#  'A16671152',
#  'A16816403',
#  'A17162996',
#  'A16807774',
#  'A16534656',
#  'A15902882',
#  'A16312351',
#  'A16091880',
#  'A16356724',
#  'A16839298',
#  'A16341810',
#  'A16315154',
#  'A15851883',
#  'A16147262',
#  'A16351140',
#  'A15852954',
#  'A15921963',
#  'A16425750',
#  'A15011222',
#  'A16031413',
#  'A15907438',
#  'A16314326',
#  'A16661125',
#  'A16248495',
#  'A15920895',
#  'A15863773',
#  'A16218261',
#  'A17009505',
#  'A15804892',
#  'A17216655',
#  'A16468481',
#  'A16155549',
#  'A15957201',
#  'A17129206',
#  'A16261926',
#  'A15986849',
#  'A15387764',
#  'A16381599']

# %%
 
def sid2name(sid):
        try:
            ret = enrolled_students.set_index('SID').loc[sid,'Student']
        except KeyError:
            print('Unknown SID: '+sid)
            ret = None
        return ret

list(map(sid2name, grouped_sids))
# Out:
# Unknown SID: A16127164
# ['Jacob Au',
#  'Evan Liu',
#  'Lauren Lui',
#  'Rina Kaura',
#  'Tunan Li',
#  'Gavin Zhao',
#  'Duy Vu',
#  'Tianyi Bian',
#  'Anthony Truong',
#  'Brandon Kao',
#  'Akshat Mittal',
#  'Adi Krishnamoorthy',
#  'Sujal Nahata',
#  'Hieu Pham',
#  'Angkitha Anguraj',
#  'Denny Yoo',
#  'Andres Villegas',
#  'Yongxi Liang',
#  'Zirui Lin',
#  'Ruoqian Huang',
#  'Yunhan Xiao',
#  'Ruoxin Li',
#  'Xiang Li',
#  'Xiaotong Zeng',
#  'Jiaxin Ye',
#  'Yandong Xiang',
#  'Zhuotong Xie',
#  'Gaoying Wang',
#  'Sally Yu',
#  'Jiawen Wang',
#  'MJ Mei',
#  'Joshua Chen',
#  'Antonio Aldama',
#  'Janet Ruiz',
#  'George Liu',
#  'Xinyao Yi',
#  'Yingnan Yang',
#  'Qiqing Li',
#  'Yutao Ye',
#  'Walter Qiu',
#  'Ellie Zou',
#  'Yaosen Zhang',
#  'Sidney Ma',
#  'Zhetai Zhou',
#  'Sarah Horne',
#  'Sean Rote',
#  'Kevin Su',
#  'Joshua Kim',
#  'Seonghun Oh',
#  'Yewon Hong',
#  'Isabella Anderson',
#  'Grant Duntugan',
#  'Jesse Sanchez-Villegas',
#  'Trent Barker',
#  'Jessica Perez',
#  'Abby Chang',
#  'Maya Beeri-Feldman',
#  'Ethan Chen',
#  'Kyra Brandt',
#  'Stephen Rabin',
#  'Bobby Baylon',
#  'Nathaniel Mackler',
#  'Jayson Gutierrez',
#  'Christian Kim',
#  'Sebastian Algharaballi-Yanow',
#  'Ian Pearson',
#  'Laurensius Junaidy',
#  'Yuntian Wu',
#  'Wenyu Zhong',
#  'Shiyuan Wang',
#  'Xinhao Zhao',
#  'Jacob Lamadrid',
#  'Keate Ehrenburg',
#  'Sung Cho',
#  'Simon Zheng',
#  'Albert Henderson',
#  'Zhengyuan Zhou',
#  'Abhinav Chandra',
#  'Dou Kwark',
#  'Christopher Myers',
#  'Selim Shaalan',
#  'Niko Calsada',
#  'Serina Khanna',
#  None,
#  'Dhathry Doppalapudi',
#  'Darius Azure',
#  'Miko Brown',
#  'Ziyu Wang',
#  'Neil Bajaj',
#  'Shenova Davis',
#  'Pratheek Sankeshi',
#  'Ria Singh',
#  'Zhangxiang Lu',
#  'Brian Chen',
#  'Jeffrey Chen',
#  'Vivian Cheung',
#  'Jorge Acevedo',
#  'Rohil Ahuja',
#  'Abraham Torok',
#  'Brinda Narayanan',
#  'Wesley Nguyen',
#  'Neel Dhar',
#  'Jay Buensuceso',
#  'Juhita Vijjali',
#  'Winah Ruiz',
#  'Deepansha Singh',
#  'Ilya Kogan',
#  'Raina Song',
#  'Irisa Jin',
#  'Mizuho Fukuda',
#  'Varsha Sampath',
#  'Maya Que',
#  'Jared Singletary',
#  'Eric Lin',
#  'Finn St-John',
#  'Cecilia Martinez',
#  'Zhilin Kong',
#  'Kai Yeung',
#  'Haixin Chen',
#  'Haokai Mao',
#  'Jiaqi Liu',
#  'Andrew Lona',
#  'Naomi Chin',
#  'Andy Chow',
#  'Zaki Ahmed',
#  'Shay Samat',
#  'Aditya Tomar',
#  'Akhil Vasanth',
#  'Vincent Rothenberg',
#  'Alden Yue',
#  'Nil Beserler',
#  'Aryan Safari',
#  'Gege Bei',
#  'Sikai Liang',
#  'Chenxi Li',
#  'Jinyi Zhao',
#  'Jialong Guo',
#  'Brooks(Ruijia) Niu',
#  'Jiaying Yang',
#  'Zehong Li',
#  'Jamie Wei',
#  'Sarita Raghunath',
#  'Nicole Rangan',
#  'Sebastian Olivas Beltran',
#  'Lucas Giumarra',
#  'Yu-Hsuan Chi',
#  'Tom Hocquet',
#  'Kira Fleischer',
#  'Kalam Park',
#  'Cray Minor',
#  'Dominik Zeman',
#  'Ryan Kan',
#  'Himanshi Gupta',
#  'Abdulrahman Sinjab',
#  'Muhammad Arsani',
#  'Sarah Kagzi',
#  'Cameron Faulkner',
#  'Atul Nair',
#  'Nikhil Hegde',
#  'Qianxi Gong',
#  'Trevor Bonaiuto',
#  'Wallace Wefel']

# %%
id2nm = enrolled_students.set_index('SID')['Student'].to_dict()

def sid2name(sid):
        try:
            ret = id2nm[sid]
        except KeyError:
            print('Unknown SID: '+sid)
            ret = None
        return ret
    
    
grouped_names_from_sids = list( map( sid2name, grouped_sids) )
grouped_names_from_sids
# Out:
# Unknown SID: A16127164
# ['Jacob Au',
#  'Evan Liu',
#  'Lauren Lui',
#  'Rina Kaura',
#  'Tunan Li',
#  'Gavin Zhao',
#  'Duy Vu',
#  'Tianyi Bian',
#  'Anthony Truong',
#  'Brandon Kao',
#  'Akshat Mittal',
#  'Adi Krishnamoorthy',
#  'Sujal Nahata',
#  'Hieu Pham',
#  'Angkitha Anguraj',
#  'Denny Yoo',
#  'Andres Villegas',
#  'Yongxi Liang',
#  'Zirui Lin',
#  'Ruoqian Huang',
#  'Yunhan Xiao',
#  'Ruoxin Li',
#  'Xiang Li',
#  'Xiaotong Zeng',
#  'Jiaxin Ye',
#  'Yandong Xiang',
#  'Zhuotong Xie',
#  'Gaoying Wang',
#  'Sally Yu',
#  'Jiawen Wang',
#  'MJ Mei',
#  'Joshua Chen',
#  'Antonio Aldama',
#  'Janet Ruiz',
#  'George Liu',
#  'Xinyao Yi',
#  'Yingnan Yang',
#  'Qiqing Li',
#  'Yutao Ye',
#  'Walter Qiu',
#  'Ellie Zou',
#  'Yaosen Zhang',
#  'Sidney Ma',
#  'Zhetai Zhou',
#  'Sarah Horne',
#  'Sean Rote',
#  'Kevin Su',
#  'Joshua Kim',
#  'Seonghun Oh',
#  'Yewon Hong',
#  'Isabella Anderson',
#  'Grant Duntugan',
#  'Jesse Sanchez-Villegas',
#  'Trent Barker',
#  'Jessica Perez',
#  'Abby Chang',
#  'Maya Beeri-Feldman',
#  'Ethan Chen',
#  'Kyra Brandt',
#  'Stephen Rabin',
#  'Bobby Baylon',
#  'Nathaniel Mackler',
#  'Jayson Gutierrez',
#  'Christian Kim',
#  'Sebastian Algharaballi-Yanow',
#  'Ian Pearson',
#  'Laurensius Junaidy',
#  'Yuntian Wu',
#  'Wenyu Zhong',
#  'Shiyuan Wang',
#  'Xinhao Zhao',
#  'Jacob Lamadrid',
#  'Keate Ehrenburg',
#  'Sung Cho',
#  'Simon Zheng',
#  'Albert Henderson',
#  'Zhengyuan Zhou',
#  'Abhinav Chandra',
#  'Dou Kwark',
#  'Christopher Myers',
#  'Selim Shaalan',
#  'Niko Calsada',
#  'Serina Khanna',
#  None,
#  'Dhathry Doppalapudi',
#  'Darius Azure',
#  'Miko Brown',
#  'Ziyu Wang',
#  'Neil Bajaj',
#  'Shenova Davis',
#  'Pratheek Sankeshi',
#  'Ria Singh',
#  'Zhangxiang Lu',
#  'Brian Chen',
#  'Jeffrey Chen',
#  'Vivian Cheung',
#  'Jorge Acevedo',
#  'Rohil Ahuja',
#  'Abraham Torok',
#  'Brinda Narayanan',
#  'Wesley Nguyen',
#  'Neel Dhar',
#  'Jay Buensuceso',
#  'Juhita Vijjali',
#  'Winah Ruiz',
#  'Deepansha Singh',
#  'Ilya Kogan',
#  'Raina Song',
#  'Irisa Jin',
#  'Mizuho Fukuda',
#  'Varsha Sampath',
#  'Maya Que',
#  'Jared Singletary',
#  'Eric Lin',
#  'Finn St-John',
#  'Cecilia Martinez',
#  'Zhilin Kong',
#  'Kai Yeung',
#  'Haixin Chen',
#  'Haokai Mao',
#  'Jiaqi Liu',
#  'Andrew Lona',
#  'Naomi Chin',
#  'Andy Chow',
#  'Zaki Ahmed',
#  'Shay Samat',
#  'Aditya Tomar',
#  'Akhil Vasanth',
#  'Vincent Rothenberg',
#  'Alden Yue',
#  'Nil Beserler',
#  'Aryan Safari',
#  'Gege Bei',
#  'Sikai Liang',
#  'Chenxi Li',
#  'Jinyi Zhao',
#  'Jialong Guo',
#  'Brooks(Ruijia) Niu',
#  'Jiaying Yang',
#  'Zehong Li',
#  'Jamie Wei',
#  'Sarita Raghunath',
#  'Nicole Rangan',
#  'Sebastian Olivas Beltran',
#  'Lucas Giumarra',
#  'Yu-Hsuan Chi',
#  'Tom Hocquet',
#  'Kira Fleischer',
#  'Kalam Park',
#  'Cray Minor',
#  'Dominik Zeman',
#  'Ryan Kan',
#  'Himanshi Gupta',
#  'Abdulrahman Sinjab',
#  'Muhammad Arsani',
#  'Sarah Kagzi',
#  'Cameron Faulkner',
#  'Atul Nair',
#  'Nikhil Hegde',
#  'Qianxi Gong',
#  'Trevor Bonaiuto',
#  'Wallace Wefel']

# %%
unassigned_2 = set(enrolled_students.Student) - set(grouped_names_from_sids)
unassigned_2
# Out:
# {'Aleksandar Bumbalov',
#  'Angel Olivas',
#  'Armaan Johal',
#  'Carly Freedman',
#  'Garrett Dungca',
#  'Gyujin Hong',
#  'Hannah Lin',
#  'Jackson Teel',
#  'Jesus Mendez',
#  'Masiah Manzano',
#  'Omri Habot',
#  'Peter Barnett',
#  'Ricardo Sedano',
#  'Ryan Kabbes',
#  'Sang Tran',
#  'Stanley Sisson',
#  'Taolan Taolan',
#  'Tej Nair',
#  'Tekin Gunasar',
#  'Weixiang Zhao',
#  'William Lutz',
#  'Xiaofei Teng',
#  'Ye Win',
#  'Zecheng Li'}

# %%
badnames_2 = set(grouped_names_from_sids) - set(enrolled_students.Student)
badnames_2
# Out:
# {None}

# %% [markdown]
# Clearly it looks like the method for unassigned students via SID is the best version for this quarter, let's roll with it.
#
# You might need to make a different call in a different quarter :)
#
# But first let's see if there's any cases where the SID was bad but the student name was recorded properly

# %%
# these are students who were recorded properly by name but not by SID
correction = unassigned_2.intersection( set(grouped_students) )
correction
# Out:
# set()

# %%
unassigned_students = list( unassigned_2 - correction)
print('there are {} unassigned_students:\n{}'.format(len(unassigned_students), unassigned_students))
# Out:
# there are 24 unassigned_students:
# ['Omri Habot', 'Aleksandar Bumbalov', 'Hannah Lin', 'Xiaofei Teng', 'Tekin Gunasar', 'Weixiang Zhao', 'Armaan Johal', 'Zecheng Li', 'Ye Win', 'Jackson Teel', 'Garrett Dungca', 'Carly Freedman', 'Gyujin Hong', 'Taolan Taolan', 'Ryan Kabbes', 'Jesus Mendez', 'Tej Nair', 'Stanley Sisson', 'Angel Olivas', 'Masiah Manzano', 'Sang Tran', 'William Lutz', 'Peter Barnett', 'Ricardo Sedano']

# %%
# theses are the students to email (copy/paste below into TO: line) 
# ask them if they really didn't sign up for a project group 
# because they are about to be randomly assigned to a group
emails = enrolled_students.set_index('Student').email + '@ucsd.edu'
for x in emails.loc[unassigned_students]:
    print(x)
# Out:
# ohabot@ucsd.edu
# abumbalo@ucsd.edu
# hal048@ucsd.edu
# xteng@ucsd.edu
# tgunasar@ucsd.edu
# w2zhao@ucsd.edu
# ajohal@ucsd.edu
# zel012@ucsd.edu
# ywin@ucsd.edu
# jeteel@ucsd.edu
# gdungca@ucsd.edu
# cfreedman@ucsd.edu
# g2hong@ucsd.edu
# jtaolan@ucsd.edu
# rkabbes@ucsd.edu
# j3mendez@ucsd.edu
# tnair@ucsd.edu
# sfsisson@ucsd.edu
# aaolivas@ucsd.edu
# m1manzan@ucsd.edu
# stt008@ucsd.edu
# wlutz@ucsd.edu
# pbarnett@ucsd.edu
# rsedano@ucsd.edu

# %% [markdown]
# Hi,
#
# You are one of a few dozen students who didn’t sign up for a project group according to my automatic scripts.
#
# This email is to verify that my scripts didn’t get messed up somehow.
#
# Please reply to this email ONLY if there is some kind of mistake.  Reply ONLY if you did actually believe that you were signed up with a group.  Otherwise you can ignore this email, and you will be assigned randomly to a project group.
#
# Thanks

# %% [markdown]
# ### Create new groups and/or fill up sub-sized groups with the unassigned

# %% [markdown]
# What should you do?  let's do this manually becuase its impossible to do it well automatically

# %%
# idiots who can't fill out a form right and say they are in a group when its too late by responding to email

print(groups.index[-3:])
# ok start at 042 this quarter
# Out:
# Index(['Group039', 'Group040', 'Group041'], dtype='object', name='group_name')

# %%
subsized_groups = groups[ groups.n_people < 3 ]
subsized_groups
# Out:
#                                        names                  sids  \
# group_name
# Group017     Jacob Lamadrid, Keate Ehrenburg  A16282531, A15322099
# Group034    Brooks(Ruijia) Niu, Jiaying Yang  A16147262, A16351140
# Group041      Trevor Bonaiuto, Wallace Wefel  A15387764, A16381599
#
#                                                        gitids  n_people
# group_name
# Group017                           j-lamadrid, keateehrenburg         2
# Group034                               jiaying6429; brooksniu         2
# Group041    tbonaiut, wewefel. Just wanted to add a quick ...         2

# %%
needed = (3 - subsized_groups.n_people).sum()
needed
# Out:
# 3

# %%
len(unassigned_students)-needed
# Out:
# 21

# %% [markdown]
# In this quarter I will be adding 3 total people to 3 subsized groups, creating groups of 3, which will leave me 21 unassigned to make 7 groups of 3
#
# As you make the groups below copy/paste the email list into a TO line and send the below email to them.
#
# **NB** If you need to add 2 or more people to a group, just copy/paste the gr = 'GroupXXX' cell that many times

# %% [markdown]
# Hi,
#
# Previously <4 people had been in your group from the signup form.  I'm randomly assigning ___ to make your group >= 4 people. This email is to serve as an introduction for you all and help you get together and organize.
#
# As a reminder, please accept the Github invite ASAP (sent as a seperate email).
#
# Good luck this quarter!

# %%
counter = 0
assignments = {}

# %%
gr = 'Group000'

print(groups.loc[gr,'names'])
groups.loc[gr,'names'] = groups.loc[gr,'names']+', '+unassigned_students[counter]
groups.loc[gr,'names']
assignments[unassigned_students[counter]] = gr
counter = counter + 1
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Ana Cunha, Kyra Hulse, Esmeralda Mejia-Trejo
# Ana Cunha, Kyra Hulse, Esmeralda Mejia-Trejo, Kimberly Johnson
# accunha@ucsd.edu
# kehulse@ucsd.edu
# emejiatr@ucsd.edu
# krj003@ucsd.edu

# %%
gr = 'Group026'

print(groups.loc[gr,'names'])
groups.loc[gr,'names'] = groups.loc[gr,'names']+', '+unassigned_students[counter]
groups.loc[gr,'names']
assignments[unassigned_students[counter]] = gr
counter = counter + 1
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Shengjie Mao, Mengyu Zhang, Yufei Deng
# Shengjie Mao, Mengyu Zhang, Yufei Deng, Dylan Nelson
# smao@ucsd.edu
# m7zhang@ucsd.edu
# yudeng@ucsd.edu
# dnelson@ucsd.edu

# %%
gr = 'Group030'

print(groups.loc[gr,'names'])
groups.loc[gr,'names'] = groups.loc[gr,'names']+', '+unassigned_students[counter]
groups.loc[gr,'names']
assignments[unassigned_students[counter]] = gr
counter = counter + 1
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Ryan Burden, Rey Mendoza, Terence Ting, Joshua Garcia
# Ryan Burden, Rey Mendoza, Terence Ting, Joshua Garcia, Xuhui Liu
# rburden@ucsd.edu
# rmendoza@ucsd.edu
# tting@ucsd.edu
# j9garcia@ucsd.edu
# xul019@ucsd.edu

# %% [markdown]
# OK now do the rest of the unassigned in new groups

# %%
# this tells you the number of the last group formed by signup; 
# start randomly assigned groups 1 up from here
groups.tail(1)
# Out:
#                                                         names  \
# group_name
# Group051    Zeven Vidmar-Barker, Nawwar Tohme, Cameron Van...
#
#                                                   sids  \
# group_name
# Group051    A15641421, A15659678, A15803073, A15834274
#
#                                                        gitids  n_people
# group_name
# Group051    zvidmarb, TohmeNawwar, IRSMsoso, jorgeacevedo1...         4

# %%
# this should match teh expeted number of groups/students
len(unassigned_students[counter:])
# Out:
# 29

# %% [markdown]
# As you make the randomly groups below, copy/paste the email list into a TO line and send the below email to them.

# %% [markdown]
# Hi,
#
# You did not sign up for a group, so you have been randomly assigned to groupXXX.
#
# Please talk with each other and organize for the group projects.
#
# Unfortunately you haven't given us your github username yet (which was part of the group signup), so we are unable to automagically give you write access to your repo (https://github.com/COGS118A/Group0XX-Sp22)just yet.  You can still view it as your repo is publicly viewable
#
# Please post your username on Piazza with the subject line "Need github write access to Group0XX" to get write access to your repo.
#
# Good luck this quarter!

# %%
gr = 'Group052'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+5
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Xuhui Liu, Yescenia Alvarez, Dong Pham, Maxwell Jung, Carter Nielsen
# xul019@ucsd.edu
# yealvare@ucsd.edu
# d9pham@ucsd.edu
# m1jung@ucsd.edu
# cnielsen@ucsd.edu

# %%
gr = 'Group053'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+5
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Cedric Wong, Nicholas Degroot, Ethan Black, Erlend Hordvei, Adam Alvord
# c8wong@ucsd.edu
# ndegroot@ucsd.edu
# eblack@ucsd.edu
# ax007667@ucsd.edu
# aalvord@ucsd.edu

# %%
gr = 'Group054'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+5
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Jaime Altamirano-Ramirez, Alexander Huynh, Taylor Drennen, Aldair Olanda, Geoffrey Hand
# jaltamir@ucsd.edu
# adhuynh@ucsd.edu
# tdrennen@ucsd.edu
# aolanda@ucsd.edu
# gbhand@ucsd.edu

# %%
gr = 'Group055'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+5
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Jenny Vu, Girish Senthil, Maya Xu, Joshua Fierro, Grant Liu
# jvu@ucsd.edu
# gsenthil@ucsd.edu
# zhx010@ucsd.edu
# jfierro@ucsd.edu
# grliu@ucsd.edu

# %%
gr = 'Group056'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+5
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Xiaonan Fu, Victor Tran, Dima Musa, Megha Chouthai, James Callahan
# xif003@ucsd.edu
# vpt006@ucsd.edu
# dimusa@ucsd.edu
# mchoutha@ucsd.edu
# jcallaha@ucsd.edu

# %%
gr = 'Group057'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+4
print(groups.loc[gr,'names'])
these_studs = pd.Series(groups.loc[gr,'names'].split(',')).str.strip()
for x in emails.loc[these_studs].values:
    print(x)
# Out:
# Peder Ditelv-Simonsen, Zhou Sun, Yimin Lu, Jalani Bowman
# ax007660@ucsd.edu
# z6sun@ucsd.edu
# yil110@ucsd.edu
# jbowman@ucsd.edu

# %%
len(unassigned_students[counter:])
# Out:
# 0

# %%
groups
# Out:
#                                                         names  \
# group_name
# Group000    Ana Cunha, Kyra Hulse, Esmeralda Mejia-Trejo, ...
# Group001    Alan Cao, Robert Aispuro, Helen Zhao, Connie C...
# Group002    Bridget Egan, John Pyjar, Alex Tyler, Aryaman ...
# Group003    Boning Yang, Chenhao Zhu, Anni Li, Muchan Li, ...
# Group004    Harini Adivikolanu, Isabella Gonzalez, Daniel ...
# Group005    Brandon Vazquez-Tellez, Vicky Chou, Hsi Chen, ...
# Group032    rich-liu,KareemaKilani,Abisawtell,suhjoshua,Ra...       5.0
# Group033    kyumin14, locomoco1313, ryandesmond1104, chris...       5.0
# Group034       Paulimorphism, xiw019, zlsjClaire, Annieqian02       4.0
# Group035    ssbarrera, vctrnna , zlenus, angrybeanz, gocegued       5.0
# Group036    samuel-d-woo, kylechristophermoore, TheRealMambaz       5.0
# Group037     rkhateeb, cdonasco, MikecraftA, IsAria233, SiuWu       5.0
# Group038      itsjanty, zuraneb, ingridalt, t7bui, romanov360       5.0
# Group039               Tianyu-Yu, Cheersbbg,  cozic, Muhan He       4.0
# Group040       wrblynch, lkatanic, hwiyeo, RynaK1, gordon1213       5.0
# Group041    mxnares,rainarit,WillSumerfield,mhm1117,abdall...       5.0
# Group042    TIMHX, Luning-Yang, yunyihuang, AnnieeeeeF, 3X...       5.0
# Group043    NicoloWX, CainChen1,  h3song, ileolin3, fjkal23jk       5.0
# Group044              yiyang-cao, pu-tan, NioOunt, ZefangYuan       4.0
# Group045    AlphaAmeame, dududubingbong, Zheran-Li, ywchoi...       5.0
# Group046      akai820, xiqiangliu, LianLumada, shz42, MChengW       5.0
# Group047    robertzhang0531,nickuncaged1201,whybruhh,Jiang...       5.0
# Group048               YashPotdar, GSam789, mmkeskar, kehulse       4.0
# Group049         Tianyu-Yu, Muhan He, cozic, Cheersbbg, z6sun       4.0
# Group050    BatelielB,jhcode14,KevThai,katndang,garyouyang...       5.0
# Group051    zvidmarb, TohmeNawwar, IRSMsoso, jorgeacevedo1...       4.0
# Group052                                                  NaN       NaN
# Group053                                                  NaN       NaN
# Group054                                                  NaN       NaN
# Group055                                                  NaN       NaN
# Group056                                                  NaN       NaN
# Group057                                                  NaN       NaN

# %%
groups.to_csv('assigned_groups.csv')

# %% [markdown]
# ### Github
# OK time to create a github repo for each and every group. Note to do this you need to have gh CLI installed and have authenticated it as your user (see `gh auth login` documentation)
#
# The process will create one repo for each group from the group_template.  Next we invite users to their repo. Then we checkout the project locally, rename the files, push, and delete the local copy

# %%
# YOU NEED TO CHANGE THINGS HERE EACH QUARTER!!!
# you'll have to change the name of the quarter in command_add_instructors
# and also in grpsuffix

import os
import glob


command_create = 'gh repo create --public --template COGS118A/group_template -y COGS118A/' # + groupname
command_invite = 'gh api -X PUT -f permission=push repos/COGS118A/' # + groupname/collaborators/username
command_add_instructors = 'gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/' # + groupname

grpsuffix = '-Sp22' #change this name suffix each quarter

# %%
for grp in groups.index:

    gname = grp+grpsuffix 
    
    # create new repo
    cmd = command_create+gname
    ret = os.system(cmd)
    print(cmd,ret)
    
    # add instructors to have admin access to the repo
    cmd=command_add_instructors+gname
    ret = os.system(cmd)
    print(cmd,ret)
    
    # invite everyone in the group to the repo
    if not pd.isnull(groups.loc[grp,'gitids']): # if no entries then we end up with NA/Null sometimes
        for uname in groups.loc[grp,'gitids'].split(','):
            cmd=command_invite+gname+'/collaborators/'+uname.strip()
            ret = os.system(cmd)
            print(cmd,ret)
        
    # get a local copy of the repo
    cmd='gh repo clone COGS118A/'+gname
    ret = os.system(cmd)
    print(cmd,ret)

    # rename the files in the repo to the groups name pattern
    for fname in glob.glob(gname+'/*groupXXX.ipynb'):
        source = fname.split('/')[1]
        target = source.split("_")[0]+gname+'.ipynb'
        cmd = ( 'cd '+gname+'; '+
                        ' '.join(['git mv',source,target]))
        ret = os.system(cmd)
        print(cmd,ret)
    
    # commit changes and push
    cmd = 'cd '+gname+'; git add -A; git commit -m "renamed files"; git push'
    ret = os.system(cmd)
    print(cmd,ret)
    
    # remove local copy of repo
    cmd = 'rm -rf '+gname
    ret = os.system(cmd)
    print(cmd,ret)
    
    # add instructors to the repo
    cmd=command_add_instructors+gname
    ret = os.system(cmd)
    print(cmd,ret)
# Out:
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group000-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group000-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group000-Sp22/collaborators/accunha11 0
# gh repo clone COGS118A/Group000-Sp22 0
# cd Group000-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup000-Sp22.ipynb 0
# cd Group000-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group000-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group000-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group001-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group001-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group001-Sp22/collaborators/alacau 0
# gh api -X PUT -f permission=push repos/COGS118A/Group001-Sp22/collaborators/DarksideRob 0
# gh api -X PUT -f permission=push repos/COGS118A/Group001-Sp22/collaborators/hszhao24 0
# gh api -X PUT -f permission=push repos/COGS118A/Group001-Sp22/collaborators/kyrni 0
# gh api -X PUT -f permission=push repos/COGS118A/Group001-Sp22/collaborators/sjk002 0
# gh repo clone COGS118A/Group001-Sp22 0
# cd Group001-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup001-Sp22.ipynb 0
# cd Group001-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group001-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group001-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group002-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group002-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group002-Sp22/collaborators/alxtyl 0
# gh api -X PUT -f permission=push repos/COGS118A/Group002-Sp22/collaborators/bridge-exe 0
# gh api -X PUT -f permission=push repos/COGS118A/Group002-Sp22/collaborators/Aryamansinha2704 0
# gh api -X PUT -f permission=push repos/COGS118A/Group002-Sp22/collaborators/chefpy 0
# gh repo clone COGS118A/Group002-Sp22 0
# cd Group002-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup002-Sp22.ipynb 0
# cd Group002-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group002-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group002-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group003-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group003-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group003-Sp22/collaborators/boyang102 0
# gh api -X PUT -f permission=push repos/COGS118A/Group003-Sp22/collaborators/chzhu2000 0
# gh api -X PUT -f permission=push repos/COGS118A/Group003-Sp22/collaborators/AnniLi1212 0
# gh api -X PUT -f permission=push repos/COGS118A/Group003-Sp22/collaborators/Lord-of-Bugs 0
# gh api -X PUT -f permission=push repos/COGS118A/Group003-Sp22/collaborators/JasonC1217 0
# gh repo clone COGS118A/Group003-Sp22 0
# cd Group003-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup003-Sp22.ipynb 0
# cd Group003-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group003-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group003-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group004-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group004-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group004-Sp22/collaborators/brocchio 0
# gh api -X PUT -f permission=push repos/COGS118A/Group004-Sp22/collaborators/Isa5805 0
# gh api -X PUT -f permission=push repos/COGS118A/Group004-Sp22/collaborators/danielmilton22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group004-Sp22/collaborators/dhruva7102 0
# gh api -X PUT -f permission=push repos/COGS118A/Group004-Sp22/collaborators/hadiviko 0
# gh repo clone COGS118A/Group004-Sp22 0
# cd Group004-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup004-Sp22.ipynb 0
# cd Group004-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group004-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group004-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group005-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group005-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group005-Sp22/collaborators/AeRoBro 0
# gh api -X PUT -f permission=push repos/COGS118A/Group005-Sp22/collaborators/vchou105 0
# gh api -X PUT -f permission=push repos/COGS118A/Group005-Sp22/collaborators/hsc012 0
# gh api -X PUT -f permission=push repos/COGS118A/Group005-Sp22/collaborators/yossshhhh 0
# gh repo clone COGS118A/Group005-Sp22 0
# cd Group005-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup005-Sp22.ipynb 0
# cd Group005-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group005-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group005-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group006-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group006-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group006-Sp22/collaborators/tfratant 0
# gh api -X PUT -f permission=push repos/COGS118A/Group006-Sp22/collaborators/ASuperior 0
# gh api -X PUT -f permission=push repos/COGS118A/Group006-Sp22/collaborators/evaneguchi 0
# gh api -X PUT -f permission=push repos/COGS118A/Group006-Sp22/collaborators/matthew-ucsd 0
# gh api -X PUT -f permission=push repos/COGS118A/Group006-Sp22/collaborators/Zachary-Tulman 0
# gh repo clone COGS118A/Group006-Sp22 0
# cd Group006-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup006-Sp22.ipynb 0
# cd Group006-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group006-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group006-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group007-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group007-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group007-Sp22/collaborators/chawei217 0
# gh api -X PUT -f permission=push repos/COGS118A/Group007-Sp22/collaborators/gnourtwerdna 0
# gh api -X PUT -f permission=push repos/COGS118A/Group007-Sp22/collaborators/tedfeng424 0
# gh api -X PUT -f permission=push repos/COGS118A/Group007-Sp22/collaborators/ahmads405 0
# gh api -X PUT -f permission=push repos/COGS118A/Group007-Sp22/collaborators/Chiadikav 0
# gh repo clone COGS118A/Group007-Sp22 0
# cd Group007-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup007-Sp22.ipynb 0
# cd Group007-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group007-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group007-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group008-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group008-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group008-Sp22/collaborators/caitlinsprojects-ml 0
# gh api -X PUT -f permission=push repos/COGS118A/Group008-Sp22/collaborators/csallesc 256
# gh api -X PUT -f permission=push repos/COGS118A/Group008-Sp22/collaborators/akoornwinder4 0
# gh api -X PUT -f permission=push repos/COGS118A/Group008-Sp22/collaborators/cyatco 0
# gh api -X PUT -f permission=push repos/COGS118A/Group008-Sp22/collaborators/WidjanarkoJoshua 0
# gh repo clone COGS118A/Group008-Sp22 0
# cd Group008-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup008-Sp22.ipynb 0
# cd Group008-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group008-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group008-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group009-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group009-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group009-Sp22/collaborators/StefanieDao 0
# gh api -X PUT -f permission=push repos/COGS118A/Group009-Sp22/collaborators/gelaneier 0
# gh api -X PUT -f permission=push repos/COGS118A/Group009-Sp22/collaborators/Matthewechong 0
# gh api -X PUT -f permission=push repos/COGS118A/Group009-Sp22/collaborators/chc012 0
# gh api -X PUT -f permission=push repos/COGS118A/Group009-Sp22/collaborators/tnl001 0
# gh repo clone COGS118A/Group009-Sp22 0
# cd Group009-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup009-Sp22.ipynb 0
# cd Group009-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group009-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group009-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group010-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group010-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group010-Sp22/collaborators/DavidSober 0
# gh api -X PUT -f permission=push repos/COGS118A/Group010-Sp22/collaborators/ernestl123 0
# gh api -X PUT -f permission=push repos/COGS118A/Group010-Sp22/collaborators/lorenzilipe 0
# gh api -X PUT -f permission=push repos/COGS118A/Group010-Sp22/collaborators/Shushruth007 0
# gh api -X PUT -f permission=push repos/COGS118A/Group010-Sp22/collaborators/Mrgnhrsn 0
# gh repo clone COGS118A/Group010-Sp22 0
# cd Group010-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup010-Sp22.ipynb 0
# cd Group010-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group010-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group010-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group011-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group011-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group011-Sp22/collaborators/shadowfall117 0
# gh api -X PUT -f permission=push repos/COGS118A/Group011-Sp22/collaborators/shli1126 0
# gh api -X PUT -f permission=push repos/COGS118A/Group011-Sp22/collaborators/yinyin0916 0
# gh api -X PUT -f permission=push repos/COGS118A/Group011-Sp22/collaborators/zic017 0
# gh api -X PUT -f permission=push repos/COGS118A/Group011-Sp22/collaborators/RecluseHermit 0
# gh repo clone COGS118A/Group011-Sp22 0
# cd Group011-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup011-Sp22.ipynb 0
# cd Group011-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group011-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group011-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group012-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group012-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group012-Sp22/collaborators/gilbertorobles24 0
# gh api -X PUT -f permission=push repos/COGS118A/Group012-Sp22/collaborators/jasonsheu 0
# gh api -X PUT -f permission=push repos/COGS118A/Group012-Sp22/collaborators/soyoybean 0
# gh api -X PUT -f permission=push repos/COGS118A/Group012-Sp22/collaborators/allantangent 0
# gh repo clone COGS118A/Group012-Sp22 0
# cd Group012-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup012-Sp22.ipynb 0
# cd Group012-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group012-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group012-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group013-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group013-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group013-Sp22/collaborators/nataliekwong925 0
# gh api -X PUT -f permission=push repos/COGS118A/Group013-Sp22/collaborators/prorick 0
# gh api -X PUT -f permission=push repos/COGS118A/Group013-Sp22/collaborators/NolanChai 0
# gh api -X PUT -f permission=push repos/COGS118A/Group013-Sp22/collaborators/gordonyye 0
# gh repo clone COGS118A/Group013-Sp22 0
# cd Group013-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup013-Sp22.ipynb 0
# cd Group013-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group013-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group013-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group014-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group014-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group014-Sp22/collaborators/vikizzz 0
# gh api -X PUT -f permission=push repos/COGS118A/Group014-Sp22/collaborators/Amandahuang0101 0
# gh api -X PUT -f permission=push repos/COGS118A/Group014-Sp22/collaborators/belladu0201 0
# gh api -X PUT -f permission=push repos/COGS118A/Group014-Sp22/collaborators/laveee 0
# gh api -X PUT -f permission=push repos/COGS118A/Group014-Sp22/collaborators/Meijiang0905 0
# gh repo clone COGS118A/Group014-Sp22 0
# cd Group014-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup014-Sp22.ipynb 0
# cd Group014-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group014-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group014-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group015-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group015-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group015-Sp22/collaborators/LJW0105 0
# gh api -X PUT -f permission=push repos/COGS118A/Group015-Sp22/collaborators/jjcggarciajuan 0
# gh api -X PUT -f permission=push repos/COGS118A/Group015-Sp22/collaborators/TomlandHilarious 0
# gh api -X PUT -f permission=push repos/COGS118A/Group015-Sp22/collaborators/suranamanan 0
# gh repo clone COGS118A/Group015-Sp22 0
# cd Group015-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup015-Sp22.ipynb 0
# cd Group015-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group015-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group015-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group016-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group016-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group016-Sp22/collaborators/satomitheito 0
# gh api -X PUT -f permission=push repos/COGS118A/Group016-Sp22/collaborators/LBY777 0
# gh api -X PUT -f permission=push repos/COGS118A/Group016-Sp22/collaborators/joakimawesome 0
# gh api -X PUT -f permission=push repos/COGS118A/Group016-Sp22/collaborators/WilsJT 0
# gh api -X PUT -f permission=push repos/COGS118A/Group016-Sp22/collaborators/PudanXu 0
# gh repo clone COGS118A/Group016-Sp22 0
# cd Group016-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup016-Sp22.ipynb 0
# cd Group016-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group016-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group016-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group017-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group017-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group017-Sp22/collaborators/bchu-ops 0
# gh api -X PUT -f permission=push repos/COGS118A/Group017-Sp22/collaborators/jik003 0
# gh api -X PUT -f permission=push repos/COGS118A/Group017-Sp22/collaborators/ethanl94 0
# gh api -X PUT -f permission=push repos/COGS118A/Group017-Sp22/collaborators/riyli 0
# gh repo clone COGS118A/Group017-Sp22 0
# cd Group017-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup017-Sp22.ipynb 0
# cd Group017-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group017-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group017-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group018-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group018-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group018-Sp22/collaborators/Jai-M9 0
# gh api -X PUT -f permission=push repos/COGS118A/Group018-Sp22/collaborators/e1gutier 0
# gh api -X PUT -f permission=push repos/COGS118A/Group018-Sp22/collaborators/Hgallocodes 0
# gh api -X PUT -f permission=push repos/COGS118A/Group018-Sp22/collaborators/artusor 0
# gh api -X PUT -f permission=push repos/COGS118A/Group018-Sp22/collaborators/marcopared 0
# gh repo clone COGS118A/Group018-Sp22 0
# cd Group018-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup018-Sp22.ipynb 0
# cd Group018-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group018-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group018-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group019-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group019-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group019-Sp22/collaborators/jjohashi 0
# gh api -X PUT -f permission=push repos/COGS118A/Group019-Sp22/collaborators/dzthai 0
# gh api -X PUT -f permission=push repos/COGS118A/Group019-Sp22/collaborators/NicholasNassour 0
# gh api -X PUT -f permission=push repos/COGS118A/Group019-Sp22/collaborators/dbyers15 0
# gh api -X PUT -f permission=push repos/COGS118A/Group019-Sp22/collaborators/mikeheheda 0
# gh repo clone COGS118A/Group019-Sp22 0
# cd Group019-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup019-Sp22.ipynb 0
# cd Group019-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group019-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group019-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group020-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group020-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group020-Sp22/collaborators/joxieli613 0
# gh api -X PUT -f permission=push repos/COGS118A/Group020-Sp22/collaborators/Bootpocalypse 0
# gh api -X PUT -f permission=push repos/COGS118A/Group020-Sp22/collaborators/Marykovic 0
# gh api -X PUT -f permission=push repos/COGS118A/Group020-Sp22/collaborators/WeiZ321 0
# gh api -X PUT -f permission=push repos/COGS118A/Group020-Sp22/collaborators/Jyamaguc 0
# gh repo clone COGS118A/Group020-Sp22 0
# cd Group020-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup020-Sp22.ipynb 0
# cd Group020-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group020-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group020-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group021-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group021-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group021-Sp22/collaborators/jspark0002 0
# gh api -X PUT -f permission=push repos/COGS118A/Group021-Sp22/collaborators/esl001 256
# gh api -X PUT -f permission=push repos/COGS118A/Group021-Sp22/collaborators/franklinle 0
# gh api -X PUT -f permission=push repos/COGS118A/Group021-Sp22/collaborators/suebeen2001 0
# gh api -X PUT -f permission=push repos/COGS118A/Group021-Sp22/collaborators/DantheCoolMan 0
# gh repo clone COGS118A/Group021-Sp22 0
# cd Group021-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup021-Sp22.ipynb 0
# cd Group021-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group021-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group021-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group022-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group022-Sp22 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-bc86ca83f951> in <module>
#      14
#      15     # invite everyone in the group to the repo
# ---> 16     for uname in groups.loc[grp,'gitids'].split(','):
#      17         cmd=command_invite+gname+'/collaborators/'+uname.strip()
#      18         ret = os.system(cmd)
#
# AttributeError: 'float' object has no attribute 'split'

# %% [markdown]
# ### oops
# someone had a shitty github username thing going on here. The fix is to edit the csv by hand and reload and continue on as if nothing had happened from the stopping point. Hopefully you don't have this again next time, but make sure what the gitids look like before running

# %%
groups.index[22:]
# Out:
# Index(['Group022', 'Group023', 'Group024', 'Group025', 'Group026', 'Group027',
#        'Group028', 'Group029', 'Group030', 'Group031', 'Group032', 'Group033',
#        'Group034', 'Group035', 'Group036', 'Group037', 'Group038', 'Group039',
#        'Group040', 'Group041', 'Group042', 'Group043', 'Group044', 'Group045',
#        'Group046', 'Group047', 'Group048', 'Group049', 'Group050', 'Group051',
#        'Group052', 'Group053', 'Group054', 'Group055', 'Group056', 'Group057'],
#       dtype='object', name='group_name')

# %%
for grp in groups.index[22:]:

    gname = grp+grpsuffix 
    
    # create new repo
    cmd = command_create+gname
    ret = os.system(cmd)
    print(cmd,ret)
    
    # add instructors to have admin access to the repo
    cmd=command_add_instructors+gname
    ret = os.system(cmd)
    print(cmd,ret)
    
    # invite everyone in the group to the repo
    if not pd.isnull(groups.loc[grp,'gitids']): # if no entries then we end up with NA/Null sometimes
        for uname in groups.loc[grp,'gitids'].split(','):
            cmd=command_invite+gname+'/collaborators/'+uname.strip()
            ret = os.system(cmd)
            print(cmd,ret)
        
    # get a local copy of the repo
    cmd='gh repo clone COGS118A/'+gname
    ret = os.system(cmd)
    print(cmd,ret)

    # rename the files in the repo to the groups name pattern
    for fname in glob.glob(gname+'/*groupXXX.ipynb'):
        source = fname.split('/')[1]
        target = source.split("_")[0]+gname+'.ipynb'
        cmd = ( 'cd '+gname+'; '+
                        ' '.join(['git mv',source,target]))
        ret = os.system(cmd)
        print(cmd,ret)
    
    # commit changes and push
    cmd = 'cd '+gname+'; git add -A; git commit -m "renamed files"; git push'
    ret = os.system(cmd)
    print(cmd,ret)
    
    # remove local copy of repo
    cmd = 'rm -rf '+gname
    ret = os.system(cmd)
    print(cmd,ret)
    
    # add instructors to the repo
    cmd=command_add_instructors+gname
    ret = os.system(cmd)
    print(cmd,ret)
# Out:
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group022-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group022-Sp22 0
# gh repo clone COGS118A/Group022-Sp22 0
# cd Group022-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup022-Sp22.ipynb 0
# cd Group022-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group022-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group022-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group023-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group023-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group023-Sp22/collaborators/kevdesilva01 0
# gh api -X PUT -f permission=push repos/COGS118A/Group023-Sp22/collaborators/alext-prog 0
# gh api -X PUT -f permission=push repos/COGS118A/Group023-Sp22/collaborators/SuperKomi 0
# gh api -X PUT -f permission=push repos/COGS118A/Group023-Sp22/collaborators/EfrainContreras-ucsd 0
# gh api -X PUT -f permission=push repos/COGS118A/Group023-Sp22/collaborators/Mhambly 0
# gh repo clone COGS118A/Group023-Sp22 0
# cd Group023-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup023-Sp22.ipynb 0
# cd Group023-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group023-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group023-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group024-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group024-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group024-Sp22/collaborators/jasqiang 0
# gh api -X PUT -f permission=push repos/COGS118A/Group024-Sp22/collaborators/DrakeCoy 0
# gh api -X PUT -f permission=push repos/COGS118A/Group024-Sp22/collaborators/simrannayyar 0
# gh api -X PUT -f permission=push repos/COGS118A/Group024-Sp22/collaborators/Aditikk00 0
# gh api -X PUT -f permission=push repos/COGS118A/Group024-Sp22/collaborators/lsztajnkrycer 0
# gh repo clone COGS118A/Group024-Sp22 0
# cd Group024-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup024-Sp22.ipynb 0
# cd Group024-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group024-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group024-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group025-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group025-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group025-Sp22/collaborators/lilly-pad 0
# gh api -X PUT -f permission=push repos/COGS118A/Group025-Sp22/collaborators/merelvdbs 0
# gh api -X PUT -f permission=push repos/COGS118A/Group025-Sp22/collaborators/ajrivera721 0
# gh api -X PUT -f permission=push repos/COGS118A/Group025-Sp22/collaborators/zmaung19 0
# gh repo clone COGS118A/Group025-Sp22 0
# cd Group025-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup025-Sp22.ipynb 0
# cd Group025-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group025-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group025-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group026-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group026-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group026-Sp22/collaborators/zmyzmyzmy 0
# gh api -X PUT -f permission=push repos/COGS118A/Group026-Sp22/collaborators/ShengjieMao 0
# gh api -X PUT -f permission=push repos/COGS118A/Group026-Sp22/collaborators/Yukodeng 0
# gh repo clone COGS118A/Group026-Sp22 0
# cd Group026-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup026-Sp22.ipynb 0
# cd Group026-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group026-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group026-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group027-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group027-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group027-Sp22/collaborators/NickHale01 0
# gh api -X PUT -f permission=push repos/COGS118A/Group027-Sp22/collaborators/DarrenWu42 0
# gh api -X PUT -f permission=push repos/COGS118A/Group027-Sp22/collaborators/dinadehaini 0
# gh api -X PUT -f permission=push repos/COGS118A/Group027-Sp22/collaborators/stephaniekwan 0
# gh api -X PUT -f permission=push repos/COGS118A/Group027-Sp22/collaborators/amyhardy 0
# gh repo clone COGS118A/Group027-Sp22 0
# cd Group027-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup027-Sp22.ipynb 0
# cd Group027-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group027-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group027-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group028-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group028-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group028-Sp22/collaborators/Pmoreno629 0
# gh api -X PUT -f permission=push repos/COGS118A/Group028-Sp22/collaborators/kade09 0
# gh api -X PUT -f permission=push repos/COGS118A/Group028-Sp22/collaborators/oakaigh 0
# gh api -X PUT -f permission=push repos/COGS118A/Group028-Sp22/collaborators/SujaySri 0
# gh api -X PUT -f permission=push repos/COGS118A/Group028-Sp22/collaborators/bvegaloj 0
# gh repo clone COGS118A/Group028-Sp22 0
# cd Group028-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup028-Sp22.ipynb 0
# cd Group028-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group028-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group028-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group029-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group029-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group029-Sp22/collaborators/pndesai2000 0
# gh api -X PUT -f permission=push repos/COGS118A/Group029-Sp22/collaborators/Zijie-Lei 0
# gh api -X PUT -f permission=push repos/COGS118A/Group029-Sp22/collaborators/ayiply 0
# gh api -X PUT -f permission=push repos/COGS118A/Group029-Sp22/collaborators/bkwong315 0
# gh api -X PUT -f permission=push repos/COGS118A/Group029-Sp22/collaborators/MingQiu99 0
# gh repo clone COGS118A/Group029-Sp22 0
# cd Group029-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup029-Sp22.ipynb 0
# cd Group029-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group029-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group029-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group030-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group030-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group030-Sp22/collaborators/ryanbbb 0
# gh api -X PUT -f permission=push repos/COGS118A/Group030-Sp22/collaborators/reymendoza111 0
# gh api -X PUT -f permission=push repos/COGS118A/Group030-Sp22/collaborators/Terence2018 0
# gh repo clone COGS118A/Group030-Sp22 0
# cd Group030-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup030-Sp22.ipynb 0
# cd Group030-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group030-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group030-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group031-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group031-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group031-Sp22/collaborators/rdoron 0
# gh api -X PUT -f permission=push repos/COGS118A/Group031-Sp22/collaborators/rravi3 0
# gh api -X PUT -f permission=push repos/COGS118A/Group031-Sp22/collaborators/brip 0
# gh api -X PUT -f permission=push repos/COGS118A/Group031-Sp22/collaborators/zterryy 0
# gh api -X PUT -f permission=push repos/COGS118A/Group031-Sp22/collaborators/kmyohan0 0
# gh repo clone COGS118A/Group031-Sp22 0
# cd Group031-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup031-Sp22.ipynb 0
# cd Group031-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group031-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group031-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group032-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group032-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group032-Sp22/collaborators/rich-liu 0
# gh api -X PUT -f permission=push repos/COGS118A/Group032-Sp22/collaborators/KareemaKilani 0
# gh api -X PUT -f permission=push repos/COGS118A/Group032-Sp22/collaborators/Abisawtell 0
# gh api -X PUT -f permission=push repos/COGS118A/Group032-Sp22/collaborators/suhjoshua 0
# gh api -X PUT -f permission=push repos/COGS118A/Group032-Sp22/collaborators/RamseyCervantes 0
# gh repo clone COGS118A/Group032-Sp22 0
# cd Group032-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup032-Sp22.ipynb 0
# cd Group032-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group032-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group032-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group033-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group033-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group033-Sp22/collaborators/kyumin14 0
# gh api -X PUT -f permission=push repos/COGS118A/Group033-Sp22/collaborators/locomoco1313 0
# gh api -X PUT -f permission=push repos/COGS118A/Group033-Sp22/collaborators/ryandesmond1104 0
# gh api -X PUT -f permission=push repos/COGS118A/Group033-Sp22/collaborators/chrismolina986 0
# gh api -X PUT -f permission=push repos/COGS118A/Group033-Sp22/collaborators/emejiatr 0
# gh repo clone COGS118A/Group033-Sp22 0
# cd Group033-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup033-Sp22.ipynb 0
# cd Group033-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group033-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group033-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group034-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group034-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group034-Sp22/collaborators/Paulimorphism 0
# gh api -X PUT -f permission=push repos/COGS118A/Group034-Sp22/collaborators/xiw019 0
# gh api -X PUT -f permission=push repos/COGS118A/Group034-Sp22/collaborators/zlsjClaire 0
# gh api -X PUT -f permission=push repos/COGS118A/Group034-Sp22/collaborators/Annieqian02 0
# gh repo clone COGS118A/Group034-Sp22 0
# cd Group034-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup034-Sp22.ipynb 0
# cd Group034-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group034-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group034-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group035-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group035-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group035-Sp22/collaborators/ssbarrera 0
# gh api -X PUT -f permission=push repos/COGS118A/Group035-Sp22/collaborators/vctrnna 0
# gh api -X PUT -f permission=push repos/COGS118A/Group035-Sp22/collaborators/zlenus 0
# gh api -X PUT -f permission=push repos/COGS118A/Group035-Sp22/collaborators/angrybeanz 0
# gh api -X PUT -f permission=push repos/COGS118A/Group035-Sp22/collaborators/gocegued 0
# gh repo clone COGS118A/Group035-Sp22 0
# cd Group035-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup035-Sp22.ipynb 0
# cd Group035-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group035-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group035-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group036-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group036-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group036-Sp22/collaborators/samuel-d-woo 0
# gh api -X PUT -f permission=push repos/COGS118A/Group036-Sp22/collaborators/kylechristophermoore 0
# gh api -X PUT -f permission=push repos/COGS118A/Group036-Sp22/collaborators/TheRealMambaz 0
# gh repo clone COGS118A/Group036-Sp22 0
# cd Group036-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup036-Sp22.ipynb 0
# cd Group036-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group036-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group036-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group037-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group037-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group037-Sp22/collaborators/rkhateeb 0
# gh api -X PUT -f permission=push repos/COGS118A/Group037-Sp22/collaborators/cdonasco 0
# gh api -X PUT -f permission=push repos/COGS118A/Group037-Sp22/collaborators/MikecraftA 0
# gh api -X PUT -f permission=push repos/COGS118A/Group037-Sp22/collaborators/IsAria233 0
# gh api -X PUT -f permission=push repos/COGS118A/Group037-Sp22/collaborators/SiuWu 0
# gh repo clone COGS118A/Group037-Sp22 0
# cd Group037-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup037-Sp22.ipynb 0
# cd Group037-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group037-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group037-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group038-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group038-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group038-Sp22/collaborators/itsjanty 0
# gh api -X PUT -f permission=push repos/COGS118A/Group038-Sp22/collaborators/zuraneb 0
# gh api -X PUT -f permission=push repos/COGS118A/Group038-Sp22/collaborators/ingridalt 0
# gh api -X PUT -f permission=push repos/COGS118A/Group038-Sp22/collaborators/t7bui 0
# gh api -X PUT -f permission=push repos/COGS118A/Group038-Sp22/collaborators/romanov360 0
# gh repo clone COGS118A/Group038-Sp22 0
# cd Group038-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup038-Sp22.ipynb 0
# cd Group038-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group038-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group038-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group039-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group039-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group039-Sp22/collaborators/Tianyu-Yu 0
# gh api -X PUT -f permission=push repos/COGS118A/Group039-Sp22/collaborators/Cheersbbg 0
# gh api -X PUT -f permission=push repos/COGS118A/Group039-Sp22/collaborators/cozic 0
# gh api -X PUT -f permission=push repos/COGS118A/Group039-Sp22/collaborators/Muhan He 256
# gh repo clone COGS118A/Group039-Sp22 0
# cd Group039-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup039-Sp22.ipynb 0
# cd Group039-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group039-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group039-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group040-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group040-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group040-Sp22/collaborators/wrblynch 0
# gh api -X PUT -f permission=push repos/COGS118A/Group040-Sp22/collaborators/lkatanic 0
# gh api -X PUT -f permission=push repos/COGS118A/Group040-Sp22/collaborators/hwiyeo 0
# gh api -X PUT -f permission=push repos/COGS118A/Group040-Sp22/collaborators/RynaK1 0
# gh api -X PUT -f permission=push repos/COGS118A/Group040-Sp22/collaborators/gordon1213 0
# gh repo clone COGS118A/Group040-Sp22 0
# cd Group040-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup040-Sp22.ipynb 0
# cd Group040-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group040-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group040-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group041-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group041-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group041-Sp22/collaborators/mxnares 0
# gh api -X PUT -f permission=push repos/COGS118A/Group041-Sp22/collaborators/rainarit 0
# gh api -X PUT -f permission=push repos/COGS118A/Group041-Sp22/collaborators/WillSumerfield 0
# gh api -X PUT -f permission=push repos/COGS118A/Group041-Sp22/collaborators/mhm1117 0
# gh api -X PUT -f permission=push repos/COGS118A/Group041-Sp22/collaborators/abdalla-atalla 0
# gh repo clone COGS118A/Group041-Sp22 0
# cd Group041-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup041-Sp22.ipynb 0
# cd Group041-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group041-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group041-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group042-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group042-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group042-Sp22/collaborators/TIMHX 0
# gh api -X PUT -f permission=push repos/COGS118A/Group042-Sp22/collaborators/Luning-Yang 0
# gh api -X PUT -f permission=push repos/COGS118A/Group042-Sp22/collaborators/yunyihuang 0
# gh api -X PUT -f permission=push repos/COGS118A/Group042-Sp22/collaborators/AnnieeeeeF 0
# gh api -X PUT -f permission=push repos/COGS118A/Group042-Sp22/collaborators/3XiangyiKong3 0
# gh repo clone COGS118A/Group042-Sp22 0
# cd Group042-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup042-Sp22.ipynb 0
# cd Group042-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group042-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group042-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group043-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group043-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group043-Sp22/collaborators/NicoloWX 0
# gh api -X PUT -f permission=push repos/COGS118A/Group043-Sp22/collaborators/CainChen1 0
# gh api -X PUT -f permission=push repos/COGS118A/Group043-Sp22/collaborators/h3song 0
# gh api -X PUT -f permission=push repos/COGS118A/Group043-Sp22/collaborators/ileolin3 0
# gh api -X PUT -f permission=push repos/COGS118A/Group043-Sp22/collaborators/fjkal23jk 0
# gh repo clone COGS118A/Group043-Sp22 0
# cd Group043-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup043-Sp22.ipynb 0
# cd Group043-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group043-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group043-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group044-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group044-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group044-Sp22/collaborators/yiyang-cao 0
# gh api -X PUT -f permission=push repos/COGS118A/Group044-Sp22/collaborators/pu-tan 0
# gh api -X PUT -f permission=push repos/COGS118A/Group044-Sp22/collaborators/NioOunt 0
# gh api -X PUT -f permission=push repos/COGS118A/Group044-Sp22/collaborators/ZefangYuan 0
# gh repo clone COGS118A/Group044-Sp22 0
# cd Group044-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup044-Sp22.ipynb 0
# cd Group044-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group044-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group044-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group045-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group045-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group045-Sp22/collaborators/AlphaAmeame 0
# gh api -X PUT -f permission=push repos/COGS118A/Group045-Sp22/collaborators/dududubingbong 0
# gh api -X PUT -f permission=push repos/COGS118A/Group045-Sp22/collaborators/Zheran-Li 0
# gh api -X PUT -f permission=push repos/COGS118A/Group045-Sp22/collaborators/ywchoi02 0
# gh api -X PUT -f permission=push repos/COGS118A/Group045-Sp22/collaborators/YiyaoL 0
# gh repo clone COGS118A/Group045-Sp22 0
# cd Group045-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup045-Sp22.ipynb 0
# cd Group045-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group045-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group045-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group046-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group046-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group046-Sp22/collaborators/akai820 0
# gh api -X PUT -f permission=push repos/COGS118A/Group046-Sp22/collaborators/xiqiangliu 0
# gh api -X PUT -f permission=push repos/COGS118A/Group046-Sp22/collaborators/LianLumada 0
# gh api -X PUT -f permission=push repos/COGS118A/Group046-Sp22/collaborators/shz42 0
# gh api -X PUT -f permission=push repos/COGS118A/Group046-Sp22/collaborators/MChengW 0
# gh repo clone COGS118A/Group046-Sp22 0
# cd Group046-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup046-Sp22.ipynb 0
# cd Group046-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group046-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group046-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group047-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group047-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group047-Sp22/collaborators/robertzhang0531 0
# gh api -X PUT -f permission=push repos/COGS118A/Group047-Sp22/collaborators/nickuncaged1201 0
# gh api -X PUT -f permission=push repos/COGS118A/Group047-Sp22/collaborators/whybruhh 0
# gh api -X PUT -f permission=push repos/COGS118A/Group047-Sp22/collaborators/Jianghualu 0
# gh api -X PUT -f permission=push repos/COGS118A/Group047-Sp22/collaborators/YLuo0216 0
# gh repo clone COGS118A/Group047-Sp22 0
# cd Group047-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup047-Sp22.ipynb 0
# cd Group047-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group047-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group047-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group048-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group048-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group048-Sp22/collaborators/YashPotdar 0
# gh api -X PUT -f permission=push repos/COGS118A/Group048-Sp22/collaborators/GSam789 0
# gh api -X PUT -f permission=push repos/COGS118A/Group048-Sp22/collaborators/mmkeskar 0
# gh api -X PUT -f permission=push repos/COGS118A/Group048-Sp22/collaborators/kehulse 0
# gh repo clone COGS118A/Group048-Sp22 0
# cd Group048-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup048-Sp22.ipynb 0
# cd Group048-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group048-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group048-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group049-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group049-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group049-Sp22/collaborators/Tianyu-Yu 0
# gh api -X PUT -f permission=push repos/COGS118A/Group049-Sp22/collaborators/Muhan He 256
# gh api -X PUT -f permission=push repos/COGS118A/Group049-Sp22/collaborators/cozic 0
# gh api -X PUT -f permission=push repos/COGS118A/Group049-Sp22/collaborators/Cheersbbg 0
# gh api -X PUT -f permission=push repos/COGS118A/Group049-Sp22/collaborators/z6sun 0
# gh repo clone COGS118A/Group049-Sp22 0
# cd Group049-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup049-Sp22.ipynb 0
# cd Group049-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group049-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group049-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group050-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group050-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group050-Sp22/collaborators/BatelielB 0
# gh api -X PUT -f permission=push repos/COGS118A/Group050-Sp22/collaborators/jhcode14 0
# gh api -X PUT -f permission=push repos/COGS118A/Group050-Sp22/collaborators/KevThai 0
# gh api -X PUT -f permission=push repos/COGS118A/Group050-Sp22/collaborators/katndang 0
# gh api -X PUT -f permission=push repos/COGS118A/Group050-Sp22/collaborators/garyouyang9449 0
# gh repo clone COGS118A/Group050-Sp22 0
# cd Group050-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup050-Sp22.ipynb 0
# cd Group050-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group050-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group050-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group051-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group051-Sp22 0
# gh api -X PUT -f permission=push repos/COGS118A/Group051-Sp22/collaborators/zvidmarb 0
# gh api -X PUT -f permission=push repos/COGS118A/Group051-Sp22/collaborators/TohmeNawwar 0
# gh api -X PUT -f permission=push repos/COGS118A/Group051-Sp22/collaborators/IRSMsoso 0
# gh api -X PUT -f permission=push repos/COGS118A/Group051-Sp22/collaborators/jorgeacevedo13 0
# gh api -X PUT -f permission=push repos/COGS118A/Group051-Sp22/collaborators/nickthegroot (Nicholas DeGroot - our 5th member 512
# gh api -X PUT -f permission=push repos/COGS118A/Group051-Sp22/collaborators/working out enrollment rn) 512
# gh repo clone COGS118A/Group051-Sp22 0
# cd Group051-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup051-Sp22.ipynb 0
# cd Group051-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group051-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group051-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group052-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group052-Sp22 0
# gh repo clone COGS118A/Group052-Sp22 0
# cd Group052-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup052-Sp22.ipynb 0
# cd Group052-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group052-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group052-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group053-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group053-Sp22 0
# gh repo clone COGS118A/Group053-Sp22 0
# cd Group053-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup053-Sp22.ipynb 0
# cd Group053-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group053-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group053-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group054-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group054-Sp22 0
# gh repo clone COGS118A/Group054-Sp22 0
# cd Group054-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup054-Sp22.ipynb 0
# cd Group054-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group054-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group054-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group055-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group055-Sp22 0
# gh repo clone COGS118A/Group055-Sp22 0
# cd Group055-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup055-Sp22.ipynb 0
# cd Group055-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group055-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group055-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group056-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group056-Sp22 0
# gh repo clone COGS118A/Group056-Sp22 0
# cd Group056-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup056-Sp22.ipynb 0
# cd Group056-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group056-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group056-Sp22 0
# gh repo create --public --template COGS118A/group_template -y COGS118A/Group057-Sp22 256
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group057-Sp22 0
# gh repo clone COGS118A/Group057-Sp22 0
# cd Group057-Sp22; git mv Proposal_groupXXX.ipynb ProposalGroup057-Sp22.ipynb 0
# cd Group057-Sp22; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group057-Sp22 0
# gh api -X PUT -f permission=admin /orgs/COGS118A/teams/Instructors_Sp22/repos/COGS118A/Group057-Sp22 0

# %%
groups = pd.read_csv('assigned_groups.csv')
groups
# Out:
#    group_name                                              names  \
# 0    Group000  Ana Cunha, Kyra Hulse, Esmeralda Mejia-Trejo, ...
# 1    Group001  Alan Cao, Robert Aispuro, Helen Zhao, Connie C...
# 2    Group002  Bridget Egan, John Pyjar, Alex Tyler, Aryaman ...
# 3    Group003  Boning Yang, Chenhao Zhu, Anni Li, Muchan Li, ...
# 4    Group004  Harini Adivikolanu, Isabella Gonzalez, Daniel ...
# 5    Group005  Brandon Vazquez-Tellez, Vicky Chou, Hsi Chen, ...
# 6    Group006  Charles Ye, Thomas Fratantoni, Evan Eguchi, Ma...
# 7    Group007  Chao-Li Wei, Andrew Truong, Ted Feng, Ahmad Sa...
# 8    Group008  Caitlin Connolly, Caike Salles-Campana, Abigai...
# 9    Group009  Stefanie Dao, Yepeng Li, Matthew Chong, Cheng ...
# 10   Group010  David Soberanis, Ernest Lin, Felipe Lorenzi, S...
# 11   Group011  Feifan Li, Shaolong Li, Rosy Xu, Zikang Chen, ...
# 12   Group012  Gilberto Robles, Jason Sheu, Soyon Kim, Allan Tan
# 13   Group013  Natalie Kwong, Prothit Halder, Nolan Chai, Gor...
# 14   Group014  Jiayi Zhao, Beibei Du, Meijiang Shen, Hongfei ...
# 15   Group015  Kimberly Liu, Ruoxuan Li, Juan Castillejos-Gar...
# 16   Group016  Satomi Ito, Boyong Liu, Joakim Nguyen, Wilson ...
# 17   Group017        Brian Chu, Jisu Kim, Taekyu Lee, Richard Li
# 18   Group018  Jaikishan Mali, Emmanuel Gutierrez, Hector Gal...
# 19   Group019  Jordyn Ohashi, David Thai, Daniel Byers, Nicho...
# 20   Group020  Wei Zhong, Jota Yamaguchi, Josie Li, Mary Kovi...
# 21   Group021  Daniel Renteria, Jonathan Park, Eun Lee, Suebe...
# 22   Group022  Jota Yamaguchi, Josie Li, David Wang, Wei Zhon...
# 23   Group023  Kevin De Silva Jayasinghe, Alex Tsatryan, Ramy...
# 24   Group024  Jasmine Qiang, Drake Coy, Simran Nayyar, Aditi...
# 25   Group025  Lillian Wood, Merel Van-Den-Bos, Alex Rivera, ...
# 26   Group026  Shengjie Mao, Mengyu Zhang, Yufei Deng, Dylan ...
# 27   Group027  Darren Wu, Dina Dehaini, Stephanie Kwan, Amy H...
# 28   Group028  Borja Vega-Lojo, Kalid Ade, Sujay Srinivasan, ...
# 29   Group029  Paayal Desai, Harry Lei, Andy Ly, Brian Wong, ...
# 30   Group030  Ryan Burden, Rey Mendoza, Terence Ting, Joshua...
# 31   Group031  Tianze Zhang, Brian Ripley, Rachel Doron, Yoha...
# 18  Jai-M9, e1gutier, Hgallocodes, artusor, marcop...       5.0
# 19  jjohashi,dzthai,NicholasNassour,dbyers15,mikeh...       5.0
# 20  joxieli613, Bootpocalypse, Marykovic, WeiZ321,...       5.0
# 21  jspark0002, esl001, franklinle, suebeen2001, D...       5.0
# 22                                                NaN       5.0
# 23  kevdesilva01, alext-prog, SuperKomi, EfrainCon...       5.0
# 24  jasqiang, DrakeCoy, simrannayyar, Aditikk00, l...       5.0
# 25        lilly-pad, merelvdbs, ajrivera721, zmaung19       4.0
# 26                   zmyzmyzmy, ShengjieMao, Yukodeng       3.0
# 27  NickHale01, DarrenWu42, dinadehaini, stephanie...       5.0
# 28    Pmoreno629, kade09, oakaigh, SujaySri, bvegaloj       5.0
# 29  pndesai2000, Zijie-Lei, ayiply, bkwong315, Min...       5.0
# 30                  ryanbbb,reymendoza111,Terence2018       3.0
# 31            rdoron, rravi3, brip, zterryy, kmyohan0       5.0
# 32  rich-liu,KareemaKilani,Abisawtell,suhjoshua,Ra...       5.0
# 33  kyumin14, locomoco1313, ryandesmond1104, chris...       5.0
# 34     Paulimorphism, xiw019, zlsjClaire, Annieqian02       4.0
# 35  ssbarrera, vctrnna , zlenus, angrybeanz, gocegued       5.0
# 36  samuel-d-woo, kylechristophermoore, TheRealMambaz       5.0
# 37   rkhateeb, cdonasco, MikecraftA, IsAria233, SiuWu       5.0
# 38    itsjanty, zuraneb, ingridalt, t7bui, romanov360       5.0
# 39             Tianyu-Yu, Cheersbbg,  cozic, Muhan He       4.0
# 40     wrblynch, lkatanic, hwiyeo, RynaK1, gordon1213       5.0
# 41  mxnares,rainarit,WillSumerfield,mhm1117,abdall...       5.0
# 42  TIMHX, Luning-Yang, yunyihuang, AnnieeeeeF, 3X...       5.0
# 43  NicoloWX, CainChen1,  h3song, ileolin3, fjkal23jk       5.0
# 44            yiyang-cao, pu-tan, NioOunt, ZefangYuan       4.0
# 45  AlphaAmeame, dududubingbong, Zheran-Li, ywchoi...       5.0
# 46    akai820, xiqiangliu, LianLumada, shz42, MChengW       5.0
# 47  robertzhang0531,nickuncaged1201,whybruhh,Jiang...       5.0
# 48             YashPotdar, GSam789, mmkeskar, kehulse       4.0
# 49       Tianyu-Yu, Muhan He, cozic, Cheersbbg, z6sun       4.0
# 50  BatelielB,jhcode14,KevThai,katndang,garyouyang...       5.0
# 51  zvidmarb, TohmeNawwar, IRSMsoso, jorgeacevedo1...       4.0
# 52                                                NaN       NaN
# 53                                                NaN       NaN
# 54                                                NaN       NaN
# 55                                                NaN       NaN
# 56                                                NaN       NaN
# 57                                                NaN       NaN

# %%
# find duplicate names
xx = groups.set_index('group_name').names.apply(lambda x: [y.strip() for y in x.split(',')])
outs = []
for nn,yy in xx.iteritems():
    #print(nn,yy)
    for zz in yy:
        outs.append((nn,zz))
peeps = pd.DataFrame(outs,columns=['group','name'])
peeps.loc[ peeps.duplicated(subset='name',keep=False)].sort_values(by=['group','name'])
# Out:
#         group                   name
# 2    Group000  Esmeralda Mejia-Trejo
# 1    Group000             Kyra Hulse
# 10   Group002             John Pyjar
# 97   Group020             David Wang
# 95   Group020               Josie Li
# 94   Group020         Jota Yamaguchi
# 96   Group020             Mary Kovic
# 93   Group020              Wei Zhong
# 105  Group022             David Wang
# 104  Group022               Josie Li
# 103  Group022         Jota Yamaguchi
# 107  Group022             Mary Kovic
# 106  Group022              Wei Zhong
# 159  Group033  Esmeralda Mejia-Trejo
# 173  Group036             John Pyjar
# 184  Group039               Muhan He
# 186  Group039            Qianxi Gong
# 187  Group039              Tianyu Yu
# 185  Group039            Ziheng Chen
# 230  Group048             Kyra Hulse
# 233  Group049               Muhan He
# 232  Group049            Qianxi Gong
# 234  Group049              Tianyu Yu
# 231  Group049            Ziheng Chen

# %% [markdown]
# # What went wrong
#
# And I have zero idea why at this point.  TBD next quarter before running this
#
# ### Duplicate groups, identical members:
# - Group020 and 022: Wang, Li, Yamaguchi, Kovic, Zhong
# - Group039 and 049: He, Gong, Yu, Chen
#
# #### Fix for dupe groups
# Notice the people involved, get the dupe groups to pick a repo and stay with it. Remove the defunct repos from teh groups file
#
#
# ### Duplicated people:
# - Pyjar: 002, 036
# - Mejia-Trejo: 000, 033
# - Hulse: 000, 048
#
# #### Fix for duped people
# see below
#
# ### Registered group broken up
# Group claiming that they belong together and registered, but it wasn't in the data until the day after I ran the scripts.
# - Huynh, Alexander A17134030
# - Lu, Yimin A16125063
# - Vu, Jenny A15560749
# - Pham, Dong A15911940
# - github usernames are AHuynh9481, jen-00, lyimin01, SomeGuy-sys
#
# #### Fix for duped people and group broken up
# Let's see which groups the people involved come from, if removing them from their 2nd group (dupes) or current group will mess things up

# %%
groups.set_index('group_name').loc[ 
    peeps.set_index('name').loc[['Ana Cunha','Kyra Hulse','John Pyjar']].group.to_list() ]
# Out:
#                                                         names  \
# group_name
# Group000    Ana Cunha, Kyra Hulse, Esmeralda Mejia-Trejo, ...
# Group000    Ana Cunha, Kyra Hulse, Esmeralda Mejia-Trejo, ...
# Group048    Yash Potdar, Gauri Samith, Maitrayee Keskar, K...
# Group002    Bridget Egan, John Pyjar, Alex Tyler, Aryaman ...
# Group036    Samuel Woo, Kyle Moore, Javon Maxie, Sebastian...
#
#                                                          sids  \
# group_name
# Group000                      A15990829, A15593181, A15667909
# Group000                      A15990829, A15593181, A15667909
# Group048           A15805085, A15828385, A15781563, A15593181
# Group002           A15769204, A16123651, A16542815, A15828821
# Group036    A15961073, A14271413, A15529501, A15396318, A1...
#
#                                                        gitids  n_people
# group_name
# Group000                                            accunha11       3.0
# Group000                                            accunha11       3.0
# Group048               YashPotdar, GSam789, mmkeskar, kehulse       4.0
# Group002         alxtyl, bridge-exe, Aryamansinha2704, chefpy       4.0
# Group036    samuel-d-woo, kylechristophermoore, TheRealMambaz       5.0

# %% [markdown]
# Shit looks like we are pretty screwed no matter which way, gonna end up with a too small group

# %%
groups.set_index('group_name').loc[ 
    peeps.set_index('name').loc[['Alexander Huynh','Yimin Lu','Jenny Vu','Dong Pham']].group.to_list() ]
#.names.str.split(',').apply( lambda x: len(x))
# Out:
#                                                         names sids gitids  \
# group_name
# Group054    Jaime Altamirano-Ramirez, Alexander Huynh, Tay...  NaN    NaN
# Group057    Peder Ditelv-Simonsen, Zhou Sun, Yimin Lu, Jal...  NaN    NaN
# Group055    Jenny Vu, Girish Senthil, Maya Xu, Joshua Fier...  NaN    NaN
# Group052    Xuhui Liu, Yescenia Alvarez, Dong Pham, Maxwel...  NaN    NaN
#
#             n_people
# group_name
# Group054         NaN
# Group057         NaN
# Group055         NaN
# Group052         NaN

# %%
groups.set_index('group_name').loc['Group002'].names
# Out:
# 'Bridget Egan, John Pyjar, Alex Tyler, Aryaman Sinha'

# %%
df.set_index('Student').loc['Sun, Zhou']
# Out:
# ID                                                2420.0
# SIS User ID                                    A15634596
# SIS Login ID                                       z6sun
# Section                          COGS 118A - A04 [86568]
# A1 (487506)                                          NaN
# D1 (487943)                                          1.8
# Syllabus quiz (486132)                               1.0
# Practice assignment (486420)                         NaN
# A2 (489913)                                          NaN
# Week 2 Current Points                               1.80
# Week 2 Final Points                                 1.80
# Week 2 Current Score                               90.00
# Week 2 Unposted Current Score                      90.00
# Week 2 Final Score                                 45.00
# Week 2 Unposted Final Score                        45.00
# Week1 Current Points                                1.00
# Week1 Final Points                                  1.00
# Week1 Current Score                               100.00
# Week1 Unposted Current Score                      100.00
# Week1 Final Score                                  50.00
# Week1 Unposted Final Score                         50.00
# Week 3 Current Points                               0.00
# Week 3 Final Points                                 0.00
# Week 3 Current Score                                 NaN
# Week 3 Unposted Current Score                        NaN
# Week 3 Final Score                                  0.00
# Week 3 Unposted Final Score                         0.00
# Current Points                                      2.80
# Final Points                                        2.80
# Current Score                                      93.33
# Unposted Current Score                             93.33
# Final Score                                        35.00
# Unposted Final Score                               35.00
# Name: Sun, Zhou, dtype: object

# %% [markdown]
# ### After group assignment and creation
# We still need to assign project groups to TAs. And we also need to create project groups on Canvas so that grading can be done that way.
#
# One way to assign TAs automagically is to take the mode of discussion lab section among all students in a group.
#
# Credit to Xiqiang Liu for figuring out that both parts of this task can be handled by
# - going to Canvas -> People -> Project groups (must be created) -> +Import button on top right
# - downloading Course Roster csv
# - putting that csv in this directory and loading it
# - joining that info with assigned project groups
# - getting

# %%
import pandas as pd

# %%
# reload if necessary; i did this the first time days after completing group assignment
groups = pd.read_csv('assigned_groups_edited.csv').set_index('group_name')
groups
# Out:
#                                                         names  \
# group_name
# Group000    Ana Cunha, Esmeralda Mejia-Trejo, Kimberly Joh...
# Group001    Alan Cao, Robert Aispuro, Helen Zhao, Connie C...
# Group002    Bridget Egan, John Pyjar, Alex Tyler, Aryaman ...
# Group003    Boning Yang, Chenhao Zhu, Anni Li, Muchan Li, ...
# Group004    Harini Adivikolanu, Isabella Gonzalez, Daniel ...
# Group005    Brandon Vazquez-Tellez, Vicky Chou, Hsi Chen, ...
# Group006    Charles Ye, Thomas Fratantoni, Evan Eguchi, Ma...
# Group007    Chao-Li Wei, Andrew Truong, Ted Feng, Ahmad Sa...
# Group008    Caitlin Connolly, Caike Salles-Campana, Abigai...
# Group036    samuel-d-woo, kylechristophermoore, TheRealMambaz       5.0
# Group037     rkhateeb, cdonasco, MikecraftA, IsAria233, SiuWu       5.0
# Group038      itsjanty, zuraneb, ingridalt, t7bui, romanov360       5.0
# Group040       wrblynch, lkatanic, hwiyeo, RynaK1, gordon1213       5.0
# Group041    mxnares,rainarit,WillSumerfield,mhm1117,abdall...       5.0
# Group042    TIMHX, Luning-Yang, yunyihuang, AnnieeeeeF, 3X...       5.0
# Group043    NicoloWX, CainChen1,  h3song, ileolin3, fjkal23jk       5.0
# Group044              yiyang-cao, pu-tan, NioOunt, ZefangYuan       4.0
# Group045    AlphaAmeame, dududubingbong, Zheran-Li, ywchoi...       5.0
# Group046      akai820, xiqiangliu, LianLumada, shz42, MChengW       5.0
# Group047    robertzhang0531,nickuncaged1201,whybruhh,Jiang...       5.0
# Group048               YashPotdar, GSam789, mmkeskar, kehulse       4.0
# Group049         Tianyu-Yu, Muhan He, cozic, Cheersbbg, z6sun       4.0
# Group050    BatelielB,jhcode14,KevThai,katndang,garyouyang...       5.0
# Group051    zvidmarb, TohmeNawwar, IRSMsoso, jorgeacevedo1...       4.0
# Group052                                                  NaN       NaN
# Group053                                                  NaN       NaN
# Group054                                                  NaN       NaN
# Group055                                       Need a another       NaN
# Group056                                                  NaN       NaN
# Group057                                        Need a nother       NaN
# Group058                                                  NaN       NaN

# %%
roster = pd.read_csv('Projects.csv')
roster['sections_short'] = roster['sections'].apply( lambda x: x.split()[3])
roster['name_rev'] = roster['name'].apply( lambda x: ' '.join(x.split(',')[::-1]).strip() ) 
roster
# Out:
#                     name  canvas_user_id    user_id  login_id  \
# 0             Ade, Kalid            4568  A15559312      kade
# 1    Adivikolanu, Harini           33578  A15834526  hadiviko
# 2        Aispuro, Robert           27643  A12086294  raispuro
# 3         Al-Hosri, Ramy            1473  A15399822  ralhosri
# 4     Altamirano, Ingrid           43323  A15501970  ialtamir
# ..                   ...             ...        ...       ...
# 250        Zhang, Tianze           70491  A16133129   t2zhang
# 251          Zhao, Helen           47879  A15919169    hszhao
# 252          Zhao, Jiayi           21085  A15814036    j4zhao
# 253           Zhong, Wei            5587  A15568452    wzhong
# 254         Zhu, Chenhao           41385  A16142340     chzhu
#
#                     sections  group_name sections_short            name_rev
# 0    COGS 118A - A04 [86568]         NaN            A04           Kalid Ade
# 1    COGS 118A - A02 [72992]         NaN            A02  Harini Adivikolanu
# 2    COGS 118A - A02 [72992]         NaN            A02      Robert Aispuro
# 3    COGS 118A - A02 [72992]         NaN            A02       Ramy Al-Hosri
# 4    COGS 118A - A01 [72991]         NaN            A01   Ingrid Altamirano
# ..                       ...         ...            ...                 ...
# 250  COGS 118A - A02 [72992]         NaN            A02        Tianze Zhang
# 251  COGS 118A - A03 [72993]         NaN            A03          Helen Zhao
# 252  COGS 118A - A03 [72993]         NaN            A03          Jiayi Zhao
# 253  COGS 118A - A03 [72993]         NaN            A03           Wei Zhong
# 254  COGS 118A - A01 [72991]         NaN            A01         Chenhao Zhu
#
# [255 rows x 8 columns]

# %%
# takes a PID or name of student
# returns the students discussion section
def find_students_section(stud,roster):
    if stud[1:].isnumeric(): # passed a PID, preferred way to do this
        try:
            section = roster.set_index('user_id').loc[stud,'sections_short']
        except KeyError: # no such student, would be very weird to occur
            section = '' 
            print('Missing key when looking up student\'s section: '+stud)
    else: # passed student name
        try: 
            section = roster.set_index('name_rev').loc[stud,'sections_short']
        except KeyError: # no such student name, happens when people signup with nicknames
            section = ''
            print('Missing key when looking up student\'s section: '+stud)
        
    return section
    
# takes a list of students as PID or name
# returns indices of where students are in roster
# no error handling required as any non-matches are silent/empty indices list
def find_students_in_roster(slist,roster): 
    if pd.Series([ stud[1:].isnumeric() for stud in slist]).all(): 
        # passed a list of PIDs, preferred way to do this
        indices = roster.index[ roster.user_id.isin(slist) ]
    else: # passed student names
        indices = roster.index[ roster.name_rev.isin(slist) ]
    
    return indices

# %%
for ind, row in groups.iterrows():
    if pd.isnull(row['sids']):
        tlist = row['names']
    else: # prefer PIDs if we can use them to avoid name lookup problems
        tlist = row['sids']
    # lists come in as single strings, make em a list of elements
    slist = [ x.strip() for x in tlist.split(',')]
#    tas = pd.Series([ sec_2_name[find_students_section(stud,roster)]
#                         for stud in slist])
#    theTA = tas.mode()[0] # in a tie .mode() returns a list, get the first one
#    groups.loc[ind,'TA_list'] = ','.join(tas)
#    groups.loc[ind,'the_TA'] = theTA
    indices = find_students_in_roster(slist,roster)
    roster.loc[indices,'group_name'] = ind
roster
# Out:
#                     name  canvas_user_id    user_id  login_id  \
# 0             Ade, Kalid            4568  A15559312      kade
# 1    Adivikolanu, Harini           33578  A15834526  hadiviko
# 2        Aispuro, Robert           27643  A12086294  raispuro
# 3         Al-Hosri, Ramy            1473  A15399822  ralhosri
# 4     Altamirano, Ingrid           43323  A15501970  ialtamir
# ..                   ...             ...        ...       ...
# 250        Zhang, Tianze           70491  A16133129   t2zhang
# 251          Zhao, Helen           47879  A15919169    hszhao
# 252          Zhao, Jiayi           21085  A15814036    j4zhao
# 253           Zhong, Wei            5587  A15568452    wzhong
# 254         Zhu, Chenhao           41385  A16142340     chzhu
#
#                     sections group_name sections_short            name_rev
# 0    COGS 118A - A04 [86568]   Group028            A04           Kalid Ade
# 1    COGS 118A - A02 [72992]   Group004            A02  Harini Adivikolanu
# 2    COGS 118A - A02 [72992]   Group001            A02      Robert Aispuro
# 3    COGS 118A - A02 [72992]   Group023            A02       Ramy Al-Hosri
# 4    COGS 118A - A01 [72991]   Group038            A01   Ingrid Altamirano
# ..                       ...        ...            ...                 ...
# 250  COGS 118A - A02 [72992]   Group031            A02        Tianze Zhang
# 251  COGS 118A - A03 [72993]   Group001            A03          Helen Zhao
# 252  COGS 118A - A03 [72993]   Group014            A03          Jiayi Zhao
# 253  COGS 118A - A03 [72993]   Group022            A03           Wei Zhong
# 254  COGS 118A - A01 [72991]   Group003            A01         Chenhao Zhu
#
# [255 rows x 8 columns]

# %%
roster.drop(['sections_short','name_rev'],axis='columns').to_csv('Projects_assigned.csv')
