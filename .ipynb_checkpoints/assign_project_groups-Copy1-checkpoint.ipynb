# %%
import pandas as pd

def flatten(t):
    return [item for sublist in t for item in sublist]

# %% [markdown]
# ### Load up the students
# Go to Canvas and export the gradesheet. This gives us a list of current students. Place the file in this directory and change the read_csv() below to load up the proper file.

# %%
df = pd.read_csv('2021-10-11T2317_Grades-COGS108_FA21_A00.csv')
enrolled_students = df.drop([0,1]).reset_index(drop=True)[['Student','SIS User ID','SIS Login ID']]
enrolled_students = enrolled_students.rename( {'SIS User ID':'SID', 'SIS Login ID':'email'},axis=1)
# turn last, first into first last
enrolled_students['Student'] = ( enrolled_students['Student']
                                .apply( lambda x: x.split(', ')[::-1]) # reverse order around the ,
                                .apply(lambda x: x[0]+' '+x[1]) # join with space between
                               )
enrolled_students = enrolled_students.dropna() # drop the canvas test student with NaN SID
enrolled_students = enrolled_students[ enrolled_students.Student != 'Cogs 108 Grader Account' ]
enrolled_students
# Out:
#                     Student        SID      email
# 0        Wajiullah Abdullah  A13013121  wabdullah
# 1    Dario Aburto-Rodriguez  A15429735   daaburto
# 2             Jorge Acevedo  A15834274   jacevedo
# 3            Gabriel Aganon  A15606091    gaganon
# 4             Leslie Aguiar  A15528409   leaguiar
# ..                      ...        ...        ...
# 435               Derek Zhu  A15820548     daz005
# 436               Haoyu Zhu  A15432720      h9zhu
# 437             Mingjia Zhu  A15498187       mzhu
# 438           Lingye Zhuang  A15827328   l1zhuang
# 439             Eduardo Zul  A14800820       ezul
#
# [439 rows x 3 columns]

# %%
enrolled_students.Student.value_counts() # there might be multiple students with the same name
# Out:
# Hoang Nguyen     2
# Brian Chen       2
# Yu Xie           1
# Kaiyu Guan       1
# Joona Kim        1
#                 ..
# Eason Law        1
# Yiyu Liu         1
# Chia-Yu Chang    1
# Ipek Eren        1
# Riley Liu        1
# Name: Student, Length: 437, dtype: int64

# %%
df
# Out:
#                      Student        ID SIS User ID  \
# 0                        NaN       NaN         NaN
# 1            Points Possible       NaN         NaN
# 2        Abdullah, Wajiullah  110418.0   A13013121
# 3    Aburto-Rodriguez, Dario   20903.0   A15429735
# 4             Acevedo, Jorge   67792.0   A15834274
# ..                       ...       ...         ...
# 438               Zhu, Haoyu   53878.0   A15432720
# 439             Zhu, Mingjia   76465.0   A15498187
# 440           Zhuang, Lingye   54998.0   A15827328
# 441             Zul, Eduardo   19501.0   A14800820
# 442            Student, Test  146188.0         NaN
#
#                                  SIS Login ID  \
# 0                                         NaN
# 1                                         NaN
# 2                                   wabdullah
# 3                                    daaburto
# 4                                    jacevedo
# ..                                        ...
# 438                                     h9zhu
# 439                                      mzhu
# 440                                  l1zhuang
# 441                                      ezul
# 442  edc7759218afe154c473c5cd953b0f41dfd88485
#
#                                                Section  \
# 0                                                  NaN
# 1                                                  NaN
# 2                               COGS 108 - A02 [52891]
# 3                               COGS 108 - A02 [52891]
# 4                               COGS 108 - A03 [52892]
# ..                                                 ...
# 438                             COGS 108 - A04 [52893]
# 439                             COGS 108 - A04 [52893]
# 440                             COGS 108 - A07 [52896]
# 441                             COGS 108 - A06 [52895]
# 442  COGS 108 - A01 [52890], COGS 108 - A02 [52891]...
#
#      Student survey (392084)  Group sign up (395150)  Project survey (396285)  \
# 0                        NaN                     NaN                      NaN
# 1                        1.0                     1.0                      5.0
# 2                        NaN                     NaN                      NaN
# 3                        NaN                     NaN                      NaN
# 4                        NaN                     NaN                      NaN
# ..                       ...                     ...                      ...
# 438                      NaN                     NaN                      NaN
# 439                      NaN                     NaN                      NaN
# 440                      NaN                     NaN                      NaN
# 441                      NaN                     NaN                      NaN
# 442                      NaN                     NaN                      NaN
#
#         Q1 (365782)     Q2 (365778)  ... Imported Assignments Current Score  \
# 0    Manual Posting  Manual Posting  ...                                NaN
# 1              1.00            1.00  ...                        (read only)
# 2              1.00             NaN  ...                                NaN
# 3              1.00             NaN  ...                                NaN
# 4              1.00             NaN  ...                                NaN
# ..              ...             ...  ...                                ...
# 438            0.98             NaN  ...                                NaN
# 439            0.88             NaN  ...                                NaN
# 440            0.98             NaN  ...                                NaN
# 441            0.90             NaN  ...                                NaN
# 442             NaN             NaN  ...                                NaN
#
#     Imported Assignments Unposted Current Score  \
# 0                                           NaN
# 1                                   (read only)
# 2                                        100.00
# 3                                        100.00
# 4                                        100.00
# ..                                          ...
# 438                                       97.50
# 439                                       87.50
# 440                                       97.50
# 441                                       90.00
# 442                                         NaN
#
#     Imported Assignments Final Score  \
# 0                                NaN
# 1                        (read only)
# 2                               0.00
# 3                               0.00
# 4                               0.00
# ..                               ...
# 438                             0.00
# 439                             0.00
# 440                             0.00
# 441                             0.00
# 442                             0.00
#
#     Imported Assignments Unposted Final Score Current Points  Final Points  \
# 0                                         NaN            NaN           NaN
# 1                                 (read only)    (read only)   (read only)
# 2                                       11.11           1.00          1.00
# 3                                       11.11           1.00          1.00
# 4                                       11.11           1.00          1.00
# ..                                        ...            ...           ...
# 438                                     10.83           0.98          0.98
# 439                                      9.72           0.88          0.88
# 440                                     10.83           0.98          0.98
# 441                                     10.00           0.90          0.90
# 442                                      0.00           0.00          0.00
#
#     Current Score Unposted Current Score  Final Score Unposted Final Score
# 0             NaN                    NaN          NaN                  NaN
# 1     (read only)            (read only)  (read only)          (read only)
# 2             NaN                 100.00         0.00                 6.25
# 3             NaN                 100.00         0.00                 6.25
# 4             NaN                 100.00         0.00                 6.25
# ..            ...                    ...          ...                  ...
# 438           NaN                  97.50         0.00                 6.09
# 439           NaN                  87.50         0.00                 5.47
# 440           NaN                  97.50         0.00                 6.09
# 441           NaN                  90.00         0.00                 5.63
# 442           NaN                    NaN         0.00                 0.00
#
# [443 rows x 41 columns]

# %%
enrolled_students.Student.unique() # take a quick look to make sure nothing got screwed up
# Out:
# array(['Wajiullah Abdullah', 'Dario Aburto-Rodriguez', 'Jorge Acevedo',
#        'Gabriel Aganon', 'Leslie Aguiar', 'Jonathan Ahern', 'Muzhen Ai',
#        'Robert Aispuro', 'Ramy Al-Hosri', 'Anudeep Alam',
#        'Sagarika Alavilli', 'Antonio Aldama', 'Zakaria Alhomsy',
#        'Ingrid Altamirano', 'Enrique Alvarado', 'Alan Amirian',
#        'Yixiao An', 'Albert Aung', 'Neel Ayyagari', 'Lara May Bacani',
#        'Bea Barcelona', 'Shimika Basuroy', 'Omar Bautista', 'Aidan Bell',
#        'Michelle Belon', 'Vishvesh Bhat', 'Emily Bledsoe',
#        'Gregory Boscaiu', 'Mehdi Bouassami', 'Nathan Bui', 'Ryan Bui',
#        'Yuri Bukhradze', 'Andrew Burda', 'Kyle Burick',
#        'Samuel Burkholder', 'Andrew Caballero', 'Joe Cai', 'Samuel Calto',
#        'Alan Cao', 'Yu Cao', 'Rodolfo Cardenas', 'Leslie Carrillo',
#        'Kyle Carter', 'Royce Casiano', 'Lance Casiple',
#        'Genevieve Cassidy', 'Raam Chaklashiya', 'Henry Chan',
#        'Chia-Yu Chang', 'Elysia Chang', 'Victor Chang', 'Brian Chen',
#        'Hsi Chen', 'Jasmine Chen', 'Jeffrey Chen', 'Lloyd Chen',
#        'Rickie Chen', 'Thais Chen', 'Vanessa Chen', 'Wilson Chen',
#        'Zhipeng Chen', 'Zongze Chen', 'Calvin Cheung', 'Matthew Chong',
#        'Megha Chouthai', 'Ashley Chu', 'Justin Chu', 'James Chung',
#        'Yong Chung', 'Isabelle Chyun', 'Hanna Clemente',
#        'Michael Colbath', 'Caitlin Connolly', 'Kyle Cook',
#        'Isaiah Cortez', 'Nolan Crespo', 'Donovan Cronkhite', 'Ana Cunha',
#        'Jacky Dam', 'Katelyn Dang', 'Nicholas Degroot', 'Esha Desai',
#        'Pedro Diaz-Saabedra', 'Tony Diep', 'Juan Ding',
#        'Ethan Dinh-Luong', 'Jan Do', 'Tung Doan', 'Rachel Doron',
#        'Yunhao Du', 'Pilaree Dulay', 'Nick Ehsani', 'Ipek Eren',
#        'Erdogan Ergit', 'Sizhe Fan', 'Cameron Faulkner', 'Ted Feng',
#        'Nicholas Fisher', 'Sydney Forster', 'Zachary Francis',
#        'Thomas Fratantoni', 'Olivia Gale', 'Aditi Gandhi', 'Siyi Gao',
#        'Jessica Gazca', 'Stephen Gelinas', 'Matin Ghaffari',
#        'Luke Glascoe', 'Shawn Gomos', 'Isabella Gonzalez',
#        'Vanessa Gonzalez', 'Steven Gov', 'Sebastian Graeber',
#        'Richard Gross', 'Joann Guan', 'Kaiyu Guan', 'Leonardo Guillen',
#        'Landi Guo', 'Zehua Guo', 'Emmanuel Gutierrez', 'Elaine Ha',
#        'Madison Hambly', 'Miriam Hamidi', 'Abigail Han',
#        'Anthony Handjojo', 'Athena Hao', 'John Harrison',
#        'Peter Hattendorf', 'Parsia Hedayat', 'Colby Hillers',
#        'Kimberly Holland', 'Xing Hong', 'Julian Hou', 'Joseph Hsieh',
#        'Jason Hsu', 'Brian Huang', 'Ruijie Huang', 'Ying Huang',
#        'Julia Hulvey', 'Jianfan Huo', 'Satomi Ito', 'Parshva Jain',
#        'Sophie Jensen', 'Grant Jiang', 'Wendi Jiang', 'Yixin Jiang',
#        'Marisol Jimenez', 'Yu Jin', 'Maxwell Jung', 'Jared Kallingal',
#        'Soumya Kalluri', 'Ellie Kanda', 'Hima Kathi', 'Ruben Kerobyan',
#        'Jacob Khaliqi', 'Rizq Khateeb', 'Merve Kilic', 'Matthew Kilzi',
#        'Haeun Kim', 'Hyunsoo Kim', 'Joona Kim', 'Laura Kim', 'Ryan Kim',
#        'Sung Kim', 'Tae Kun Kim', 'Caleb Ko', 'Abigail Koornwinder',
#        'Mary Kovic', 'Sukanya Krishna', 'Iisha Kshatriya', 'Daniel Lam',
#        'Eason Law', 'Ryan Lay', 'Athena Le', 'Franklin Le', 'John Le',
#        'Justin Le', 'Vivian Le', 'Elliot Lee', 'Kristy Lee', 'Mandy Lee',
#        'Taekyu Lee', 'Teresa Lee', 'Vivian Lee', 'Bohan Lei',
#        'Kelly Leon-Marquez', 'Trisa Leung', 'Carmen Li', 'Diane Li',
#        'Jodie Li', 'John Li', 'Josie Li', 'Katie Li', 'Ruoxuan Li',
#        'Shaolong Li', 'Weiyue Li', 'Xiangwen Li', 'Xinyi Li', 'Yaoxin Li',
#        'Zhuotong Li', 'Katherine Lim', 'Dustin Lin', 'Hannah Lin',
#        'Linda Lin', 'Yu-Jung Lin', 'Colin Lintereur', 'Angela Liu',
#        'Cecilia Liu', 'Changchen Liu', 'Fengdi Liu', 'Johnny Liu',
#        'Juanyu Liu', 'Kimberly Liu', 'Mingxin Liu', 'Rich Liu',
#        'Riley Liu', 'Xiqiang Liu', 'Yiyu Liu', 'Luke Lloyd',
#        'Laticia Long', 'Mary Longano', 'Amber Lu', 'James Lu', 'Yang Lu',
#        'Zhangxiang Lu', 'Dennis Luc', 'Chris Lucas', 'Sophia Lui',
#        'Matthew Lund', 'Kelly Luu', 'Yichen Lyu', 'Austin Ma',
#        'Rongyu Ma', 'Tiancheng Ma', 'Gaurav Mahindru', 'Ashlyn Mahoney',
#        'Prathik Malireddy', 'Christian Malki', 'Bailey Man',
#        'Marvin Maninang', 'Andrea Mansilla', 'William Martino',
#        'Tatum Maston', 'Javon Maxie', 'Uday Mehra', 'Jorge Mendoza',
#        'Matilda Michel', 'Daniel Milton', 'Campbell Moco',
#        'Shamis Mohamed', 'Rosalind Moore', 'Dhanush Nanjunda-Reddy',
#        'Chayuda Naulmanee', 'Simran Nayyar', 'Zara Nazir',
#        'Briana Nevarez', 'Dylan Newman', 'Sean Ng', 'Allison Ngo',
#        'Elise Ngo', 'Amy Nguyen', 'Cassidy Nguyen', 'Hoang Nguyen',
#        'Jenna Nguyen', 'Jonathan Nguyen', 'Kenneth Nguyen',
#        'Kurtis Nguyen', 'Tj Nguyen', 'Tracy Nguyen', 'Mingjie Ni',
#        'Isaiah Nicasio', 'Lazar Nikolic', 'Michael Nodini',
#        'Athina Obfenda', 'Gina Ocegueda', 'Aldair Olanda',
#        'Ramzy Oncy-Avila', 'Ivan Ozerets', 'Nia Page', 'Bochen Pan',
#        'Alec Panattoni', 'Joonsung Park', 'Alysandra Rae Pascua',
#        'Zina Patel', 'Truong Pham', 'Billy Phannavong', 'Justin Phen',
#        'Michael Phung', 'Moksha Poladi', 'Michael Poon', 'Richie Porras',
#        'Yash Potdar', 'Nimish Prabhakaran', 'Gokul Prasad',
#        'Kristen Prescaro', 'John Pyjar', 'Shirley Qi', 'Alexander Quan',
#        'Akil Rajendra-Janarthanan', 'Manav Ram', 'Sonika Ram',
#        'Alexis Ramachandran', 'Vishaal Ramaswamy-Kasi-Vasu',
#        'Sergio Ramirez', 'Jinyu Rao', 'Tanay Reddy', 'Finn Reid',
#        'John Rhee', 'James Riddell', 'Gilberto Robles',
#        'Manuel Rodriguez-Nunez', 'Olivia Roth', 'Jacob Ryan',
#        'Kayla Sacks', 'Kairi Sageshima', 'Sanjay Sampat',
#        'Karina Sanchez', 'John Santos', 'Jumana Sarwar',
#        'Amiet Scheidegger', 'David Seo', 'Shantelle Serafin',
#        'Rahil Shah', 'Siyu Shen', 'Hang Shi', 'Seph Shia', 'Miles Simitz',
#        'Hargun Singh-Mahindra', 'Nimish Singh', 'Katherine Sisombath',
#        'Rasya Soeroso', 'Alexandra Soltan-Kashefi', 'Zhengde Song',
#        'Phoebe Sonnad', 'Arturo Sorensen', 'Janty Sphabmixay',
#        'Finn St-John', 'William Sumerfield', 'Sik Sun',
#        'Gokul Swaminathan', 'Vineet Tallavajhala', 'Pu Tan', 'Wilson Tan',
#        'Allison Tang', 'Mustansir Taquee', 'Isabel Tate', 'Destynee Tau',
#        'Martin Thai', 'Victor Thai', 'Kristine Thipatima',
#        'Keionni Thompson', 'Yalong Tian', 'Thanh Tong', 'Lorenzo Topacio',
#        'Hamlet Torosian', 'Kenny Tran', 'Tyler Tran', 'Simon Tsui',
#        'Zachary Tulman', 'Kaushika Uppu', 'Cameron Vandertuig',
#        'Angel Ventura', 'Isa Vidanes', 'Juhita Vijjali',
#        'Danielle Villa-Agustin', 'Duc Vo', 'Jenny Vu', 'Ethan Wadsworth',
#        'Alvin Wang', 'Brandon Wang', 'Brian Wang', 'Colin Wang',
#        'Heqi Wang', 'Joshua Wang', 'Kevin Wang', 'Melanie Wang',
#        'Siyuan Wang', 'Jie Wei', 'William Wei', 'Kenzy Wirth',
#        'Riese Wismer', 'Brian Wong', 'Kevin Wong', 'Banglun Wu',
#        'Lanzhuo Wu', 'Mingxuan Wu', 'William Xia', 'Zichun Xia',
#        'Brian Xie', 'Yingshan Xie', 'Yu Xie', 'Caroline Xiong',
#        'Mingze Xu', 'Yundi Xu', 'Hayley Yamamoto', 'Jerry Yan',
#        'Jialin Yan', 'Julian Yan', 'Aung Yang', 'Edward Yang',
#        'Reyna Yang', 'Carolyn Yatco', 'Charles Ye', 'Hwi Yeo',
#        'Christopher Yoon', 'Harry You', 'Eric Youn', 'Jianchang Yu',
#        'Tianyu Yu', 'Zefang Yuan', 'Jacqueline Yuke', 'Jonathan Yun',
#        'Tong Zeng', 'Crystal Zhan', 'Hanjie Zhan', 'Anson Zhang',
#        'Hinn Zhang', 'Luis Zhang', 'Min Zhang', 'Ruijia Zhang',
#        'Siyuan Zhang', 'Thea Zhang', 'Yichi Zhang', 'Yikai Zhang',
#        'Zixun Zhang', 'Celine Zhao', 'Grace Zheng', 'Jacob Zhong',
#        'Tiffany Zhong', 'Lisa Zhou', 'Yuru Zhou', 'Zhetai Zhou',
#        'Derek Zhu', 'Haoyu Zhu', 'Mingjia Zhu', 'Lingye Zhuang',
#        'Eduardo Zul'], dtype=object)

# %% [markdown]
# ### Load up the group signup google form
# The studnets are responsible for signing themselves up for the self-formed groups via a google form currently in shared drive COGS108/Projects. Export the finished form to a Sheet and download the responses in CSV format. Place them in this directory and change the read_csv(filename) below to point at the proper file

# %%
df = pd.read_csv('COGS 108 Groups (Fa21) (Responses) - Form Responses.csv')
cols = df.columns.to_list()
cols[1] = 'names'
cols[2] = 'sids'
cols[3] = 'gitids'
df.columns = cols

groups = df.loc[:,['names','sids','gitids']]
gnames = []
for group_num in groups.index:
    gnames.append('Group{:03d}'.format(group_num))
groups['group_name']=gnames
groups['n_people'] = groups.names.apply( lambda x: len(x.split(',')) )
groups = groups.set_index('group_name')
groups
# Out:
#                                                         names  \
# group_name
# Group000    Truong Pham, Briana Nevarez, Ipek Eren, Yaoxin...
# Group001    Joshua Discar, Kelly Luu, Isaiah Nicasio, Nich...
# Group002    Shantelle Serafin, Elliot Lee, Finn St John, H...
# Group003    Gilberto Robles, Michael Nodini, Nia Page, Chr...
# Group004    Arturo Sorensen, Anudeep Alam, Kyle Carter, Vi...
# ...                                                       ...
# Group095    Kairi Sageshima, Brandon Wang, Marisol Jimenez...
# Group096    Phoebe Sonnad, Kyle Burick, Aidan Bell, Thea Z...
# Group097    Tracy Nguyen, Kenny Tran, Rickie Chen, Andrew ...
# Group098    Matthew Kilzi, Alexandra Soltan-Kashefi, Chris...
# Group099     Joonsung Park,  James Chung, Richard Gross, M...
#
#                                                          sids  \
# group_name
# Group000    A15619342, A14558091, A16074539, A16542726, A1...
# Group001    A15659137, A16312606, A15645856, A15592188, A1...
# Group002    A16162300, A15796673, A16133473, A16158139, A1...
# Group003    A15415579. A16007357, A16086395, A16592184, A1...
# Group004           A15834453, A15886397, A15806576, A15959751
# ...                                                       ...
# Group095    A15036608, A15667730, A15509322, A16678105, A1...
# Group096           A13086700, A15386728, A16580009, A16405621
# Group097           A15889891, A15418907, A15928667, A16143137
# Group098           A16690085, A13190332, A16546082, A15436546
# Group099    A91122505, A15852697, A16661487, A16625551, A1...
#
#                                                        gitids  n_people
# group_name
# Group000            tgnpham, banevare, ipekerenn, hblyx, ezul         5
# Group001    Serious-Fish, kellyyluu, isaiahin, nickfish716...         5
# Group002    shantellemeganserafin, Eal001, stjohnfinn, hin...         5
# Group003    gilbertorobles24, mnodini, niakai, cjlucas-ucs...         5
# Group004        artusor, SleepyDeep, krcarter223, vineettalla         4
# ...                                                       ...       ...
# Group095    Kairiki12198, b1wang, Marisol-Jim, ashleyychu,...         5
# Group096                hsonnad, kyleburick, zhqa, abell-ucsd         4
# Group097         tracynguyen6, kennytrand, ric005, TheAndrewC         4
# Group098      daveshc, aleykashefi, chrismalki, soumyakalluri         4
# Group099    jop003, jchung01, ucsdRgross, Mhambly, colinli...         5
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Figure out who still needs to be assigned to a group
#
# Method 1: do it by name
#
# Method 2: do it by SID
#
# We will figure out which one works best and correct at the end for the people caught better by the other method

# %%
grouped_students = flatten( 
    groups.names
    .apply( lambda y: [x.strip() for x in y.split(',')])
)
grouped_students
# Out:
# ['Truong Pham',
#  'Briana Nevarez',
#  'Ipek Eren',
#  'Yaoxin Li',
#  'Eduardo Zul',
#  'Joshua Discar',
#  'Kelly Luu',
#  'Isaiah Nicasio',
#  'Nicholas Fisher',
#  'Destynee Tau',
#  'Shantelle Serafin',
#  'Elliot Lee',
#  'Finn St John',
#  'Hinn Zhang',
#  'Isa Vidanes',
#  'Gilberto Robles',
#  'Michael Nodini',
#  'Nia Page',
#  'Chris Lucas',
#  'Donovan Cronkhite',
#  'Arturo Sorensen',
#  'Anudeep Alam',
#  'Kyle Carter',
#  'Vineet Tallavajhala',
#  'Ruben Kerobyan',
#  'Siyuan Wang',
#  'Angel Ventura',
#  'Aung Yang',
#  'Rielle Santos',
#  'David Seo',
#  'Jessica Mata',
#  'Nolan Crespo',
#  'Luke Glascoe',
#  'Julian Yan',
#  'Steven Gov',
#  'Tung Doan',
#  'Mary Kovic',
#  'Sergio Ramirez',
#  'Jodie Li',
#  'Josie Li',
#  'Kelly Leon',
#  'Manav Ram',
#  'Vishaal Ramaswamy Kasi Vasu',
#  'Justin Phen',
#  'Dhanush Nanjunda',
#  'Alexis Ramachandran',
#  'Jake Pyjar',
#  'Katherine Sisombath',
#  'Zina Patel',
#  'Aditi Gandhi',
#  'Billy Phannavong',
#  'Nicole Rangan',
#  'Leslie Aguiar',
#  'Tiancheng Ma',
#  'Parsia Hedayat',
#  'Olivia Gale',
#  'Mingjia Zhu',
#  'Jumana Sarwar',
#  'Ethan Dinh-Luong',
#  'Crystal Zhan',
#  'Akil Selvan Rajendra Janarthanan',
#  'Kristine Thipatima',
#  'Kristen Prescaro',
#  'Jianchang Yu',
#  'Gokul Swaminathan',
#  'Jia Wei Chen',
#  'John Minh Le',
#  'Emmanuel Gutierrez',
#  'Colby Hillers',
#  'Calvin Cheung',
#  'Hoang Nguyen',
#  'Javon Maxie',
#  'Jorge Mendoza',
#  'Jessica Gazca',
#  'Jenny Vu',
#  'Rich Liu',
#  'Genevieve Cassidy',
#  'Alexandra Soltan-Kashefi',
#  'Christian Makli',
#  'Matthew Kilzi',
#  'Soumya Kalluri',
#  'Zhengde Song',
#  'Kevin Wang',
#  'Eric Youn',
#  'Zakaria Alhomsy',
#  'Siyi Gao',
#  'Chia-yu Chang',
#  'Cecilia Liu',
#  'Hannah Lin',
#  'Jinyu Rao',
#  'Lanzhuo Wu',
#  'Royce Casiano',
#  'Keionni Thompson',
#  'Hargun Singh Mahindra',
#  'Ryan Kim',
#  'Brian Wong',
#  'Lance Casiple',
#  'Lloyd Chen',
#  'Joona Kim',
#  'Finn Reid',
#  'Ethan Wadsworth',
#  'Nicholas DeGroot',
#  'Dario Aburto Rodriguez',
#  'Greg Boscaiu',
#  'Amber Lu',
#  'Hsi Chen',
#  'Stephen Gelinas',
#  'Brian Wang',
#  'Katherine Lim',
#  'Daniel Lam',
#  'Michael Phung',
#  'Jacky Dam',
#  'Olivia Roth',
#  'Amiet Scheidegger',
#  'Riley Liu',
#  'Katie Li',
#  'Jingwen Liu',
#  'Jasmine Chen',
#  'Hoang Nguyen',
#  'Ruoxuan Li',
#  'Dylan Newman',
#  'Samuel Calto',
#  'Manuel Rodriguez Nunez',
#  'Julia Hulvey',
#  'Rosalind Moore',
#  'Rasya Soeroso',
#  'Kayla Sacks',
#  'Hima Kathi',
#  'Brian Xie',
#  'Ted Feng',
#  'Xing Hong',
#  'Zhipeng Chen',
#  'Yikai Zhang',
#  'Wenqian Zhao',
#  'Grant Jiang',
#  'Elaine Ha',
#  'Joann Guan',
#  'Eason Law',
#  'Alex Quan',
#  'Shamis Mohamed',
#  'Hamlet Torosian',
#  'Merve Kilic',
#  'Ashlyn Mahoney',
#  'TJ Nguyen',
#  'Joshua Wang',
#  'Katelyn Dang',
#  'Zachary Tulman',
#  'TJ Nguyen',
#  'Joshua Wang',
#  'Katelyn Dang',
#  'Zachary Tulman',
#  'Henry Chan',
#  'Cameron VanderTuig',
#  'Erdogan Ergit',
#  'Vanessa Gonzalez',
#  'Bailey Man',
#  'Justin Le',
#  'Isaiah Cortez',
#  'Andrea Mansilla',
#  'Yalong Tian',
#  'Wendi Jiang',
#  'Xiqiang Liu',
#  'Yiyu Liu',
#  'Landi Guo',
#  'Sydney Forster',
#  'Kenzy Wirth',
#  'Brian Huang',
#  'Tatum Maston',
#  'Abigail Han',
#  'Xinyi Li',
#  'Zhetai Zhou',
#  'Mingxuan Wu',
#  'Yu Cao',
#  'Yu Jin',
#  'Sebastian Graeber',
#  'Rizq Khateeb',
#  'Samuel Burkholder',
#  'Sik Yin Sun',
#  'Cameron Faulkner',
#  'Fengdi Liu',
#  'Hanjie Zhan',
#  'Tianyu Yu',
#  'Shaolong Li',
#  'Alan Cao',
#  'Edward Yang',
#  'Kurtis Nguyen',
#  'Derek Zhu',
#  'Nick Ehsani',
#  'Alysandra Pascua',
#  'Bea Angela Barcelona',
#  'Emily Bledsoe',
#  'Caitlin Connolly',
#  'Ramzy Oncy-Avila',
#  'Yash Potdar',
#  'Kenneth Nguyen',
#  'Mandy Lee',
#  'Matthew Lund',
#  'Yongqing Li',
#  'Matthew Chong',
#  'Amy Nguyen',
#  'Caleb Ko',
#  'Yuri Bukhradze',
#  'Miles Simitz',
#  'Victor Chang',
#  'Changchen Liu',
#  'Yu Xie',
#  'Sanjay Sampat',
#  'Jason Hsu',
#  'Joe Cai',
#  'Nimish Prabhakaran',
#  'Haoyu Zhu',
#  'Ruijia Zhang',
#  'Zhuotong Li',
#  'Charles Ye',
#  'Thomas Fratantoni',
#  'Victor Thai',
#  'Wajiullah Abdullah',
#  'Pak Hin Chan',
#  'Harry You',
#  'Austin Ma',
#  'Jenna Nguyen',
#  'Pilaree Dulay',
#  'Carolyn Yatco',
#  'Kristy Lee',
#  'Sophie Jensen',
#  'Abigail Koornwinder',
#  'Hanna Clemente',
#  'Omar Bautista',
#  'Pedro Luis Diaz',
#  'Enrique Alvarado',
#  'Allison Ngo',
#  'Karina Sanchez',
#  'Lingye Zhuang',
#  'Athena Hao',
#  'Tianyu Yu',
#  'Shaolong Li',
#  'Fengdi Liu',
#  'Hanjie Zhan',
#  'Will Sumerfield',
#  'Kaiyu Guan',
#  'Tong Zeng',
#  'Dat Ta',
#  'Janty Sphabmixay',
#  'Juhita Vijjali',
#  'Briyana Preiger',
#  'Kimberly Holland',
#  'Lara May Bacani',
#  'Andrew Burda',
#  'Isabelle Chyun',
#  'Brian Chen',
#  'Michael Poon',
#  'Jeffrey Chen',
#  'Simran Nayyar',
#  'Duc Vo',
#  'Shimika Basuroy',
#  'Sagarika Alavilli',
#  'Sukanya Krishna',
#  'Mustansir Taquee',
#  'Michelle Belon',
#  'Nolan Chai',
#  'Leslie Carrillo',
#  'Antonio Aldama',
#  'Zichun Xia',
#  'Banglun Wu',
#  'Laura Kim',
#  'Allison Tang',
#  'Zhangxiang Lu',
#  'Diane Li',
#  'Johnny Liu',
#  'Tae Kun Kim',
#  'Seph Shia',
#  'Dustin Lin',
#  'Luke Lloyd',
#  'Justin Chu',
#  'John Li',
#  'Prathik Malireddy',
#  'Alvin Wang',
#  'Shirley Qi',
#  'Tanay Reddy',
#  'Trisa Leung',
#  'Grace Zheng',
#  'Luis Zhang',
#  'William Wei',
#  'Jerry Yan',
#  'Bohan Lei',
#  'Yiling Cao',
#  'Hayley Yamamoto',
#  'Ellie Kanda',
#  'Elise Ngo',
#  'Kevin Wong',
#  'Zongze Chen',
#  'Luis Zhang',
#  'Jerry Yan',
#  'William Wei',
#  'Yiling Cao',
#  'Bohan Lei',
#  'Hyunsoo Kim',
#  'Jonathan Yun',
#  'John Rhee',
#  'Madison Kim',
#  'Colin Wang',
#  'Yuru Zhou',
#  'Weiyue Li',
#  'Luning Yang',
#  'Muzhen Ai',
#  'Mingze Xu',
#  'Zehua Guo',
#  'Yichen Lyu',
#  'Julian Hou',
#  'Chayuda Naulmanee',
#  'Danielle Villa-Agustin',
#  'Megha Chouthai',
#  'Marvin Maninang',
#  'Gokul Prasad',
#  'Vanessa Chen',
#  'Caroline Xiong',
#  'Carmen Li',
#  'Iisha Kshatriya',
#  'James Riddell',
#  'Michael Colbath',
#  'Laticia Long',
#  'Sung Kim',
#  'Mustansir Taquee',
#  'Antonio Aldama',
#  'Michelle Belon',
#  'Leslie Carrillo',
#  'Campbell Moco',
#  'Isabella Gonzalez',
#  'John Vincent Santos',
#  'Zara Nazir',
#  'Mary Mei Longano',
#  'Robert Aispuro',
#  'William Martino',
#  'Angela Liu',
#  'Mingxin (Bowen) Liu',
#  'Jared Kallingal',
#  'Rachel Doron',
#  'Lisa Zhou',
#  'Jacob Ryan',
#  'Parshva Jain',
#  'Jacqueline Yuke',
#  'Mehdi Bouassami',
#  'Lisa',
#  'Gabriel Aganon',
#  'Ramy Al-Hosri',
#  'Sean Ng',
#  'Hwi Yeo',
#  'Jan Do',
#  'Franklin Le',
#  'Vivian Le',
#  'Dennis Luc',
#  'Elysia Chang',
#  'Simon Tsui',
#  'Juan Ding',
#  'Min Zhang',
#  'Siyu Shen',
#  'Yang Lu',
#  'Yunhao Du',
#  'Jianfan Huo',
#  'Yixin Jiang',
#  'Celine Zhao',
#  'Yixiao An',
#  'Bochen Pan',
#  'Ruijie Huang',
#  'Xiangwen Li',
#  'Rongyu Ma',
#  'Mingjie Ni',
#  'Hang Shi',
#  'Juanyu Liu',
#  'Siyuan Zhang',
#  'Jie Wei',
#  'Yingshan Xie',
#  'Ivan Ozerets',
#  'Joseph Hsieh',
#  'Riese Wismer',
#  'Cassidy Nguyen',
#  'Shawn Gomos',
#  'Heqi Wang',
#  'Yundi Xu',
#  'Yan Zhang',
#  'Sizhe Fan',
#  'Ana Cunha',
#  'Christopher Yoon',
#  'Albert Aung',
#  'Uday Mehra',
#  'Carmen Le',
#  'Athina Obfenda',
#  'Matilda Michel',
#  'Thais Chen',
#  'Athena Le',
#  'Matin Ghaffari',
#  'James Lu',
#  'Rahil Shah',
#  'Jorge Acevedo',
#  'Alan Amirian',
#  'Zachary Francis',
#  'Nimish Singh',
#  'Neel Ayyagari',
#  'Jacob Khaliqi',
#  'Teresa Lee',
#  'William Xia',
#  'Ingrid Altamirano',
#  'Morgan Harrison',
#  'Isabel Tate',
#  'Martin Thai',
#  'Ryan Bui',
#  'Nathan Bui',
#  'Sophia Lui',
#  'Alec Panattoni',
#  'Rodolfo Cardenas',
#  'Abishek Siva',
#  'Tyler Tran',
#  'Sophia Lui',
#  'Alec Panattoni',
#  'Rodolfo Cardenas',
#  'Abishek Siva',
#  'Tyler Tran',
#  'Moksha Poladi',
#  'Esha Desai',
#  'Sonika Ram',
#  'Divneet Kaur',
#  'Satomi Ito',
#  'Jacob Zhong',
#  'Lorenzo Topacio',
#  'Kaushika Uppu',
#  'Yu-Jung Lin',
#  'Jialin Yan',
#  'Ryan Lay',
#  'Richie Porras',
#  'Aldair Olanda',
#  'Tiffany Zhong',
#  'Gina Ocegueda',
#  'Zefang Yuan',
#  'Pu Tan',
#  'Linda Lin',
#  'Zixun Zhang',
#  'Kairi Sageshima',
#  'Brandon Wang',
#  'Marisol Jimenez',
#  'Ashley Chu',
#  'Daniel Milton',
#  'Phoebe Sonnad',
#  'Kyle Burick',
#  'Aidan Bell',
#  'Thea Zhang',
#  'Tracy Nguyen',
#  'Kenny Tran',
#  'Rickie Chen',
#  'Andrew Caballero',
#  'Matthew Kilzi',
#  'Alexandra Soltan-Kashefi',
#  'Christian Malki',
#  'Soumya Kalluri',
#  'Joonsung Park',
#  'James Chung',
#  'Richard Gross',
#  'Madison Hambly',
#  'Colin Lintereur']

# %%
unassigned_1 = set(enrolled_students.Student) - set(grouped_students)
unassigned_1
# Out:
# {'Akil Rajendra-Janarthanan',
#  'Alexander Quan',
#  'Alysandra Rae Pascua',
#  'Anson Zhang',
#  'Anthony Handjojo',
#  'Bea Barcelona',
#  'Cameron Vandertuig',
#  'Chia-Yu Chang',
#  'Dario Aburto-Rodriguez',
#  'Dhanush Nanjunda-Reddy',
#  'Finn St-John',
#  'Gaurav Mahindru',
#  'Gregory Boscaiu',
#  'Haeun Kim',
#  'Hargun Singh-Mahindra',
#  'John Harrison',
#  'John Le',
#  'John Pyjar',
#  'John Santos',
#  'Jonathan Ahern',
#  'Jonathan Nguyen',
#  'Kelly Leon-Marquez',
#  'Kimberly Liu',
#  'Kyle Cook',
#  'Lazar Nikolic',
#  'Leonardo Guillen',
#  'Manuel Rodriguez-Nunez',
#  'Mary Longano',
#  'Maxwell Jung',
#  'Melanie Wang',
#  'Mingxin Liu',
#  'Miriam Hamidi',
#  'Nicholas Degroot',
#  'Pedro Diaz-Saabedra',
#  'Peter Hattendorf',
#  'Raam Chaklashiya',
#  'Reyna Yang',
#  'Sik Sun',
#  'Taekyu Lee',
#  'Thanh Tong',
#  'Tj Nguyen',
#  'Tony Diep',
#  'Vishaal Ramaswamy-Kasi-Vasu',
#  'Vishvesh Bhat',
#  'Vivian Lee',
#  'William Sumerfield',
#  'Wilson Chen',
#  'Wilson Tan',
#  'Yichi Zhang',
#  'Ying Huang',
#  'Yong Chung'}

# %%
badnames_1 = set(grouped_students) - set(enrolled_students.Student)
badnames_1
# Out:
# {'Abishek Siva',
#  'Akil Selvan Rajendra Janarthanan',
#  'Alex Quan',
#  'Alysandra Pascua',
#  'Bea Angela Barcelona',
#  'Briyana Preiger',
#  'Cameron VanderTuig',
#  'Carmen Le',
#  'Chia-yu Chang',
#  'Christian Makli',
#  'Dario Aburto Rodriguez',
#  'Dat Ta',
#  'Dhanush Nanjunda',
#  'Divneet Kaur',
#  'Finn St John',
#  'Greg Boscaiu',
#  'Hargun Singh Mahindra',
#  'Jake Pyjar',
#  'Jessica Mata',
#  'Jia Wei Chen',
#  'Jingwen Liu',
#  'John Minh Le',
#  'John Vincent Santos',
#  'Joshua Discar',
#  'Kelly Leon',
#  'Lisa',
#  'Luning Yang',
#  'Madison Kim',
#  'Manuel Rodriguez Nunez',
#  'Mary Mei Longano',
#  'Mingxin (Bowen) Liu',
#  'Morgan Harrison',
#  'Nicholas DeGroot',
#  'Nicole Rangan',
#  'Nolan Chai',
#  'Pak Hin Chan',
#  'Pedro Luis Diaz',
#  'Rielle Santos',
#  'Sik Yin Sun',
#  'TJ Nguyen',
#  'Vishaal Ramaswamy Kasi Vasu',
#  'Wenqian Zhao',
#  'Will Sumerfield',
#  'Yan Zhang',
#  'Yiling Cao',
#  'Yongqing Li'}

# %%
grouped_sids = flatten( 
    groups.sids
    .apply( lambda y: [x.strip() for x in 
                         y.replace('.',',') # some idiot used a . instead of a ,
                         .split(',') # split sids grouped by commas
                      ]
          ) 
    

)
grouped_sids
# Out:
# ['A15619342',
#  'A14558091',
#  'A16074539',
#  'A16542726',
#  'A14800820',
#  'A15659137',
#  'A16312606',
#  'A15645856',
#  'A15592188',
#  'A14784508',
#  'A16162300',
#  'A15796673',
#  'A16133473',
#  'A16158139',
#  'A16363180',
#  'A15415579',
#  'A16007357',
#  'A16086395',
#  'A16592184',
#  'A15418298',
#  'A15834453',
#  'A15886397',
#  'A15806576',
#  'A15959751',
#  'A14513122',
#  'A16564380',
#  'A14367342',
#  'A16119914',
#  'unsure',
#  'A08878485',
#  'A14833734',
#  'A15906457',
#  'A16182215',
#  'A15493579',
#  'A15601331',
#  'A15808272',
#  'A15292606',
#  'A16618994',
#  'A15793169',
#  'A15924327',
#  'A16619109',
#  'A15807086',
#  'A15926398',
#  'A15823978',
#  'A16038304',
#  'A16008232',
#  'A16123651',
#  'A14413906',
#  'A15462246',
#  'A15418668',
#  'A15308712',
#  'A15011222',
#  'A15528409',
#  'A15419480',
#  'A15622748',
#  'A15643758',
#  'A15498187',
#  'A15472649',
#  'A15582365',
#  'A16505937',
#  'A16498373',
#  'A15602826',
#  'A15529179',
#  'A15482991',
#  'A16127419',
#  'A15588293',
#  'A15215076',
#  'A15769736',
#  'A15949627',
#  'A16029496',
#  'A15207070',
#  'A15529501',
#  'A15403351',
#  'A15506953',
#  'A15560749',
#  'A13140565',
#  'A15462793',
#  'A13190332',
#  'A16546082',
#  'A16690085',
#  'A15436546',
#  'A16142930',
#  'A15553619',
#  'A15565647',
#  'A14143661',
#  'A15601619',
#  'A15935893',
#  'A15912399',
#  'A15999441',
#  'A15625300',
#  'A15581462',
#  'A15276453',
#  'A15614572',
#  'A16176734',
#  'A15597864',
#  'A15546683',
#  'A15597975',
#  'A16113561',
#  'A15430496',
#  'A16121806',
#  'A15901022',
#  'A15948734',
#  'A15429735',
#  'A15512055',
#  'A16175801',
#  'A15852740',
#  'A15816513',
#  'A15873467',
#  'A15601406',
#  'A16611358',
#  'A16163141',
#  'A15566990',
#  'A15932612',
#  'A15444966',
#  'A15822370',
#  'A15464243',
#  'A16147364',
#  'A15489083',
#  'A15448985',
#  'A16151137',
#  'A16127272',
#  'A16015039',
#  'A15746436',
#  'A15829188',
#  'A15482584',
#  'A16088908',
#  'A15468160',
#  'A16019620',
#  'A15627542',
#  'A15889396',
#  'A15867895',
#  'A16020342',
#  'A15818684',
#  'A15939639',
#  'A15641167',
#  'A15670722',
#  'A15470214',
#  'A14946018',
#  'A15636116',
#  'A15630289',
#  'A15530841',
#  'A15978640',
#  'A15451680',
#  'A15467551',
#  'A15936719',
#  'A15784965',
#  'A15642011',
#  'A15467551',
#  'A15936719',
#  'A15784965',
#  'A15642011',
#  'A16617919',
#  'A15803073',
#  'A16175522',
#  'A14657583',
#  'A14476296',
#  'A15218674',
#  'A16151047',
#  'A15626005',
#  'A16550525',
#  'A15963589',
#  'A15860116',
#  'A15569910',
#  'A15551497',
#  'A15544206',
#  'A15466738',
#  'A16023555',
#  'A15669228',
#  'A15392642',
#  'A16614177',
#  'A15428825',
#  'A15569646',
#  'A15539622',
#  'A16531618',
#  'A15548477',
#  'A15848068',
#  'A15628673',
#  'A16543327',
#  'A15957201',
#  'A10646247',
#  'A16089692',
#  'A16149145',
#  'A16159625',
#  'A16160244',
#  'A15827065',
#  'A16584216',
#  'A15820548',
#  'A15824296',
#  'A15912798',
#  'A15467764',
#  'A16119373',
#  'A15831721',
#  'A16104033',
#  'A15805085',
#  'A15905157',
#  'A16135652',
#  'A15665143',
#  'A16131531',
#  'A16156411',
#  'A16125627',
#  'A14825642',
#  'A16127437',
#  'A15808638',
#  'A15992680',
#  'A15650570',
#  'A15839275',
#  'A15464651',
#  'A16600088',
#  'A15575572',
#  'A15367986',
#  'A15432720',
#  'A15550228',
#  'A16554690',
#  'A15864281',
#  'A15940388',
#  'A16666301',
#  'A13013121',
#  'A16550648',
#  'A15663893',
#  'A15663586',
#  'A15621171',
#  'A15490325',
#  'A15959301',
#  'A16166398',
#  'A16133279',
#  'A16164029',
#  'A15607959',
#  'A15641842',
#  'A15556809',
#  'A15559152',
#  'A15905481',
#  'A16607274',
#  'A15827328',
#  'A16128914',
#  'A16149145',
#  'A16159625',
#  'A16046247',
#  'A16089692',
#  'A15652060',
#  'A14423221',
#  'A14096653',
#  'A15882889',
#  'A15878991',
#  'A15669338',
#  'A16086824',
#  'A15875831',
#  'A15865702',
#  'A15549815',
#  'A15901471',
#  'A16135243',
#  'A16135072',
#  'A15544865',
#  'A16135050',
#  'A15913026',
#  'A15046611',
#  'A15423558',
#  'A15575239',
#  'A16459892',
#  'A16591516',
#  'A15780834',
#  'A16653842',
#  'A14556504',
#  'A15548280',
#  'A15658803',
#  'A16092591',
#  'A15659437',
#  'A16036416',
#  'A16029521',
#  'A15773774',
#  'A15866771',
#  'A15998846',
#  'A15470985',
#  'A15963882',
#  'A15932697',
#  'A15794048',
#  'A15867767',
#  'A15812392',
#  'A15772618',
#  'A15818203',
#  'A15832303',
#  'A15818018',
#  'A15796755',
#  'A15828548',
#  'A16137249',
#  'A15881043',
#  'A15473837',
#  'A16458236',
#  'A15484976',
#  'A15803987',
#  'A15971698',
#  'A16687709',
#  'A15635761',
#  'A15828548',
#  'A15881043',
#  'A16137249',
#  'A16458236',
#  'A15473837',
#  'A15466213',
#  'A15431969',
#  'A16005579',
#  'A15873302',
#  'A15868104',
#  'A16014225',
#  'A16226730',
#  'A16158834',
#  'A15502193',
#  'A15565489',
#  'A15556613',
#  'A15570229',
#  'A16622886',
#  'A166225527',
#  'A16572509',
#  'A15985433',
#  'A16115571',
#  'A15935807',
#  'A15971351',
#  'A15812033',
#  'A16012455',
#  'A16536716',
#  'A15639134',
#  'A15664659',
#  'A15956794',
#  'A13062364',
#  'A16591516',
#  'A15780834',
#  'A14556504',
#  'A15548280',
#  'A16127310',
#  'A15629890',
#  'A15124139',
#  'A15619486',
#  'A15640380',
#  'A12086294',
#  'A15656769',
#  'A15484427',
#  'A15667257',
#  'A15617441',
#  'A15861108',
#  'A16000135',
#  'A16011012',
#  'A15837184',
#  'A15827160',
#  'A15879034',
#  '',
#  'A15606091',
#  'A15399822',
#  'A15591387',
#  'A16082500',
#  'A16031094',
#  'A16545549',
#  'A15569878',
#  'A16011002',
#  'A15437549',
#  'A15848382',
#  'A16595711',
#  'A16542243',
#  'A16624558',
#  'A16594769',
#  'A16557902',
#  'A16600104',
#  'A16534308',
#  'A16474817',
#  'A16125989',
#  'A15562542',
#  'A15453047',
#  'A15523391',
#  'A15442775',
#  'A15589405',
#  'A15476011',
#  'A15424155',
#  'A16059936',
#  'A15572033',
#  'A16066329',
#  'A14929186',
#  'A15599841',
#  'A16079950',
#  'A15579171',
#  'A16107184',
#  'A15511678',
#  'A15573709',
#  'A15588181',
#  'A15442215',
#  'A15990829',
#  'A16155478',
#  'A16040416',
#  'A15966914',
#  'A15547577',
#  'A15545946',
#  'A15205228',
#  'A16572585',
#  'A15902677',
#  'A16617005',
#  'A16687580',
#  'A16375599',
#  'A15834274',
#  'A15424176',
#  'A13166216',
#  'A15041911',
#  'A15567660',
#  'A16082977',
#  'A16327096',
#  'A16436624',
#  'A15501970',
#  'A15641611',
#  'A15875068',
#  'A15815245',
#  'A15847181',
#  'A15847396',
#  'A14681728',
#  'A16562827',
#  'A16101695',
#  'A16290933',
#  'A13930691',
#  'A14681728',
#  'A16562827',
#  'A16101695',
#  'A16290933',
#  'A13930691',
#  'A15913342',
#  'A15813884',
#  'A15864644',
#  'A15983294',
#  'A16157881',
#  'A15634635',
#  'A15657069',
#  'A16196379',
#  'A16091619',
#  'A16531902',
#  'A16038139',
#  'A14022598',
#  'A16031730',
#  'A15953437',
#  'A15652608',
#  'A15559636',
#  'A15508176',
#  'A15608026',
#  'A15597348',
#  'A15036608',
#  'A15667730',
#  'A15509322',
#  'A16678105',
#  'A15599774',
#  'A13086700',
#  'A15386728',
#  'A16580009',
#  'A16405621',
#  'A15889891',
#  'A15418907',
#  'A15928667',
#  'A16143137',
#  'A16690085',
#  'A13190332',
#  'A16546082',
#  'A15436546',
#  'A91122505',
#  'A15852697',
#  'A16661487',
#  'A16625551',
#  'A15389666']

# %%
 
def sid2name(sid):
        try:
            ret = enrolled_students.set_index('SID').loc[sid,'Student']
        except KeyError:
            print('Unknown SID: '+sid)
            ret = None
        return ret

list(map(sid2name, grouped_sids))
# Out:
# Unknown SID: A15659137
# Unknown SID: unsure
# Unknown SID: A14833734
# Unknown SID: A15011222
# Unknown SID: A15565647
# Unknown SID: A15939639
# Unknown SID: A10646247
# Unknown SID: A16131531
# Unknown SID: A16550648
# Unknown SID: A14423221
# Unknown SID: A16086824
# Unknown SID: A16653842
# Unknown SID: A16458236
# Unknown SID: A16458236
# Unknown SID: A16158834
# Unknown SID: A166225527
# Unknown SID:
# Unknown SID: A15547577
# Unknown SID: A16290933
# Unknown SID: A16290933
# Unknown SID: A15983294
# ['Truong Pham',
#  'Briana Nevarez',
#  'Ipek Eren',
#  'Yaoxin Li',
#  'Eduardo Zul',
#  None,
#  'Kelly Luu',
#  'Isaiah Nicasio',
#  'Nicholas Fisher',
#  'Destynee Tau',
#  'Shantelle Serafin',
#  'Elliot Lee',
#  'Finn St-John',
#  'Hinn Zhang',
#  'Isa Vidanes',
#  'Gilberto Robles',
#  'Michael Nodini',
#  'Nia Page',
#  'Chris Lucas',
#  'Donovan Cronkhite',
#  'Arturo Sorensen',
#  'Anudeep Alam',
#  'Kyle Carter',
#  'Vineet Tallavajhala',
#  'Ruben Kerobyan',
#  'Siyuan Wang',
#  'Angel Ventura',
#  'Aung Yang',
#  None,
#  'David Seo',
#  None,
#  'Nolan Crespo',
#  'Luke Glascoe',
#  'Julian Yan',
#  'Steven Gov',
#  'Tung Doan',
#  'Mary Kovic',
#  'Sergio Ramirez',
#  'Jodie Li',
#  'Josie Li',
#  'Kelly Leon-Marquez',
#  'Manav Ram',
#  'Vishaal Ramaswamy-Kasi-Vasu',
#  'Justin Phen',
#  'Dhanush Nanjunda-Reddy',
#  'Alexis Ramachandran',
#  'John Pyjar',
#  'Katherine Sisombath',
#  'Zina Patel',
#  'Aditi Gandhi',
#  'Billy Phannavong',
#  None,
#  'Leslie Aguiar',
#  'Tiancheng Ma',
#  'Parsia Hedayat',
#  'Olivia Gale',
#  'Mingjia Zhu',
#  'Jumana Sarwar',
#  'Ethan Dinh-Luong',
#  'Crystal Zhan',
#  'Akil Rajendra-Janarthanan',
#  'Kristine Thipatima',
#  'Kristen Prescaro',
#  'Jianchang Yu',
#  'Gokul Swaminathan',
#  'Wilson Chen',
#  'John Le',
#  'Emmanuel Gutierrez',
#  'Colby Hillers',
#  'Calvin Cheung',
#  'Hoang Nguyen',
#  'Javon Maxie',
#  'Jorge Mendoza',
#  'Jessica Gazca',
#  'Jenny Vu',
#  'Rich Liu',
#  'Genevieve Cassidy',
#  'Alexandra Soltan-Kashefi',
#  'Christian Malki',
#  'Matthew Kilzi',
#  'Soumya Kalluri',
#  'Zhengde Song',
#  'Kevin Wang',
#  None,
#  'Zakaria Alhomsy',
#  'Siyi Gao',
#  'Chia-Yu Chang',
#  'Cecilia Liu',
#  'Hannah Lin',
#  'Jinyu Rao',
#  'Lanzhuo Wu',
#  'Royce Casiano',
#  'Keionni Thompson',
#  'Hargun Singh-Mahindra',
#  'Ryan Kim',
#  'Brian Wong',
#  'Lance Casiple',
#  'Lloyd Chen',
#  'Joona Kim',
#  'Finn Reid',
#  'Ethan Wadsworth',
#  'Nicholas Degroot',
#  'Dario Aburto-Rodriguez',
#  'Gregory Boscaiu',
#  'Amber Lu',
#  'Hsi Chen',
#  'Stephen Gelinas',
#  'Brian Wang',
#  'Katherine Lim',
#  'Daniel Lam',
#  'Michael Phung',
#  'Jacky Dam',
#  'Olivia Roth',
#  'Amiet Scheidegger',
#  'Riley Liu',
#  'Katie Li',
#  'Kimberly Liu',
#  'Jasmine Chen',
#  'Hoang Nguyen',
#  'Ruoxuan Li',
#  'Dylan Newman',
#  'Samuel Calto',
#  'Manuel Rodriguez-Nunez',
#  'Julia Hulvey',
#  'Rosalind Moore',
#  'Rasya Soeroso',
#  'Kayla Sacks',
#  'Hima Kathi',
#  'Brian Xie',
#  'Ted Feng',
#  'Xing Hong',
#  'Zhipeng Chen',
#  'Yikai Zhang',
#  None,
#  'Grant Jiang',
#  'Elaine Ha',
#  'Joann Guan',
#  'Eason Law',
#  'Alexander Quan',
#  'Shamis Mohamed',
#  'Hamlet Torosian',
#  'Merve Kilic',
#  'Ashlyn Mahoney',
#  'Tj Nguyen',
#  'Joshua Wang',
#  'Katelyn Dang',
#  'Zachary Tulman',
#  'Tj Nguyen',
#  'Joshua Wang',
#  'Katelyn Dang',
#  'Zachary Tulman',
#  'Henry Chan',
#  'Cameron Vandertuig',
#  'Erdogan Ergit',
#  'Vanessa Gonzalez',
#  'Bailey Man',
#  'Justin Le',
#  'Isaiah Cortez',
#  'Andrea Mansilla',
#  'Yalong Tian',
#  'Wendi Jiang',
#  'Xiqiang Liu',
#  'Yiyu Liu',
#  'Landi Guo',
#  'Sydney Forster',
#  'Kenzy Wirth',
#  'Brian Huang',
#  'Tatum Maston',
#  'Abigail Han',
#  'Xinyi Li',
#  'Zhetai Zhou',
#  'Mingxuan Wu',
#  'Yu Cao',
#  'Yu Jin',
#  'Sebastian Graeber',
#  'Rizq Khateeb',
#  'Samuel Burkholder',
#  'Sik Sun',
#  'Cameron Faulkner',
#  None,
#  'Hanjie Zhan',
#  'Tianyu Yu',
#  'Shaolong Li',
#  'Alan Cao',
#  'Edward Yang',
#  'Kurtis Nguyen',
#  'Derek Zhu',
#  'Nick Ehsani',
#  'Alysandra Rae Pascua',
#  'Bea Barcelona',
#  'Emily Bledsoe',
#  'Caitlin Connolly',
#  'Ramzy Oncy-Avila',
#  'Yash Potdar',
#  'Kenneth Nguyen',
#  'Mandy Lee',
#  'Matthew Lund',
#  None,
#  'Matthew Chong',
#  'Amy Nguyen',
#  'Caleb Ko',
#  'Yuri Bukhradze',
#  'Miles Simitz',
#  'Victor Chang',
#  'Changchen Liu',
#  'Yu Xie',
#  'Sanjay Sampat',
#  'Jason Hsu',
#  'Joe Cai',
#  'Nimish Prabhakaran',
#  'Haoyu Zhu',
#  'Ruijia Zhang',
#  'Zhuotong Li',
#  'Charles Ye',
#  'Thomas Fratantoni',
#  'Victor Thai',
#  'Wajiullah Abdullah',
#  None,
#  'Harry You',
#  'Jenna Nguyen',
#  'Austin Ma',
#  'Pilaree Dulay',
#  'Carolyn Yatco',
#  'Kristy Lee',
#  'Sophie Jensen',
#  'Abigail Koornwinder',
#  'Hanna Clemente',
#  'Omar Bautista',
#  'Pedro Diaz-Saabedra',
#  'Enrique Alvarado',
#  'Allison Ngo',
#  'Karina Sanchez',
#  'Lingye Zhuang',
#  'Athena Hao',
#  'Tianyu Yu',
#  'Shaolong Li',
#  'Fengdi Liu',
#  'Hanjie Zhan',
#  'William Sumerfield',
#  None,
#  'Janty Sphabmixay',
#  'Tong Zeng',
#  'Kaiyu Guan',
#  'Juhita Vijjali',
#  None,
#  'Kimberly Holland',
#  'Lara May Bacani',
#  'Andrew Burda',
#  'Reyna Yang',
#  'Isabelle Chyun',
#  'Brian Chen',
#  'Michael Poon',
#  'Jeffrey Chen',
#  'Simran Nayyar',
#  'Duc Vo',
#  'Shimika Basuroy',
#  'Sagarika Alavilli',
#  'Sukanya Krishna',
#  'Mustansir Taquee',
#  'Antonio Aldama',
#  None,
#  'Michelle Belon',
#  'Leslie Carrillo',
#  'Zichun Xia',
#  'Banglun Wu',
#  'Laura Kim',
#  'Allison Tang',
#  'Zhangxiang Lu',
#  'Diane Li',
#  'Johnny Liu',
#  'Tae Kun Kim',
#  'Seph Shia',
#  'Dustin Lin',
#  'Luke Lloyd',
#  'Justin Chu',
#  'John Li',
#  'Prathik Malireddy',
#  'Alvin Wang',
#  'Shirley Qi',
#  'Tanay Reddy',
#  'Trisa Leung',
#  'Grace Zheng',
#  'Luis Zhang',
#  'William Wei',
#  'Jerry Yan',
#  'Bohan Lei',
#  None,
#  'Hayley Yamamoto',
#  'Ellie Kanda',
#  'Elise Ngo',
#  'Kevin Wong',
#  'Zongze Chen',
#  'Luis Zhang',
#  'Jerry Yan',
#  'William Wei',
#  None,
#  'Bohan Lei',
#  'Hyunsoo Kim',
#  'Jonathan Yun',
#  'John Rhee',
#  'Haeun Kim',
#  'Colin Wang',
#  'Yuru Zhou',
#  'Weiyue Li',
#  None,
#  'Muzhen Ai',
#  'Mingze Xu',
#  'Zehua Guo',
#  'Yichen Lyu',
#  'Julian Hou',
#  None,
#  'Danielle Villa-Agustin',
#  'Megha Chouthai',
#  'Marvin Maninang',
#  'Gokul Prasad',
#  'Vanessa Chen',
#  'Caroline Xiong',
#  'Carmen Li',
#  'Iisha Kshatriya',
#  'James Riddell',
#  'Michael Colbath',
#  'Laticia Long',
#  'Sung Kim',
#  'Mustansir Taquee',
#  'Antonio Aldama',
#  'Michelle Belon',
#  'Leslie Carrillo',
#  'Campbell Moco',
#  'Isabella Gonzalez',
#  'John Santos',
#  'Zara Nazir',
#  'Mary Longano',
#  'Robert Aispuro',
#  'William Martino',
#  'Angela Liu',
#  'Mingxin Liu',
#  'Jared Kallingal',
#  'Rachel Doron',
#  'Lisa Zhou',
#  'Jacob Ryan',
#  'Parshva Jain',
#  'Jacqueline Yuke',
#  'Mehdi Bouassami',
#  None,
#  'Gabriel Aganon',
#  'Ramy Al-Hosri',
#  'Sean Ng',
#  'Hwi Yeo',
#  'Jan Do',
#  'Franklin Le',
#  'Vivian Le',
#  'Dennis Luc',
#  'Elysia Chang',
#  'Simon Tsui',
#  'Juan Ding',
#  'Min Zhang',
#  'Siyu Shen',
#  'Yang Lu',
#  'Yunhao Du',
#  'Jianfan Huo',
#  'Yixin Jiang',
#  'Celine Zhao',
#  'Yixiao An',
#  'Bochen Pan',
#  'Ruijie Huang',
#  'Xiangwen Li',
#  'Rongyu Ma',
#  'Mingjie Ni',
#  'Hang Shi',
#  'Juanyu Liu',
#  'Siyuan Zhang',
#  'Jie Wei',
#  'Yingshan Xie',
#  'Ivan Ozerets',
#  'Joseph Hsieh',
#  'Riese Wismer',
#  'Cassidy Nguyen',
#  'Shawn Gomos',
#  'Heqi Wang',
#  'Anson Zhang',
#  'Yundi Xu',
#  'Sizhe Fan',
#  'Ana Cunha',
#  'Christopher Yoon',
#  'Albert Aung',
#  'Uday Mehra',
#  None,
#  'Athina Obfenda',
#  'Matilda Michel',
#  'Thais Chen',
#  'Athena Le',
#  'Matin Ghaffari',
#  'James Lu',
#  'Rahil Shah',
#  'Jorge Acevedo',
#  'Alan Amirian',
#  'Zachary Francis',
#  'Nimish Singh',
#  'Neel Ayyagari',
#  'Jacob Khaliqi',
#  'Teresa Lee',
#  'William Xia',
#  'Ingrid Altamirano',
#  'John Harrison',
#  'Isabel Tate',
#  'Martin Thai',
#  'Ryan Bui',
#  'Nathan Bui',
#  'Sophia Lui',
#  'Alec Panattoni',
#  'Rodolfo Cardenas',
#  None,
#  'Tyler Tran',
#  'Sophia Lui',
#  'Alec Panattoni',
#  'Rodolfo Cardenas',
#  None,
#  'Tyler Tran',
#  'Moksha Poladi',
#  'Esha Desai',
#  'Sonika Ram',
#  None,
#  'Satomi Ito',
#  'Jacob Zhong',
#  'Lorenzo Topacio',
#  'Kaushika Uppu',
#  'Yu-Jung Lin',
#  'Jialin Yan',
#  'Ryan Lay',
#  'Richie Porras',
#  'Aldair Olanda',
#  'Tiffany Zhong',
#  'Gina Ocegueda',
#  'Zefang Yuan',
#  'Pu Tan',
#  'Linda Lin',
#  'Zixun Zhang',
#  'Kairi Sageshima',
#  'Brandon Wang',
#  'Marisol Jimenez',
#  'Ashley Chu',
#  'Daniel Milton',
#  'Phoebe Sonnad',
#  'Kyle Burick',
#  'Thea Zhang',
#  'Aidan Bell',
#  'Tracy Nguyen',
#  'Kenny Tran',
#  'Rickie Chen',
#  'Andrew Caballero',
#  'Matthew Kilzi',
#  'Alexandra Soltan-Kashefi',
#  'Christian Malki',
#  'Soumya Kalluri',
#  'Joonsung Park',
#  'James Chung',
#  'Richard Gross',
#  'Madison Hambly',
#  'Colin Lintereur']

# %%
id2nm = enrolled_students.set_index('SID')['Student'].to_dict()

def sid2name(sid):
        try:
            ret = id2nm[sid]
        except KeyError:
            print('Unknown SID: '+sid)
            ret = None
        return ret
    
    
grouped_names_from_sids = list( map( sid2name, grouped_sids) )
grouped_names_from_sids
# Out:
# Unknown SID: A15659137
# Unknown SID: unsure
# Unknown SID: A14833734
# Unknown SID: A15011222
# Unknown SID: A15565647
# Unknown SID: A15939639
# Unknown SID: A10646247
# Unknown SID: A16131531
# Unknown SID: A16550648
# Unknown SID: A14423221
# Unknown SID: A16086824
# Unknown SID: A16653842
# Unknown SID: A16458236
# Unknown SID: A16458236
# Unknown SID: A16158834
# Unknown SID: A166225527
# Unknown SID:
# Unknown SID: A15547577
# Unknown SID: A16290933
# Unknown SID: A16290933
# Unknown SID: A15983294
# ['Truong Pham',
#  'Briana Nevarez',
#  'Ipek Eren',
#  'Yaoxin Li',
#  'Eduardo Zul',
#  None,
#  'Kelly Luu',
#  'Isaiah Nicasio',
#  'Nicholas Fisher',
#  'Destynee Tau',
#  'Shantelle Serafin',
#  'Elliot Lee',
#  'Finn St-John',
#  'Hinn Zhang',
#  'Isa Vidanes',
#  'Gilberto Robles',
#  'Michael Nodini',
#  'Nia Page',
#  'Chris Lucas',
#  'Donovan Cronkhite',
#  'Arturo Sorensen',
#  'Anudeep Alam',
#  'Kyle Carter',
#  'Vineet Tallavajhala',
#  'Ruben Kerobyan',
#  'Siyuan Wang',
#  'Angel Ventura',
#  'Aung Yang',
#  None,
#  'David Seo',
#  None,
#  'Nolan Crespo',
#  'Luke Glascoe',
#  'Julian Yan',
#  'Steven Gov',
#  'Tung Doan',
#  'Mary Kovic',
#  'Sergio Ramirez',
#  'Jodie Li',
#  'Josie Li',
#  'Kelly Leon-Marquez',
#  'Manav Ram',
#  'Vishaal Ramaswamy-Kasi-Vasu',
#  'Justin Phen',
#  'Dhanush Nanjunda-Reddy',
#  'Alexis Ramachandran',
#  'John Pyjar',
#  'Katherine Sisombath',
#  'Zina Patel',
#  'Aditi Gandhi',
#  'Billy Phannavong',
#  None,
#  'Leslie Aguiar',
#  'Tiancheng Ma',
#  'Parsia Hedayat',
#  'Olivia Gale',
#  'Mingjia Zhu',
#  'Jumana Sarwar',
#  'Ethan Dinh-Luong',
#  'Crystal Zhan',
#  'Akil Rajendra-Janarthanan',
#  'Kristine Thipatima',
#  'Kristen Prescaro',
#  'Jianchang Yu',
#  'Gokul Swaminathan',
#  'Wilson Chen',
#  'John Le',
#  'Emmanuel Gutierrez',
#  'Colby Hillers',
#  'Calvin Cheung',
#  'Hoang Nguyen',
#  'Javon Maxie',
#  'Jorge Mendoza',
#  'Jessica Gazca',
#  'Jenny Vu',
#  'Rich Liu',
#  'Genevieve Cassidy',
#  'Alexandra Soltan-Kashefi',
#  'Christian Malki',
#  'Matthew Kilzi',
#  'Soumya Kalluri',
#  'Zhengde Song',
#  'Kevin Wang',
#  None,
#  'Zakaria Alhomsy',
#  'Siyi Gao',
#  'Chia-Yu Chang',
#  'Cecilia Liu',
#  'Hannah Lin',
#  'Jinyu Rao',
#  'Lanzhuo Wu',
#  'Royce Casiano',
#  'Keionni Thompson',
#  'Hargun Singh-Mahindra',
#  'Ryan Kim',
#  'Brian Wong',
#  'Lance Casiple',
#  'Lloyd Chen',
#  'Joona Kim',
#  'Finn Reid',
#  'Ethan Wadsworth',
#  'Nicholas Degroot',
#  'Dario Aburto-Rodriguez',
#  'Gregory Boscaiu',
#  'Amber Lu',
#  'Hsi Chen',
#  'Stephen Gelinas',
#  'Brian Wang',
#  'Katherine Lim',
#  'Daniel Lam',
#  'Michael Phung',
#  'Jacky Dam',
#  'Olivia Roth',
#  'Amiet Scheidegger',
#  'Riley Liu',
#  'Katie Li',
#  'Kimberly Liu',
#  'Jasmine Chen',
#  'Hoang Nguyen',
#  'Ruoxuan Li',
#  'Dylan Newman',
#  'Samuel Calto',
#  'Manuel Rodriguez-Nunez',
#  'Julia Hulvey',
#  'Rosalind Moore',
#  'Rasya Soeroso',
#  'Kayla Sacks',
#  'Hima Kathi',
#  'Brian Xie',
#  'Ted Feng',
#  'Xing Hong',
#  'Zhipeng Chen',
#  'Yikai Zhang',
#  None,
#  'Grant Jiang',
#  'Elaine Ha',
#  'Joann Guan',
#  'Eason Law',
#  'Alexander Quan',
#  'Shamis Mohamed',
#  'Hamlet Torosian',
#  'Merve Kilic',
#  'Ashlyn Mahoney',
#  'Tj Nguyen',
#  'Joshua Wang',
#  'Katelyn Dang',
#  'Zachary Tulman',
#  'Tj Nguyen',
#  'Joshua Wang',
#  'Katelyn Dang',
#  'Zachary Tulman',
#  'Henry Chan',
#  'Cameron Vandertuig',
#  'Erdogan Ergit',
#  'Vanessa Gonzalez',
#  'Bailey Man',
#  'Justin Le',
#  'Isaiah Cortez',
#  'Andrea Mansilla',
#  'Yalong Tian',
#  'Wendi Jiang',
#  'Xiqiang Liu',
#  'Yiyu Liu',
#  'Landi Guo',
#  'Sydney Forster',
#  'Kenzy Wirth',
#  'Brian Huang',
#  'Tatum Maston',
#  'Abigail Han',
#  'Xinyi Li',
#  'Zhetai Zhou',
#  'Mingxuan Wu',
#  'Yu Cao',
#  'Yu Jin',
#  'Sebastian Graeber',
#  'Rizq Khateeb',
#  'Samuel Burkholder',
#  'Sik Sun',
#  'Cameron Faulkner',
#  None,
#  'Hanjie Zhan',
#  'Tianyu Yu',
#  'Shaolong Li',
#  'Alan Cao',
#  'Edward Yang',
#  'Kurtis Nguyen',
#  'Derek Zhu',
#  'Nick Ehsani',
#  'Alysandra Rae Pascua',
#  'Bea Barcelona',
#  'Emily Bledsoe',
#  'Caitlin Connolly',
#  'Ramzy Oncy-Avila',
#  'Yash Potdar',
#  'Kenneth Nguyen',
#  'Mandy Lee',
#  'Matthew Lund',
#  None,
#  'Matthew Chong',
#  'Amy Nguyen',
#  'Caleb Ko',
#  'Yuri Bukhradze',
#  'Miles Simitz',
#  'Victor Chang',
#  'Changchen Liu',
#  'Yu Xie',
#  'Sanjay Sampat',
#  'Jason Hsu',
#  'Joe Cai',
#  'Nimish Prabhakaran',
#  'Haoyu Zhu',
#  'Ruijia Zhang',
#  'Zhuotong Li',
#  'Charles Ye',
#  'Thomas Fratantoni',
#  'Victor Thai',
#  'Wajiullah Abdullah',
#  None,
#  'Harry You',
#  'Jenna Nguyen',
#  'Austin Ma',
#  'Pilaree Dulay',
#  'Carolyn Yatco',
#  'Kristy Lee',
#  'Sophie Jensen',
#  'Abigail Koornwinder',
#  'Hanna Clemente',
#  'Omar Bautista',
#  'Pedro Diaz-Saabedra',
#  'Enrique Alvarado',
#  'Allison Ngo',
#  'Karina Sanchez',
#  'Lingye Zhuang',
#  'Athena Hao',
#  'Tianyu Yu',
#  'Shaolong Li',
#  'Fengdi Liu',
#  'Hanjie Zhan',
#  'William Sumerfield',
#  None,
#  'Janty Sphabmixay',
#  'Tong Zeng',
#  'Kaiyu Guan',
#  'Juhita Vijjali',
#  None,
#  'Kimberly Holland',
#  'Lara May Bacani',
#  'Andrew Burda',
#  'Reyna Yang',
#  'Isabelle Chyun',
#  'Brian Chen',
#  'Michael Poon',
#  'Jeffrey Chen',
#  'Simran Nayyar',
#  'Duc Vo',
#  'Shimika Basuroy',
#  'Sagarika Alavilli',
#  'Sukanya Krishna',
#  'Mustansir Taquee',
#  'Antonio Aldama',
#  None,
#  'Michelle Belon',
#  'Leslie Carrillo',
#  'Zichun Xia',
#  'Banglun Wu',
#  'Laura Kim',
#  'Allison Tang',
#  'Zhangxiang Lu',
#  'Diane Li',
#  'Johnny Liu',
#  'Tae Kun Kim',
#  'Seph Shia',
#  'Dustin Lin',
#  'Luke Lloyd',
#  'Justin Chu',
#  'John Li',
#  'Prathik Malireddy',
#  'Alvin Wang',
#  'Shirley Qi',
#  'Tanay Reddy',
#  'Trisa Leung',
#  'Grace Zheng',
#  'Luis Zhang',
#  'William Wei',
#  'Jerry Yan',
#  'Bohan Lei',
#  None,
#  'Hayley Yamamoto',
#  'Ellie Kanda',
#  'Elise Ngo',
#  'Kevin Wong',
#  'Zongze Chen',
#  'Luis Zhang',
#  'Jerry Yan',
#  'William Wei',
#  None,
#  'Bohan Lei',
#  'Hyunsoo Kim',
#  'Jonathan Yun',
#  'John Rhee',
#  'Haeun Kim',
#  'Colin Wang',
#  'Yuru Zhou',
#  'Weiyue Li',
#  None,
#  'Muzhen Ai',
#  'Mingze Xu',
#  'Zehua Guo',
#  'Yichen Lyu',
#  'Julian Hou',
#  None,
#  'Danielle Villa-Agustin',
#  'Megha Chouthai',
#  'Marvin Maninang',
#  'Gokul Prasad',
#  'Vanessa Chen',
#  'Caroline Xiong',
#  'Carmen Li',
#  'Iisha Kshatriya',
#  'James Riddell',
#  'Michael Colbath',
#  'Laticia Long',
#  'Sung Kim',
#  'Mustansir Taquee',
#  'Antonio Aldama',
#  'Michelle Belon',
#  'Leslie Carrillo',
#  'Campbell Moco',
#  'Isabella Gonzalez',
#  'John Santos',
#  'Zara Nazir',
#  'Mary Longano',
#  'Robert Aispuro',
#  'William Martino',
#  'Angela Liu',
#  'Mingxin Liu',
#  'Jared Kallingal',
#  'Rachel Doron',
#  'Lisa Zhou',
#  'Jacob Ryan',
#  'Parshva Jain',
#  'Jacqueline Yuke',
#  'Mehdi Bouassami',
#  None,
#  'Gabriel Aganon',
#  'Ramy Al-Hosri',
#  'Sean Ng',
#  'Hwi Yeo',
#  'Jan Do',
#  'Franklin Le',
#  'Vivian Le',
#  'Dennis Luc',
#  'Elysia Chang',
#  'Simon Tsui',
#  'Juan Ding',
#  'Min Zhang',
#  'Siyu Shen',
#  'Yang Lu',
#  'Yunhao Du',
#  'Jianfan Huo',
#  'Yixin Jiang',
#  'Celine Zhao',
#  'Yixiao An',
#  'Bochen Pan',
#  'Ruijie Huang',
#  'Xiangwen Li',
#  'Rongyu Ma',
#  'Mingjie Ni',
#  'Hang Shi',
#  'Juanyu Liu',
#  'Siyuan Zhang',
#  'Jie Wei',
#  'Yingshan Xie',
#  'Ivan Ozerets',
#  'Joseph Hsieh',
#  'Riese Wismer',
#  'Cassidy Nguyen',
#  'Shawn Gomos',
#  'Heqi Wang',
#  'Anson Zhang',
#  'Yundi Xu',
#  'Sizhe Fan',
#  'Ana Cunha',
#  'Christopher Yoon',
#  'Albert Aung',
#  'Uday Mehra',
#  None,
#  'Athina Obfenda',
#  'Matilda Michel',
#  'Thais Chen',
#  'Athena Le',
#  'Matin Ghaffari',
#  'James Lu',
#  'Rahil Shah',
#  'Jorge Acevedo',
#  'Alan Amirian',
#  'Zachary Francis',
#  'Nimish Singh',
#  'Neel Ayyagari',
#  'Jacob Khaliqi',
#  'Teresa Lee',
#  'William Xia',
#  'Ingrid Altamirano',
#  'John Harrison',
#  'Isabel Tate',
#  'Martin Thai',
#  'Ryan Bui',
#  'Nathan Bui',
#  'Sophia Lui',
#  'Alec Panattoni',
#  'Rodolfo Cardenas',
#  None,
#  'Tyler Tran',
#  'Sophia Lui',
#  'Alec Panattoni',
#  'Rodolfo Cardenas',
#  None,
#  'Tyler Tran',
#  'Moksha Poladi',
#  'Esha Desai',
#  'Sonika Ram',
#  None,
#  'Satomi Ito',
#  'Jacob Zhong',
#  'Lorenzo Topacio',
#  'Kaushika Uppu',
#  'Yu-Jung Lin',
#  'Jialin Yan',
#  'Ryan Lay',
#  'Richie Porras',
#  'Aldair Olanda',
#  'Tiffany Zhong',
#  'Gina Ocegueda',
#  'Zefang Yuan',
#  'Pu Tan',
#  'Linda Lin',
#  'Zixun Zhang',
#  'Kairi Sageshima',
#  'Brandon Wang',
#  'Marisol Jimenez',
#  'Ashley Chu',
#  'Daniel Milton',
#  'Phoebe Sonnad',
#  'Kyle Burick',
#  'Thea Zhang',
#  'Aidan Bell',
#  'Tracy Nguyen',
#  'Kenny Tran',
#  'Rickie Chen',
#  'Andrew Caballero',
#  'Matthew Kilzi',
#  'Alexandra Soltan-Kashefi',
#  'Christian Malki',
#  'Soumya Kalluri',
#  'Joonsung Park',
#  'James Chung',
#  'Richard Gross',
#  'Madison Hambly',
#  'Colin Lintereur']

# %%
unassigned_2 = set(enrolled_students.Student) - set(grouped_names_from_sids)
unassigned_2
# Out:
# {'Anthony Handjojo',
#  'Chayuda Naulmanee',
#  'Eric Youn',
#  'Gaurav Mahindru',
#  'Jonathan Ahern',
#  'Jonathan Nguyen',
#  'Kyle Cook',
#  'Lazar Nikolic',
#  'Leonardo Guillen',
#  'Maxwell Jung',
#  'Melanie Wang',
#  'Miriam Hamidi',
#  'Peter Hattendorf',
#  'Raam Chaklashiya',
#  'Taekyu Lee',
#  'Thanh Tong',
#  'Tony Diep',
#  'Vishvesh Bhat',
#  'Vivian Lee',
#  'Wilson Tan',
#  'Yichi Zhang',
#  'Ying Huang',
#  'Yong Chung'}

# %%
badnames_2 = set(grouped_names_from_sids) - set(enrolled_students.Student)
badnames_2
# Out:
# {None}

# %% [markdown]
# Clearly it looks like the method for unassigned students via SID is the best version for this quarter, let's roll with it.
#
# You might need to make a different call in a different quarter :)
#
# But first let's see if there's any cases where the SID was bad but the student name was recorded properly

# %%
# these are students who were recorded properly by name but not by SID
correction = unassigned_2.intersection( set(grouped_students) )
correction
# Out:
# {'Chayuda Naulmanee', 'Eric Youn'}

# %%
unassigned_students = list( unassigned_2 - correction)
print('there are {} unassigned_students:\n{}'.format(len(unassigned_students), unassigned_students))
# Out:
# there are 21 unassigned_students:
# ['Miriam Hamidi', 'Raam Chaklashiya', 'Vivian Lee', 'Maxwell Jung', 'Anthony Handjojo', 'Wilson Tan', 'Melanie Wang', 'Ying Huang', 'Yichi Zhang', 'Gaurav Mahindru', 'Yong Chung', 'Kyle Cook', 'Vishvesh Bhat', 'Jonathan Nguyen', 'Thanh Tong', 'Taekyu Lee', 'Lazar Nikolic', 'Leonardo Guillen', 'Tony Diep', 'Peter Hattendorf', 'Jonathan Ahern']

# %% [markdown]
# ### Create new groups and/or fill up sub-sized groups with the unassigned

# %% [markdown]
# What should you do?  let's do this manually becuase its impossible to do it well automatically
#
# In this quarter I will be adding 6 total people to 4 subsized groups, creating groups of 4,4,5,5, which will leave me 15 unassigned to make 3 groups of 5

# %%
subsized_groups = groups[ groups.n_people < 4 ]
subsized_groups
# Out:
#                                                         names  \
# group_name
# Group007                    Julian Yan, Steven Gov, Tung Doan
# Group010    Alexis Ramachandran, Jake Pyjar, Katherine Sis...
# Group034        Henry Chan, Cameron VanderTuig, Erdogan Ergit
# Group088                      Martin Thai,Ryan Bui,Nathan Bui
#
#                                        sids                            gitids  \
# group_name
# Group007    A15493579, A15601331, A15808272          jwyan, stevengov, tbdoan
# Group010    A16008232, A16123651, A14413906      apramach, chefpy, ksisombath
# Group034    A16617919, A15803073, A16175522         kctter, IRSMsoso, Gauss-x
# Group088      A15815245,A15847181,A15847396  martintthai,ryanbuui,nathan42424
#
#             n_people
# group_name
# Group007           3
# Group010           3
# Group034           3
# Group088           3

# %%
21 - 6
# Out:
# 15

# %%
counter = 0
assignments = {}

# %%
gr = 'Group007'

print(groups.loc[gr,'names'])
groups.loc[gr,'names'] = groups.loc[gr,'names']+', '+unassigned_students[counter]
groups.loc[gr,'names']
assignments[unassigned_students[counter]] = gr
counter = counter + 1
print(groups.loc[gr,'names'])
# Out:
# Julian Yan, Steven Gov, Tung Doan
# Julian Yan, Steven Gov, Tung Doan, Miriam Hamidi

# %%
gr = 'Group010'

print(groups.loc[gr,'names'])
groups.loc[gr,'names'] = groups.loc[gr,'names']+', '+unassigned_students[counter]
groups.loc[gr,'names']
assignments[unassigned_students[counter]] = gr
counter = counter + 1
print(groups.loc[gr,'names'])
# Out:
# Alexis Ramachandran, Jake Pyjar, Katherine Sisombath
# Alexis Ramachandran, Jake Pyjar, Katherine Sisombath, Raam Chaklashiya

# %%
gr = 'Group034'

print(groups.loc[gr,'names'])
groups.loc[gr,'names'] = groups.loc[gr,'names']+', '+unassigned_students[counter]
groups.loc[gr,'names']
assignments[unassigned_students[counter]] = gr
counter = counter + 1
print(groups.loc[gr,'names'])
# Out:
# Henry Chan, Cameron VanderTuig, Erdogan Ergit
# Henry Chan, Cameron VanderTuig, Erdogan Ergit, Vivian Lee

# %%
gr = 'Group034'

print(groups.loc[gr,'names'])
groups.loc[gr,'names'] = groups.loc[gr,'names']+', '+unassigned_students[counter]
groups.loc[gr,'names']
assignments[unassigned_students[counter]] = gr
counter = counter + 1
print(groups.loc[gr,'names'])
# Out:
# Henry Chan, Cameron VanderTuig, Erdogan Ergit, Vivian Lee
# Henry Chan, Cameron VanderTuig, Erdogan Ergit, Vivian Lee, Maxwell Jung

# %%
gr = 'Group088'

print(groups.loc[gr,'names'])
groups.loc[gr,'names'] = groups.loc[gr,'names']+', '+unassigned_students[counter]
groups.loc[gr,'names']
assignments[unassigned_students[counter]] = gr
counter = counter + 1
print(groups.loc[gr,'names'])
# Out:
# Martin Thai,Ryan Bui,Nathan Bui
# Martin Thai,Ryan Bui,Nathan Bui, Anthony Handjojo

# %%
gr = 'Group088'

print(groups.loc[gr,'names'])
groups.loc[gr,'names'] = groups.loc[gr,'names']+', '+unassigned_students[counter]
groups.loc[gr,'names']
assignments[unassigned_students[counter]] = gr
counter = counter + 1
print(groups.loc[gr,'names'])
# Out:
# Martin Thai,Ryan Bui,Nathan Bui, Anthony Handjojo
# Martin Thai,Ryan Bui,Nathan Bui, Anthony Handjojo, Wilson Tan

# %% [markdown]
# OK now do the rest of the unassigned in new groups

# %%
groups.tail(1)
# Out:
#                                                         names  \
# group_name
# Group099     Joonsung Park,  James Chung, Richard Gross, M...
#
#                                                          sids  \
# group_name
# Group099    A91122505, A15852697, A16661487, A16625551, A1...
#
#                                                        gitids  n_people
# group_name
# Group099    jop003, jchung01, ucsdRgross, Mhambly, colinli...         5

# %%
len(unassigned_students[counter:])
# Out:
# 15

# %%
gr = 'Group100'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+5
print(groups.loc[gr,'names'])
# Out:
# Melanie Wang, Ying Huang, Yichi Zhang, Gaurav Mahindru, Yong Chung

# %%
gr = 'Group101'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+5
print(groups.loc[gr,'names'])
# Out:
# Kyle Cook, Vishvesh Bhat, Jonathan Nguyen, Thanh Tong, Taekyu Lee

# %%
gr = 'Group102'

groups.loc[gr,'names'] = ', '.join(unassigned_students[counter:counter+5])
counter = counter+5
print(groups.loc[gr,'names'])
# Out:
# Lazar Nikolic, Leonardo Guillen, Tony Diep, Peter Hattendorf, Jonathan Ahern

# %%
len(unassigned_students[counter:])
# Out:
# 0

# %%
groups
# Out:
#                                                         names  \
# group_name
# Group000    Truong Pham, Briana Nevarez, Ipek Eren, Yaoxin...
# Group001    Joshua Discar, Kelly Luu, Isaiah Nicasio, Nich...
# Group002    Shantelle Serafin, Elliot Lee, Finn St John, H...
# Group003    Gilberto Robles, Michael Nodini, Nia Page, Chr...
# Group004    Arturo Sorensen, Anudeep Alam, Kyle Carter, Vi...
# ...                                                       ...
# Group098    Matthew Kilzi, Alexandra Soltan-Kashefi, Chris...
# Group099     Joonsung Park,  James Chung, Richard Gross, M...
# Group100    Melanie Wang, Ying Huang, Yichi Zhang, Gaurav ...
# Group101    Kyle Cook, Vishvesh Bhat, Jonathan Nguyen, Tha...
# Group102    Lazar Nikolic, Leonardo Guillen, Tony Diep, Pe...
#
#                                                          sids  \
# group_name
# Group000    A15619342, A14558091, A16074539, A16542726, A1...
# Group001    A15659137, A16312606, A15645856, A15592188, A1...
# Group002    A16162300, A15796673, A16133473, A16158139, A1...
# Group003    A15415579. A16007357, A16086395, A16592184, A1...
# Group004           A15834453, A15886397, A15806576, A15959751
# ...                                                       ...
# Group098           A16690085, A13190332, A16546082, A15436546
# Group099    A91122505, A15852697, A16661487, A16625551, A1...
# Group100                                                  NaN
# Group101                                                  NaN
# Group102                                                  NaN
#
#                                                        gitids  n_people
# group_name
# Group000            tgnpham, banevare, ipekerenn, hblyx, ezul       5.0
# Group001    Serious-Fish, kellyyluu, isaiahin, nickfish716...       5.0
# Group002    shantellemeganserafin, Eal001, stjohnfinn, hin...       5.0
# Group003    gilbertorobles24, mnodini, niakai, cjlucas-ucs...       5.0
# Group004        artusor, SleepyDeep, krcarter223, vineettalla       4.0
# ...                                                       ...       ...
# Group098      daveshc, aleykashefi, chrismalki, soumyakalluri       4.0
# Group099    jop003, jchung01, ucsdRgross, Mhambly, colinli...       5.0
# Group100                                                  NaN       NaN
# Group101                                                  NaN       NaN
# Group102                                                  NaN       NaN
#
# [103 rows x 4 columns]

# %%
groups.drop(columns='n_people').to_csv('assigned_groups.csv')

# %% [markdown]
# I then took the above into Google Sheets, edited it by hand to remove at least 3 duplicate rows I hadn't caught previously, adding red formatting to names that had been randomly assigned (to request that those students give me their GitHub user names)
#
# Next I will hand add in the new usernames in Google sheets, then import that edited list back in so we can operate on github next.

# %%
newgroups = pd.read_csv('Project_Review_Assignments_Fa20 - Sheet1.csv').set_index('group_name')

# %% [markdown]
# ### Github
# OK time to create a github repo for each and every group. Note to do this you need to have gh CLI installed and have authenticated it as your user (see `gh auth login` documentation)
#
# The process will create one repo for each group from the group_template.  Next we invite users to their repo. Then we checkout the project locally, rename the files, push, and delete the local copy

# %%
import os
import glob

command_create = 'gh repo create --private --template COGS108/group_template -y COGS108/' # + groupname
command_invite = 'gh api -X PUT -f permission=push repos/COGS108/' # + groupname/collaborators/username

# %%
for grp in newgroups.index:

    gname = grp+'-Fa21' #change this name suffix each quarter
    
    # create new repo
    cmd = command_create+gname
    ret = os.system(cmd)
    print(cmd,ret)
    
    # invite everyone in the group to the repo
    for uname in newgroups.loc[grp,'gitids'].split(','):
        cmd=command_invite+gname+'/collaborators/'+uname.strip()
        ret = os.system(cmd)
        print(cmd,ret)
        
    # get a local copy of the repo
    cmd='gh repo clone COGS108/'+gname
    ret = os.system(cmd)
    print(cmd,ret)

    # rename the files in the repo to the groups name pattern
    for fname in glob.glob(gname+'/*groupXXX.ipynb'):
        source = fname.split('/')[1]
        target = source.split("_")[0]+gname+'.ipynb'
        cmd = ( 'cd '+gname+'; '+
                        ' '.join(['git mv',source,target]))
        ret = os.system(cmd)
        print(cmd,ret)
    
    # commit changes and push
    cmd = 'cd '+gname+'; git add -A; git commit -m "renamed files"; git push'
    ret = os.system(cmd)
    print(cmd,ret)
    
    # remove local copy of repo
    cmd = 'rm -rf '+gname
    ret = os.system(cmd)
    print(cmd,ret)
# Out:
# gh repo create --private --template COGS108/group_template -y COGS108/Group000-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group000-Fa21/collaborators/tgnpham 0
# gh api -X PUT -f permission=push repos/COGS108/Group000-Fa21/collaborators/banevare 0
# gh api -X PUT -f permission=push repos/COGS108/Group000-Fa21/collaborators/ipekerenn 0
# gh api -X PUT -f permission=push repos/COGS108/Group000-Fa21/collaborators/hblyx 0
# gh api -X PUT -f permission=push repos/COGS108/Group000-Fa21/collaborators/ezul 0
# gh repo clone COGS108/Group000-Fa21 0
# cd Group000-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup000-Fa21.ipynb 0
# cd Group000-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup000-Fa21.ipynb 0
# cd Group000-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup000-Fa21.ipynb 0
# cd Group000-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup000-Fa21.ipynb 0
# cd Group000-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group000-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group001-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group001-Fa21/collaborators/Serious-Fish 0
# gh api -X PUT -f permission=push repos/COGS108/Group001-Fa21/collaborators/kellyyluu 0
# gh api -X PUT -f permission=push repos/COGS108/Group001-Fa21/collaborators/isaiahin 0
# gh api -X PUT -f permission=push repos/COGS108/Group001-Fa21/collaborators/nickfish716 0
# gh api -X PUT -f permission=push repos/COGS108/Group001-Fa21/collaborators/destynee 0
# gh repo clone COGS108/Group001-Fa21 0
# cd Group001-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup001-Fa21.ipynb 0
# cd Group001-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup001-Fa21.ipynb 0
# cd Group001-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup001-Fa21.ipynb 0
# cd Group001-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup001-Fa21.ipynb 0
# cd Group001-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group001-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group002-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group002-Fa21/collaborators/shantellemeganserafin 0
# gh api -X PUT -f permission=push repos/COGS108/Group002-Fa21/collaborators/Eal001 0
# gh api -X PUT -f permission=push repos/COGS108/Group002-Fa21/collaborators/stjohnfinn 0
# gh api -X PUT -f permission=push repos/COGS108/Group002-Fa21/collaborators/hinyzee 0
# gh api -X PUT -f permission=push repos/COGS108/Group002-Fa21/collaborators/veloimv 0
# gh repo clone COGS108/Group002-Fa21 0
# cd Group002-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup002-Fa21.ipynb 0
# cd Group002-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup002-Fa21.ipynb 0
# cd Group002-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup002-Fa21.ipynb 0
# cd Group002-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup002-Fa21.ipynb 0
# cd Group002-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group002-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group003-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group003-Fa21/collaborators/gilbertorobles24 0
# gh api -X PUT -f permission=push repos/COGS108/Group003-Fa21/collaborators/mnodini 0
# gh api -X PUT -f permission=push repos/COGS108/Group003-Fa21/collaborators/niakai 0
# gh api -X PUT -f permission=push repos/COGS108/Group003-Fa21/collaborators/cjlucas-ucsd 0
# gh api -X PUT -f permission=push repos/COGS108/Group003-Fa21/collaborators/dcronkhi 0
# gh repo clone COGS108/Group003-Fa21 0
# cd Group003-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup003-Fa21.ipynb 0
# cd Group003-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup003-Fa21.ipynb 0
# cd Group003-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup003-Fa21.ipynb 0
# cd Group003-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup003-Fa21.ipynb 0
# cd Group003-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group003-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group004-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group004-Fa21/collaborators/artusor 0
# gh api -X PUT -f permission=push repos/COGS108/Group004-Fa21/collaborators/SleepyDeep 0
# gh api -X PUT -f permission=push repos/COGS108/Group004-Fa21/collaborators/krcarter223 0
# gh api -X PUT -f permission=push repos/COGS108/Group004-Fa21/collaborators/vineettalla 0
# gh repo clone COGS108/Group004-Fa21 0
# cd Group004-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup004-Fa21.ipynb 0
# cd Group004-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup004-Fa21.ipynb 0
# cd Group004-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup004-Fa21.ipynb 0
# cd Group004-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup004-Fa21.ipynb 0
# cd Group004-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group004-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group005-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group005-Fa21/collaborators/DetectivBananas 0
# gh api -X PUT -f permission=push repos/COGS108/Group005-Fa21/collaborators/siw021 0
# gh api -X PUT -f permission=push repos/COGS108/Group005-Fa21/collaborators/Angelv1 0
# gh api -X PUT -f permission=push repos/COGS108/Group005-Fa21/collaborators/AungYang 0
# gh api -X PUT -f permission=push repos/COGS108/Group005-Fa21/collaborators/unsure 0
# gh repo clone COGS108/Group005-Fa21 0
# cd Group005-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup005-Fa21.ipynb 0
# cd Group005-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup005-Fa21.ipynb 0
# cd Group005-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup005-Fa21.ipynb 0
# cd Group005-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup005-Fa21.ipynb 0
# cd Group005-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group005-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group006-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group006-Fa21/collaborators/canyouhodl 0
# gh api -X PUT -f permission=push repos/COGS108/Group006-Fa21/collaborators/jmata21 0
# gh api -X PUT -f permission=push repos/COGS108/Group006-Fa21/collaborators/nicrespo 0
# gh api -X PUT -f permission=push repos/COGS108/Group006-Fa21/collaborators/lukeglas11 0
# gh repo clone COGS108/Group006-Fa21 0
# cd Group006-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup006-Fa21.ipynb 0
# cd Group006-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup006-Fa21.ipynb 0
# cd Group006-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup006-Fa21.ipynb 0
# cd Group006-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup006-Fa21.ipynb 0
# cd Group006-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group006-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group007-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group007-Fa21/collaborators/jwyan 0
# gh api -X PUT -f permission=push repos/COGS108/Group007-Fa21/collaborators/stevengov 0
# gh api -X PUT -f permission=push repos/COGS108/Group007-Fa21/collaborators/tbdoan 0
# gh repo clone COGS108/Group007-Fa21 0
# cd Group007-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup007-Fa21.ipynb 0
# cd Group007-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup007-Fa21.ipynb 0
# cd Group007-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup007-Fa21.ipynb 0
# cd Group007-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup007-Fa21.ipynb 0
# cd Group007-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group007-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group008-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group008-Fa21/collaborators/marykovic 0
# gh api -X PUT -f permission=push repos/COGS108/Group008-Fa21/collaborators/serz19 0
# gh api -X PUT -f permission=push repos/COGS108/Group008-Fa21/collaborators/jodieli 0
# gh api -X PUT -f permission=push repos/COGS108/Group008-Fa21/collaborators/joxieli613 0
# gh api -X PUT -f permission=push repos/COGS108/Group008-Fa21/collaborators/kellyxlm 0
# gh repo clone COGS108/Group008-Fa21 0
# cd Group008-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup008-Fa21.ipynb 0
# cd Group008-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup008-Fa21.ipynb 0
# cd Group008-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup008-Fa21.ipynb 0
# cd Group008-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup008-Fa21.ipynb 0
# cd Group008-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group008-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group009-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group009-Fa21/collaborators/Manav-Ram19 0
# gh api -X PUT -f permission=push repos/COGS108/Group009-Fa21/collaborators/Vishaal1301 0
# gh api -X PUT -f permission=push repos/COGS108/Group009-Fa21/collaborators/jphen 0
# gh api -X PUT -f permission=push repos/COGS108/Group009-Fa21/collaborators/dnanjunda 0
# gh repo clone COGS108/Group009-Fa21 0
# cd Group009-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup009-Fa21.ipynb 0
# cd Group009-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup009-Fa21.ipynb 0
# cd Group009-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup009-Fa21.ipynb 0
# cd Group009-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup009-Fa21.ipynb 0
# cd Group009-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group009-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group010-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group010-Fa21/collaborators/apramach 0
# gh api -X PUT -f permission=push repos/COGS108/Group010-Fa21/collaborators/chefpy 0
# gh api -X PUT -f permission=push repos/COGS108/Group010-Fa21/collaborators/ksisombath 0
# gh api -X PUT -f permission=push repos/COGS108/Group010-Fa21/collaborators/NguyenSanh 0
# gh repo clone COGS108/Group010-Fa21 0
# cd Group010-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup010-Fa21.ipynb 0
# cd Group010-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup010-Fa21.ipynb 0
# cd Group010-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup010-Fa21.ipynb 0
# cd Group010-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup010-Fa21.ipynb 0
# cd Group010-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group010-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group011-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group011-Fa21/collaborators/zaproxa17 0
# gh api -X PUT -f permission=push repos/COGS108/Group011-Fa21/collaborators/aditigandhi 0
# gh api -X PUT -f permission=push repos/COGS108/Group011-Fa21/collaborators/bphannavong 0
# gh api -X PUT -f permission=push repos/COGS108/Group011-Fa21/collaborators/nicolerangan 0
# gh api -X PUT -f permission=push repos/COGS108/Group011-Fa21/collaborators/leslieaguiar 0
# gh repo clone COGS108/Group011-Fa21 0
# cd Group011-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup011-Fa21.ipynb 0
# cd Group011-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup011-Fa21.ipynb 0
# cd Group011-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup011-Fa21.ipynb 0
# cd Group011-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup011-Fa21.ipynb 0
# cd Group011-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group011-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group012-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group012-Fa21/collaborators/TianchengMa-0 0
# gh api -X PUT -f permission=push repos/COGS108/Group012-Fa21/collaborators/phedayat 0
# gh api -X PUT -f permission=push repos/COGS108/Group012-Fa21/collaborators/oliverstuff 0
# gh api -X PUT -f permission=push repos/COGS108/Group012-Fa21/collaborators/mingjiazhu 0
# gh api -X PUT -f permission=push repos/COGS108/Group012-Fa21/collaborators/jsarwar711 0
# gh repo clone COGS108/Group012-Fa21 0
# cd Group012-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup012-Fa21.ipynb 0
# cd Group012-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup012-Fa21.ipynb 0
# cd Group012-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup012-Fa21.ipynb 0
# cd Group012-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup012-Fa21.ipynb 0
# cd Group012-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group012-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group013-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group013-Fa21/collaborators/edinhluo 0
# gh api -X PUT -f permission=push repos/COGS108/Group013-Fa21/collaborators/mr4tt 0
# gh api -X PUT -f permission=push repos/COGS108/Group013-Fa21/collaborators/bubloo7 0
# gh api -X PUT -f permission=push repos/COGS108/Group013-Fa21/collaborators/kthipatima 0
# gh api -X PUT -f permission=push repos/COGS108/Group013-Fa21/collaborators/kprescaro 0
# gh repo clone COGS108/Group013-Fa21 0
# cd Group013-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup013-Fa21.ipynb 0
# cd Group013-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup013-Fa21.ipynb 0
# cd Group013-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup013-Fa21.ipynb 0
# cd Group013-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup013-Fa21.ipynb 0
# cd Group013-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group013-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group014-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group014-Fa21/collaborators/kennyyu168 0
# gh api -X PUT -f permission=push repos/COGS108/Group014-Fa21/collaborators/JavaCafe01 0
# gh api -X PUT -f permission=push repos/COGS108/Group014-Fa21/collaborators/strawhatwilson22 0
# gh api -X PUT -f permission=push repos/COGS108/Group014-Fa21/collaborators/jmle99 0
# gh api -X PUT -f permission=push repos/COGS108/Group014-Fa21/collaborators/e1gutier 0
# gh repo clone COGS108/Group014-Fa21 0
# cd Group014-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup014-Fa21.ipynb 0
# cd Group014-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup014-Fa21.ipynb 0
# cd Group014-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup014-Fa21.ipynb 0
# cd Group014-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup014-Fa21.ipynb 0
# cd Group014-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group014-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group015-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group015-Fa21/collaborators/colbyhillers 0
# gh api -X PUT -f permission=push repos/COGS108/Group015-Fa21/collaborators/ccheung8 0
# gh api -X PUT -f permission=push repos/COGS108/Group015-Fa21/collaborators/hoang-nguyen1 0
# gh api -X PUT -f permission=push repos/COGS108/Group015-Fa21/collaborators/TheRealMambaz 0
# gh api -X PUT -f permission=push repos/COGS108/Group015-Fa21/collaborators/Jorg3M3ndoza 0
# gh repo clone COGS108/Group015-Fa21 0
# cd Group015-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup015-Fa21.ipynb 0
# cd Group015-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup015-Fa21.ipynb 0
# cd Group015-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup015-Fa21.ipynb 0
# cd Group015-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup015-Fa21.ipynb 0
# cd Group015-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group015-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group016-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group016-Fa21/collaborators/JessieMGB 0
# gh api -X PUT -f permission=push repos/COGS108/Group016-Fa21/collaborators/jen-00 0
# gh api -X PUT -f permission=push repos/COGS108/Group016-Fa21/collaborators/rich-liu 0
# gh api -X PUT -f permission=push repos/COGS108/Group016-Fa21/collaborators/glcassidy 0
# gh repo clone COGS108/Group016-Fa21 0
# cd Group016-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup016-Fa21.ipynb 0
# cd Group016-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup016-Fa21.ipynb 0
# cd Group016-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup016-Fa21.ipynb 0
# cd Group016-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup016-Fa21.ipynb 0
# cd Group016-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group016-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group017-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group017-Fa21/collaborators/aleykashefi 0
# gh api -X PUT -f permission=push repos/COGS108/Group017-Fa21/collaborators/chrismalki 0
# gh api -X PUT -f permission=push repos/COGS108/Group017-Fa21/collaborators/daveshc 0
# gh api -X PUT -f permission=push repos/COGS108/Group017-Fa21/collaborators/soumyakalluri 0
# gh repo clone COGS108/Group017-Fa21 0
# cd Group017-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup017-Fa21.ipynb 0
# cd Group017-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup017-Fa21.ipynb 0
# cd Group017-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup017-Fa21.ipynb 0
# cd Group017-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup017-Fa21.ipynb 0
# cd Group017-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group017-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group018-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group018-Fa21/collaborators/ZhengdeSong 0
# gh api -X PUT -f permission=push repos/COGS108/Group018-Fa21/collaborators/KevinJiechengWang 0
# gh api -X PUT -f permission=push repos/COGS108/Group018-Fa21/collaborators/ericyoun430 0
# gh api -X PUT -f permission=push repos/COGS108/Group018-Fa21/collaborators/zakariaAlhomsy 0
# gh api -X PUT -f permission=push repos/COGS108/Group018-Fa21/collaborators/Siyigao991122 0
# gh repo clone COGS108/Group018-Fa21 0
# cd Group018-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup018-Fa21.ipynb 0
# cd Group018-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup018-Fa21.ipynb 0
# cd Group018-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup018-Fa21.ipynb 0
# cd Group018-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup018-Fa21.ipynb 0
# cd Group018-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group018-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group019-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group019-Fa21/collaborators/ChiayuC 0
# gh api -X PUT -f permission=push repos/COGS108/Group019-Fa21/collaborators/cecilialmw 0
# gh api -X PUT -f permission=push repos/COGS108/Group019-Fa21/collaborators/lin-hannah 0
# gh api -X PUT -f permission=push repos/COGS108/Group019-Fa21/collaborators/JinyuRao 0
# gh api -X PUT -f permission=push repos/COGS108/Group019-Fa21/collaborators/AdelaideW15 0
# gh repo clone COGS108/Group019-Fa21 0
# cd Group019-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup019-Fa21.ipynb 0
# cd Group019-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup019-Fa21.ipynb 0
# cd Group019-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup019-Fa21.ipynb 0
# cd Group019-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup019-Fa21.ipynb 0
# cd Group019-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group019-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group020-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group020-Fa21/collaborators/rrcasiano 0
# gh api -X PUT -f permission=push repos/COGS108/Group020-Fa21/collaborators/kat002 0
# gh api -X PUT -f permission=push repos/COGS108/Group020-Fa21/collaborators/hsingh1010 0
# gh api -X PUT -f permission=push repos/COGS108/Group020-Fa21/collaborators/rskim25 0
# gh repo clone COGS108/Group020-Fa21 0
# cd Group020-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup020-Fa21.ipynb 0
# cd Group020-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup020-Fa21.ipynb 0
# cd Group020-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup020-Fa21.ipynb 0
# cd Group020-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup020-Fa21.ipynb 0
# cd Group020-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group020-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group021-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group021-Fa21/collaborators/bkwong315 0
# gh api -X PUT -f permission=push repos/COGS108/Group021-Fa21/collaborators/lancecasiple 0
# gh api -X PUT -f permission=push repos/COGS108/Group021-Fa21/collaborators/lloyd-chen 0
# gh api -X PUT -f permission=push repos/COGS108/Group021-Fa21/collaborators/jokimucsd 0
# gh api -X PUT -f permission=push repos/COGS108/Group021-Fa21/collaborators/stayingqold 0
# gh repo clone COGS108/Group021-Fa21 0
# cd Group021-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup021-Fa21.ipynb 0
# cd Group021-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup021-Fa21.ipynb 0
# cd Group021-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup021-Fa21.ipynb 0
# cd Group021-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup021-Fa21.ipynb 0
# cd Group021-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group021-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group022-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group022-Fa21/collaborators/EthanWadsworth 0
# gh api -X PUT -f permission=push repos/COGS108/Group022-Fa21/collaborators/nickthegroot 0
# gh api -X PUT -f permission=push repos/COGS108/Group022-Fa21/collaborators/DarioAburto 0
# gh api -X PUT -f permission=push repos/COGS108/Group022-Fa21/collaborators/gboscaiu 0
# gh repo clone COGS108/Group022-Fa21 0
# cd Group022-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup022-Fa21.ipynb 0
# cd Group022-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup022-Fa21.ipynb 0
# cd Group022-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup022-Fa21.ipynb 0
# cd Group022-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup022-Fa21.ipynb 0
# cd Group022-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group022-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group023-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group023-Fa21/collaborators/amberlu-design 0
# gh api -X PUT -f permission=push repos/COGS108/Group023-Fa21/collaborators/hsc012 0
# gh api -X PUT -f permission=push repos/COGS108/Group023-Fa21/collaborators/srgelinas 0
# gh api -X PUT -f permission=push repos/COGS108/Group023-Fa21/collaborators/Brian96086 0
# gh repo clone COGS108/Group023-Fa21 0
# cd Group023-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup023-Fa21.ipynb 0
# cd Group023-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup023-Fa21.ipynb 0
# cd Group023-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup023-Fa21.ipynb 0
# cd Group023-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup023-Fa21.ipynb 0
# cd Group023-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group023-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group024-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group024-Fa21/collaborators/katherin467 0
# gh api -X PUT -f permission=push repos/COGS108/Group024-Fa21/collaborators/chefyes 0
# gh api -X PUT -f permission=push repos/COGS108/Group024-Fa21/collaborators/klm4life 0
# gh api -X PUT -f permission=push repos/COGS108/Group024-Fa21/collaborators/jacky3331 0
# gh repo clone COGS108/Group024-Fa21 0
# cd Group024-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup024-Fa21.ipynb 0
# cd Group024-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup024-Fa21.ipynb 0
# cd Group024-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup024-Fa21.ipynb 0
# cd Group024-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup024-Fa21.ipynb 0
# cd Group024-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group024-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group025-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group025-Fa21/collaborators/oroth16 0
# gh api -X PUT -f permission=push repos/COGS108/Group025-Fa21/collaborators/ascheide 0
# gh api -X PUT -f permission=push repos/COGS108/Group025-Fa21/collaborators/rilliu08 0
# gh api -X PUT -f permission=push repos/COGS108/Group025-Fa21/collaborators/KatKat-gif 0
# gh repo clone COGS108/Group025-Fa21 0
# cd Group025-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup025-Fa21.ipynb 0
# cd Group025-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup025-Fa21.ipynb 0
# cd Group025-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup025-Fa21.ipynb 0
# cd Group025-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup025-Fa21.ipynb 0
# cd Group025-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group025-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group026-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group026-Fa21/collaborators/LJW0105 0
# gh api -X PUT -f permission=push repos/COGS108/Group026-Fa21/collaborators/hoang534 0
# gh api -X PUT -f permission=push repos/COGS108/Group026-Fa21/collaborators/Jazmusic1234 0
# gh api -X PUT -f permission=push repos/COGS108/Group026-Fa21/collaborators/TomlandHilarious 0
# gh repo clone COGS108/Group026-Fa21 0
# cd Group026-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup026-Fa21.ipynb 0
# cd Group026-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup026-Fa21.ipynb 0
# cd Group026-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup026-Fa21.ipynb 0
# cd Group026-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup026-Fa21.ipynb 0
# cd Group026-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group026-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group027-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group027-Fa21/collaborators/Mesablip 0
# gh api -X PUT -f permission=push repos/COGS108/Group027-Fa21/collaborators/soltosirius 0
# gh api -X PUT -f permission=push repos/COGS108/Group027-Fa21/collaborators/manrod28 0
# gh api -X PUT -f permission=push repos/COGS108/Group027-Fa21/collaborators/dogbath 0
# gh api -X PUT -f permission=push repos/COGS108/Group027-Fa21/collaborators/rosmoore 0
# gh repo clone COGS108/Group027-Fa21 0
# cd Group027-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup027-Fa21.ipynb 0
# cd Group027-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup027-Fa21.ipynb 0
# cd Group027-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup027-Fa21.ipynb 0
# cd Group027-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup027-Fa21.ipynb 0
# cd Group027-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group027-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group028-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group028-Fa21/collaborators/rsoeroso 0
# gh api -X PUT -f permission=push repos/COGS108/Group028-Fa21/collaborators/mcsacks 0
# gh api -X PUT -f permission=push repos/COGS108/Group028-Fa21/collaborators/heeemmsss 0
# gh api -X PUT -f permission=push repos/COGS108/Group028-Fa21/collaborators/brian-x86 0
# gh repo clone COGS108/Group028-Fa21 0
# cd Group028-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup028-Fa21.ipynb 0
# cd Group028-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup028-Fa21.ipynb 0
# cd Group028-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup028-Fa21.ipynb 0
# cd Group028-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup028-Fa21.ipynb 0
# cd Group028-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group028-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group029-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group029-Fa21/collaborators/BillChen24 0
# gh api -X PUT -f permission=push repos/COGS108/Group029-Fa21/collaborators/yikaizhang88 0
# gh api -X PUT -f permission=push repos/COGS108/Group029-Fa21/collaborators/TIMHX 0
# gh api -X PUT -f permission=push repos/COGS108/Group029-Fa21/collaborators/tedfeng0424 256
# gh api -X PUT -f permission=push repos/COGS108/Group029-Fa21/collaborators/wenqian-Zhao 0
# gh repo clone COGS108/Group029-Fa21 0
# cd Group029-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup029-Fa21.ipynb 0
# cd Group029-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup029-Fa21.ipynb 0
# cd Group029-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup029-Fa21.ipynb 0
# cd Group029-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup029-Fa21.ipynb 0
# cd Group029-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group029-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group030-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group030-Fa21/collaborators/GrantJiang 0
# gh api -X PUT -f permission=push repos/COGS108/Group030-Fa21/collaborators/haelaine 0
# gh api -X PUT -f permission=push repos/COGS108/Group030-Fa21/collaborators/jojoguan 0
# gh api -X PUT -f permission=push repos/COGS108/Group030-Fa21/collaborators/Eason1018 0
# gh api -X PUT -f permission=push repos/COGS108/Group030-Fa21/collaborators/quanalex 0
# gh repo clone COGS108/Group030-Fa21 0
# cd Group030-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup030-Fa21.ipynb 0
# cd Group030-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup030-Fa21.ipynb 0
# cd Group030-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup030-Fa21.ipynb 0
# cd Group030-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup030-Fa21.ipynb 0
# cd Group030-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group030-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group031-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group031-Fa21/collaborators/sjmohame 0
# gh api -X PUT -f permission=push repos/COGS108/Group031-Fa21/collaborators/Hamlet7247 0
# gh api -X PUT -f permission=push repos/COGS108/Group031-Fa21/collaborators/merve-kilic 0
# gh api -X PUT -f permission=push repos/COGS108/Group031-Fa21/collaborators/ashmahoney 0
# gh repo clone COGS108/Group031-Fa21 0
# cd Group031-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup031-Fa21.ipynb 0
# cd Group031-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup031-Fa21.ipynb 0
# cd Group031-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup031-Fa21.ipynb 0
# cd Group031-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup031-Fa21.ipynb 0
# cd Group031-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group031-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group032-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group032-Fa21/collaborators/TojoDojo 0
# gh api -X PUT -f permission=push repos/COGS108/Group032-Fa21/collaborators/joshu-wa 0
# gh api -X PUT -f permission=push repos/COGS108/Group032-Fa21/collaborators/katndang 0
# gh api -X PUT -f permission=push repos/COGS108/Group032-Fa21/collaborators/Zachary-Tulman 0
# gh repo clone COGS108/Group032-Fa21 0
# cd Group032-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup032-Fa21.ipynb 0
# cd Group032-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup032-Fa21.ipynb 0
# cd Group032-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup032-Fa21.ipynb 0
# cd Group032-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup032-Fa21.ipynb 0
# cd Group032-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group032-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group033-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group033-Fa21/collaborators/kctter 0
# gh api -X PUT -f permission=push repos/COGS108/Group033-Fa21/collaborators/IRSMsoso 0
# gh api -X PUT -f permission=push repos/COGS108/Group033-Fa21/collaborators/Gauss-x 0
# gh repo clone COGS108/Group033-Fa21 0
# cd Group033-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup033-Fa21.ipynb 0
# cd Group033-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup033-Fa21.ipynb 0
# cd Group033-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup033-Fa21.ipynb 0
# cd Group033-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup033-Fa21.ipynb 0
# cd Group033-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group033-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group034-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group034-Fa21/collaborators/vanessa-004 256
# gh api -X PUT -f permission=push repos/COGS108/Group034-Fa21/collaborators/Bailey-Man 0
# gh api -X PUT -f permission=push repos/COGS108/Group034-Fa21/collaborators/jnle029 0
# gh api -X PUT -f permission=push repos/COGS108/Group034-Fa21/collaborators/Isaiahcortezz 0
# gh api -X PUT -f permission=push repos/COGS108/Group034-Fa21/collaborators/amansilla05 0
# gh repo clone COGS108/Group034-Fa21 0
# cd Group034-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup034-Fa21.ipynb 0
# cd Group034-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup034-Fa21.ipynb 0
# cd Group034-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup034-Fa21.ipynb 0
# cd Group034-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup034-Fa21.ipynb 0
# cd Group034-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group034-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group035-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group035-Fa21/collaborators/Yalong-T 0
# gh api -X PUT -f permission=push repos/COGS108/Group035-Fa21/collaborators/WendiJiang 0
# gh api -X PUT -f permission=push repos/COGS108/Group035-Fa21/collaborators/endersodium 0
# gh api -X PUT -f permission=push repos/COGS108/Group035-Fa21/collaborators/yil018 0
# gh api -X PUT -f permission=push repos/COGS108/Group035-Fa21/collaborators/lllandi 0
# gh repo clone COGS108/Group035-Fa21 0
# cd Group035-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup035-Fa21.ipynb 0
# cd Group035-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup035-Fa21.ipynb 0
# cd Group035-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup035-Fa21.ipynb 0
# cd Group035-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup035-Fa21.ipynb 0
# cd Group035-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group035-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group036-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group036-Fa21/collaborators/sydneyforster 0
# gh api -X PUT -f permission=push repos/COGS108/Group036-Fa21/collaborators/kenzywirth 0
# gh api -X PUT -f permission=push repos/COGS108/Group036-Fa21/collaborators/brianjhuang 0
# gh api -X PUT -f permission=push repos/COGS108/Group036-Fa21/collaborators/tatummaston 0
# gh api -X PUT -f permission=push repos/COGS108/Group036-Fa21/collaborators/abbyhan26 0
# gh repo clone COGS108/Group036-Fa21 0
# cd Group036-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup036-Fa21.ipynb 0
# cd Group036-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup036-Fa21.ipynb 0
# cd Group036-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup036-Fa21.ipynb 0
# cd Group036-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup036-Fa21.ipynb 0
# cd Group036-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group036-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group037-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group037-Fa21/collaborators/xil111 0
# gh api -X PUT -f permission=push repos/COGS108/Group037-Fa21/collaborators/Cyuaz 0
# gh api -X PUT -f permission=push repos/COGS108/Group037-Fa21/collaborators/Mingxuan225Wu 0
# gh api -X PUT -f permission=push repos/COGS108/Group037-Fa21/collaborators/ycao9 0
# gh api -X PUT -f permission=push repos/COGS108/Group037-Fa21/collaborators/jyy83 0
# gh repo clone COGS108/Group037-Fa21 0
# cd Group037-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup037-Fa21.ipynb 0
# cd Group037-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup037-Fa21.ipynb 0
# cd Group037-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup037-Fa21.ipynb 0
# cd Group037-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup037-Fa21.ipynb 0
# cd Group037-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group037-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group038-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group038-Fa21/collaborators/sgraeber7 0
# gh api -X PUT -f permission=push repos/COGS108/Group038-Fa21/collaborators/rkhateeb 0
# gh api -X PUT -f permission=push repos/COGS108/Group038-Fa21/collaborators/SamBurky 0
# gh api -X PUT -f permission=push repos/COGS108/Group038-Fa21/collaborators/SikYinSun 0
# gh api -X PUT -f permission=push repos/COGS108/Group038-Fa21/collaborators/Devouringbowl57 0
# gh repo clone COGS108/Group038-Fa21 0
# cd Group038-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup038-Fa21.ipynb 0
# cd Group038-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup038-Fa21.ipynb 0
# cd Group038-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup038-Fa21.ipynb 0
# cd Group038-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup038-Fa21.ipynb 0
# cd Group038-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group038-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group039-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group039-Fa21/collaborators/fengdi-liu 0
# gh api -X PUT -f permission=push repos/COGS108/Group039-Fa21/collaborators/k464483963 0
# gh api -X PUT -f permission=push repos/COGS108/Group039-Fa21/collaborators/Tianyu-Yu 0
# gh api -X PUT -f permission=push repos/COGS108/Group039-Fa21/collaborators/shli1126 0
# gh repo clone COGS108/Group039-Fa21 0
# cd Group039-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup039-Fa21.ipynb 0
# cd Group039-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup039-Fa21.ipynb 0
# cd Group039-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup039-Fa21.ipynb 0
# cd Group039-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup039-Fa21.ipynb 0
# cd Group039-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group039-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group040-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group040-Fa21/collaborators/alacau 0
# gh api -X PUT -f permission=push repos/COGS108/Group040-Fa21/collaborators/edwardyang12 0
# gh api -X PUT -f permission=push repos/COGS108/Group040-Fa21/collaborators/kurtisnguyen 0
# gh api -X PUT -f permission=push repos/COGS108/Group040-Fa21/collaborators/daz005 0
# gh api -X PUT -f permission=push repos/COGS108/Group040-Fa21/collaborators/nickehsani 0
# gh repo clone COGS108/Group040-Fa21 0
# cd Group040-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup040-Fa21.ipynb 0
# cd Group040-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup040-Fa21.ipynb 0
# cd Group040-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup040-Fa21.ipynb 0
# cd Group040-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup040-Fa21.ipynb 0
# cd Group040-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group040-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group041-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group041-Fa21/collaborators/kuma-ardp 0
# gh api -X PUT -f permission=push repos/COGS108/Group041-Fa21/collaborators/bea-angela 0
# gh api -X PUT -f permission=push repos/COGS108/Group041-Fa21/collaborators/emilybledsoe 0
# gh api -X PUT -f permission=push repos/COGS108/Group041-Fa21/collaborators/caitlinsprojects-ml 0
# gh api -X PUT -f permission=push repos/COGS108/Group041-Fa21/collaborators/roncyavi 0
# gh repo clone COGS108/Group041-Fa21 0
# cd Group041-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup041-Fa21.ipynb 0
# cd Group041-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup041-Fa21.ipynb 0
# cd Group041-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup041-Fa21.ipynb 0
# cd Group041-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup041-Fa21.ipynb 0
# cd Group041-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group041-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group042-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group042-Fa21/collaborators/YashPotdar 0
# gh api -X PUT -f permission=push repos/COGS108/Group042-Fa21/collaborators/ProfessorMomo 0
# gh api -X PUT -f permission=push repos/COGS108/Group042-Fa21/collaborators/mandylee900125 0
# gh api -X PUT -f permission=push repos/COGS108/Group042-Fa21/collaborators/mtlund 0
# gh api -X PUT -f permission=push repos/COGS108/Group042-Fa21/collaborators/YongqingLi14 0
# gh repo clone COGS108/Group042-Fa21 0
# cd Group042-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup042-Fa21.ipynb 0
# cd Group042-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup042-Fa21.ipynb 0
# cd Group042-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup042-Fa21.ipynb 0
# cd Group042-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup042-Fa21.ipynb 0
# cd Group042-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group042-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group043-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group043-Fa21/collaborators/mechong 0
# gh api -X PUT -f permission=push repos/COGS108/Group043-Fa21/collaborators/amytnguyen01 0
# gh api -X PUT -f permission=push repos/COGS108/Group043-Fa21/collaborators/BranchAddict 0
# gh api -X PUT -f permission=push repos/COGS108/Group043-Fa21/collaborators/yuribz 0
# gh api -X PUT -f permission=push repos/COGS108/Group043-Fa21/collaborators/msimitz 0
# gh repo clone COGS108/Group043-Fa21 0
# cd Group043-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup043-Fa21.ipynb 0
# cd Group043-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup043-Fa21.ipynb 0
# cd Group043-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup043-Fa21.ipynb 0
# cd Group043-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup043-Fa21.ipynb 0
# cd Group043-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group043-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group044-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group044-Fa21/collaborators/victorchang282 0
# gh api -X PUT -f permission=push repos/COGS108/Group044-Fa21/collaborators/Al231349 0
# gh api -X PUT -f permission=push repos/COGS108/Group044-Fa21/collaborators/Cathyxy024 0
# gh api -X PUT -f permission=push repos/COGS108/Group044-Fa21/collaborators/Sanjay-Sampat 0
# gh api -X PUT -f permission=push repos/COGS108/Group044-Fa21/collaborators/jhcode14 0
# gh repo clone COGS108/Group044-Fa21 0
# cd Group044-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup044-Fa21.ipynb 0
# cd Group044-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup044-Fa21.ipynb 0
# cd Group044-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup044-Fa21.ipynb 0
# cd Group044-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup044-Fa21.ipynb 0
# cd Group044-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group044-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group045-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group045-Fa21/collaborators/joecai6 0
# gh api -X PUT -f permission=push repos/COGS108/Group045-Fa21/collaborators/nprabhak17 0
# gh api -X PUT -f permission=push repos/COGS108/Group045-Fa21/collaborators/hee1zhy 0
# gh api -X PUT -f permission=push repos/COGS108/Group045-Fa21/collaborators/illonaivesky 0
# gh api -X PUT -f permission=push repos/COGS108/Group045-Fa21/collaborators/kkkathy981 0
# gh repo clone COGS108/Group045-Fa21 0
# cd Group045-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup045-Fa21.ipynb 0
# cd Group045-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup045-Fa21.ipynb 0
# cd Group045-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup045-Fa21.ipynb 0
# cd Group045-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup045-Fa21.ipynb 0
# cd Group045-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group045-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group046-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group046-Fa21/collaborators/ASuperior 0
# gh api -X PUT -f permission=push repos/COGS108/Group046-Fa21/collaborators/tfratant 0
# gh api -X PUT -f permission=push repos/COGS108/Group046-Fa21/collaborators/vvctvrr 0
# gh api -X PUT -f permission=push repos/COGS108/Group046-Fa21/collaborators/wajiabdullah 0
# gh api -X PUT -f permission=push repos/COGS108/Group046-Fa21/collaborators/darwinchan2002 0
# gh repo clone COGS108/Group046-Fa21 0
# cd Group046-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup046-Fa21.ipynb 0
# cd Group046-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup046-Fa21.ipynb 0
# cd Group046-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup046-Fa21.ipynb 0
# cd Group046-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup046-Fa21.ipynb 0
# cd Group046-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group046-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group047-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group047-Fa21/collaborators/hcjyou 0
# gh api -X PUT -f permission=push repos/COGS108/Group047-Fa21/collaborators/jennaelisea 0
# gh api -X PUT -f permission=push repos/COGS108/Group047-Fa21/collaborators/austin-horse 0
# gh api -X PUT -f permission=push repos/COGS108/Group047-Fa21/collaborators/misspilaree 0
# gh repo clone COGS108/Group047-Fa21 0
# cd Group047-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup047-Fa21.ipynb 0
# cd Group047-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup047-Fa21.ipynb 0
# cd Group047-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup047-Fa21.ipynb 0
# cd Group047-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup047-Fa21.ipynb 0
# cd Group047-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group047-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group048-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group048-Fa21/collaborators/cyatco 0
# gh api -X PUT -f permission=push repos/COGS108/Group048-Fa21/collaborators/leekristy 0
# gh api -X PUT -f permission=push repos/COGS108/Group048-Fa21/collaborators/sophiejensen 0
# gh api -X PUT -f permission=push repos/COGS108/Group048-Fa21/collaborators/akoornwinder4 0
# gh repo clone COGS108/Group048-Fa21 0
# cd Group048-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup048-Fa21.ipynb 0
# cd Group048-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup048-Fa21.ipynb 0
# cd Group048-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup048-Fa21.ipynb 0
# cd Group048-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup048-Fa21.ipynb 0
# cd Group048-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group048-Fa21 0
# ...
# gh api -X PUT -f permission=push repos/COGS108/Group083-Fa21/collaborators/mhm1117 0
# gh api -X PUT -f permission=push repos/COGS108/Group083-Fa21/collaborators/chickenwings123 0
# gh api -X PUT -f permission=push repos/COGS108/Group083-Fa21/collaborators/athena023 0
# gh repo clone COGS108/Group083-Fa21 0
# cd Group083-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup083-Fa21.ipynb 0
# cd Group083-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup083-Fa21.ipynb 0
# cd Group083-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup083-Fa21.ipynb 0
# cd Group083-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup083-Fa21.ipynb 0
# cd Group083-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group083-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group084-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group084-Fa21/collaborators/matin-g 0
# gh api -X PUT -f permission=push repos/COGS108/Group084-Fa21/collaborators/j1u 0
# gh api -X PUT -f permission=push repos/COGS108/Group084-Fa21/collaborators/greeenbeans 0
# gh api -X PUT -f permission=push repos/COGS108/Group084-Fa21/collaborators/jorgeacevedo13 0
# gh api -X PUT -f permission=push repos/COGS108/Group084-Fa21/collaborators/AlanLFC273 0
# gh repo clone COGS108/Group084-Fa21 0
# cd Group084-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup084-Fa21.ipynb 0
# cd Group084-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup084-Fa21.ipynb 0
# cd Group084-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup084-Fa21.ipynb 0
# cd Group084-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup084-Fa21.ipynb 0
# cd Group084-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group084-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group085-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group085-Fa21/collaborators/zbfrancis 0
# gh api -X PUT -f permission=push repos/COGS108/Group085-Fa21/collaborators/neelayyagar1 0
# gh api -X PUT -f permission=push repos/COGS108/Group085-Fa21/collaborators/nimsin173 0
# gh api -X PUT -f permission=push repos/COGS108/Group085-Fa21/collaborators/jkhaliqi 0
# gh repo clone COGS108/Group085-Fa21 0
# cd Group085-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup085-Fa21.ipynb 0
# cd Group085-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup085-Fa21.ipynb 0
# cd Group085-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup085-Fa21.ipynb 0
# cd Group085-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup085-Fa21.ipynb 0
# cd Group085-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group085-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group086-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group086-Fa21/collaborators/t1lee 0
# gh api -X PUT -f permission=push repos/COGS108/Group086-Fa21/collaborators/willxia 0
# gh api -X PUT -f permission=push repos/COGS108/Group086-Fa21/collaborators/ingridalt 0
# gh api -X PUT -f permission=push repos/COGS108/Group086-Fa21/collaborators/mrgnhrsn 0
# gh api -X PUT -f permission=push repos/COGS108/Group086-Fa21/collaborators/bel577 0
# gh repo clone COGS108/Group086-Fa21 0
# cd Group086-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup086-Fa21.ipynb 0
# cd Group086-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup086-Fa21.ipynb 0
# cd Group086-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup086-Fa21.ipynb 0
# cd Group086-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup086-Fa21.ipynb 0
# cd Group086-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group086-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group087-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group087-Fa21/collaborators/martintthai 0
# gh api -X PUT -f permission=push repos/COGS108/Group087-Fa21/collaborators/ryanbuui 0
# gh api -X PUT -f permission=push repos/COGS108/Group087-Fa21/collaborators/nathan42424 0
# gh api -X PUT -f permission=push repos/COGS108/Group087-Fa21/collaborators/willch8 0
# gh api -X PUT -f permission=push repos/COGS108/Group087-Fa21/collaborators/YingHuang54 0
# gh repo clone COGS108/Group087-Fa21 0
# cd Group087-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup087-Fa21.ipynb 0
# cd Group087-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup087-Fa21.ipynb 0
# cd Group087-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup087-Fa21.ipynb 0
# cd Group087-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup087-Fa21.ipynb 0
# cd Group087-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group087-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group088-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group088-Fa21/collaborators/sophiaallui 0
# gh api -X PUT -f permission=push repos/COGS108/Group088-Fa21/collaborators/alecpanattoni 0
# gh api -X PUT -f permission=push repos/COGS108/Group088-Fa21/collaborators/rudycardenas 0
# gh api -X PUT -f permission=push repos/COGS108/Group088-Fa21/collaborators/abi2020 0
# gh api -X PUT -f permission=push repos/COGS108/Group088-Fa21/collaborators/tktran11 0
# gh repo clone COGS108/Group088-Fa21 0
# cd Group088-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup088-Fa21.ipynb 0
# cd Group088-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup088-Fa21.ipynb 0
# cd Group088-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup088-Fa21.ipynb 0
# cd Group088-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup088-Fa21.ipynb 0
# cd Group088-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group088-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group089-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group089-Fa21/collaborators/M2606 0
# gh api -X PUT -f permission=push repos/COGS108/Group089-Fa21/collaborators/eadesai 0
# gh api -X PUT -f permission=push repos/COGS108/Group089-Fa21/collaborators/sramcode 0
# gh api -X PUT -f permission=push repos/COGS108/Group089-Fa21/collaborators/Divneet18 0
# gh api -X PUT -f permission=push repos/COGS108/Group089-Fa21/collaborators/satomitheito 0
# gh repo clone COGS108/Group089-Fa21 0
# cd Group089-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup089-Fa21.ipynb 0
# cd Group089-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup089-Fa21.ipynb 0
# cd Group089-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup089-Fa21.ipynb 0
# cd Group089-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup089-Fa21.ipynb 0
# cd Group089-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group089-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group090-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group090-Fa21/collaborators/jczhonglol 0
# gh api -X PUT -f permission=push repos/COGS108/Group090-Fa21/collaborators/ltopacio 0
# gh api -X PUT -f permission=push repos/COGS108/Group090-Fa21/collaborators/kushiu 0
# gh api -X PUT -f permission=push repos/COGS108/Group090-Fa21/collaborators/y2lin1019 0
# gh api -X PUT -f permission=push repos/COGS108/Group090-Fa21/collaborators/jialin115 0
# gh repo clone COGS108/Group090-Fa21 0
# cd Group090-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup090-Fa21.ipynb 0
# cd Group090-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup090-Fa21.ipynb 0
# cd Group090-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup090-Fa21.ipynb 0
# cd Group090-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup090-Fa21.ipynb 0
# cd Group090-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group090-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group091-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group091-Fa21/collaborators/totally-not-frito-lays 0
# gh api -X PUT -f permission=push repos/COGS108/Group091-Fa21/collaborators/aSlothMachine 0
# gh api -X PUT -f permission=push repos/COGS108/Group091-Fa21/collaborators/aolandaUCSD 0
# gh api -X PUT -f permission=push repos/COGS108/Group091-Fa21/collaborators/zhongtiff 0
# gh api -X PUT -f permission=push repos/COGS108/Group091-Fa21/collaborators/gocegued 0
# gh repo clone COGS108/Group091-Fa21 0
# cd Group091-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup091-Fa21.ipynb 0
# cd Group091-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup091-Fa21.ipynb 0
# cd Group091-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup091-Fa21.ipynb 0
# cd Group091-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup091-Fa21.ipynb 0
# cd Group091-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group091-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group092-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group092-Fa21/collaborators/ZefangYuan 0
# gh api -X PUT -f permission=push repos/COGS108/Group092-Fa21/collaborators/pu-tan 0
# gh api -X PUT -f permission=push repos/COGS108/Group092-Fa21/collaborators/lindaisj 0
# gh api -X PUT -f permission=push repos/COGS108/Group092-Fa21/collaborators/ZixunMarkZhang 0
# gh repo clone COGS108/Group092-Fa21 0
# cd Group092-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup092-Fa21.ipynb 0
# cd Group092-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup092-Fa21.ipynb 0
# cd Group092-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup092-Fa21.ipynb 0
# cd Group092-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup092-Fa21.ipynb 0
# cd Group092-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group092-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group093-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group093-Fa21/collaborators/Kairiki12198 0
# gh api -X PUT -f permission=push repos/COGS108/Group093-Fa21/collaborators/b1wang 0
# gh api -X PUT -f permission=push repos/COGS108/Group093-Fa21/collaborators/Marisol-Jim 0
# gh api -X PUT -f permission=push repos/COGS108/Group093-Fa21/collaborators/ashleyychu 0
# gh api -X PUT -f permission=push repos/COGS108/Group093-Fa21/collaborators/danielmilton22 0
# gh repo clone COGS108/Group093-Fa21 0
# cd Group093-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup093-Fa21.ipynb 0
# cd Group093-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup093-Fa21.ipynb 0
# cd Group093-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup093-Fa21.ipynb 0
# cd Group093-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup093-Fa21.ipynb 0
# cd Group093-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group093-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group094-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group094-Fa21/collaborators/hsonnad 0
# gh api -X PUT -f permission=push repos/COGS108/Group094-Fa21/collaborators/kyleburick 0
# gh api -X PUT -f permission=push repos/COGS108/Group094-Fa21/collaborators/zhqa 0
# gh api -X PUT -f permission=push repos/COGS108/Group094-Fa21/collaborators/abell-ucsd 0
# gh repo clone COGS108/Group094-Fa21 0
# cd Group094-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup094-Fa21.ipynb 0
# cd Group094-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup094-Fa21.ipynb 0
# cd Group094-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup094-Fa21.ipynb 0
# cd Group094-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup094-Fa21.ipynb 0
# cd Group094-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group094-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group095-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group095-Fa21/collaborators/tracynguyen6 0
# gh api -X PUT -f permission=push repos/COGS108/Group095-Fa21/collaborators/kennytrand 0
# gh api -X PUT -f permission=push repos/COGS108/Group095-Fa21/collaborators/ric005 0
# gh api -X PUT -f permission=push repos/COGS108/Group095-Fa21/collaborators/TheAndrewC 0
# gh repo clone COGS108/Group095-Fa21 0
# cd Group095-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup095-Fa21.ipynb 0
# cd Group095-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup095-Fa21.ipynb 0
# cd Group095-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup095-Fa21.ipynb 0
# cd Group095-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup095-Fa21.ipynb 0
# cd Group095-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group095-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group096-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group096-Fa21/collaborators/jop003 0
# gh api -X PUT -f permission=push repos/COGS108/Group096-Fa21/collaborators/jchung01 0
# gh api -X PUT -f permission=push repos/COGS108/Group096-Fa21/collaborators/ucsdRgross 0
# gh api -X PUT -f permission=push repos/COGS108/Group096-Fa21/collaborators/Mhambly 0
# gh api -X PUT -f permission=push repos/COGS108/Group096-Fa21/collaborators/colinlintereur 0
# gh repo clone COGS108/Group096-Fa21 0
# cd Group096-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup096-Fa21.ipynb 0
# cd Group096-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup096-Fa21.ipynb 0
# cd Group096-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup096-Fa21.ipynb 0
# cd Group096-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup096-Fa21.ipynb 0
# cd Group096-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group096-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group097-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group097-Fa21/collaborators/ethanl94 0
# gh api -X PUT -f permission=push repos/COGS108/Group097-Fa21/collaborators/rchaklas 0
# gh api -X PUT -f permission=push repos/COGS108/Group097-Fa21/collaborators/gmahindru 0
# gh repo clone COGS108/Group097-Fa21 0
# cd Group097-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup097-Fa21.ipynb 0
# cd Group097-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup097-Fa21.ipynb 0
# cd Group097-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup097-Fa21.ipynb 0
# cd Group097-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup097-Fa21.ipynb 0
# cd Group097-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group097-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group098-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group098-Fa21/collaborators/thanhtong010 0
# gh api -X PUT -f permission=push repos/COGS108/Group098-Fa21/collaborators/ahandjoj 0
# gh repo clone COGS108/Group098-Fa21 0
# cd Group098-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup098-Fa21.ipynb 0
# cd Group098-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup098-Fa21.ipynb 0
# cd Group098-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup098-Fa21.ipynb 0
# cd Group098-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup098-Fa21.ipynb 0
# cd Group098-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group098-Fa21 0
# gh repo create --private --template COGS108/group_template -y COGS108/Group099-Fa21 256
# gh api -X PUT -f permission=push repos/COGS108/Group099-Fa21/collaborators/m1jung 0
# gh api -X PUT -f permission=push repos/COGS108/Group099-Fa21/collaborators/JoannaZyc 0
# gh repo clone COGS108/Group099-Fa21 0
# cd Group099-Fa21; git mv EDACheckpoint_groupXXX.ipynb EDACheckpointGroup099-Fa21.ipynb 0
# cd Group099-Fa21; git mv ProjectProposal_groupXXX.ipynb ProjectProposalGroup099-Fa21.ipynb 0
# cd Group099-Fa21; git mv FinalProject_groupXXX.ipynb FinalProjectGroup099-Fa21.ipynb 0
# cd Group099-Fa21; git mv DataCheckpoint_groupXXX.ipynb DataCheckpointGroup099-Fa21.ipynb 0
# cd Group099-Fa21; git add -A; git commit -m "renamed files"; git push 0
# rm -rf Group099-Fa21 0
